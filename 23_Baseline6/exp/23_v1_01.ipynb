# %%
VERSION = '23_v1_01'
MODEL = 'microsoft/deberta-v3-base'
#TEACHER_VERSION = '14_v1_15' # deverta-v2-xlarge
#'bert-large-cased'
#'bert-large-cased-whole-word-masking'
#'albert-large-v2'
#'facebook/bart-large'
#'xlm-roberta-large'
#'deepset/roberta-large-squad2'
#'google/electra-large-discriminator'
#'sentence-transformeres/paraphrase-mpnet-base-v2'
#'funnel-transformer/large-base'
#'facebook/bart-base'
#'distilroberta-base'
#'deepset/roberta-base-squad2'
#'microsoft/deberta-v3-base'
#'roberta-large'
#'roberta-base'
#'microsoft/deberta-v3-large'
#'microsoft/deberta-base'
LR = 2e-5 #8e-6
HEAD_LR = 2e-4 #2e-5 #8e-6 
SEED = 100
TRN_BS = 8
VAL_BS = 8
ACCUM_STEP = 1
HIDDEN_DROP_PROB = 0
P_DROP = 0
RNN = 'none'
WARMUP_RATIO = 0.1
HEAD = 'simple'
AUG = 'false'
MIXUP_ALPHA = 0
P_AUG = 0
AUG_STOP_EPOCH = 0
MSD = 'false'
POOLING = 'mean' #'weighted_layer'
NUM_POOLING_LAYERS = 4 #1
MULTI_LAYERS = 1
EVAL_STEP_START_EPOCH = -1
EVAL_STEP = -1
#NUM_LABELS = 6
NUM_LABELS_2 = -1
FP16 = 'true'
WD = 0.01
FREEZE = 'false'
MULTI_TASK = 'false' 
W_MT = 0 
AWP = 'false'
AWP_LR = 0
AWP_EPS = 0
AWP_START_EPOCH = -1
#PRETRAINED_DETECTOR_PATH = f'../../input/tascj/result/deberta_base_fold0.pth'
PRETRAINED_DETECTOR_PATH = 'none' #f'../../05_Detection/exp/result/05_v2_09/model_seed100_fold0_swa.pth'
MASK_PROB = 0 #0.8
MASK_RATIO = 0 #0.3
SCHEDULER = 'cosine_hard'
CP = 'true' #'false'
WINDOW_SIZE = -1 #512
INNER_LEN = -1 #384
EDGE_LEN = -1 #64
MAX_LEN = 512

GRAD_CLIP = 1

LOSS = 'smoothl1'#'mse'

CROP_PROB = 0 #1.0

# %% [markdown]
# # Train

# %%
MODE = 'train'
EPOCHS = 5
STOP_EPOCH = 5
RESTART = 1
NUM_CYCLES = EPOCHS
EVAL_STEP = -1
ADD_FB3 = 'false' #'true'
FB3_FOLD_PATH = 'none' #'../../00_EDA/00_v1_02/result/'

REMOVE_CLASS = "vocabulary"
NUM_LABELS = 5

for FOLD in [0,1,2,3,4]:
    print("-"*50)
    print("FOLD = ", FOLD)
    print("-"*50)
    INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
    FOLD_PATH = '../../00_EDA/00_v1_02/result/'
    #INPUT_PATH = f'../../99_Ensemble/99_v1_03/result/99_v1_03_03_pseudo_fold{FOLD}.csv'
    #INPUT_PATH = f'../../99_Ensemble/99_v1_03/result/99_v1_03_03_{TEACHER_VERSION}_pseudo_fold{FOLD}.csv'
    #FOLD_PATH = '../../00_EDA/00_v1_08/result/' # for pseudo-label
    PRETRAIN_PATH = 'none'
    #PRETRAIN_PATH = f'result/{VERSION}/model_seed{SEED}_fold{FOLD}_pseudo.pth'
    # !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
        --lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
        --epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
        --accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
        --mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
        --msd $MSD --multi_layers $MULTI_LAYERS \
        --eval_step_start_epoch $EVAL_STEP_START_EPOCH --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
        --num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
        --restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
        --mt $MULTI_TASK --w_mt $W_MT \
        --awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
        --pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
        --scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
        --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN \
        --gradient_clip_val $GRAD_CLIP \
        --input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN \
        --crop_prob $CROP_PROB --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS \
        --add_fb3 $ADD_FB3 --fb3_fold_path $FB3_FOLD_PATH --remove_class $REMOVE_CLASS
# Out:
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3128, 8)
# val_df.shape =  (783, 8)
# 2022-11-09 00:13:29.746253: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-09 00:13:29.746275: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['cohesion', 'syntax', 'phraseology', 'grammar', 'conventions']
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [02:24<00:00,  2.71it/s, loss=0.442]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.28it/s]
# epoch 1: trn_loss = 0.4417, val_loss = 0.1167, trn_score = 1.1726, val_score = 0.4842
# model (best score) saved
# lr :  [8.224468037456969e-06, 8.224468037456969e-06, 8.224468037456969e-05]
# 100%|█████████████████████████████| 391/391 [02:26<00:00,  2.67it/s, loss=0.117]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.26it/s]
# epoch 2: trn_loss = 0.1174, val_loss = 0.1114, trn_score = 0.4865, val_score = 0.4726
# model (best score) saved
# lr :  [4.974257968932691e-06, 4.974257968932691e-06, 4.974257968932691e-05]
# 100%|█████████████████████████████| 391/391 [02:27<00:00,  2.64it/s, loss=0.104]
# 100%|███████████████████████████████████████████| 98/98 [00:23<00:00,  4.23it/s]
# epoch 3: trn_loss = 0.1039, val_loss = 0.1087, trn_score = 0.4571, val_score = 0.4674
# model (best score) saved
# lr :  [2.3268220525837457e-06, 2.3268220525837457e-06, 2.3268220525837457e-05]
# 100%|████████████████████████████| 391/391 [02:28<00:00,  2.64it/s, loss=0.0961]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.34it/s]
# epoch 4: trn_loss = 0.0961, val_loss = 0.1071, trn_score = 0.4393, val_score = 0.4638
# model (best score) saved
# lr :  [5.996867213330993e-07, 5.996867213330993e-07, 5.996867213330992e-06]
# 100%|████████████████████████████| 391/391 [02:27<00:00,  2.65it/s, loss=0.0891]
# 100%|███████████████████████████████████████████| 98/98 [00:23<00:00,  4.22it/s]
# epoch 5: trn_loss = 0.0891, val_loss = 0.1074, trn_score = 0.4226, val_score = 0.4643
#
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-11-09 00:27:59.982216: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-09 00:27:59.982239: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['cohesion', 'syntax', 'phraseology', 'grammar', 'conventions']
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [02:28<00:00,  2.64it/s, loss=0.436]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.26it/s]
# epoch 1: trn_loss = 0.4365, val_loss = 0.1147, trn_score = 1.1338, val_score = 0.4806
# model (best score) saved
# lr :  [8.224468037456969e-06, 8.224468037456969e-06, 8.224468037456969e-05]
# 100%|█████████████████████████████| 391/391 [02:28<00:00,  2.64it/s, loss=0.109]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.30it/s]
# epoch 2: trn_loss = 0.1088, val_loss = 0.1086, trn_score = 0.4677, val_score = 0.4673
# model (best score) saved
# lr :  [4.974257968932691e-06, 4.974257968932691e-06, 4.974257968932691e-05]
# 100%|█████████████████████████████| 391/391 [02:27<00:00,  2.65it/s, loss=0.102]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.34it/s]
# epoch 3: trn_loss = 0.1015, val_loss = 0.1060, trn_score = 0.4514, val_score = 0.4618
# model (best score) saved
# lr :  [2.3268220525837457e-06, 2.3268220525837457e-06, 2.3268220525837457e-05]
# 100%|█████████████████████████████| 391/391 [02:27<00:00,  2.65it/s, loss=0.094]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.34it/s]
# epoch 4: trn_loss = 0.0940, val_loss = 0.1085, trn_score = 0.4344, val_score = 0.4676
# lr :  [5.996867213330993e-07, 5.996867213330993e-07, 5.996867213330992e-06]
# 100%|████████████████████████████| 391/391 [02:27<00:00,  2.65it/s, loss=0.0876]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.34it/s]
# epoch 5: trn_loss = 0.0876, val_loss = 0.1082, trn_score = 0.4192, val_score = 0.4669
#
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-11-09 00:42:31.544565: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-09 00:42:31.544589: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['cohesion', 'syntax', 'phraseology', 'grammar', 'conventions']
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [02:28<00:00,  2.63it/s, loss=0.425]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.33it/s]
# epoch 1: trn_loss = 0.4248, val_loss = 0.1082, trn_score = 1.1164, val_score = 0.4665
# model (best score) saved
# lr :  [8.224468037456969e-06, 8.224468037456969e-06, 8.224468037456969e-05]
# 100%|█████████████████████████████| 391/391 [02:27<00:00,  2.65it/s, loss=0.113]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.38it/s]
# epoch 2: trn_loss = 0.1127, val_loss = 0.1062, trn_score = 0.4763, val_score = 0.4621
# model (best score) saved
# lr :  [4.974257968932691e-06, 4.974257968932691e-06, 4.974257968932691e-05]
# 100%|█████████████████████████████| 391/391 [02:26<00:00,  2.67it/s, loss=0.111]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.38it/s]
# epoch 3: trn_loss = 0.1110, val_loss = 0.1040, trn_score = 0.4726, val_score = 0.4572
# model (best score) saved
# lr :  [2.3268220525837457e-06, 2.3268220525837457e-06, 2.3268220525837457e-05]
# 100%|█████████████████████████████| 391/391 [02:26<00:00,  2.68it/s, loss=0.103]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.34it/s]
# epoch 4: trn_loss = 0.1027, val_loss = 0.1015, trn_score = 0.4541, val_score = 0.4513
# model (best score) saved
# lr :  [5.996867213330993e-07, 5.996867213330993e-07, 5.996867213330992e-06]
# 100%|████████████████████████████| 391/391 [02:26<00:00,  2.67it/s, loss=0.0965]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.39it/s]
# epoch 5: trn_loss = 0.0965, val_loss = 0.1014, trn_score = 0.4402, val_score = 0.4513
# model (best score) saved
#
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-11-09 00:57:00.298553: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-09 00:57:00.298573: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['cohesion', 'syntax', 'phraseology', 'grammar', 'conventions']
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [02:27<00:00,  2.66it/s, loss=0.466]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.35it/s]
# epoch 1: trn_loss = 0.4660, val_loss = 0.1174, trn_score = 1.2106, val_score = 0.4859
# model (best score) saved
# lr :  [8.224468037456969e-06, 8.224468037456969e-06, 8.224468037456969e-05]
# 100%|█████████████████████████████| 391/391 [02:27<00:00,  2.66it/s, loss=0.111]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.44it/s]
# epoch 2: trn_loss = 0.1106, val_loss = 0.1111, trn_score = 0.4719, val_score = 0.4723
# model (best score) saved
# lr :  [4.974257968932691e-06, 4.974257968932691e-06, 4.974257968932691e-05]
# 100%|█████████████████████████████| 391/391 [02:25<00:00,  2.68it/s, loss=0.105]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.46it/s]
# epoch 3: trn_loss = 0.1051, val_loss = 0.1088, trn_score = 0.4596, val_score = 0.4675
# model (best score) saved
# lr :  [2.3268220525837457e-06, 2.3268220525837457e-06, 2.3268220525837457e-05]
# 100%|█████████████████████████████| 391/391 [02:25<00:00,  2.68it/s, loss=0.102]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.46it/s]
# epoch 4: trn_loss = 0.1024, val_loss = 0.1081, trn_score = 0.4536, val_score = 0.4660
# model (best score) saved
# lr :  [5.996867213330993e-07, 5.996867213330993e-07, 5.996867213330992e-06]
# 100%|████████████████████████████| 391/391 [02:25<00:00,  2.68it/s, loss=0.0987]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.43it/s]
# epoch 5: trn_loss = 0.0987, val_loss = 0.1094, trn_score = 0.4452, val_score = 0.4689
#
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-11-09 01:11:23.064310: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-09 01:11:23.064334: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['cohesion', 'syntax', 'phraseology', 'grammar', 'conventions']
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [02:27<00:00,  2.66it/s, loss=0.374]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.37it/s]
# epoch 1: trn_loss = 0.3742, val_loss = 0.1115, trn_score = 1.0180, val_score = 0.4736
# model (best score) saved
# lr :  [8.224468037456969e-06, 8.224468037456969e-06, 8.224468037456969e-05]
# 100%|█████████████████████████████| 391/391 [02:27<00:00,  2.66it/s, loss=0.109]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.42it/s]
# epoch 2: trn_loss = 0.1086, val_loss = 0.1108, trn_score = 0.4672, val_score = 0.4723
# model (best score) saved
# lr :  [4.974257968932691e-06, 4.974257968932691e-06, 4.974257968932691e-05]
# 100%|█████████████████████████████| 391/391 [02:26<00:00,  2.68it/s, loss=0.103]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.40it/s]
# epoch 3: trn_loss = 0.1034, val_loss = 0.1079, trn_score = 0.4557, val_score = 0.4657
# model (best score) saved
# lr :  [2.3268220525837457e-06, 2.3268220525837457e-06, 2.3268220525837457e-05]
# 100%|█████████████████████████████| 391/391 [02:25<00:00,  2.68it/s, loss=0.101]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.43it/s]
# epoch 4: trn_loss = 0.1009, val_loss = 0.1074, trn_score = 0.4502, val_score = 0.4649
# model (best score) saved
# lr :  [5.996867213330993e-07, 5.996867213330993e-07, 5.996867213330992e-06]
# 100%|████████████████████████████| 391/391 [02:25<00:00,  2.69it/s, loss=0.0981]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.45it/s]
# epoch 5: trn_loss = 0.0981, val_loss = 0.1071, trn_score = 0.4437, val_score = 0.4641
# model (best score) saved

# %% [markdown]
# # OOF

# %%
INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_02/result/'

# %%
for FOLD in [0,1,2,3,4]:
    print("-"*50)
    print("FOLD = ", FOLD)
    print("-"*50)
    WEIGHT_PATH = f'./result/{VERSION}/model_seed{SEED}_fold{FOLD}.pth'
    #WEIGHT_PATH = f'./result/{VERSION}/model_{CLASS}_seed{SEED}_fold{FOLD}.pth'
    #WEIGHT_PATH = f'result/{VERSION}/model_{CLASS}_seed{SEED}_fold{FOLD}_pseudo.pth'
    #WEIGHT_PATH = f'result/{VERSION}/model_seed{SEED}_fold{FOLD}_pseudo.pth'
    # !python ../$VERSION/validation.py --model $MODEL --version $VERSION \
        --fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS \
        --rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH \
        --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --max_length $MAX_LEN \
        --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS --remove_class $REMOVE_CLASS
# Out:
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# 2022-11-09 07:56:50.346515: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-09 07:56:50.346536: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3128, 8)
# val_df.shape =  (783, 8)
# target_cols =  ['cohesion', 'syntax', 'phraseology', 'grammar', 'conventions']
# 100%|███████████████████████████████████████████| 98/98 [00:16<00:00,  5.94it/s]
# val_loss=0.1071, val_score=0.4638
# essay_ids.shape =  (783,)
# preds.shape =  (783, 5)
# labels.shape =  (783, 5)
# losses.shape =  (783, 5)
# embeds.shape =  (783, 768)
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# 2022-11-09 07:57:24.291899: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-09 07:57:24.291924: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# target_cols =  ['cohesion', 'syntax', 'phraseology', 'grammar', 'conventions']
# 100%|███████████████████████████████████████████| 98/98 [00:16<00:00,  5.92it/s]
# val_loss=0.1060, val_score=0.4618
# essay_ids.shape =  (782,)
# preds.shape =  (782, 5)
# labels.shape =  (782, 5)
# losses.shape =  (782, 5)
# embeds.shape =  (782, 768)
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# 2022-11-09 07:57:57.622469: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-09 07:57:57.622489: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# target_cols =  ['cohesion', 'syntax', 'phraseology', 'grammar', 'conventions']
# 100%|███████████████████████████████████████████| 98/98 [00:16<00:00,  5.92it/s]
# val_loss=0.1014, val_score=0.4513
# essay_ids.shape =  (782,)
# preds.shape =  (782, 5)
# labels.shape =  (782, 5)
# losses.shape =  (782, 5)
# embeds.shape =  (782, 768)
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.1
# 2022-11-09 07:58:31.161104: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-09 07:58:31.161147: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# target_cols =  ['cohesion', 'syntax', 'phraseology', 'grammar', 'conventions']
# 100%|███████████████████████████████████████████| 98/98 [00:16<00:00,  5.91it/s]
# val_loss=0.1081, val_score=0.4660
# essay_ids.shape =  (782,)
# preds.shape =  (782, 5)
# labels.shape =  (782, 5)
# losses.shape =  (782, 5)
# embeds.shape =  (782, 768)
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.1
# 2022-11-09 07:59:04.938920: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-09 07:59:04.938941: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# target_cols =  ['cohesion', 'syntax', 'phraseology', 'grammar', 'conventions']
# 100%|███████████████████████████████████████████| 98/98 [00:16<00:00,  5.90it/s]
# val_loss=0.1071, val_score=0.4641
# essay_ids.shape =  (782,)
# preds.shape =  (782, 5)
# labels.shape =  (782, 5)
# losses.shape =  (782, 5)
# embeds.shape =  (782, 768)

# %%
import pandas as pd
import numpy as np

preds = []
for fold in [0,1,2,3,4]:
    print("-"*50)
    print("FOLD = ", fold)
    print("-"*50)
    pred_df = pd.read_csv(f'./result/{VERSION}/pred_fold{fold}.csv')
    preds.append(pred_df)
    
all_pred_df = pd.concat(preds, axis=0).reset_index(drop=True)

train_df = pd.read_csv('../../input/feedback-prize-english-language-learning/train.csv')
oof_df = train_df[['text_id']].merge(all_pred_df, on='text_id', how='left')
oof_df.to_csv(f'./result/{VERSION}/oof_df.csv', index=False)
# Out:
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------

# %%
oof_df.shape, oof_df.isnull().sum()
# Out:
# ((3911, 11),
#  text_id             0
#  cohesion            0
#  syntax              0
#  phraseology         0
#  grammar             0
#  conventions         0
#  loss_cohesion       0
#  loss_syntax         0
#  loss_phraseology    0
#  loss_grammar        0
#  loss_conventions    0
#  dtype: int64)

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
oof_df[cols].describe()

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
train_df[cols].describe()

# %% [markdown]
# # Error Analysis - Check Corr

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
train_df[cols].corr()

# %%
#cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
cols = ['cohesion','syntax','phraseology','grammar','conventions']
oof_df[cols].corr()
# Out:
#              cohesion    syntax  phraseology   grammar  conventions
# cohesion     1.000000  0.975006     0.937502  0.863996     0.918328
# syntax       0.975006  1.000000     0.973961  0.932843     0.940555
# phraseology  0.937502  0.973961     1.000000  0.960541     0.898319
# grammar      0.863996  0.932843     0.960541  1.000000     0.879986
# conventions  0.918328  0.940555     0.898319  0.879986     1.000000
