# %%
VERSION = '14_v1_16'
MODEL = 'microsoft/deberta-xlarge'
#'microsoft/deberta-v2-xlarge'
#'xlm-roberta-large'
#'roberta-large'
#'microsoft/deberta-large'
#'xlm-roberta-base'
#'roberta-base'
#'microsoft/deberta-base'
#'microsoft/deberta-v3-base'
#'bert-large-cased'
#'bert-large-cased-whole-word-masking'
#'albert-large-v2'
#'facebook/bart-large'
#'deepset/roberta-large-squad2'
#'google/electra-large-discriminator'
#'sentence-transformeres/paraphrase-mpnet-base-v2'
#'funnel-transformer/large-base'
#'facebook/bart-base'
#'distilroberta-base'
#'deepset/roberta-base-squad2'
#'microsoft/deberta-v3-large'
LR = 8e-6 #1e-5 #2e-5 #8e-6
HEAD_LR = 8e-5 #1e-4 #2e-4 #2e-5 #8e-6 
SEED = 100
TRN_BS = 8
VAL_BS = 8
ACCUM_STEP = 1
HIDDEN_DROP_PROB = 0
P_DROP = 0
RNN = 'none'
WARMUP_RATIO = 0.1
HEAD = 'simple'
AUG = 'false'
MIXUP_ALPHA = 0
P_AUG = 0
AUG_STOP_EPOCH = 0
MSD = 'false'
POOLING = 'mean' #'weighted_layer'
NUM_POOLING_LAYERS = 4 #1
MULTI_LAYERS = 1
EVAL_STEP_START_EPOCH = -1
EVAL_STEP = -1
NUM_LABELS = 1 #6
NUM_LABELS_2 = -1
FP16 = 'true'
WD = 0.01
FREEZE = 'true' #'false'
MULTI_TASK = 'false' 
W_MT = 0 
AWP = 'false'
AWP_LR = 0
AWP_EPS = 0
AWP_START_EPOCH = -1
#PRETRAINED_DETECTOR_PATH = f'../../input/tascj/result/deberta_base_fold0.pth'
PRETRAINED_DETECTOR_PATH = 'none' #f'../../05_Detection/exp/result/05_v2_09/model_seed100_fold0_swa.pth'
MASK_PROB = 0 #0.8
MASK_RATIO = 0 #0.3
SCHEDULER = 'cosine_hard'
CP = 'true' #'false'
WINDOW_SIZE = -1 #512
INNER_LEN = -1 #384
EDGE_LEN = -1 #64
MAX_LEN = 512

GRAD_CLIP = 1

LOSS = 'smoothl1'#'mse'

CROP_PROB = 0 #1.0

CLASS = 'cohesion'

# %%
print("*"*50)
print(CLASS)
print("*"*50)
for FOLD in [0]: #[0,1,2,3,4]:
    print("-"*50)
    print("FOLD = ", FOLD)
    print("-"*50)
    INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
    FOLD_PATH = '../../00_EDA/00_v1_02/result/'
    MODE = 'train'
    EPOCHS = 5
    STOP_EPOCH = 5
    RESTART = 1
    NUM_CYCLES = EPOCHS
    PRETRAIN_PATH = 'none' #f'result/{VERSION}/model_seed{SEED}_fold{FOLD}_epoch{EPOCHS}_pseudo.pth'

    # !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
    --lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
    --epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
    --accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
    --mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
    --msd $MSD --multi_layers $MULTI_LAYERS \
    --eval_step_start_epoch $EVAL_STEP_START_EPOCH --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
    --num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
    --restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
    --mt $MULTI_TASK --w_mt $W_MT \
    --awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
    --pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
    --scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
    --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN \
    --gradient_clip_val $GRAD_CLIP \
    --input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN \
    --crop_prob $CROP_PROB --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS --class_name $CLASS
# Out:
# **************************************************
# cohesion
# **************************************************
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3128, 8)
# val_df.shape =  (783, 8)
# 2022-10-25 07:13:20.868036: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-25 07:13:20.868058: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [12:50<00:00,  1.97s/it, loss=0.428]
# 100%|███████████████████████████████████████████| 98/98 [01:37<00:00,  1.01it/s]
# epoch 1: trn_loss = 0.4277, val_loss = 0.1209, trn_score = 1.2214, val_score = 0.4941
# model_cohesion (best score) saved
# lr :  [3.2897872149827876e-06, 3.2897872149827876e-06, 3.2897872149827876e-05]
# 100%|█████████████████████████████| 391/391 [12:53<00:00,  1.98s/it, loss=0.115]
# 100%|███████████████████████████████████████████| 98/98 [01:37<00:00,  1.00it/s]
# epoch 2: trn_loss = 0.1154, val_loss = 0.1206, trn_score = 0.4822, val_score = 0.4936
# model_cohesion (best score) saved
# lr :  [1.9897031875730762e-06, 1.9897031875730762e-06, 1.9897031875730763e-05]
# 100%|██████████████████████████████| 391/391 [12:51<00:00,  1.97s/it, loss=0.11]
# 100%|███████████████████████████████████████████| 98/98 [01:37<00:00,  1.00it/s]
# epoch 3: trn_loss = 0.1104, val_loss = 0.1194, trn_score = 0.4714, val_score = 0.4913
# model_cohesion (best score) saved
# lr :  [9.307288210334982e-07, 9.307288210334982e-07, 9.307288210334983e-06]
# 100%|█████████████████████████████| 391/391 [12:52<00:00,  1.98s/it, loss=0.102]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.00s/it]
# epoch 4: trn_loss = 0.1018, val_loss = 0.1193, trn_score = 0.4523, val_score = 0.4913
# model_cohesion (best score) saved
# lr :  [2.3987468853323964e-07, 2.3987468853323964e-07, 2.398746885332397e-06]
# 100%|████████████████████████████| 391/391 [12:53<00:00,  1.98s/it, loss=0.0927]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.00s/it]
# epoch 5: trn_loss = 0.0927, val_loss = 0.1230, trn_score = 0.4312, val_score = 0.4988

# %%
for FOLD in [1,2,3,4]:
    print("-"*50)
    print("FOLD = ", FOLD)
    print("-"*50)
    INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
    FOLD_PATH = '../../00_EDA/00_v1_02/result/'
    MODE = 'train'
    EPOCHS = 5
    STOP_EPOCH = 5
    RESTART = 1
    NUM_CYCLES = EPOCHS
    PRETRAIN_PATH = 'none' #f'result/{VERSION}/model_seed{SEED}_fold{FOLD}_epoch{EPOCHS}_pseudo.pth'

    # !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
    --lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
    --epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
    --accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
    --mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
    --msd $MSD --multi_layers $MULTI_LAYERS \
    --eval_step_start_epoch $EVAL_STEP_START_EPOCH --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
    --num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
    --restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
    --mt $MULTI_TASK --w_mt $W_MT \
    --awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
    --pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
    --scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
    --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN \
    --gradient_clip_val $GRAD_CLIP \
    --input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN \
    --crop_prob $CROP_PROB --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS --class_name $CLASS
# Out:
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-10-25 08:26:33.083880: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-25 08:26:33.083935: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [12:55<00:00,  1.98s/it, loss=0.326]
# 100%|███████████████████████████████████████████| 98/98 [01:36<00:00,  1.01it/s]
# epoch 1: trn_loss = 0.3265, val_loss = 0.1121, trn_score = 0.9582, val_score = 0.4754
# model_cohesion (best score) saved
# lr :  [3.2897872149827876e-06, 3.2897872149827876e-06, 3.2897872149827876e-05]
# 100%|█████████████████████████████| 391/391 [12:47<00:00,  1.96s/it, loss=0.119]
# 100%|███████████████████████████████████████████| 98/98 [01:36<00:00,  1.01it/s]
# epoch 2: trn_loss = 0.1188, val_loss = 0.1066, trn_score = 0.4897, val_score = 0.4628
# model_cohesion (best score) saved
# lr :  [1.9897031875730762e-06, 1.9897031875730762e-06, 1.9897031875730763e-05]
# 100%|█████████████████████████████| 391/391 [12:48<00:00,  1.96s/it, loss=0.111]
# 100%|███████████████████████████████████████████| 98/98 [01:37<00:00,  1.01it/s]
# epoch 3: trn_loss = 0.1111, val_loss = 0.1071, trn_score = 0.4733, val_score = 0.4634
# lr :  [9.307288210334982e-07, 9.307288210334982e-07, 9.307288210334983e-06]
# 100%|█████████████████████████████| 391/391 [12:50<00:00,  1.97s/it, loss=0.107]
# 100%|███████████████████████████████████████████| 98/98 [01:37<00:00,  1.00it/s]
# epoch 4: trn_loss = 0.1074, val_loss = 0.1080, trn_score = 0.4648, val_score = 0.4660
# lr :  [2.3987468853323964e-07, 2.3987468853323964e-07, 2.398746885332397e-06]
# 100%|████████████████████████████| 391/391 [12:51<00:00,  1.97s/it, loss=0.0945]
# 100%|███████████████████████████████████████████| 98/98 [01:37<00:00,  1.00it/s]
# epoch 5: trn_loss = 0.0945, val_loss = 0.1088, trn_score = 0.4355, val_score = 0.4677
#
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-10-25 09:39:21.668305: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-25 09:39:21.668330: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [12:57<00:00,  1.99s/it, loss=0.222]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.00s/it]
# epoch 1: trn_loss = 0.2217, val_loss = 0.1240, trn_score = 0.7068, val_score = 0.5001
# model_cohesion (best score) saved
# lr :  [3.2897872149827876e-06, 3.2897872149827876e-06, 3.2897872149827876e-05]
# 100%|█████████████████████████████| 391/391 [12:52<00:00,  1.97s/it, loss=0.118]
# 100%|███████████████████████████████████████████| 98/98 [01:37<00:00,  1.00it/s]
# epoch 2: trn_loss = 0.1176, val_loss = 0.1258, trn_score = 0.4867, val_score = 0.5044
# lr :  [1.9897031875730762e-06, 1.9897031875730762e-06, 1.9897031875730763e-05]
# 100%|█████████████████████████████| 391/391 [12:52<00:00,  1.98s/it, loss=0.108]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.00s/it]
# epoch 3: trn_loss = 0.1078, val_loss = 0.1235, trn_score = 0.4653, val_score = 0.4998
# model_cohesion (best score) saved
# lr :  [9.307288210334982e-07, 9.307288210334982e-07, 9.307288210334983e-06]
# 100%|█████████████████████████████| 391/391 [12:53<00:00,  1.98s/it, loss=0.106]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.00s/it]
# epoch 4: trn_loss = 0.1056, val_loss = 0.1159, trn_score = 0.4615, val_score = 0.4831
# model_cohesion (best score) saved
# lr :  [2.3987468853323964e-07, 2.3987468853323964e-07, 2.398746885332397e-06]
# 100%|████████████████████████████| 391/391 [12:51<00:00,  1.97s/it, loss=0.0953]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.00s/it]
# epoch 5: trn_loss = 0.0953, val_loss = 0.1173, trn_score = 0.4373, val_score = 0.4859
#
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-10-25 10:52:31.274544: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-25 10:52:31.274567: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [12:58<00:00,  1.99s/it, loss=0.279]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.01s/it]
# epoch 1: trn_loss = 0.2787, val_loss = 0.1214, trn_score = 0.8481, val_score = 0.4944
# model_cohesion (best score) saved
# lr :  [3.2897872149827876e-06, 3.2897872149827876e-06, 3.2897872149827876e-05]
# 100%|█████████████████████████████| 391/391 [12:54<00:00,  1.98s/it, loss=0.114]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.01s/it]
# epoch 2: trn_loss = 0.1136, val_loss = 0.1222, trn_score = 0.4784, val_score = 0.4955
# lr :  [1.9897031875730762e-06, 1.9897031875730762e-06, 1.9897031875730763e-05]
# 100%|█████████████████████████████| 391/391 [12:54<00:00,  1.98s/it, loss=0.106]
# 100%|███████████████████████████████████████████| 98/98 [01:37<00:00,  1.00it/s]
# epoch 3: trn_loss = 0.1062, val_loss = 0.1266, trn_score = 0.4623, val_score = 0.5052
# lr :  [9.307288210334982e-07, 9.307288210334982e-07, 9.307288210334983e-06]
# 100%|████████████████████████████| 391/391 [12:50<00:00,  1.97s/it, loss=0.0992]
# 100%|███████████████████████████████████████████| 98/98 [01:37<00:00,  1.00it/s]
# epoch 4: trn_loss = 0.0992, val_loss = 0.1224, trn_score = 0.4474, val_score = 0.4959
# lr :  [2.3987468853323964e-07, 2.3987468853323964e-07, 2.398746885332397e-06]
# 100%|████████████████████████████| 391/391 [12:52<00:00,  1.98s/it, loss=0.0871]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.00s/it]
# epoch 5: trn_loss = 0.0871, val_loss = 0.1278, trn_score = 0.4182, val_score = 0.5072
#
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-10-25 12:05:37.665395: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-25 12:05:37.665418: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [12:59<00:00,  1.99s/it, loss=0.386]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.01s/it]
# epoch 1: trn_loss = 0.3864, val_loss = 0.1172, trn_score = 1.1052, val_score = 0.4853
# model_cohesion (best score) saved
# lr :  [3.2897872149827876e-06, 3.2897872149827876e-06, 3.2897872149827876e-05]
# 100%|█████████████████████████████| 391/391 [12:48<00:00,  1.96s/it, loss=0.115]
# 100%|███████████████████████████████████████████| 98/98 [01:37<00:00,  1.01it/s]
# epoch 2: trn_loss = 0.1149, val_loss = 0.1180, trn_score = 0.4822, val_score = 0.4871
# lr :  [1.9897031875730762e-06, 1.9897031875730762e-06, 1.9897031875730763e-05]
# 100%|█████████████████████████████| 391/391 [12:50<00:00,  1.97s/it, loss=0.109]
# 100%|███████████████████████████████████████████| 98/98 [01:37<00:00,  1.01it/s]
# epoch 3: trn_loss = 0.1086, val_loss = 0.1189, trn_score = 0.4676, val_score = 0.4892
# lr :  [9.307288210334982e-07, 9.307288210334982e-07, 9.307288210334983e-06]
# 100%|████████████████████████████| 391/391 [12:51<00:00,  1.97s/it, loss=0.0996]
# 100%|███████████████████████████████████████████| 98/98 [01:37<00:00,  1.00it/s]
# epoch 4: trn_loss = 0.0996, val_loss = 0.1134, trn_score = 0.4478, val_score = 0.4769
# model_cohesion (best score) saved
# lr :  [2.3987468853323964e-07, 2.3987468853323964e-07, 2.398746885332397e-06]
# 100%|████████████████████████████| 391/391 [12:52<00:00,  1.97s/it, loss=0.0904]
# 100%|███████████████████████████████████████████| 98/98 [01:37<00:00,  1.00it/s]
# epoch 5: trn_loss = 0.0904, val_loss = 0.1160, trn_score = 0.4256, val_score = 0.4825

# %%
for CLASS in [
    #'cohesion',
    'syntax','vocabulary','phraseology','grammar','conventions'
]:
    print("*"*50)
    print(CLASS)
    print("*"*50)
    for FOLD in [0,1,2,3,4]:
        print("-"*50)
        print("FOLD = ", FOLD)
        print("-"*50)
        INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
        FOLD_PATH = '../../00_EDA/00_v1_02/result/'
        MODE = 'train'
        EPOCHS = 5
        STOP_EPOCH = 5
        RESTART = 1
        NUM_CYCLES = EPOCHS
        PRETRAIN_PATH = 'none' #f'result/{VERSION}/model_seed{SEED}_fold{FOLD}_epoch{EPOCHS}_pseudo.pth'

        # !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
        --lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
        --epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
        --accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
        --mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
        --msd $MSD --multi_layers $MULTI_LAYERS \
        --eval_step_start_epoch $EVAL_STEP_START_EPOCH --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
        --num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
        --restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
        --mt $MULTI_TASK --w_mt $W_MT \
        --awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
        --pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
        --scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
        --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN \
        --gradient_clip_val $GRAD_CLIP \
        --input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN \
        --crop_prob $CROP_PROB --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS --class_name $CLASS
# Out:
# **************************************************
# syntax
# **************************************************
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3128, 8)
# val_df.shape =  (783, 8)
# 2022-10-25 13:18:36.973486: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-25 13:18:36.973510: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [12:54<00:00,  1.98s/it, loss=0.403]
# 100%|███████████████████████████████████████████| 98/98 [01:37<00:00,  1.01it/s]
# epoch 1: trn_loss = 0.4027, val_loss = 0.1094, trn_score = 1.1718, val_score = 0.4694
# model_syntax (best score) saved
# lr :  [3.2897872149827876e-06, 3.2897872149827876e-06, 3.2897872149827876e-05]
# 100%|█████████████████████████████| 391/391 [12:49<00:00,  1.97s/it, loss=0.102]
# 100%|███████████████████████████████████████████| 98/98 [01:36<00:00,  1.01it/s]
# epoch 2: trn_loss = 0.1021, val_loss = 0.1046, trn_score = 0.4536, val_score = 0.4582
# model_syntax (best score) saved
# lr :  [1.9897031875730762e-06, 1.9897031875730762e-06, 1.9897031875730763e-05]
# 100%|████████████████████████████| 391/391 [12:51<00:00,  1.97s/it, loss=0.0991]
# 100%|███████████████████████████████████████████| 98/98 [01:37<00:00,  1.01it/s]
# epoch 3: trn_loss = 0.0991, val_loss = 0.1024, trn_score = 0.4472, val_score = 0.4533
# model_syntax (best score) saved
# lr :  [9.307288210334982e-07, 9.307288210334982e-07, 9.307288210334983e-06]
# 100%|████████████████████████████| 391/391 [12:51<00:00,  1.97s/it, loss=0.0913]
# 100%|███████████████████████████████████████████| 98/98 [01:37<00:00,  1.00it/s]
# epoch 4: trn_loss = 0.0913, val_loss = 0.1001, trn_score = 0.4284, val_score = 0.4485
# model_syntax (best score) saved
# lr :  [2.3987468853323964e-07, 2.3987468853323964e-07, 2.398746885332397e-06]
# 100%|████████████████████████████| 391/391 [12:52<00:00,  1.98s/it, loss=0.0823]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.01s/it]
# epoch 5: trn_loss = 0.0823, val_loss = 0.1019, trn_score = 0.4065, val_score = 0.4525
#
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-10-25 14:31:39.937143: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-25 14:31:39.937167: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|██████████████████████████████| 391/391 [13:31<00:00,  2.08s/it, loss=0.29]
# 100%|███████████████████████████████████████████| 98/98 [01:42<00:00,  1.05s/it]
# epoch 1: trn_loss = 0.2905, val_loss = 0.1048, trn_score = 0.8916, val_score = 0.4597
# model_syntax (best score) saved
# lr :  [3.2897872149827876e-06, 3.2897872149827876e-06, 3.2897872149827876e-05]
# 100%|████████████████████████████| 391/391 [13:36<00:00,  2.09s/it, loss=0.0999]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.00s/it]
# epoch 2: trn_loss = 0.0999, val_loss = 0.1044, trn_score = 0.4483, val_score = 0.4583
# model_syntax (best score) saved
# lr :  [1.9897031875730762e-06, 1.9897031875730762e-06, 1.9897031875730763e-05]
# 100%|████████████████████████████| 391/391 [12:55<00:00,  1.98s/it, loss=0.0947]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.01s/it]
# epoch 3: trn_loss = 0.0947, val_loss = 0.1009, trn_score = 0.4363, val_score = 0.4508
# model_syntax (best score) saved
# lr :  [9.307288210334982e-07, 9.307288210334982e-07, 9.307288210334983e-06]
# 100%|█████████████████████████████| 391/391 [12:53<00:00,  1.98s/it, loss=0.088]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.00s/it]
# epoch 4: trn_loss = 0.0880, val_loss = 0.1014, trn_score = 0.4202, val_score = 0.4517
# lr :  [2.3987468853323964e-07, 2.3987468853323964e-07, 2.398746885332397e-06]
# 100%|████████████████████████████| 391/391 [12:53<00:00,  1.98s/it, loss=0.0833]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.00s/it]
# epoch 5: trn_loss = 0.0833, val_loss = 0.1031, trn_score = 0.4090, val_score = 0.4557
#
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-10-25 15:46:18.612407: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-25 15:46:18.612429: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [13:01<00:00,  2.00s/it, loss=0.204]
# 100%|███████████████████████████████████████████| 98/98 [01:39<00:00,  1.01s/it]
# epoch 1: trn_loss = 0.2036, val_loss = 0.1047, trn_score = 0.6800, val_score = 0.4595
# model_syntax (best score) saved
# lr :  [3.2897872149827876e-06, 3.2897872149827876e-06, 3.2897872149827876e-05]
# 100%|█████████████████████████████| 391/391 [12:55<00:00,  1.98s/it, loss=0.102]
# 100%|███████████████████████████████████████████| 98/98 [01:39<00:00,  1.01s/it]
# epoch 2: trn_loss = 0.1024, val_loss = 0.1006, trn_score = 0.4533, val_score = 0.4507
# model_syntax (best score) saved
# lr :  [1.9897031875730762e-06, 1.9897031875730762e-06, 1.9897031875730763e-05]
# 100%|████████████████████████████| 391/391 [12:55<00:00,  1.98s/it, loss=0.0954]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.01s/it]
# epoch 3: trn_loss = 0.0954, val_loss = 0.1025, trn_score = 0.4376, val_score = 0.4549
# lr :  [9.307288210334982e-07, 9.307288210334982e-07, 9.307288210334983e-06]
# 100%|████████████████████████████| 391/391 [12:55<00:00,  1.98s/it, loss=0.0897]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.01s/it]
# epoch 4: trn_loss = 0.0897, val_loss = 0.0985, trn_score = 0.4243, val_score = 0.4454
# model_syntax (best score) saved
# lr :  [2.3987468853323964e-07, 2.3987468853323964e-07, 2.398746885332397e-06]
# 100%|████████████████████████████| 391/391 [12:52<00:00,  1.98s/it, loss=0.0856]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.00s/it]
# epoch 5: trn_loss = 0.0856, val_loss = 0.1014, trn_score = 0.4145, val_score = 0.4523
#
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-10-25 16:59:42.941421: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-25 16:59:42.941441: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [12:49<00:00,  1.97s/it, loss=0.258]
# 100%|███████████████████████████████████████████| 98/98 [01:36<00:00,  1.02it/s]
# epoch 1: trn_loss = 0.2580, val_loss = 0.1045, trn_score = 0.8135, val_score = 0.4580
# model_syntax (best score) saved
# lr :  [3.2897872149827876e-06, 3.2897872149827876e-06, 3.2897872149827876e-05]
# 100%|█████████████████████████████| 391/391 [12:48<00:00,  1.97s/it, loss=0.102]
# 100%|███████████████████████████████████████████| 98/98 [01:36<00:00,  1.01it/s]
# epoch 2: trn_loss = 0.1020, val_loss = 0.1004, trn_score = 0.4531, val_score = 0.4493
# model_syntax (best score) saved
# lr :  [1.9897031875730762e-06, 1.9897031875730762e-06, 1.9897031875730763e-05]
# 100%|████████████████████████████| 391/391 [12:49<00:00,  1.97s/it, loss=0.0946]
# 100%|███████████████████████████████████████████| 98/98 [01:36<00:00,  1.01it/s]
# epoch 3: trn_loss = 0.0946, val_loss = 0.1170, trn_score = 0.4360, val_score = 0.4851
# lr :  [9.307288210334982e-07, 9.307288210334982e-07, 9.307288210334983e-06]
# 100%|████████████████████████████| 391/391 [12:48<00:00,  1.97s/it, loss=0.0903]
# 100%|███████████████████████████████████████████| 98/98 [01:36<00:00,  1.01it/s]
# epoch 4: trn_loss = 0.0903, val_loss = 0.1024, trn_score = 0.4257, val_score = 0.4533
# lr :  [2.3987468853323964e-07, 2.3987468853323964e-07, 2.398746885332397e-06]
# 100%|████████████████████████████| 391/391 [12:49<00:00,  1.97s/it, loss=0.0822]
# 100%|███████████████████████████████████████████| 98/98 [01:37<00:00,  1.01it/s]
# epoch 5: trn_loss = 0.0822, val_loss = 0.1030, trn_score = 0.4062, val_score = 0.4548
#
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-10-25 18:12:21.471918: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-25 18:12:21.471941: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [12:55<00:00,  1.98s/it, loss=0.355]
# 100%|███████████████████████████████████████████| 98/98 [01:37<00:00,  1.00it/s]
# epoch 1: trn_loss = 0.3555, val_loss = 0.1155, trn_score = 1.0568, val_score = 0.4826
# model_syntax (best score) saved
# lr :  [3.2897872149827876e-06, 3.2897872149827876e-06, 3.2897872149827876e-05]
# 100%|████████████████████████████| 391/391 [12:53<00:00,  1.98s/it, loss=0.0977]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.00s/it]
# epoch 2: trn_loss = 0.0977, val_loss = 0.1064, trn_score = 0.4436, val_score = 0.4624
# model_syntax (best score) saved
# lr :  [1.9897031875730762e-06, 1.9897031875730762e-06, 1.9897031875730763e-05]
# 100%|████████████████████████████| 391/391 [12:52<00:00,  1.98s/it, loss=0.0986]
# 100%|███████████████████████████████████████████| 98/98 [01:37<00:00,  1.00it/s]
# epoch 3: trn_loss = 0.0986, val_loss = 0.1049, trn_score = 0.4453, val_score = 0.4590
# model_syntax (best score) saved
# lr :  [9.307288210334982e-07, 9.307288210334982e-07, 9.307288210334983e-06]
# 100%|████████████████████████████| 391/391 [12:54<00:00,  1.98s/it, loss=0.0881]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.01s/it]
# epoch 4: trn_loss = 0.0881, val_loss = 0.1057, trn_score = 0.4205, val_score = 0.4609
# lr :  [2.3987468853323964e-07, 2.3987468853323964e-07, 2.398746885332397e-06]
# 100%|████████████████████████████| 391/391 [12:54<00:00,  1.98s/it, loss=0.0817]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.01s/it]
# epoch 5: trn_loss = 0.0817, val_loss = 0.1072, trn_score = 0.4050, val_score = 0.4643
#
# **************************************************
# vocabulary
# **************************************************
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3128, 8)
# val_df.shape =  (783, 8)
# 2022-10-25 19:25:34.669607: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-25 19:25:34.669630: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [13:00<00:00,  2.00s/it, loss=0.421]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.01s/it]
# epoch 1: trn_loss = 0.4207, val_loss = 0.0916, trn_score = 1.2282, val_score = 0.4288
# model_vocabulary (best score) saved
# lr :  [3.2897872149827876e-06, 3.2897872149827876e-06, 3.2897872149827876e-05]
# 100%|████████████████████████████| 391/391 [12:55<00:00,  1.98s/it, loss=0.0959]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.00s/it]
# epoch 2: trn_loss = 0.0959, val_loss = 0.0841, trn_score = 0.4394, val_score = 0.4108
# model_vocabulary (best score) saved
# lr :  [1.9897031875730762e-06, 1.9897031875730762e-06, 1.9897031875730763e-05]
# 100%|████████████████████████████| 391/391 [12:53<00:00,  1.98s/it, loss=0.0866]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.00s/it]
# epoch 3: trn_loss = 0.0866, val_loss = 0.0836, trn_score = 0.4170, val_score = 0.4095
# model_vocabulary (best score) saved
# lr :  [9.307288210334982e-07, 9.307288210334982e-07, 9.307288210334983e-06]
# 100%|████████████████████████████| 391/391 [12:54<00:00,  1.98s/it, loss=0.0792]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.00s/it]
# epoch 4: trn_loss = 0.0792, val_loss = 0.0852, trn_score = 0.3985, val_score = 0.4135
# lr :  [2.3987468853323964e-07, 2.3987468853323964e-07, 2.398746885332397e-06]
# 100%|████████████████████████████| 391/391 [12:55<00:00,  1.98s/it, loss=0.0738]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.01s/it]
# epoch 5: trn_loss = 0.0738, val_loss = 0.0831, trn_score = 0.3848, val_score = 0.4082
# model_vocabulary (best score) saved
#
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-10-25 20:39:00.444562: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-25 20:39:00.444585: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [13:01<00:00,  2.00s/it, loss=0.302]
# 100%|███████████████████████████████████████████| 98/98 [01:39<00:00,  1.01s/it]
# epoch 1: trn_loss = 0.3020, val_loss = 0.0858, trn_score = 0.9350, val_score = 0.4164
# model_vocabulary (best score) saved
# lr :  [3.2897872149827876e-06, 3.2897872149827876e-06, 3.2897872149827876e-05]
# 100%|████████████████████████████| 391/391 [12:57<00:00,  1.99s/it, loss=0.0881]
# 100%|███████████████████████████████████████████| 98/98 [01:39<00:00,  1.02s/it]
# epoch 2: trn_loss = 0.0881, val_loss = 0.1120, trn_score = 0.4205, val_score = 0.4757
# lr :  [1.9897031875730762e-06, 1.9897031875730762e-06, 1.9897031875730763e-05]
# 100%|████████████████████████████| 391/391 [12:51<00:00,  1.97s/it, loss=0.0867]
# 100%|███████████████████████████████████████████| 98/98 [01:37<00:00,  1.01it/s]
# epoch 3: trn_loss = 0.0867, val_loss = 0.0835, trn_score = 0.4172, val_score = 0.4109
# model_vocabulary (best score) saved
# lr :  [9.307288210334982e-07, 9.307288210334982e-07, 9.307288210334983e-06]
# 100%|████████████████████████████| 391/391 [12:49<00:00,  1.97s/it, loss=0.0782]
# 100%|███████████████████████████████████████████| 98/98 [01:37<00:00,  1.00it/s]
# epoch 4: trn_loss = 0.0782, val_loss = 0.0841, trn_score = 0.3958, val_score = 0.4117
# lr :  [2.3987468853323964e-07, 2.3987468853323964e-07, 2.398746885332397e-06]
# 100%|████████████████████████████| 391/391 [12:50<00:00,  1.97s/it, loss=0.0763]
# 100%|███████████████████████████████████████████| 98/98 [01:40<00:00,  1.02s/it]
# epoch 5: trn_loss = 0.0763, val_loss = 0.0838, trn_score = 0.3912, val_score = 0.4111
#
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-10-25 21:52:12.841916: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-25 21:52:12.841940: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|███████████████████████████████| 391/391 [13:00<00:00,  2.00s/it, loss=0.2]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.00s/it]
# epoch 1: trn_loss = 0.2000, val_loss = 0.0955, trn_score = 0.6843, val_score = 0.4383
# model_vocabulary (best score) saved
# lr :  [3.2897872149827876e-06, 3.2897872149827876e-06, 3.2897872149827876e-05]
# 100%|████████████████████████████| 391/391 [12:54<00:00,  1.98s/it, loss=0.0886]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.01s/it]
# epoch 2: trn_loss = 0.0886, val_loss = 0.0921, trn_score = 0.4220, val_score = 0.4300
# model_vocabulary (best score) saved
# lr :  [1.9897031875730762e-06, 1.9897031875730762e-06, 1.9897031875730763e-05]
# 100%|████████████████████████████| 391/391 [12:57<00:00,  1.99s/it, loss=0.0812]
# 100%|███████████████████████████████████████████| 98/98 [01:39<00:00,  1.01s/it]
# epoch 3: trn_loss = 0.0812, val_loss = 0.0950, trn_score = 0.4036, val_score = 0.4370
# lr :  [9.307288210334982e-07, 9.307288210334982e-07, 9.307288210334983e-06]
# 100%|████████████████████████████| 391/391 [12:58<00:00,  1.99s/it, loss=0.0823]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.01s/it]
# epoch 4: trn_loss = 0.0823, val_loss = 0.0884, trn_score = 0.4063, val_score = 0.4213
# model_vocabulary (best score) saved
# lr :  [2.3987468853323964e-07, 2.3987468853323964e-07, 2.398746885332397e-06]
# 100%|████████████████████████████| 391/391 [12:54<00:00,  1.98s/it, loss=0.0756]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.01s/it]
# epoch 5: trn_loss = 0.0756, val_loss = 0.0937, trn_score = 0.3896, val_score = 0.4339
#
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-10-25 23:05:43.824029: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-25 23:05:43.824050: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [13:00<00:00,  2.00s/it, loss=0.259]
# 100%|███████████████████████████████████████████| 98/98 [01:37<00:00,  1.00it/s]
# epoch 1: trn_loss = 0.2585, val_loss = 0.1071, trn_score = 0.8312, val_score = 0.4636
# model_vocabulary (best score) saved
# lr :  [3.2897872149827876e-06, 3.2897872149827876e-06, 3.2897872149827876e-05]
# 100%|████████████████████████████| 391/391 [12:52<00:00,  1.98s/it, loss=0.0888]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.00s/it]
# epoch 2: trn_loss = 0.0888, val_loss = 0.0958, trn_score = 0.4223, val_score = 0.4389
# model_vocabulary (best score) saved
# lr :  [1.9897031875730762e-06, 1.9897031875730762e-06, 1.9897031875730763e-05]
# 100%|████████████████████████████| 391/391 [12:56<00:00,  1.99s/it, loss=0.0827]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.01s/it]
# epoch 3: trn_loss = 0.0827, val_loss = 0.0900, trn_score = 0.4073, val_score = 0.4248
# model_vocabulary (best score) saved
# lr :  [9.307288210334982e-07, 9.307288210334982e-07, 9.307288210334983e-06]
# 100%|████████████████████████████| 391/391 [12:55<00:00,  1.98s/it, loss=0.0804]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.01s/it]
# epoch 4: trn_loss = 0.0804, val_loss = 0.0888, trn_score = 0.4017, val_score = 0.4217
# model_vocabulary (best score) saved
# lr :  [2.3987468853323964e-07, 2.3987468853323964e-07, 2.398746885332397e-06]
# 100%|████████████████████████████| 391/391 [12:57<00:00,  1.99s/it, loss=0.0727]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.01s/it]
# epoch 5: trn_loss = 0.0727, val_loss = 0.0885, trn_score = 0.3819, val_score = 0.4212
# model_vocabulary (best score) saved
#
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-10-26 00:19:17.799647: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 00:19:17.799668: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [12:57<00:00,  1.99s/it, loss=0.377]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.00s/it]
# epoch 1: trn_loss = 0.3773, val_loss = 0.0901, trn_score = 1.1109, val_score = 0.4257
# model_vocabulary (best score) saved
# lr :  [3.2897872149827876e-06, 3.2897872149827876e-06, 3.2897872149827876e-05]
# 100%|████████████████████████████| 391/391 [12:52<00:00,  1.98s/it, loss=0.0856]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.00s/it]
# epoch 2: trn_loss = 0.0856, val_loss = 0.0891, trn_score = 0.4148, val_score = 0.4228
# model_vocabulary (best score) saved
# lr :  [1.9897031875730762e-06, 1.9897031875730762e-06, 1.9897031875730763e-05]
# 100%|█████████████████████████████| 391/391 [12:54<00:00,  1.98s/it, loss=0.083]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.00s/it]
# epoch 3: trn_loss = 0.0830, val_loss = 0.0875, trn_score = 0.4082, val_score = 0.4191
# model_vocabulary (best score) saved
# lr :  [9.307288210334982e-07, 9.307288210334982e-07, 9.307288210334983e-06]
# 100%|████████████████████████████| 391/391 [12:53<00:00,  1.98s/it, loss=0.0768]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.00s/it]
# epoch 4: trn_loss = 0.0768, val_loss = 0.0875, trn_score = 0.3924, val_score = 0.4193
# lr :  [2.3987468853323964e-07, 2.3987468853323964e-07, 2.398746885332397e-06]
# 100%|████████████████████████████| 391/391 [12:52<00:00,  1.98s/it, loss=0.0701]
# 100%|███████████████████████████████████████████| 98/98 [01:35<00:00,  1.02it/s]
# epoch 5: trn_loss = 0.0701, val_loss = 0.0901, trn_score = 0.3749, val_score = 0.4253
#
# **************************************************
# phraseology
# **************************************************
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3128, 8)
# val_df.shape =  (783, 8)
# 2022-10-26 01:32:29.781477: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 01:32:29.781500: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [12:47<00:00,  1.96s/it, loss=0.422]
# 100%|███████████████████████████████████████████| 98/98 [01:35<00:00,  1.02it/s]
# epoch 1: trn_loss = 0.4220, val_loss = 0.1100, trn_score = 1.2130, val_score = 0.4704
# model_phraseology (best score) saved
# lr :  [3.2897872149827876e-06, 3.2897872149827876e-06, 3.2897872149827876e-05]
# 100%|█████████████████████████████| 391/391 [12:43<00:00,  1.95s/it, loss=0.107]
# 100%|███████████████████████████████████████████| 98/98 [01:35<00:00,  1.02it/s]
# epoch 2: trn_loss = 0.1073, val_loss = 0.1067, trn_score = 0.4646, val_score = 0.4629
# model_phraseology (best score) saved
# lr :  [1.9897031875730762e-06, 1.9897031875730762e-06, 1.9897031875730763e-05]
# 100%|████████████████████████████| 391/391 [12:43<00:00,  1.95s/it, loss=0.0966]
# 100%|███████████████████████████████████████████| 98/98 [01:35<00:00,  1.02it/s]
# epoch 3: trn_loss = 0.0966, val_loss = 0.1077, trn_score = 0.4405, val_score = 0.4653
# lr :  [9.307288210334982e-07, 9.307288210334982e-07, 9.307288210334983e-06]
# 100%|████████████████████████████| 391/391 [12:42<00:00,  1.95s/it, loss=0.0941]
# 100%|███████████████████████████████████████████| 98/98 [01:35<00:00,  1.02it/s]
# epoch 4: trn_loss = 0.0941, val_loss = 0.1067, trn_score = 0.4351, val_score = 0.4631
# lr :  [2.3987468853323964e-07, 2.3987468853323964e-07, 2.398746885332397e-06]
# 100%|████████████████████████████| 391/391 [12:43<00:00,  1.95s/it, loss=0.0877]
# 100%|███████████████████████████████████████████| 98/98 [01:35<00:00,  1.02it/s]
# epoch 5: trn_loss = 0.0877, val_loss = 0.1079, trn_score = 0.4194, val_score = 0.4656
#
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-10-26 02:44:38.103408: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 02:44:38.103428: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [12:46<00:00,  1.96s/it, loss=0.304]
# 100%|███████████████████████████████████████████| 98/98 [01:35<00:00,  1.03it/s]
# epoch 1: trn_loss = 0.3041, val_loss = 0.1204, trn_score = 0.9215, val_score = 0.4929
# model_phraseology (best score) saved
# lr :  [3.2897872149827876e-06, 3.2897872149827876e-06, 3.2897872149827876e-05]
# 100%|█████████████████████████████| 391/391 [12:42<00:00,  1.95s/it, loss=0.106]
# 100%|███████████████████████████████████████████| 98/98 [01:35<00:00,  1.03it/s]
# epoch 2: trn_loss = 0.1063, val_loss = 0.1265, trn_score = 0.4627, val_score = 0.5051
# lr :  [1.9897031875730762e-06, 1.9897031875730762e-06, 1.9897031875730763e-05]
# 100%|█████████████████████████████| 391/391 [12:42<00:00,  1.95s/it, loss=0.101]
# 100%|███████████████████████████████████████████| 98/98 [01:35<00:00,  1.03it/s]
# epoch 3: trn_loss = 0.1014, val_loss = 0.1081, trn_score = 0.4521, val_score = 0.4659
# model_phraseology (best score) saved
# lr :  [9.307288210334982e-07, 9.307288210334982e-07, 9.307288210334983e-06]
# 100%|████████████████████████████| 391/391 [12:41<00:00,  1.95s/it, loss=0.0943]
# 100%|███████████████████████████████████████████| 98/98 [01:35<00:00,  1.03it/s]
# epoch 4: trn_loss = 0.0943, val_loss = 0.1087, trn_score = 0.4354, val_score = 0.4674
# lr :  [2.3987468853323964e-07, 2.3987468853323964e-07, 2.398746885332397e-06]
# 100%|████████████████████████████| 391/391 [12:41<00:00,  1.95s/it, loss=0.0871]
# 100%|███████████████████████████████████████████| 98/98 [01:35<00:00,  1.03it/s]
# epoch 5: trn_loss = 0.0871, val_loss = 0.1075, trn_score = 0.4185, val_score = 0.4646
# model_phraseology (best score) saved
#
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-10-26 03:56:41.592218: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 03:56:41.592241: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [12:46<00:00,  1.96s/it, loss=0.208]
# 100%|███████████████████████████████████████████| 98/98 [01:35<00:00,  1.02it/s]
# epoch 1: trn_loss = 0.2085, val_loss = 0.1024, trn_score = 0.6919, val_score = 0.4535
# model_phraseology (best score) saved
# lr :  [3.2897872149827876e-06, 3.2897872149827876e-06, 3.2897872149827876e-05]
# 100%|█████████████████████████████| 391/391 [12:41<00:00,  1.95s/it, loss=0.111]
# 100%|███████████████████████████████████████████| 98/98 [01:35<00:00,  1.03it/s]
# epoch 2: trn_loss = 0.1108, val_loss = 0.1104, trn_score = 0.4730, val_score = 0.4713
# lr :  [1.9897031875730762e-06, 1.9897031875730762e-06, 1.9897031875730763e-05]
# 100%|█████████████████████████████| 391/391 [12:41<00:00,  1.95s/it, loss=0.103]
# 100%|███████████████████████████████████████████| 98/98 [01:35<00:00,  1.03it/s]
# epoch 3: trn_loss = 0.1027, val_loss = 0.0926, trn_score = 0.4547, val_score = 0.4311
# model_phraseology (best score) saved
# lr :  [9.307288210334982e-07, 9.307288210334982e-07, 9.307288210334983e-06]
# 100%|████████████████████████████| 391/391 [12:41<00:00,  1.95s/it, loss=0.0986]
# 100%|███████████████████████████████████████████| 98/98 [01:35<00:00,  1.03it/s]
# epoch 4: trn_loss = 0.0986, val_loss = 0.0898, trn_score = 0.4453, val_score = 0.4242
# model_phraseology (best score) saved
# lr :  [2.3987468853323964e-07, 2.3987468853323964e-07, 2.398746885332397e-06]
# 100%|████████████████████████████| 391/391 [12:40<00:00,  1.94s/it, loss=0.0953]
# 100%|███████████████████████████████████████████| 98/98 [01:35<00:00,  1.03it/s]
# epoch 5: trn_loss = 0.0953, val_loss = 0.0953, trn_score = 0.4380, val_score = 0.4373
#
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-10-26 05:08:42.315175: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 05:08:42.315198: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [12:45<00:00,  1.96s/it, loss=0.274]
# 100%|███████████████████████████████████████████| 98/98 [01:35<00:00,  1.03it/s]
# epoch 1: trn_loss = 0.2745, val_loss = 0.1141, trn_score = 0.8460, val_score = 0.4803
# model_phraseology (best score) saved
# lr :  [3.2897872149827876e-06, 3.2897872149827876e-06, 3.2897872149827876e-05]
# 100%|█████████████████████████████| 391/391 [12:41<00:00,  1.95s/it, loss=0.109]
# 100%|███████████████████████████████████████████| 98/98 [01:35<00:00,  1.03it/s]
# epoch 2: trn_loss = 0.1095, val_loss = 0.1089, trn_score = 0.4700, val_score = 0.4678
# model_phraseology (best score) saved
# lr :  [1.9897031875730762e-06, 1.9897031875730762e-06, 1.9897031875730763e-05]
# 100%|█████████████████████████████| 391/391 [12:41<00:00,  1.95s/it, loss=0.101]
# 100%|███████████████████████████████████████████| 98/98 [01:35<00:00,  1.03it/s]
# epoch 3: trn_loss = 0.1012, val_loss = 0.1061, trn_score = 0.4509, val_score = 0.4617
# model_phraseology (best score) saved
# lr :  [9.307288210334982e-07, 9.307288210334982e-07, 9.307288210334983e-06]
# 100%|████████████████████████████| 391/391 [12:40<00:00,  1.94s/it, loss=0.0944]
# 100%|███████████████████████████████████████████| 98/98 [01:35<00:00,  1.03it/s]
# epoch 4: trn_loss = 0.0944, val_loss = 0.1089, trn_score = 0.4355, val_score = 0.4681
# lr :  [2.3987468853323964e-07, 2.3987468853323964e-07, 2.398746885332397e-06]
# 100%|████████████████████████████| 391/391 [12:41<00:00,  1.95s/it, loss=0.0866]
# 100%|███████████████████████████████████████████| 98/98 [01:35<00:00,  1.03it/s]
# epoch 5: trn_loss = 0.0866, val_loss = 0.1082, trn_score = 0.4169, val_score = 0.4665
#
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-10-26 06:20:40.848505: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 06:20:40.848540: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|██████████████████████████████| 391/391 [12:45<00:00,  1.96s/it, loss=0.37]
# 100%|███████████████████████████████████████████| 98/98 [01:35<00:00,  1.03it/s]
# epoch 1: trn_loss = 0.3702, val_loss = 0.1135, trn_score = 1.0864, val_score = 0.4784
# model_phraseology (best score) saved
# lr :  [3.2897872149827876e-06, 3.2897872149827876e-06, 3.2897872149827876e-05]
# 100%|█████████████████████████████| 391/391 [12:40<00:00,  1.94s/it, loss=0.104]
# 100%|███████████████████████████████████████████| 98/98 [01:35<00:00,  1.03it/s]
# epoch 2: trn_loss = 0.1036, val_loss = 0.1139, trn_score = 0.4568, val_score = 0.4791
# lr :  [1.9897031875730762e-06, 1.9897031875730762e-06, 1.9897031875730763e-05]
# 100%|█████████████████████████████| 391/391 [12:40<00:00,  1.94s/it, loss=0.101]
# 100%|███████████████████████████████████████████| 98/98 [01:35<00:00,  1.03it/s]
# epoch 3: trn_loss = 0.1014, val_loss = 0.1093, trn_score = 0.4523, val_score = 0.4693
# model_phraseology (best score) saved
# lr :  [9.307288210334982e-07, 9.307288210334982e-07, 9.307288210334983e-06]
# 100%|████████████████████████████| 391/391 [12:40<00:00,  1.94s/it, loss=0.0886]
# 100%|███████████████████████████████████████████| 98/98 [01:35<00:00,  1.03it/s]
# epoch 4: trn_loss = 0.0886, val_loss = 0.1161, trn_score = 0.4215, val_score = 0.4847
# lr :  [2.3987468853323964e-07, 2.3987468853323964e-07, 2.398746885332397e-06]
# 100%|████████████████████████████| 391/391 [12:41<00:00,  1.95s/it, loss=0.0858]
# 100%|███████████████████████████████████████████| 98/98 [01:35<00:00,  1.02it/s]
# epoch 5: trn_loss = 0.0858, val_loss = 0.1121, trn_score = 0.4149, val_score = 0.4752
#
# **************************************************
# grammar
# **************************************************
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3128, 8)
# val_df.shape =  (783, 8)
# 2022-10-26 07:32:33.571907: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 07:32:33.571928: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [13:34<00:00,  2.08s/it, loss=0.409]
# 100%|███████████████████████████████████████████| 98/98 [01:39<00:00,  1.01s/it]
# epoch 1: trn_loss = 0.4089, val_loss = 0.1204, trn_score = 1.1798, val_score = 0.4923
# model_grammar (best score) saved
# lr :  [3.2897872149827876e-06, 3.2897872149827876e-06, 3.2897872149827876e-05]
# 100%|█████████████████████████████| 391/391 [12:54<00:00,  1.98s/it, loss=0.112]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.00s/it]
# epoch 2: trn_loss = 0.1116, val_loss = 0.1148, trn_score = 0.4756, val_score = 0.4802
# model_grammar (best score) saved
# lr :  [1.9897031875730762e-06, 1.9897031875730762e-06, 1.9897031875730763e-05]
# 100%|█████████████████████████████| 391/391 [12:55<00:00,  1.98s/it, loss=0.103]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.01s/it]
# epoch 3: trn_loss = 0.1032, val_loss = 0.1157, trn_score = 0.4571, val_score = 0.4821
# lr :  [9.307288210334982e-07, 9.307288210334982e-07, 9.307288210334983e-06]
# 100%|███████████████████████████████| 391/391 [12:54<00:00,  1.98s/it, loss=0.1]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.00s/it]
# epoch 4: trn_loss = 0.1001, val_loss = 0.1165, trn_score = 0.4493, val_score = 0.4839
# lr :  [2.3987468853323964e-07, 2.3987468853323964e-07, 2.398746885332397e-06]
# 100%|████████████████████████████| 391/391 [12:52<00:00,  1.98s/it, loss=0.0848]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.00s/it]
# epoch 5: trn_loss = 0.0848, val_loss = 0.1202, trn_score = 0.4134, val_score = 0.4918
#
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-10-26 08:46:27.230009: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 08:46:27.230030: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [12:57<00:00,  1.99s/it, loss=0.304]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.00s/it]
# epoch 1: trn_loss = 0.3042, val_loss = 0.1234, trn_score = 0.9115, val_score = 0.5019
# model_grammar (best score) saved
# lr :  [3.2897872149827876e-06, 3.2897872149827876e-06, 3.2897872149827876e-05]
# 100%|█████████████████████████████| 391/391 [12:53<00:00,  1.98s/it, loss=0.113]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.00s/it]
# epoch 2: trn_loss = 0.1130, val_loss = 0.1132, trn_score = 0.4774, val_score = 0.4806
# model_grammar (best score) saved
# lr :  [1.9897031875730762e-06, 1.9897031875730762e-06, 1.9897031875730763e-05]
# 100%|█████████████████████████████| 391/391 [12:46<00:00,  1.96s/it, loss=0.108]
# 100%|███████████████████████████████████████████| 98/98 [01:36<00:00,  1.02it/s]
# epoch 3: trn_loss = 0.1078, val_loss = 0.1103, trn_score = 0.4664, val_score = 0.4737
# model_grammar (best score) saved
# lr :  [9.307288210334982e-07, 9.307288210334982e-07, 9.307288210334983e-06]
# 100%|████████████████████████████| 391/391 [12:45<00:00,  1.96s/it, loss=0.0995]
# 100%|███████████████████████████████████████████| 98/98 [01:36<00:00,  1.02it/s]
# epoch 4: trn_loss = 0.0995, val_loss = 0.1122, trn_score = 0.4475, val_score = 0.4778
# lr :  [2.3987468853323964e-07, 2.3987468853323964e-07, 2.398746885332397e-06]
# 100%|████████████████████████████| 391/391 [12:46<00:00,  1.96s/it, loss=0.0936]
# 100%|███████████████████████████████████████████| 98/98 [01:36<00:00,  1.01it/s]
# epoch 5: trn_loss = 0.0936, val_loss = 0.1133, trn_score = 0.4342, val_score = 0.4798
#
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-10-26 09:59:20.320753: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 09:59:20.320856: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [12:52<00:00,  1.98s/it, loss=0.218]
# 100%|███████████████████████████████████████████| 98/98 [01:36<00:00,  1.01it/s]
# epoch 1: trn_loss = 0.2178, val_loss = 0.1127, trn_score = 0.7079, val_score = 0.4763
# model_grammar (best score) saved
# lr :  [3.2897872149827876e-06, 3.2897872149827876e-06, 3.2897872149827876e-05]
# 100%|█████████████████████████████| 391/391 [12:50<00:00,  1.97s/it, loss=0.112]
# 100%|███████████████████████████████████████████| 98/98 [01:37<00:00,  1.00it/s]
# epoch 2: trn_loss = 0.1118, val_loss = 0.1202, trn_score = 0.4748, val_score = 0.4917
# lr :  [1.9897031875730762e-06, 1.9897031875730762e-06, 1.9897031875730763e-05]
# 100%|█████████████████████████████| 391/391 [12:51<00:00,  1.97s/it, loss=0.104]
# 100%|███████████████████████████████████████████| 98/98 [01:37<00:00,  1.00it/s]
# epoch 3: trn_loss = 0.1043, val_loss = 0.1051, trn_score = 0.4582, val_score = 0.4594
# model_grammar (best score) saved
# lr :  [9.307288210334982e-07, 9.307288210334982e-07, 9.307288210334983e-06]
# 100%|████████████████████████████| 391/391 [12:52<00:00,  1.98s/it, loss=0.0949]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.00s/it]
# epoch 4: trn_loss = 0.0949, val_loss = 0.1054, trn_score = 0.4369, val_score = 0.4603
# lr :  [2.3987468853323964e-07, 2.3987468853323964e-07, 2.398746885332397e-06]
# 100%|████████████████████████████| 391/391 [12:52<00:00,  1.98s/it, loss=0.0902]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.00s/it]
# epoch 5: trn_loss = 0.0902, val_loss = 0.1096, trn_score = 0.4260, val_score = 0.4696
#
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-10-26 11:12:21.520145: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 11:12:21.520161: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|██████████████████████████████| 391/391 [12:58<00:00,  1.99s/it, loss=0.27]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.01s/it]
# epoch 1: trn_loss = 0.2702, val_loss = 0.1157, trn_score = 0.8295, val_score = 0.4835
# model_grammar (best score) saved
# lr :  [3.2897872149827876e-06, 3.2897872149827876e-06, 3.2897872149827876e-05]
# 100%|█████████████████████████████| 391/391 [12:54<00:00,  1.98s/it, loss=0.118]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.00s/it]
# epoch 2: trn_loss = 0.1182, val_loss = 0.1256, trn_score = 0.4882, val_score = 0.5053
# lr :  [1.9897031875730762e-06, 1.9897031875730762e-06, 1.9897031875730763e-05]
# 100%|█████████████████████████████| 391/391 [12:53<00:00,  1.98s/it, loss=0.106]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.00s/it]
# epoch 3: trn_loss = 0.1059, val_loss = 0.1322, trn_score = 0.4616, val_score = 0.5194
# lr :  [9.307288210334982e-07, 9.307288210334982e-07, 9.307288210334983e-06]
# 100%|████████████████████████████| 391/391 [12:54<00:00,  1.98s/it, loss=0.0939]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.01s/it]
# epoch 4: trn_loss = 0.0939, val_loss = 0.1150, trn_score = 0.4344, val_score = 0.4821
# model_grammar (best score) saved
# lr :  [2.3987468853323964e-07, 2.3987468853323964e-07, 2.398746885332397e-06]
# 100%|████████████████████████████| 391/391 [12:55<00:00,  1.98s/it, loss=0.0801]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.00s/it]
# epoch 5: trn_loss = 0.0801, val_loss = 0.1168, trn_score = 0.4012, val_score = 0.4863
#
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-10-26 12:25:38.928366: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 12:25:38.928390: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [12:58<00:00,  1.99s/it, loss=0.377]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.01s/it]
# epoch 1: trn_loss = 0.3773, val_loss = 0.1493, trn_score = 1.0884, val_score = 0.5512
# model_grammar (best score) saved
# lr :  [3.2897872149827876e-06, 3.2897872149827876e-06, 3.2897872149827876e-05]
# 100%|██████████████████████████████| 391/391 [12:55<00:00,  1.98s/it, loss=0.11]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.01s/it]
# epoch 2: trn_loss = 0.1103, val_loss = 0.1459, trn_score = 0.4717, val_score = 0.5451
# model_grammar (best score) saved
# lr :  [1.9897031875730762e-06, 1.9897031875730762e-06, 1.9897031875730763e-05]
# 100%|█████████████████████████████| 391/391 [12:52<00:00,  1.98s/it, loss=0.104]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.00s/it]
# epoch 3: trn_loss = 0.1040, val_loss = 0.1283, trn_score = 0.4576, val_score = 0.5104
# model_grammar (best score) saved
# lr :  [9.307288210334982e-07, 9.307288210334982e-07, 9.307288210334983e-06]
# 100%|████████████████████████████| 391/391 [12:53<00:00,  1.98s/it, loss=0.0897]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.00s/it]
# epoch 4: trn_loss = 0.0897, val_loss = 0.1204, trn_score = 0.4247, val_score = 0.4931
# model_grammar (best score) saved
# lr :  [2.3987468853323964e-07, 2.3987468853323964e-07, 2.398746885332397e-06]
# 100%|████████████████████████████| 391/391 [12:56<00:00,  1.99s/it, loss=0.0832]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.01s/it]
# epoch 5: trn_loss = 0.0832, val_loss = 0.1242, trn_score = 0.4091, val_score = 0.5012
# **************************************************
# conventions
# **************************************************
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3128, 8)
# val_df.shape =  (783, 8)
# 2022-10-26 13:39:03.866704: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 13:39:03.866727: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [12:52<00:00,  1.98s/it, loss=0.406]
# 100%|███████████████████████████████████████████| 98/98 [01:37<00:00,  1.01it/s]
# epoch 1: trn_loss = 0.4060, val_loss = 0.1519, trn_score = 1.1777, val_score = 0.5537
# model_conventions (best score) saved
# lr :  [3.2897872149827876e-06, 3.2897872149827876e-06, 3.2897872149827876e-05]
# 100%|█████████████████████████████| 391/391 [12:47<00:00,  1.96s/it, loss=0.106]
# 100%|███████████████████████████████████████████| 98/98 [01:36<00:00,  1.01it/s]
# epoch 2: trn_loss = 0.1061, val_loss = 0.0972, trn_score = 0.4627, val_score = 0.4414
# model_conventions (best score) saved
# lr :  [1.9897031875730762e-06, 1.9897031875730762e-06, 1.9897031875730763e-05]
# 100%|████████████████████████████| 391/391 [12:48<00:00,  1.96s/it, loss=0.0951]
# 100%|███████████████████████████████████████████| 98/98 [01:36<00:00,  1.01it/s]
# epoch 3: trn_loss = 0.0951, val_loss = 0.0964, trn_score = 0.4378, val_score = 0.4396
# model_conventions (best score) saved
# lr :  [9.307288210334982e-07, 9.307288210334982e-07, 9.307288210334983e-06]
# 100%|████████████████████████████| 391/391 [12:47<00:00,  1.96s/it, loss=0.0903]
# 100%|███████████████████████████████████████████| 98/98 [01:37<00:00,  1.01it/s]
# epoch 4: trn_loss = 0.0903, val_loss = 0.1001, trn_score = 0.4259, val_score = 0.4480
# lr :  [2.3987468853323964e-07, 2.3987468853323964e-07, 2.398746885332397e-06]
# 100%|████████████████████████████| 391/391 [12:55<00:00,  1.98s/it, loss=0.0882]
# 100%|███████████████████████████████████████████| 98/98 [01:39<00:00,  1.01s/it]
# epoch 5: trn_loss = 0.0882, val_loss = 0.1007, trn_score = 0.4212, val_score = 0.4496
#
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-10-26 14:51:56.142552: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 14:51:56.142586: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [13:02<00:00,  2.00s/it, loss=0.306]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.01s/it]
# epoch 1: trn_loss = 0.3058, val_loss = 0.1106, trn_score = 0.9258, val_score = 0.4733
# model_conventions (best score) saved
# lr :  [3.2897872149827876e-06, 3.2897872149827876e-06, 3.2897872149827876e-05]
# 100%|█████████████████████████████| 391/391 [12:56<00:00,  1.99s/it, loss=0.101]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.01s/it]
# epoch 2: trn_loss = 0.1012, val_loss = 0.1177, trn_score = 0.4515, val_score = 0.4881
# lr :  [1.9897031875730762e-06, 1.9897031875730762e-06, 1.9897031875730763e-05]
# 100%|████████████████████████████| 391/391 [12:57<00:00,  1.99s/it, loss=0.0985]
# 100%|███████████████████████████████████████████| 98/98 [01:39<00:00,  1.01s/it]
# epoch 3: trn_loss = 0.0985, val_loss = 0.0998, trn_score = 0.4451, val_score = 0.4485
# model_conventions (best score) saved
# lr :  [9.307288210334982e-07, 9.307288210334982e-07, 9.307288210334983e-06]
# 100%|████████████████████████████| 391/391 [12:57<00:00,  1.99s/it, loss=0.0949]
# 100%|███████████████████████████████████████████| 98/98 [01:39<00:00,  1.02s/it]
# epoch 4: trn_loss = 0.0949, val_loss = 0.1016, trn_score = 0.4368, val_score = 0.4523
# lr :  [2.3987468853323964e-07, 2.3987468853323964e-07, 2.398746885332397e-06]
# 100%|████████████████████████████| 391/391 [12:58<00:00,  1.99s/it, loss=0.0893]
# 100%|███████████████████████████████████████████| 98/98 [01:39<00:00,  1.02s/it]
# epoch 5: trn_loss = 0.0893, val_loss = 0.1047, trn_score = 0.4240, val_score = 0.4593
#
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-10-26 16:05:33.521576: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 16:05:33.521599: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [13:05<00:00,  2.01s/it, loss=0.202]
# 100%|███████████████████████████████████████████| 98/98 [01:40<00:00,  1.02s/it]
# epoch 1: trn_loss = 0.2021, val_loss = 0.1089, trn_score = 0.6776, val_score = 0.4687
# model_conventions (best score) saved
# lr :  [3.2897872149827876e-06, 3.2897872149827876e-06, 3.2897872149827876e-05]
# 100%|█████████████████████████████| 391/391 [13:00<00:00,  2.00s/it, loss=0.103]
# 100%|███████████████████████████████████████████| 98/98 [01:40<00:00,  1.02s/it]
# epoch 2: trn_loss = 0.1027, val_loss = 0.1013, trn_score = 0.4544, val_score = 0.4519
# model_conventions (best score) saved
# lr :  [1.9897031875730762e-06, 1.9897031875730762e-06, 1.9897031875730763e-05]
# 100%|█████████████████████████████| 391/391 [13:00<00:00,  2.00s/it, loss=0.102]
# 100%|███████████████████████████████████████████| 98/98 [01:40<00:00,  1.02s/it]
# epoch 3: trn_loss = 0.1017, val_loss = 0.0998, trn_score = 0.4523, val_score = 0.4485
# model_conventions (best score) saved
# lr :  [9.307288210334982e-07, 9.307288210334982e-07, 9.307288210334983e-06]
# 100%|████████████████████████████| 391/391 [12:59<00:00,  1.99s/it, loss=0.0947]
# 100%|███████████████████████████████████████████| 98/98 [01:39<00:00,  1.01s/it]
# epoch 4: trn_loss = 0.0947, val_loss = 0.0991, trn_score = 0.4363, val_score = 0.4469
# model_conventions (best score) saved
# lr :  [2.3987468853323964e-07, 2.3987468853323964e-07, 2.398746885332397e-06]
# 100%|████████████████████████████| 391/391 [12:55<00:00,  1.98s/it, loss=0.0854]
# 100%|███████████████████████████████████████████| 98/98 [01:39<00:00,  1.01s/it]
# epoch 5: trn_loss = 0.0854, val_loss = 0.1029, trn_score = 0.4142, val_score = 0.4554
#
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-10-26 17:19:28.927812: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 17:19:28.927836: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [12:51<00:00,  1.97s/it, loss=0.264]
# 100%|███████████████████████████████████████████| 98/98 [01:36<00:00,  1.01it/s]
# epoch 1: trn_loss = 0.2636, val_loss = 0.1052, trn_score = 0.8237, val_score = 0.4600
# model_conventions (best score) saved
# lr :  [3.2897872149827876e-06, 3.2897872149827876e-06, 3.2897872149827876e-05]
# 100%|███████████████████████████████| 391/391 [12:46<00:00,  1.96s/it, loss=0.1]
# 100%|███████████████████████████████████████████| 98/98 [01:36<00:00,  1.02it/s]
# epoch 2: trn_loss = 0.1003, val_loss = 0.1039, trn_score = 0.4494, val_score = 0.4571
# model_conventions (best score) saved
# lr :  [1.9897031875730762e-06, 1.9897031875730762e-06, 1.9897031875730763e-05]
# 100%|████████████████████████████| 391/391 [12:49<00:00,  1.97s/it, loss=0.0972]
# 100%|███████████████████████████████████████████| 98/98 [01:37<00:00,  1.01it/s]
# epoch 3: trn_loss = 0.0972, val_loss = 0.1079, trn_score = 0.4426, val_score = 0.4663
# lr :  [9.307288210334982e-07, 9.307288210334982e-07, 9.307288210334983e-06]
# 100%|████████████████████████████| 391/391 [12:49<00:00,  1.97s/it, loss=0.0904]
# 100%|███████████████████████████████████████████| 98/98 [01:37<00:00,  1.01it/s]
# epoch 4: trn_loss = 0.0904, val_loss = 0.1063, trn_score = 0.4263, val_score = 0.4627
# lr :  [2.3987468853323964e-07, 2.3987468853323964e-07, 2.398746885332397e-06]
# 100%|████████████████████████████| 391/391 [12:51<00:00,  1.97s/it, loss=0.0842]
# 100%|███████████████████████████████████████████| 98/98 [01:37<00:00,  1.01it/s]
# epoch 5: trn_loss = 0.0842, val_loss = 0.1059, trn_score = 0.4113, val_score = 0.4618
#
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-10-26 18:32:09.931700: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 18:32:09.931725: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [12:56<00:00,  1.99s/it, loss=0.374]
# 100%|███████████████████████████████████████████| 98/98 [01:37<00:00,  1.00it/s]
# epoch 1: trn_loss = 0.3739, val_loss = 0.1063, trn_score = 1.0930, val_score = 0.4626
# model_conventions (best score) saved
# lr :  [3.2897872149827876e-06, 3.2897872149827876e-06, 3.2897872149827876e-05]
# 100%|█████████████████████████████| 391/391 [12:51<00:00,  1.97s/it, loss=0.101]
# 100%|███████████████████████████████████████████| 98/98 [01:37<00:00,  1.00it/s]
# epoch 2: trn_loss = 0.1014, val_loss = 0.1060, trn_score = 0.4518, val_score = 0.4620
# model_conventions (best score) saved
# lr :  [1.9897031875730762e-06, 1.9897031875730762e-06, 1.9897031875730763e-05]
# 100%|███████████████████████████████| 391/391 [12:52<00:00,  1.98s/it, loss=0.1]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.00s/it]
# epoch 3: trn_loss = 0.1000, val_loss = 0.1000, trn_score = 0.4488, val_score = 0.4485
# model_conventions (best score) saved
# lr :  [9.307288210334982e-07, 9.307288210334982e-07, 9.307288210334983e-06]
# 100%|█████████████████████████████| 391/391 [12:53<00:00,  1.98s/it, loss=0.089]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.00s/it]
# epoch 4: trn_loss = 0.0890, val_loss = 0.1008, trn_score = 0.4229, val_score = 0.4504
# lr :  [2.3987468853323964e-07, 2.3987468853323964e-07, 2.398746885332397e-06]
# 100%|████████████████████████████| 391/391 [12:54<00:00,  1.98s/it, loss=0.0837]
# 100%|███████████████████████████████████████████| 98/98 [01:38<00:00,  1.01s/it]
# epoch 5: trn_loss = 0.0837, val_loss = 0.1000, trn_score = 0.4102, val_score = 0.4488

# %% [markdown]
# # OOF

# %%
INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_02/result/'

# %%
for CLASS in [
    'cohesion',
    'syntax','vocabulary','phraseology','grammar','conventions'
]:
    print("*"*50)
    print(CLASS)
    print("*"*50)
    for FOLD in [0,1,2,3,4]:
        print("-"*50)
        print("FOLD = ", FOLD)
        print("-"*50)
        WEIGHT_PATH = f'./result/{VERSION}/model_{CLASS}_seed{SEED}_fold{FOLD}.pth'
        # !python ../$VERSION/validation.py --model $MODEL --version $VERSION \
        --fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS \
        --rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH \
        --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --max_length $MAX_LEN \
        --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS --class_name $CLASS
# Out:
# **************************************************
# cohesion
# **************************************************
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# 2022-10-26 22:53:08.503017: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 22:53:08.503037: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3128, 8)
# val_df.shape =  (783, 8)
# 100%|███████████████████████████████████████████| 98/98 [01:25<00:00,  1.14it/s]
# val_loss=0.1193, val_score=0.4913
# essay_ids.shape =  (783,)
# preds.shape =  (783, 1)
# labels.shape =  (783, 1)
# losses.shape =  (783, 1)
# embeds.shape =  (783, 1024)
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# 2022-10-26 22:55:00.478029: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 22:55:00.478050: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 100%|███████████████████████████████████████████| 98/98 [01:27<00:00,  1.12it/s]
# val_loss=0.1066, val_score=0.4628
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 1024)
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# 2022-10-26 22:56:54.329261: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 22:56:54.329286: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 100%|███████████████████████████████████████████| 98/98 [01:29<00:00,  1.10it/s]
# val_loss=0.1159, val_score=0.4831
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 1024)
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.1
# 2022-10-26 22:58:50.342067: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 22:58:50.342091: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 100%|███████████████████████████████████████████| 98/98 [01:30<00:00,  1.09it/s]
# val_loss=0.1214, val_score=0.4944
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 1024)
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.1
# 2022-10-26 23:00:47.154731: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 23:00:47.154756: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 100%|███████████████████████████████████████████| 98/98 [01:30<00:00,  1.08it/s]
# val_loss=0.1134, val_score=0.4769
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 1024)
# **************************************************
# syntax
# **************************************************
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# 2022-10-26 23:02:44.931928: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 23:02:44.931952: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3128, 8)
# val_df.shape =  (783, 8)
# 100%|███████████████████████████████████████████| 98/98 [01:31<00:00,  1.08it/s]
# val_loss=0.1001, val_score=0.4485
# essay_ids.shape =  (783,)
# preds.shape =  (783, 1)
# labels.shape =  (783, 1)
# losses.shape =  (783, 1)
# embeds.shape =  (783, 1024)
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# 2022-10-26 23:04:42.915269: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 23:04:42.915290: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 100%|███████████████████████████████████████████| 98/98 [01:31<00:00,  1.07it/s]
# val_loss=0.1009, val_score=0.4508
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 1024)
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# 2022-10-26 23:06:40.770870: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 23:06:40.770894: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 100%|███████████████████████████████████████████| 98/98 [01:31<00:00,  1.07it/s]
# val_loss=0.0985, val_score=0.4454
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 1024)
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.1
# 2022-10-26 23:08:39.854744: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 23:08:39.854769: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 100%|███████████████████████████████████████████| 98/98 [01:31<00:00,  1.07it/s]
# val_loss=0.1004, val_score=0.4493
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 1024)
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.1
# 2022-10-26 23:10:38.439890: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 23:10:38.439914: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 100%|███████████████████████████████████████████| 98/98 [01:31<00:00,  1.07it/s]
# val_loss=0.1049, val_score=0.4590
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 1024)
# **************************************************
# vocabulary
# **************************************************
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# 2022-10-26 23:12:36.802105: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 23:12:36.802136: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3128, 8)
# val_df.shape =  (783, 8)
# 100%|███████████████████████████████████████████| 98/98 [01:31<00:00,  1.07it/s]
# val_loss=0.0831, val_score=0.4082
# essay_ids.shape =  (783,)
# preds.shape =  (783, 1)
# labels.shape =  (783, 1)
# losses.shape =  (783, 1)
# embeds.shape =  (783, 1024)
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# 2022-10-26 23:14:36.296462: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 23:14:36.296485: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 100%|███████████████████████████████████████████| 98/98 [01:31<00:00,  1.07it/s]
# val_loss=0.0835, val_score=0.4109
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 1024)
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# 2022-10-26 23:16:34.644142: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 23:16:34.644166: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 100%|███████████████████████████████████████████| 98/98 [01:31<00:00,  1.07it/s]
# val_loss=0.0884, val_score=0.4213
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 1024)
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.1
# 2022-10-26 23:18:33.448159: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 23:18:33.448182: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 100%|███████████████████████████████████████████| 98/98 [01:34<00:00,  1.04it/s]
# val_loss=0.0885, val_score=0.4212
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 1024)
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.1
# 2022-10-26 23:20:34.257996: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 23:20:34.258020: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 100%|███████████████████████████████████████████| 98/98 [01:32<00:00,  1.06it/s]
# val_loss=0.0875, val_score=0.4191
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 1024)
# **************************************************
# phraseology
# **************************************************
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# 2022-10-26 23:22:33.579774: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 23:22:33.579799: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3128, 8)
# val_df.shape =  (783, 8)
# 100%|███████████████████████████████████████████| 98/98 [01:32<00:00,  1.05it/s]
# val_loss=0.1067, val_score=0.4629
# essay_ids.shape =  (783,)
# preds.shape =  (783, 1)
# labels.shape =  (783, 1)
# losses.shape =  (783, 1)
# embeds.shape =  (783, 1024)
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# 2022-10-26 23:24:33.272201: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 23:24:33.272222: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 100%|███████████████████████████████████████████| 98/98 [01:32<00:00,  1.06it/s]
# val_loss=0.1075, val_score=0.4646
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 1024)
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# 2022-10-26 23:26:33.308720: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 23:26:33.308740: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 100%|███████████████████████████████████████████| 98/98 [01:32<00:00,  1.06it/s]
# val_loss=0.0898, val_score=0.4242
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 1024)
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.1
# 2022-10-26 23:28:33.073444: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 23:28:33.073468: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 100%|███████████████████████████████████████████| 98/98 [01:31<00:00,  1.07it/s]
# val_loss=0.1061, val_score=0.4617
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 1024)
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.1
# 2022-10-26 23:30:32.293511: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 23:30:32.293536: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 100%|███████████████████████████████████████████| 98/98 [01:32<00:00,  1.06it/s]
# val_loss=0.1093, val_score=0.4693
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 1024)
# **************************************************
# grammar
# **************************************************
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# 2022-10-26 23:32:32.403386: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 23:32:32.403412: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3128, 8)
# val_df.shape =  (783, 8)
# 100%|███████████████████████████████████████████| 98/98 [01:32<00:00,  1.05it/s]
# val_loss=0.1148, val_score=0.4802
# essay_ids.shape =  (783,)
# preds.shape =  (783, 1)
# labels.shape =  (783, 1)
# losses.shape =  (783, 1)
# embeds.shape =  (783, 1024)
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# 2022-10-26 23:34:32.392390: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 23:34:32.392416: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 100%|███████████████████████████████████████████| 98/98 [01:32<00:00,  1.06it/s]
# val_loss=0.1103, val_score=0.4737
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 1024)
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# 2022-10-26 23:36:31.934273: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 23:36:31.934297: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 100%|███████████████████████████████████████████| 98/98 [01:33<00:00,  1.05it/s]
# val_loss=0.1051, val_score=0.4594
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 1024)
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.1
# 2022-10-26 23:38:31.951990: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 23:38:31.952013: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 100%|███████████████████████████████████████████| 98/98 [01:32<00:00,  1.06it/s]
# val_loss=0.1150, val_score=0.4821
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 1024)
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.1
# 2022-10-26 23:40:30.905895: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 23:40:30.905919: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 100%|███████████████████████████████████████████| 98/98 [01:32<00:00,  1.06it/s]
# val_loss=0.1204, val_score=0.4931
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 1024)
# **************************************************
# conventions
# **************************************************
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# 2022-10-26 23:42:30.604240: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 23:42:30.604265: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3128, 8)
# val_df.shape =  (783, 8)
# 100%|███████████████████████████████████████████| 98/98 [01:32<00:00,  1.06it/s]
# val_loss=0.0964, val_score=0.4396
# essay_ids.shape =  (783,)
# preds.shape =  (783, 1)
# labels.shape =  (783, 1)
# losses.shape =  (783, 1)
# embeds.shape =  (783, 1024)
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# 2022-10-26 23:44:30.376097: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 23:44:30.376121: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 100%|███████████████████████████████████████████| 98/98 [01:32<00:00,  1.06it/s]
# val_loss=0.0998, val_score=0.4485
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 1024)
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# 2022-10-26 23:46:29.751080: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 23:46:29.751103: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 100%|███████████████████████████████████████████| 98/98 [01:32<00:00,  1.06it/s]
# val_loss=0.0991, val_score=0.4469
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 1024)
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.1
# 2022-10-26 23:48:28.797338: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 23:48:28.797364: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 100%|███████████████████████████████████████████| 98/98 [01:32<00:00,  1.06it/s]
# val_loss=0.1039, val_score=0.4571
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 1024)
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.1
# 2022-10-26 23:50:27.970504: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-26 23:50:27.970528: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 100%|███████████████████████████████████████████| 98/98 [01:32<00:00,  1.06it/s]
# val_loss=0.1000, val_score=0.4485
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 1024)

# %%
import pandas as pd
import numpy as np

preds = []
for CLASS in [
    'cohesion',
    'syntax','vocabulary','phraseology','grammar','conventions'
]:
    print("*"*50)
    print(CLASS)
    print("*"*50)
    preds_class = []
    for fold in [0,1,2,3,4]:
        print("-"*50)
        print("FOLD = ", fold)
        print("-"*50)
        tmp_df = pd.read_csv(f'./result/{VERSION}/pred_{CLASS}_fold{fold}.csv')
        embeds = np.load(f'./result/{VERSION}/embeds_{CLASS}_fold{fold}.npz')['arr_0']
        tmp_df[f'embed_{CLASS}'] = embeds.tolist()
        preds_class.append(tmp_df)
    pred_df = pd.concat(preds_class, axis=0).reset_index(drop=True)
    if len(preds)==0:
        preds.append(pred_df)
    else:
        del pred_df["text_id"]
        preds.append(pred_df)
    
all_pred_df = pd.concat(preds, axis=1)

train_df = pd.read_csv('../../input/feedback-prize-english-language-learning/train.csv')
oof_df = train_df[['text_id']].merge(all_pred_df, on='text_id', how='left')
oof_df.to_csv(f'./result/{VERSION}/oof_df.csv', index=False)
# Out:
# **************************************************
# cohesion
# **************************************************
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# **************************************************
# syntax
# **************************************************
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# **************************************************
# vocabulary
# **************************************************
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# **************************************************
# phraseology
# **************************************************
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# **************************************************
# grammar
# **************************************************
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# **************************************************
# conventions
# **************************************************
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------

# %%
oof_df.shape, oof_df.isnull().sum()
# Out:
# ((3911, 19),
#  text_id              0
#  cohesion             0
#  loss_cohesion        0
#  embed_cohesion       0
#  syntax               0
#  loss_syntax          0
#  embed_syntax         0
#  vocabulary           0
#  loss_vocabulary      0
#  embed_vocabulary     0
#  phraseology          0
#  loss_phraseology     0
#  embed_phraseology    0
#  grammar              0
#  loss_grammar         0
#  embed_grammar        0
#  conventions          0
#  loss_conventions     0
#  embed_conventions    0
#  dtype: int64)

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
oof_df[cols].describe()
# Out:
#           cohesion       syntax   vocabulary  phraseology      grammar  \
# count  3911.000000  3911.000000  3911.000000  3911.000000  3911.000000
# mean      3.167238     3.022131     3.260484     3.128700     3.043990
# std       0.468136     0.461429     0.431479     0.506631     0.543291
# min       0.989069     1.168824     1.444239     1.327617     1.294793
# 25%       2.849187     2.705702     2.967839     2.770819     2.639022
# 50%       3.171358     3.024227     3.238596     3.123684     3.017464
# 75%       3.501020     3.343478     3.547031     3.477932     3.401306
# max       4.829308     4.683497     5.345220     4.847304     4.742308
#
#        conventions
# count  3911.000000
# mean      3.092509
# std       0.524720
# min       1.058660
# 25%       2.733027
# 50%       3.095149
# 75%       3.457022
# max       4.764770

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
train_df[cols].describe()
# Out:
#           cohesion       syntax   vocabulary  phraseology      grammar  \
# count  3911.000000  3911.000000  3911.000000  3911.000000  3911.000000
# mean      3.127077     3.028254     3.235745     3.116850     3.032856
# std       0.662542     0.644399     0.583148     0.655997     0.699841
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%       2.500000     2.500000     3.000000     2.500000     2.500000
# 50%       3.000000     3.000000     3.000000     3.000000     3.000000
# 75%       3.500000     3.500000     3.500000     3.500000     3.500000
# max       5.000000     5.000000     5.000000     5.000000     5.000000
#
#        conventions
# count  3911.000000
# mean      3.081053
# std       0.671450
# min       1.000000
# 25%       2.500000
# 50%       3.000000
# 75%       3.500000
# max       5.000000

# %% [markdown]
# # Error Analysis - Check Corr

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
train_df[cols].corr()
# Out:
#              cohesion    syntax  vocabulary  phraseology   grammar  \
# cohesion     1.000000  0.695459    0.666151     0.690058  0.638689
# syntax       0.695459  1.000000    0.680562     0.725467  0.709525
# vocabulary   0.666151  0.680562    1.000000     0.735261  0.654852
# phraseology  0.690058  0.725467    0.735261     1.000000  0.719746
# grammar      0.638689  0.709525    0.654852     0.719746  1.000000
# conventions  0.666151  0.700025    0.664292     0.666842  0.673301
#
#              conventions
# cohesion        0.666151
# syntax          0.700025
# vocabulary      0.664292
# phraseology     0.666842
# grammar         0.673301
# conventions     1.000000

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
oof_df[cols].corr()
# Out:
#              cohesion    syntax  vocabulary  phraseology   grammar  \
# cohesion     1.000000  0.916247    0.875272     0.875868  0.779187
# syntax       0.916247  1.000000    0.915251     0.940020  0.894398
# vocabulary   0.875272  0.915251    1.000000     0.935343  0.851045
# phraseology  0.875868  0.940020    0.935343     1.000000  0.920082
# grammar      0.779187  0.894398    0.851045     0.920082  1.000000
# conventions  0.845486  0.911602    0.863714     0.861325  0.837362
#
#              conventions
# cohesion        0.845486
# syntax          0.911602
# vocabulary      0.863714
# phraseology     0.861325
# grammar         0.837362
# conventions     1.000000
