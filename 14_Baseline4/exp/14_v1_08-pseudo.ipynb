# %%
VERSION = '14_v1_08'
MODEL = 'microsoft/deberta-base'
#'microsoft/deberta-v3-base'
#'bert-large-cased'
#'bert-large-cased-whole-word-masking'
#'albert-large-v2'
#'facebook/bart-large'
#'xlm-roberta-large'
#'deepset/roberta-large-squad2'
#'google/electra-large-discriminator'
#'sentence-transformeres/paraphrase-mpnet-base-v2'
#'funnel-transformer/large-base'
#'facebook/bart-base'
#'distilroberta-base'
#'deepset/roberta-base-squad2'
#'microsoft/deberta-v3-base'
#'roberta-large'
#'roberta-base'
#'microsoft/deberta-v3-large'
LR = 2e-5 #8e-6
HEAD_LR = 2e-4 #2e-5 #8e-6 
SEED = 100
TRN_BS = 8
VAL_BS = 64
ACCUM_STEP = 1
HIDDEN_DROP_PROB = 0
P_DROP = 0
RNN = 'none'
WARMUP_RATIO = 0.1
HEAD = 'simple'
AUG = 'false'
MIXUP_ALPHA = 0
P_AUG = 0
AUG_STOP_EPOCH = 0
MSD = 'false'
POOLING = 'mean' #'weighted_layer'
NUM_POOLING_LAYERS = 4 #1
MULTI_LAYERS = 1
EVAL_STEP_START_EPOCH = -1
EVAL_STEP = -1
NUM_LABELS = 1 #6
NUM_LABELS_2 = -1
FP16 = 'true'
WD = 0.01
FREEZE = 'false'
MULTI_TASK = 'false' 
W_MT = 0 
AWP = 'false'
AWP_LR = 0
AWP_EPS = 0
AWP_START_EPOCH = -1
#PRETRAINED_DETECTOR_PATH = f'../../input/tascj/result/deberta_base_fold0.pth'
PRETRAINED_DETECTOR_PATH = 'none' #f'../../05_Detection/exp/result/05_v2_09/model_seed100_fold0_swa.pth'
MASK_PROB = 0 #0.8
MASK_RATIO = 0 #0.3
SCHEDULER = 'cosine_hard'
CP = 'true' #'false'
WINDOW_SIZE = -1 #512
INNER_LEN = -1 #384
EDGE_LEN = -1 #64
MAX_LEN = 512

GRAD_CLIP = 1

LOSS = 'smoothl1'#'mse'

CROP_PROB = 0 #1.0

# %% [markdown]
# # Pseudo-label

# %%
INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_02/result/'

UNLABELED_DATA_PATH = '../../00_EDA/00_v1_07/result/similar_df.csv'

# %%
for CLASS in [
    'cohesion',
    'syntax','vocabulary','phraseology','grammar','conventions'
]:
    print("*"*50)
    print(CLASS)
    print("*"*50)
    for FOLD in [0,1,2,3,4]:
        print("*"*50)
        print("FOLD = ", FOLD)
        print("*"*50)
        WEIGHT_PATH = f'./result/{VERSION}/model_{CLASS}_seed{SEED}_fold{FOLD}.pth'
        # !python ../$VERSION/pseudo_label.py --model $MODEL --version $VERSION \
        --fold_path $FOLD_PATH --fold $FOLD --seed $SEED --test_batch_size $VAL_BS \
        --rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH \
        --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --max_length $MAX_LEN \
        --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS --class_name $CLASS \
        --unlabeled_data_path $UNLABELED_DATA_PATH
# Out:
# **************************************************
# cohesion
# **************************************************
# **************************************************
# FOLD =  0
# **************************************************
# torch 1.10.1
# 2022-10-28 03:16:42.763364: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-28 03:16:42.763389: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# test_df.shape =  (15142, 2)
# test_df.columns =  Index(['essay_id', 'full_text'], dtype='object')
# 100%|█████████████████████████████████████████| 237/237 [04:32<00:00,  1.15s/it]
# essay_ids.shape =  (15142,)
# preds.shape =  (15142, 1)
# **************************************************
# FOLD =  1
# **************************************************
# torch 1.10.1
# 2022-10-28 03:21:33.192179: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-28 03:21:33.192202: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# test_df.shape =  (15142, 2)
# test_df.columns =  Index(['essay_id', 'full_text'], dtype='object')
# 100%|█████████████████████████████████████████| 237/237 [04:40<00:00,  1.18s/it]
# essay_ids.shape =  (15142,)
# preds.shape =  (15142, 1)
# **************************************************
# FOLD =  2
# **************************************************
# torch 1.10.1
# 2022-10-28 03:26:32.101847: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-28 03:26:32.101871: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# test_df.shape =  (15142, 2)
# test_df.columns =  Index(['essay_id', 'full_text'], dtype='object')
# 100%|█████████████████████████████████████████| 237/237 [04:42<00:00,  1.19s/it]
# essay_ids.shape =  (15142,)
# preds.shape =  (15142, 1)
# **************************************************
# FOLD =  3
# **************************************************
# torch 1.10.1
# 2022-10-28 03:31:33.393624: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-28 03:31:33.393649: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# test_df.shape =  (15142, 2)
# test_df.columns =  Index(['essay_id', 'full_text'], dtype='object')
# 100%|█████████████████████████████████████████| 237/237 [04:43<00:00,  1.19s/it]
# essay_ids.shape =  (15142,)
# preds.shape =  (15142, 1)
# **************************************************
# FOLD =  4
# **************************************************
# torch 1.10.1
# 2022-10-28 03:36:35.420709: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-28 03:36:35.420732: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# test_df.shape =  (15142, 2)
# test_df.columns =  Index(['essay_id', 'full_text'], dtype='object')
# 100%|█████████████████████████████████████████| 237/237 [04:43<00:00,  1.20s/it]
# essay_ids.shape =  (15142,)
# preds.shape =  (15142, 1)
# **************************************************
# syntax
# **************************************************
# **************************************************
# FOLD =  0
# **************************************************
# torch 1.10.1
# 2022-10-28 03:41:37.176768: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-28 03:41:37.176791: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# test_df.shape =  (15142, 2)
# test_df.columns =  Index(['essay_id', 'full_text'], dtype='object')
# 100%|█████████████████████████████████████████| 237/237 [04:44<00:00,  1.20s/it]
# essay_ids.shape =  (15142,)
# preds.shape =  (15142, 1)
# **************************************************
# FOLD =  1
# **************************************************
# torch 1.10.1
# 2022-10-28 03:46:39.788123: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-28 03:46:39.788146: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# test_df.shape =  (15142, 2)
# test_df.columns =  Index(['essay_id', 'full_text'], dtype='object')
# 100%|█████████████████████████████████████████| 237/237 [04:44<00:00,  1.20s/it]
# essay_ids.shape =  (15142,)
# preds.shape =  (15142, 1)
# **************************************************
# FOLD =  2
# **************************************************
# torch 1.10.1
# 2022-10-28 03:51:42.472115: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-28 03:51:42.472136: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# test_df.shape =  (15142, 2)
# test_df.columns =  Index(['essay_id', 'full_text'], dtype='object')
# 100%|█████████████████████████████████████████| 237/237 [04:44<00:00,  1.20s/it]
# essay_ids.shape =  (15142,)
# preds.shape =  (15142, 1)
# **************************************************
# FOLD =  3
# **************************************************
# torch 1.10.1
# 2022-10-28 03:56:45.483599: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-28 03:56:45.483620: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# test_df.shape =  (15142, 2)
# test_df.columns =  Index(['essay_id', 'full_text'], dtype='object')
# 100%|█████████████████████████████████████████| 237/237 [04:43<00:00,  1.20s/it]
# essay_ids.shape =  (15142,)
# preds.shape =  (15142, 1)
# **************************************************
# FOLD =  4
# **************************************************
# torch 1.10.1
# 2022-10-28 04:01:47.743348: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-28 04:01:47.743374: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# test_df.shape =  (15142, 2)
# test_df.columns =  Index(['essay_id', 'full_text'], dtype='object')
# 100%|█████████████████████████████████████████| 237/237 [04:44<00:00,  1.20s/it]
# essay_ids.shape =  (15142,)
# preds.shape =  (15142, 1)
# **************************************************
# vocabulary
# **************************************************
# **************************************************
# FOLD =  0
# **************************************************
# torch 1.10.1
# 2022-10-28 04:06:50.450337: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-28 04:06:50.450360: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# test_df.shape =  (15142, 2)
# test_df.columns =  Index(['essay_id', 'full_text'], dtype='object')
# 100%|█████████████████████████████████████████| 237/237 [04:39<00:00,  1.18s/it]
# essay_ids.shape =  (15142,)
# preds.shape =  (15142, 1)
# **************************************************
# FOLD =  1
# **************************************************
# torch 1.10.1
# 2022-10-28 04:11:48.256825: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-28 04:11:48.256848: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# test_df.shape =  (15142, 2)
# test_df.columns =  Index(['essay_id', 'full_text'], dtype='object')
# 100%|█████████████████████████████████████████| 237/237 [04:38<00:00,  1.18s/it]
# essay_ids.shape =  (15142,)
# preds.shape =  (15142, 1)
# **************************************************
# FOLD =  2
# **************************************************
# torch 1.10.1
# 2022-10-28 04:16:45.663976: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-28 04:16:45.663999: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# test_df.shape =  (15142, 2)
# test_df.columns =  Index(['essay_id', 'full_text'], dtype='object')
# 100%|█████████████████████████████████████████| 237/237 [04:39<00:00,  1.18s/it]
# essay_ids.shape =  (15142,)
# preds.shape =  (15142, 1)
# **************************************************
# FOLD =  3
# **************************************************
# torch 1.10.1
# 2022-10-28 04:21:43.918048: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-28 04:21:43.918071: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# test_df.shape =  (15142, 2)
# test_df.columns =  Index(['essay_id', 'full_text'], dtype='object')
# 100%|█████████████████████████████████████████| 237/237 [04:39<00:00,  1.18s/it]
# essay_ids.shape =  (15142,)
# preds.shape =  (15142, 1)
# **************************************************
# FOLD =  4
# **************************************************
# torch 1.10.1
# 2022-10-28 04:26:41.929889: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-28 04:26:41.929913: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# test_df.shape =  (15142, 2)
# test_df.columns =  Index(['essay_id', 'full_text'], dtype='object')
# 100%|█████████████████████████████████████████| 237/237 [04:39<00:00,  1.18s/it]
# essay_ids.shape =  (15142,)
# preds.shape =  (15142, 1)
# **************************************************
# phraseology
# **************************************************
# **************************************************
# FOLD =  0
# **************************************************
# torch 1.10.1
# 2022-10-28 04:31:39.948630: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-28 04:31:39.948656: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# test_df.shape =  (15142, 2)
# test_df.columns =  Index(['essay_id', 'full_text'], dtype='object')
# 100%|█████████████████████████████████████████| 237/237 [04:39<00:00,  1.18s/it]
# essay_ids.shape =  (15142,)
# preds.shape =  (15142, 1)
# **************************************************
# FOLD =  1
# **************************************************
# torch 1.10.1
# 2022-10-28 04:36:38.128402: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-28 04:36:38.128426: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# test_df.shape =  (15142, 2)
# test_df.columns =  Index(['essay_id', 'full_text'], dtype='object')
# 100%|█████████████████████████████████████████| 237/237 [04:39<00:00,  1.18s/it]
# essay_ids.shape =  (15142,)
# preds.shape =  (15142, 1)
# **************************************************
# FOLD =  2
# **************************************************
# torch 1.10.1
# 2022-10-28 04:41:36.609441: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-28 04:41:36.609465: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# test_df.shape =  (15142, 2)
# test_df.columns =  Index(['essay_id', 'full_text'], dtype='object')
# 100%|█████████████████████████████████████████| 237/237 [04:39<00:00,  1.18s/it]
# essay_ids.shape =  (15142,)
# preds.shape =  (15142, 1)
# **************************************************
# FOLD =  3
# **************************************************
# torch 1.10.1
# 2022-10-28 04:46:35.057958: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-28 04:46:35.057984: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# test_df.shape =  (15142, 2)
# test_df.columns =  Index(['essay_id', 'full_text'], dtype='object')
# 100%|█████████████████████████████████████████| 237/237 [04:38<00:00,  1.18s/it]
# essay_ids.shape =  (15142,)
# preds.shape =  (15142, 1)
# **************************************************
# FOLD =  4
# **************************************************
# torch 1.10.1
# 2022-10-28 04:51:32.232965: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-28 04:51:32.232990: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# test_df.shape =  (15142, 2)
# test_df.columns =  Index(['essay_id', 'full_text'], dtype='object')
# 100%|█████████████████████████████████████████| 237/237 [04:39<00:00,  1.18s/it]
# essay_ids.shape =  (15142,)
# preds.shape =  (15142, 1)
# **************************************************
# grammar
# **************************************************
# **************************************************
# FOLD =  0
# **************************************************
# torch 1.10.1
# 2022-10-28 04:56:30.478553: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-28 04:56:30.478579: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# test_df.shape =  (15142, 2)
# test_df.columns =  Index(['essay_id', 'full_text'], dtype='object')
# 100%|█████████████████████████████████████████| 237/237 [04:39<00:00,  1.18s/it]
# essay_ids.shape =  (15142,)
# preds.shape =  (15142, 1)
# **************************************************
# FOLD =  1
# **************************************************
# torch 1.10.1
# 2022-10-28 05:01:28.221324: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-28 05:01:28.221345: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# test_df.shape =  (15142, 2)
# test_df.columns =  Index(['essay_id', 'full_text'], dtype='object')
# 100%|█████████████████████████████████████████| 237/237 [04:39<00:00,  1.18s/it]
# essay_ids.shape =  (15142,)
# preds.shape =  (15142, 1)
# **************************************************
# FOLD =  2
# **************************************************
# torch 1.10.1
# 2022-10-28 05:06:26.207257: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-28 05:06:26.207281: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# test_df.shape =  (15142, 2)
# test_df.columns =  Index(['essay_id', 'full_text'], dtype='object')
# 100%|█████████████████████████████████████████| 237/237 [04:39<00:00,  1.18s/it]
# essay_ids.shape =  (15142,)
# preds.shape =  (15142, 1)
# **************************************************
# FOLD =  3
# **************************************************
# torch 1.10.1
# 2022-10-28 05:11:24.403464: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-28 05:11:24.403488: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# test_df.shape =  (15142, 2)
# test_df.columns =  Index(['essay_id', 'full_text'], dtype='object')
# 100%|█████████████████████████████████████████| 237/237 [04:39<00:00,  1.18s/it]
# essay_ids.shape =  (15142,)
# preds.shape =  (15142, 1)
# **************************************************
# FOLD =  4
# **************************************************
# torch 1.10.1
# 2022-10-28 05:16:22.861624: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-28 05:16:22.861648: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# test_df.shape =  (15142, 2)
# test_df.columns =  Index(['essay_id', 'full_text'], dtype='object')
# 100%|█████████████████████████████████████████| 237/237 [04:38<00:00,  1.18s/it]
# essay_ids.shape =  (15142,)
# preds.shape =  (15142, 1)
# **************************************************
# conventions
# **************************************************
# **************************************************
# FOLD =  0
# **************************************************
# torch 1.10.1
# 2022-10-28 05:21:59.657385: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-28 05:21:59.657410: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# test_df.shape =  (15142, 2)
# test_df.columns =  Index(['essay_id', 'full_text'], dtype='object')
# 100%|█████████████████████████████████████████| 237/237 [04:39<00:00,  1.18s/it]
# essay_ids.shape =  (15142,)
# preds.shape =  (15142, 1)
# **************************************************
# FOLD =  1
# **************************************************
# torch 1.10.1
# 2022-10-28 05:26:57.741949: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-28 05:26:57.741973: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# test_df.shape =  (15142, 2)
# test_df.columns =  Index(['essay_id', 'full_text'], dtype='object')
# 100%|█████████████████████████████████████████| 237/237 [04:38<00:00,  1.18s/it]
# essay_ids.shape =  (15142,)
# preds.shape =  (15142, 1)
# **************************************************
# FOLD =  2
# **************************************************
# torch 1.10.1
# 2022-10-28 05:31:55.683569: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-28 05:31:55.683589: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# test_df.shape =  (15142, 2)
# test_df.columns =  Index(['essay_id', 'full_text'], dtype='object')
# 100%|█████████████████████████████████████████| 237/237 [04:39<00:00,  1.18s/it]
# essay_ids.shape =  (15142,)
# preds.shape =  (15142, 1)
# **************************************************
# FOLD =  3
# **************************************************
# torch 1.10.1
# 2022-10-28 05:36:53.649352: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-28 05:36:53.649378: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# test_df.shape =  (15142, 2)
# test_df.columns =  Index(['essay_id', 'full_text'], dtype='object')
# 100%|█████████████████████████████████████████| 237/237 [04:39<00:00,  1.18s/it]
# essay_ids.shape =  (15142,)
# preds.shape =  (15142, 1)
# **************************************************
# FOLD =  4
# **************************************************
# torch 1.10.1
# 2022-10-28 05:41:51.907210: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-28 05:41:51.907234: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# test_df.shape =  (15142, 2)
# test_df.columns =  Index(['essay_id', 'full_text'], dtype='object')
# 100%|█████████████████████████████████████████| 237/237 [04:39<00:00,  1.18s/it]
# essay_ids.shape =  (15142,)
# preds.shape =  (15142, 1)

# %% [markdown]
# # Combine

# %%
import pandas as pd
import numpy as np

for fold in [0,1,2,3,4]:
    print("*"*50)
    print("FOLD = ", fold)
    print("*"*50)
    pred_df = None
    for CLASS in [
        'cohesion',
        'syntax','vocabulary','phraseology','grammar','conventions'
    ]:
        print("*"*50)
        print(CLASS)
        print("*"*50)
        tmp_df = pd.read_csv(f'./result/{VERSION}/pseudo_{CLASS}_fold{fold}.csv')
        if pred_df is None:
            pred_df = tmp_df.copy()
        else:
            pred_df = pred_df.merge(tmp_df, on="text_id", how="left")

    test_df = pd.read_csv(UNLABELED_DATA_PATH)
    test_df = test_df.rename(columns={'id':'text_id'})
    pseudo_df = test_df[['text_id']].merge(pred_df, on='text_id', how='left')
    pseudo_df.to_csv(f'./result/{VERSION}/pseudo_fold{fold}.csv', index=False)
# Out:
# **************************************************
# FOLD =  0
# **************************************************
# **************************************************
# cohesion
# **************************************************
# **************************************************
# syntax
# **************************************************
# **************************************************
# vocabulary
# **************************************************
# **************************************************
# phraseology
# **************************************************
# **************************************************
# grammar
# **************************************************
# **************************************************
# conventions
# **************************************************
# **************************************************
# FOLD =  1
# **************************************************
# **************************************************
# cohesion
# **************************************************
# **************************************************
# syntax
# **************************************************
# **************************************************
# vocabulary
# **************************************************
# **************************************************
# phraseology
# **************************************************
# **************************************************
# grammar
# **************************************************
# **************************************************
# conventions
# **************************************************
# **************************************************
# FOLD =  2
# **************************************************
# **************************************************
# cohesion
# **************************************************
# **************************************************
# syntax
# **************************************************
# **************************************************
# vocabulary
# **************************************************
# **************************************************
# phraseology
# **************************************************
# **************************************************
# grammar
# **************************************************
# **************************************************
# conventions
# **************************************************
# **************************************************
# FOLD =  3
# **************************************************
# **************************************************
# cohesion
# **************************************************
# **************************************************
# syntax
# **************************************************
# **************************************************
# vocabulary
# **************************************************
# **************************************************
# phraseology
# **************************************************
# **************************************************
# grammar
# **************************************************
# **************************************************
# conventions
# **************************************************
# **************************************************
# FOLD =  4
# **************************************************
# **************************************************
# cohesion
# **************************************************
# **************************************************
# syntax
# **************************************************
# **************************************************
# vocabulary
# **************************************************
# **************************************************
# phraseology
# **************************************************
# **************************************************
# grammar
# **************************************************
# **************************************************
# conventions
# **************************************************

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
pseudo_df[cols].describe()
# Out:
#            cohesion        syntax    vocabulary   phraseology       grammar  \
# count  15142.000000  15142.000000  15142.000000  15142.000000  15142.000000
# mean       3.503833      3.609053      3.704262      3.641452      3.736258
# std        0.502874      0.536437      0.423043      0.489295      0.515944
# min        1.681339      1.797385      2.194714      1.924113      1.703181
# 25%        3.153006      3.230907      3.410617      3.295862      3.407707
# 50%        3.497515      3.613680      3.697776      3.631203      3.791690
# 75%        3.861632      4.001262      3.995134      3.985779      4.116226
# max        4.941718      5.098206      5.109589      5.168823      4.991330
#
#         conventions
# count  15142.000000
# mean       3.500995
# std        0.601285
# min        1.518972
# 25%        3.084044
# 50%        3.513544
# 75%        3.927529
# max        5.246330

# %% [markdown]
# # Error Analysis - Check Corr

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
pseudo_df[cols].corr()
# Out:
#              cohesion    syntax  vocabulary  phraseology   grammar  \
# cohesion     1.000000  0.949172    0.928930     0.946686  0.883114
# syntax       0.949172  1.000000    0.916930     0.951177  0.903397
# vocabulary   0.928930  0.916930    1.000000     0.971192  0.902706
# phraseology  0.946686  0.951177    0.971192     1.000000  0.917937
# grammar      0.883114  0.903397    0.902706     0.917937  1.000000
# conventions  0.920870  0.908087    0.920096     0.904939  0.892998
#
#              conventions
# cohesion        0.920870
# syntax          0.908087
# vocabulary      0.920096
# phraseology     0.904939
# grammar         0.892998
# conventions     1.000000
