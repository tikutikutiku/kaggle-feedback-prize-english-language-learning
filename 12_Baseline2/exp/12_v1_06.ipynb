# %%
VERSION = '12_v1_06'
MODEL = 'microsoft/deberta-v3-base'
#'bert-large-cased'
#'bert-large-cased-whole-word-masking'
#'albert-large-v2'
#'facebook/bart-large'
#'xlm-roberta-large'
#'deepset/roberta-large-squad2'
#'google/electra-large-discriminator'
#'sentence-transformeres/paraphrase-mpnet-base-v2'
#'funnel-transformer/large-base'
#'facebook/bart-base'
#'distilroberta-base'
#'deepset/roberta-base-squad2'
#'microsoft/deberta-v3-base'
#'roberta-large'
#'roberta-base'
#'microsoft/deberta-v3-large'
#'microsoft/deberta-base'
LR = 2e-5 #8e-6
HEAD_LR = 2e-4 #2e-5 #8e-6 
SEED = 42 #2022 #100
TRN_BS = 8
VAL_BS = 8
ACCUM_STEP = 1
HIDDEN_DROP_PROB = 0
P_DROP = 0
RNN = 'none'
WARMUP_RATIO = 0.1
HEAD = 'simple'
AUG = 'false'
MIXUP_ALPHA = 0
P_AUG = 0
AUG_STOP_EPOCH = 0
MSD = 'false'
MULTI_LAYERS = 1
EVAL_STEP_START_EPOCH = -1
EVAL_STEP = -1
NUM_LABELS = 6
NUM_LABELS_2 = -1
FP16 = 'true'
WD = 0.01
FREEZE = 'false'
MULTI_TASK = 'false' 
W_MT = 0 
AWP = 'false'
AWP_LR = 0
AWP_EPS = 0
AWP_START_EPOCH = -1
#PRETRAINED_DETECTOR_PATH = f'../../input/tascj/result/deberta_base_fold0.pth'
PRETRAINED_DETECTOR_PATH = 'none' #f'../../05_Detection/exp/result/05_v2_09/model_seed100_fold0_swa.pth'
MASK_PROB = 0 #0.8
MASK_RATIO = 0 #0.3
SCHEDULER = 'cosine_hard'
CP = 'true' #'false'
WINDOW_SIZE = -1 #512
INNER_LEN = -1 #384
EDGE_LEN = -1 #64
MAX_LEN = 512

GRAD_CLIP = 1

LOSS = 'smoothl1'#'mse'

CROP_PROB = 0 #1.0

# %%
for FOLD in [0,1,2,3,4]:
    INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
    FOLD_PATH = '../../00_EDA/00_v1_10/result/'
    MODE = 'train'
    EPOCHS = 5
    STOP_EPOCH = 5
    RESTART = 1
    NUM_CYCLES = EPOCHS
    PRETRAIN_PATH = 'none' #f'result/{VERSION}/model_seed{SEED}_fold{FOLD}_epoch{EPOCHS}_pseudo.pth'

    # !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
    --lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
    --epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
    --accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
    --mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
    --msd $MSD --multi_layers $MULTI_LAYERS \
    --eval_step_start_epoch $EVAL_STEP_START_EPOCH --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
    --num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
    --restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
    --mt $MULTI_TASK --w_mt $W_MT \
    --awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
    --pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
    --scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
    --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN \
    --gradient_clip_val $GRAD_CLIP \
    --input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN \
    --crop_prob $CROP_PROB
# Out:
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-10-11 08:25:43.170407: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-11 08:25:43.170428: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [02:22<00:00,  2.74it/s, loss=0.456]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.37it/s]
# epoch 1: trn_loss = 0.4562, val_loss = 0.1156, trn_score = 1.2170, val_score = 0.4812
# model (best score) saved
# lr :  [8.224468037456969e-06, 8.224468037456969e-06, 8.224468037456969e-05]
# 100%|█████████████████████████████| 391/391 [02:25<00:00,  2.69it/s, loss=0.111]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.34it/s]
# epoch 2: trn_loss = 0.1108, val_loss = 0.1187, trn_score = 0.4719, val_score = 0.4876
# lr :  [4.974257968932691e-06, 4.974257968932691e-06, 4.974257968932691e-05]
# 100%|█████████████████████████████| 391/391 [02:26<00:00,  2.66it/s, loss=0.102]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.31it/s]
# epoch 3: trn_loss = 0.1022, val_loss = 0.1072, trn_score = 0.4527, val_score = 0.4633
# model (best score) saved
# lr :  [2.3268220525837457e-06, 2.3268220525837457e-06, 2.3268220525837457e-05]
# 100%|████████████████████████████| 391/391 [02:26<00:00,  2.67it/s, loss=0.0983]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.30it/s]
# epoch 4: trn_loss = 0.0983, val_loss = 0.1018, trn_score = 0.4439, val_score = 0.4514
# model (best score) saved
# lr :  [5.996867213330993e-07, 5.996867213330993e-07, 5.996867213330992e-06]
# 100%|████████████████████████████| 391/391 [02:26<00:00,  2.67it/s, loss=0.0945]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.28it/s]
# epoch 5: trn_loss = 0.0945, val_loss = 0.1030, trn_score = 0.4350, val_score = 0.4540
#
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3128, 8)
# val_df.shape =  (783, 8)
# 2022-10-11 08:40:04.574056: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-11 08:40:04.574077: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [02:26<00:00,  2.67it/s, loss=0.482]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.28it/s]
# epoch 1: trn_loss = 0.4817, val_loss = 0.1079, trn_score = 1.2676, val_score = 0.4652
# model (best score) saved
# lr :  [8.224468037456969e-06, 8.224468037456969e-06, 8.224468037456969e-05]
# 100%|█████████████████████████████| 391/391 [02:27<00:00,  2.65it/s, loss=0.107]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.36it/s]
# epoch 2: trn_loss = 0.1065, val_loss = 0.1085, trn_score = 0.4623, val_score = 0.4669
# lr :  [4.974257968932691e-06, 4.974257968932691e-06, 4.974257968932691e-05]
# 100%|█████████████████████████████| 391/391 [02:25<00:00,  2.68it/s, loss=0.101]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.34it/s]
# epoch 3: trn_loss = 0.1012, val_loss = 0.1062, trn_score = 0.4506, val_score = 0.4619
# model (best score) saved
# lr :  [2.3268220525837457e-06, 2.3268220525837457e-06, 2.3268220525837457e-05]
# 100%|█████████████████████████████| 391/391 [02:25<00:00,  2.68it/s, loss=0.098]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.34it/s]
# epoch 4: trn_loss = 0.0980, val_loss = 0.1059, trn_score = 0.4435, val_score = 0.4613
# model (best score) saved
# lr :  [5.996867213330993e-07, 5.996867213330993e-07, 5.996867213330992e-06]
# 100%|████████████████████████████| 391/391 [02:25<00:00,  2.68it/s, loss=0.0923]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.35it/s]
# epoch 5: trn_loss = 0.0923, val_loss = 0.1042, trn_score = 0.4298, val_score = 0.4573
# model (best score) saved
#
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-10-11 08:54:29.147391: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-11 08:54:29.147414: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [02:27<00:00,  2.66it/s, loss=0.504]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.30it/s]
# epoch 1: trn_loss = 0.5045, val_loss = 0.1111, trn_score = 1.2584, val_score = 0.4724
# model (best score) saved
# lr :  [8.224468037456969e-06, 8.224468037456969e-06, 8.224468037456969e-05]
# 100%|█████████████████████████████| 391/391 [02:27<00:00,  2.65it/s, loss=0.105]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.37it/s]
# epoch 2: trn_loss = 0.1050, val_loss = 0.1087, trn_score = 0.4591, val_score = 0.4672
# model (best score) saved
# lr :  [4.974257968932691e-06, 4.974257968932691e-06, 4.974257968932691e-05]
# 100%|███████████████████████████████| 391/391 [02:26<00:00,  2.67it/s, loss=0.1]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.34it/s]
# epoch 3: trn_loss = 0.1000, val_loss = 0.1108, trn_score = 0.4478, val_score = 0.4719
# lr :  [2.3268220525837457e-06, 2.3268220525837457e-06, 2.3268220525837457e-05]
# 100%|████████████████████████████| 391/391 [02:26<00:00,  2.67it/s, loss=0.0963]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.35it/s]
# epoch 4: trn_loss = 0.0963, val_loss = 0.1068, trn_score = 0.4393, val_score = 0.4631
# model (best score) saved
# lr :  [5.996867213330993e-07, 5.996867213330993e-07, 5.996867213330992e-06]
# 100%|████████████████████████████| 391/391 [02:26<00:00,  2.68it/s, loss=0.0911]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.34it/s]
# epoch 5: trn_loss = 0.0911, val_loss = 0.1061, trn_score = 0.4273, val_score = 0.4617
# model (best score) saved
#
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-10-11 09:08:56.353473: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-11 09:08:56.353496: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [02:27<00:00,  2.66it/s, loss=0.412]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.30it/s]
# epoch 1: trn_loss = 0.4122, val_loss = 0.1069, trn_score = 1.1244, val_score = 0.4627
# model (best score) saved
# lr :  [8.224468037456969e-06, 8.224468037456969e-06, 8.224468037456969e-05]
# 100%|█████████████████████████████| 391/391 [02:28<00:00,  2.64it/s, loss=0.107]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.30it/s]
# epoch 2: trn_loss = 0.1068, val_loss = 0.1093, trn_score = 0.4634, val_score = 0.4683
# lr :  [4.974257968932691e-06, 4.974257968932691e-06, 4.974257968932691e-05]
# 100%|█████████████████████████████| 391/391 [02:26<00:00,  2.67it/s, loss=0.104]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.38it/s]
# epoch 3: trn_loss = 0.1042, val_loss = 0.1068, trn_score = 0.4576, val_score = 0.4629
# lr :  [2.3268220525837457e-06, 2.3268220525837457e-06, 2.3268220525837457e-05]
# 100%|████████████████████████████| 391/391 [02:26<00:00,  2.68it/s, loss=0.0976]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.33it/s]
# epoch 4: trn_loss = 0.0976, val_loss = 0.1039, trn_score = 0.4422, val_score = 0.4561
# model (best score) saved
# lr :  [5.996867213330993e-07, 5.996867213330993e-07, 5.996867213330992e-06]
# 100%|████████████████████████████| 391/391 [02:26<00:00,  2.67it/s, loss=0.0905]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.39it/s]
# epoch 5: trn_loss = 0.0905, val_loss = 0.1029, trn_score = 0.4258, val_score = 0.4542
# model (best score) saved
#
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-10-11 09:23:23.117754: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-11 09:23:23.117778: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [02:26<00:00,  2.66it/s, loss=0.522]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.37it/s]
# epoch 1: trn_loss = 0.5217, val_loss = 0.1114, trn_score = 1.3154, val_score = 0.4733
# model (best score) saved
# lr :  [8.224468037456969e-06, 8.224468037456969e-06, 8.224468037456969e-05]
# 100%|█████████████████████████████| 391/391 [02:26<00:00,  2.68it/s, loss=0.108]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.39it/s]
# epoch 2: trn_loss = 0.1084, val_loss = 0.1061, trn_score = 0.4666, val_score = 0.4618
# model (best score) saved
# lr :  [4.974257968932691e-06, 4.974257968932691e-06, 4.974257968932691e-05]
# 100%|█████████████████████████████| 391/391 [02:25<00:00,  2.68it/s, loss=0.106]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.37it/s]
# epoch 3: trn_loss = 0.1057, val_loss = 0.1024, trn_score = 0.4606, val_score = 0.4534
# model (best score) saved
# lr :  [2.3268220525837457e-06, 2.3268220525837457e-06, 2.3268220525837457e-05]
# 100%|████████████████████████████| 391/391 [02:25<00:00,  2.69it/s, loss=0.0995]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.39it/s]
# epoch 4: trn_loss = 0.0995, val_loss = 0.1025, trn_score = 0.4468, val_score = 0.4538
# lr :  [5.996867213330993e-07, 5.996867213330993e-07, 5.996867213330992e-06]
# 100%|████████████████████████████| 391/391 [02:25<00:00,  2.69it/s, loss=0.0951]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.40it/s]
# epoch 5: trn_loss = 0.0951, val_loss = 0.1015, trn_score = 0.4366, val_score = 0.4515
# model (best score) saved

# %% [markdown]
# # OOF

# %%
INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_10/result/'
WEIGHT_PATH = f'./result/{VERSION}/model_seed{SEED}_fold{FOLD}.pth'

# %%
for FOLD in [0,1,2,3,4]:
    WEIGHT_PATH = f'./result/{VERSION}/model_seed{SEED}_fold{FOLD}.pth'
    # !python ../$VERSION/validation.py --model $MODEL --version $VERSION \
    --fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS \
    --rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH \
    --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --max_length $MAX_LEN
# Out:
# torch 1.10.1
# 2022-10-11 09:37:44.603501: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-11 09:37:44.603525: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 100%|███████████████████████████████████████████| 98/98 [00:16<00:00,  6.09it/s]
# val_loss=0.1018, val_score=0.4514
# essay_ids.shape =  (782,)
# preds.shape =  (782, 6)
# labels.shape =  (782, 6)
# losses.shape =  (782, 6)
# embeds.shape =  (782, 768)
# torch 1.10.1
# 2022-10-11 09:38:17.488879: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-11 09:38:17.488900: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3128, 8)
# val_df.shape =  (783, 8)
# 100%|███████████████████████████████████████████| 98/98 [00:16<00:00,  6.08it/s]
# val_loss=0.1042, val_score=0.4573
# essay_ids.shape =  (783,)
# preds.shape =  (783, 6)
# labels.shape =  (783, 6)
# losses.shape =  (783, 6)
# embeds.shape =  (783, 768)
# torch 1.10.1
# 2022-10-11 09:38:50.321778: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-11 09:38:50.321800: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 100%|███████████████████████████████████████████| 98/98 [00:16<00:00,  6.09it/s]
# val_loss=0.1061, val_score=0.4617
# essay_ids.shape =  (782,)
# preds.shape =  (782, 6)
# labels.shape =  (782, 6)
# losses.shape =  (782, 6)
# embeds.shape =  (782, 768)
# torch 1.10.1
# 2022-10-11 09:39:23.236137: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-11 09:39:23.236157: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 100%|███████████████████████████████████████████| 98/98 [00:16<00:00,  6.10it/s]
# val_loss=0.1029, val_score=0.4542
# essay_ids.shape =  (782,)
# preds.shape =  (782, 6)
# labels.shape =  (782, 6)
# losses.shape =  (782, 6)
# embeds.shape =  (782, 768)
# torch 1.10.1
# 2022-10-11 09:39:56.008765: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-11 09:39:56.008789: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 100%|███████████████████████████████████████████| 98/98 [00:15<00:00,  6.18it/s]
# val_loss=0.1015, val_score=0.4515
# essay_ids.shape =  (782,)
# preds.shape =  (782, 6)
# labels.shape =  (782, 6)
# losses.shape =  (782, 6)
# embeds.shape =  (782, 768)

# %%
import pandas as pd
import numpy as np

num_fold = 5

preds = []
for fold in range(num_fold):
    tmp_df = pd.read_csv(f'./result/{VERSION}/pred_fold{fold}.csv')
    embeds = np.load(f'./result/{VERSION}/embeds_fold{fold}.npz')['arr_0']
    tmp_df['embed'] = embeds.tolist()
    preds.append(tmp_df)
    
pred_df = pd.concat(preds, axis=0).reset_index(drop=True)
train_df = pd.read_csv('../../input/feedback-prize-english-language-learning/train.csv')

oof_df = train_df[['text_id']].merge(pred_df, on='text_id', how='left')
oof_df.to_csv(f'./result/{VERSION}/oof_df.csv', index=False)

# %%
oof_df.shape, oof_df.isnull().sum()
# Out:
# ((3911, 14),
#  text_id             0
#  cohesion            0
#  syntax              0
#  vocabulary          0
#  phraseology         0
#  grammar             0
#  conventions         0
#  loss_cohesion       0
#  loss_syntax         0
#  loss_vocabulary     0
#  loss_phraseology    0
#  loss_grammar        0
#  loss_conventions    0
#  embed               0
#  dtype: int64)
