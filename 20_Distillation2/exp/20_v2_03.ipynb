# %%
VERSION = '20_v2_03'
MODEL = 'microsoft/deberta-v3-large'
TEACHER_VERSION = '14_v1_10' # deberta-v3-large
#'roberta-base'
#'microsoft/deberta-base'
#'microsoft/deberta-v3-base'
#'bert-large-cased'
#'bert-large-cased-whole-word-masking'
#'albert-large-v2'
#'facebook/bart-large'
#'xlm-roberta-large'
#'deepset/roberta-large-squad2'
#'google/electra-large-discriminator'
#'sentence-transformeres/paraphrase-mpnet-base-v2'
#'funnel-transformer/large-base'
#'facebook/bart-base'
#'distilroberta-base'
#'deepset/roberta-base-squad2'
#'microsoft/deberta-v3-base'
#'roberta-large'
LR = 1e-5 #2e-5 #8e-6
HEAD_LR = 1e-4 #2e-4 #2e-5 #8e-6 
SEED = 100
TRN_BS = 8
VAL_BS = 8
ACCUM_STEP = 1
HIDDEN_DROP_PROB = 0
P_DROP = 0
RNN = 'none'
WARMUP_RATIO = 0.1
HEAD = 'simple'
AUG = 'false'
MIXUP_ALPHA = 0
P_AUG = 0
AUG_STOP_EPOCH = 0
MSD = 'false'
POOLING = 'mean' #'weighted_layer'
NUM_POOLING_LAYERS = 4 #1
MULTI_LAYERS = 1
EVAL_STEP_START_EPOCH = -1
EVAL_STEP = -1
NUM_LABELS = 6
NUM_LABELS_2 = -1
FP16 = 'true'
WD = 0.01
FREEZE = 'true' #'false'
MULTI_TASK = 'false' 
W_MT = 0 
AWP = 'false'
AWP_LR = 0
AWP_EPS = 0
AWP_START_EPOCH = -1
#PRETRAINED_DETECTOR_PATH = f'../../input/tascj/result/deberta_base_fold0.pth'
PRETRAINED_DETECTOR_PATH = 'none' #f'../../05_Detection/exp/result/05_v2_09/model_seed100_fold0_swa.pth'
MASK_PROB = 0 #0.8
MASK_RATIO = 0 #0.3
SCHEDULER = 'cosine_hard'
CP = 'true' #'false'
WINDOW_SIZE = -1 #512
INNER_LEN = -1 #384
EDGE_LEN = -1 #64
MAX_LEN = 512

GRAD_CLIP = 1

LOSS = 'smoothl1'#'mse'

CROP_PROB = 0 #1.0

# %% [markdown]
# # Train with Pseudo-Label

# %%
MODE = 'pseudo'
EPOCHS = 1 #8
STOP_EPOCH = 1 #3
RESTART = 1
NUM_CYCLES = 1
EVAL_STEP = -1
ADD_FB3 = 'true'
FB3_FOLD_PATH = '../../00_EDA/00_v1_02/result/'

for FOLD in [0,1,2,3,4]:
    print("-"*50)
    print("FOLD = ", FOLD)
    print("-"*50)
    #INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
    #FOLD_PATH = '../../00_EDA/00_v1_02/result/'
    #INPUT_PATH = f'../../99_Ensemble/99_v1_03/result/99_v1_03_03_pseudo_fold{FOLD}.csv'
    INPUT_PATH = f'../../99_Ensemble/99_v1_03/result/99_v1_03_03_{TEACHER_VERSION}_pseudo_fold{FOLD}.csv'
    FOLD_PATH = '../../00_EDA/00_v1_08/result/' # for pseudo-label
    PRETRAIN_PATH = 'none'
    # !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
        --lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
        --epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
        --accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
        --mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
        --msd $MSD --multi_layers $MULTI_LAYERS \
        --eval_step_start_epoch $EVAL_STEP_START_EPOCH --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
        --num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
        --restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
        --mt $MULTI_TASK --w_mt $W_MT \
        --awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
        --pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
        --scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
        --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN \
        --gradient_clip_val $GRAD_CLIP \
        --input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN \
        --crop_prob $CROP_PROB --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS \
        --add_fb3 $ADD_FB3 --fb3_fold_path $FB3_FOLD_PATH
# Out:
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.2
# args.mode =  pseudo
# train_df.shape =  (15142, 8)
# load folds...
# trn_df.shape =  (12113, 8)
# val_df.shape =  (3029, 8)
# adding fb3 data...
# trn_df.columns =  Index(['essay_id', 'cohesion', 'syntax', 'vocabulary', 'phraseology',
#        'grammar', 'conventions', 'full_text'],
#       dtype='object')
# fb3_trn_df.columns =  Index(['essay_id', 'full_text', 'cohesion', 'syntax', 'vocabulary',
#        'phraseology', 'grammar', 'conventions'],
#       dtype='object')
# fb3_trn_df.shape =  (3128, 8)
# fb3_trn_df[trn_df.columns].shape =  (3128, 8)
# adding fb3 data, done
# trn_df.shape =  (15241, 8)
# 2022-11-05 14:45:04.903905: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-11-05 14:45:04.903927: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  1905
# num_warmup_steps =  190
# lr :  [0.0, 0.0, 0.0]
# 100%|███████████████████████████| 1905/1905 [22:22<00:00,  1.42it/s, loss=0.128]
# 100%|█████████████████████████████████████████| 379/379 [01:58<00:00,  3.21it/s]
# epoch 1: trn_loss = 0.1281, val_loss = 0.0036, trn_score = 0.6579, val_score = 0.0843
# model (best score) saved
#
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.2
# args.mode =  pseudo
# train_df.shape =  (15142, 8)
# load folds...
# trn_df.shape =  (12113, 8)
# val_df.shape =  (3029, 8)
# adding fb3 data...
# trn_df.columns =  Index(['essay_id', 'cohesion', 'syntax', 'vocabulary', 'phraseology',
#        'grammar', 'conventions', 'full_text'],
#       dtype='object')
# fb3_trn_df.columns =  Index(['essay_id', 'full_text', 'cohesion', 'syntax', 'vocabulary',
#        'phraseology', 'grammar', 'conventions'],
#       dtype='object')
# fb3_trn_df.shape =  (3129, 8)
# fb3_trn_df[trn_df.columns].shape =  (3129, 8)
# adding fb3 data, done
# trn_df.shape =  (15242, 8)
# 2022-11-05 15:09:42.236785: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-11-05 15:09:42.236804: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  1905
# num_warmup_steps =  190
# lr :  [0.0, 0.0, 0.0]
# 100%|███████████████████████████| 1905/1905 [22:22<00:00,  1.42it/s, loss=0.147]
# 100%|█████████████████████████████████████████| 379/379 [01:58<00:00,  3.19it/s]
# epoch 1: trn_loss = 0.1473, val_loss = 0.0034, trn_score = 0.7321, val_score = 0.0826
# model (best score) saved
#
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.2
# args.mode =  pseudo
# train_df.shape =  (15142, 8)
# load folds...
# trn_df.shape =  (12114, 8)
# val_df.shape =  (3028, 8)
# adding fb3 data...
# trn_df.columns =  Index(['essay_id', 'cohesion', 'syntax', 'vocabulary', 'phraseology',
#        'grammar', 'conventions', 'full_text'],
#       dtype='object')
# fb3_trn_df.columns =  Index(['essay_id', 'full_text', 'cohesion', 'syntax', 'vocabulary',
#        'phraseology', 'grammar', 'conventions'],
#       dtype='object')
# fb3_trn_df.shape =  (3129, 8)
# fb3_trn_df[trn_df.columns].shape =  (3129, 8)
# adding fb3 data, done
# trn_df.shape =  (15243, 8)
# 2022-11-05 15:34:20.147313: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-11-05 15:34:20.147336: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  1905
# num_warmup_steps =  190
# lr :  [0.0, 0.0, 0.0]
# 100%|███████████████████████████| 1905/1905 [22:20<00:00,  1.42it/s, loss=0.126]
# 100%|█████████████████████████████████████████| 379/379 [01:56<00:00,  3.24it/s]
# epoch 1: trn_loss = 0.1256, val_loss = 0.0032, trn_score = 0.6486, val_score = 0.0797
# model (best score) saved
#
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.2
# args.mode =  pseudo
# train_df.shape =  (15142, 8)
# load folds...
# trn_df.shape =  (12114, 8)
# val_df.shape =  (3028, 8)
# adding fb3 data...
# trn_df.columns =  Index(['essay_id', 'cohesion', 'syntax', 'vocabulary', 'phraseology',
#        'grammar', 'conventions', 'full_text'],
#       dtype='object')
# fb3_trn_df.columns =  Index(['essay_id', 'full_text', 'cohesion', 'syntax', 'vocabulary',
#        'phraseology', 'grammar', 'conventions'],
#       dtype='object')
# fb3_trn_df.shape =  (3129, 8)
# fb3_trn_df[trn_df.columns].shape =  (3129, 8)
# adding fb3 data, done
# trn_df.shape =  (15243, 8)
# 2022-11-05 15:58:54.199857: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-11-05 15:58:54.199879: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  1905
# num_warmup_steps =  190
# lr :  [0.0, 0.0, 0.0]
# 100%|███████████████████████████| 1905/1905 [22:22<00:00,  1.42it/s, loss=0.123]
# 100%|█████████████████████████████████████████| 379/379 [01:57<00:00,  3.21it/s]
# epoch 1: trn_loss = 0.1225, val_loss = 0.0028, trn_score = 0.6336, val_score = 0.0741
# model (best score) saved
#
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.2
# args.mode =  pseudo
# train_df.shape =  (15142, 8)
# load folds...
# trn_df.shape =  (12114, 8)
# val_df.shape =  (3028, 8)
# adding fb3 data...
# trn_df.columns =  Index(['essay_id', 'cohesion', 'syntax', 'vocabulary', 'phraseology',
#        'grammar', 'conventions', 'full_text'],
#       dtype='object')
# fb3_trn_df.columns =  Index(['essay_id', 'full_text', 'cohesion', 'syntax', 'vocabulary',
#        'phraseology', 'grammar', 'conventions'],
#       dtype='object')
# fb3_trn_df.shape =  (3129, 8)
# fb3_trn_df[trn_df.columns].shape =  (3129, 8)
# adding fb3 data, done
# trn_df.shape =  (15243, 8)
# 2022-11-05 16:23:31.038322: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-11-05 16:23:31.038345: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  1905
# num_warmup_steps =  190
# lr :  [0.0, 0.0, 0.0]
# 100%|████████████████████████████| 1905/1905 [22:20<00:00,  1.42it/s, loss=0.15]
# 100%|█████████████████████████████████████████| 379/379 [01:57<00:00,  3.23it/s]
# epoch 1: trn_loss = 0.1499, val_loss = 0.0032, trn_score = 0.7484, val_score = 0.0794
# model (best score) saved

# %% [markdown]
# # Finetune

# %% [markdown]
# # OOF

# %%
INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_02/result/'

# %%
for FOLD in [0,1,2,3,4]:
    print("-"*50)
    print("FOLD = ", FOLD)
    print("-"*50)
    #WEIGHT_PATH = f'./result/{VERSION}/model_{CLASS}_seed{SEED}_fold{FOLD}.pth'
    #WEIGHT_PATH = f'result/{VERSION}/model_{CLASS}_seed{SEED}_fold{FOLD}_pseudo.pth'
    WEIGHT_PATH = f'result/{VERSION}/model_seed{SEED}_fold{FOLD}_pseudo.pth'
    # !python ../$VERSION/validation.py --model $MODEL --version $VERSION \
        --fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS \
        --rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH \
        --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --max_length $MAX_LEN \
        --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS
# Out:
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.2
# 2022-11-05 16:48:05.377744: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-11-05 16:48:05.377764: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3128, 8)
# val_df.shape =  (783, 8)
# 100%|███████████████████████████████████████████| 98/98 [00:25<00:00,  3.78it/s]
# val_loss=0.1020, val_score=0.4518
# essay_ids.shape =  (783,)
# preds.shape =  (783, 6)
# labels.shape =  (783, 6)
# losses.shape =  (783, 6)
# embeds.shape =  (783, 1024)
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.2
# 2022-11-05 16:48:46.815889: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-11-05 16:48:46.815911: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 100%|███████████████████████████████████████████| 98/98 [00:25<00:00,  3.87it/s]
# val_loss=0.1004, val_score=0.4487
# essay_ids.shape =  (782,)
# preds.shape =  (782, 6)
# labels.shape =  (782, 6)
# losses.shape =  (782, 6)
# embeds.shape =  (782, 1024)
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.2
# 2022-11-05 16:49:27.595314: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-11-05 16:49:27.595335: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 100%|███████████████████████████████████████████| 98/98 [00:26<00:00,  3.71it/s]
# val_loss=0.0989, val_score=0.4451
# essay_ids.shape =  (782,)
# preds.shape =  (782, 6)
# labels.shape =  (782, 6)
# losses.shape =  (782, 6)
# embeds.shape =  (782, 1024)
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.2
# 2022-11-05 16:50:09.472539: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-11-05 16:50:09.472560: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 100%|███████████████████████████████████████████| 98/98 [00:25<00:00,  3.84it/s]
# val_loss=0.1056, val_score=0.4604
# essay_ids.shape =  (782,)
# preds.shape =  (782, 6)
# labels.shape =  (782, 6)
# losses.shape =  (782, 6)
# embeds.shape =  (782, 1024)
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.2
# 2022-11-05 16:50:50.366401: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-11-05 16:50:50.366422: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 100%|███████████████████████████████████████████| 98/98 [00:25<00:00,  3.84it/s]
# val_loss=0.1026, val_score=0.4537
# essay_ids.shape =  (782,)
# preds.shape =  (782, 6)
# labels.shape =  (782, 6)
# losses.shape =  (782, 6)
# embeds.shape =  (782, 1024)

# %%
import pandas as pd
import numpy as np

preds = []
for fold in [0,1,2,3,4]:
    print("-"*50)
    print("FOLD = ", fold)
    print("-"*50)
    pred_df = pd.read_csv(f'./result/{VERSION}/pred_fold{fold}.csv')
    preds.append(pred_df)
    
all_pred_df = pd.concat(preds, axis=0).reset_index(drop=True)

train_df = pd.read_csv('../../input/feedback-prize-english-language-learning/train.csv')
oof_df = train_df[['text_id']].merge(all_pred_df, on='text_id', how='left')
oof_df.to_csv(f'./result/{VERSION}/oof_df.csv', index=False)
# Out:
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------

# %%
oof_df.shape, oof_df.isnull().sum()
# Out:
# ((3911, 13),
#  text_id             0
#  cohesion            0
#  syntax              0
#  vocabulary          0
#  phraseology         0
#  grammar             0
#  conventions         0
#  loss_cohesion       0
#  loss_syntax         0
#  loss_vocabulary     0
#  loss_phraseology    0
#  loss_grammar        0
#  loss_conventions    0
#  dtype: int64)

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
oof_df[cols].describe()
# Out:
#           cohesion       syntax   vocabulary  phraseology      grammar  \
# count  3911.000000  3911.000000  3911.000000  3911.000000  3911.000000
# mean      3.159083     3.048061     3.258188     3.146313     3.050808
# std       0.442610     0.481164     0.419019     0.496098     0.551204
# min       0.756768     0.838747     2.015100     1.358348     1.083651
# 25%       2.856119     2.711177     2.962715     2.797314     2.644068
# 50%       3.172836     3.039834     3.230328     3.145053     3.060281
# 75%       3.460878     3.382238     3.527973     3.487118     3.435523
# max       4.790507     4.811085     5.053530     5.016769     5.017452
#
#        conventions
# count  3911.000000
# mean      3.112891
# std       0.514617
# min       1.290563
# 25%       2.757332
# 50%       3.111747
# 75%       3.467607
# max       4.737938

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
train_df[cols].describe()
# Out:
#           cohesion       syntax   vocabulary  phraseology      grammar  \
# count  3911.000000  3911.000000  3911.000000  3911.000000  3911.000000
# mean      3.127077     3.028254     3.235745     3.116850     3.032856
# std       0.662542     0.644399     0.583148     0.655997     0.699841
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%       2.500000     2.500000     3.000000     2.500000     2.500000
# 50%       3.000000     3.000000     3.000000     3.000000     3.000000
# 75%       3.500000     3.500000     3.500000     3.500000     3.500000
# max       5.000000     5.000000     5.000000     5.000000     5.000000
#
#        conventions
# count  3911.000000
# mean      3.081053
# std       0.671450
# min       1.000000
# 25%       2.500000
# 50%       3.000000
# 75%       3.500000
# max       5.000000

# %% [markdown]
# # Error Analysis - Check Corr

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
train_df[cols].corr()
# Out:
#              cohesion    syntax  vocabulary  phraseology   grammar  \
# cohesion     1.000000  0.695459    0.666151     0.690058  0.638689
# syntax       0.695459  1.000000    0.680562     0.725467  0.709525
# vocabulary   0.666151  0.680562    1.000000     0.735261  0.654852
# phraseology  0.690058  0.725467    0.735261     1.000000  0.719746
# grammar      0.638689  0.709525    0.654852     0.719746  1.000000
# conventions  0.666151  0.700025    0.664292     0.666842  0.673301
#
#              conventions
# cohesion        0.666151
# syntax          0.700025
# vocabulary      0.664292
# phraseology     0.666842
# grammar         0.673301
# conventions     1.000000

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
oof_df[cols].corr()
# Out:
#              cohesion    syntax  vocabulary  phraseology   grammar  \
# cohesion     1.000000  0.957907    0.936444     0.933451  0.852967
# syntax       0.957907  1.000000    0.947241     0.962458  0.926680
# vocabulary   0.936444  0.947241    1.000000     0.967619  0.893099
# phraseology  0.933451  0.962458    0.967619     1.000000  0.950069
# grammar      0.852967  0.926680    0.893099     0.950069  1.000000
# conventions  0.902666  0.937034    0.907388     0.895012  0.876130
#
#              conventions
# cohesion        0.902666
# syntax          0.937034
# vocabulary      0.907388
# phraseology     0.895012
# grammar         0.876130
# conventions     1.000000
