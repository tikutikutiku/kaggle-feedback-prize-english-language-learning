# %%
VERSION = '20_v2_01'
MODEL = 'microsoft/deberta-v3-base'
TEACHER_VERSION = '14_v1_01' # deberta-v3-base
#'bert-large-cased'
#'bert-large-cased-whole-word-masking'
#'albert-large-v2'
#'facebook/bart-large'
#'xlm-roberta-large'
#'deepset/roberta-large-squad2'
#'google/electra-large-discriminator'
#'sentence-transformeres/paraphrase-mpnet-base-v2'
#'funnel-transformer/large-base'
#'facebook/bart-base'
#'distilroberta-base'
#'deepset/roberta-base-squad2'
#'microsoft/deberta-v3-base'
#'roberta-large'
#'roberta-base'
#'microsoft/deberta-v3-large'
#'microsoft/deberta-base'
LR = 2e-5 #8e-6
HEAD_LR = 2e-4 #2e-5 #8e-6 
SEED = 100
TRN_BS = 8
VAL_BS = 8
ACCUM_STEP = 1
HIDDEN_DROP_PROB = 0
P_DROP = 0
RNN = 'none'
WARMUP_RATIO = 0.1
HEAD = 'simple'
AUG = 'false'
MIXUP_ALPHA = 0
P_AUG = 0
AUG_STOP_EPOCH = 0
MSD = 'false'
POOLING = 'mean' #'weighted_layer'
NUM_POOLING_LAYERS = 4 #1
MULTI_LAYERS = 1
EVAL_STEP_START_EPOCH = -1
EVAL_STEP = -1
NUM_LABELS = 6
NUM_LABELS_2 = -1
FP16 = 'true'
WD = 0.01
FREEZE = 'false'
MULTI_TASK = 'false' 
W_MT = 0 
AWP = 'false'
AWP_LR = 0
AWP_EPS = 0
AWP_START_EPOCH = -1
#PRETRAINED_DETECTOR_PATH = f'../../input/tascj/result/deberta_base_fold0.pth'
PRETRAINED_DETECTOR_PATH = 'none' #f'../../05_Detection/exp/result/05_v2_09/model_seed100_fold0_swa.pth'
MASK_PROB = 0 #0.8
MASK_RATIO = 0 #0.3
SCHEDULER = 'cosine_hard'
CP = 'true' #'false'
WINDOW_SIZE = -1 #512
INNER_LEN = -1 #384
EDGE_LEN = -1 #64
MAX_LEN = 512

GRAD_CLIP = 1

LOSS = 'smoothl1'#'mse'

CROP_PROB = 0 #1.0

# %% [markdown]
# # Train with Pseudo-Label

# %%
MODE = 'pseudo'
EPOCHS = 1 #8
STOP_EPOCH = 1 #3
RESTART = 1
NUM_CYCLES = 1
EVAL_STEP = -1
ADD_FB3 = 'true'
FB3_FOLD_PATH = '../../00_EDA/00_v1_02/result/'

for FOLD in [0,1,2,3,4]:
    print("-"*50)
    print("FOLD = ", FOLD)
    print("-"*50)
    #INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
    #FOLD_PATH = '../../00_EDA/00_v1_02/result/'
    #INPUT_PATH = f'../../99_Ensemble/99_v1_03/result/99_v1_03_03_pseudo_fold{FOLD}.csv'
    INPUT_PATH = f'../../99_Ensemble/99_v1_03/result/99_v1_03_03_{TEACHER_VERSION}_pseudo_fold{FOLD}.csv'
    FOLD_PATH = '../../00_EDA/00_v1_08/result/' # for pseudo-label
    PRETRAIN_PATH = 'none'
    # !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
        --lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
        --epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
        --accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
        --mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
        --msd $MSD --multi_layers $MULTI_LAYERS \
        --eval_step_start_epoch $EVAL_STEP_START_EPOCH --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
        --num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
        --restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
        --mt $MULTI_TASK --w_mt $W_MT \
        --awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
        --pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
        --scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
        --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN \
        --gradient_clip_val $GRAD_CLIP \
        --input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN \
        --crop_prob $CROP_PROB --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS \
        --add_fb3 $ADD_FB3 --fb3_fold_path $FB3_FOLD_PATH
# Out:
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.2
# args.mode =  pseudo
# train_df.shape =  (15142, 8)
# load folds...
# trn_df.shape =  (12113, 8)
# val_df.shape =  (3029, 8)
# adding fb3 data...
# trn_df.columns =  Index(['essay_id', 'cohesion', 'syntax', 'vocabulary', 'phraseology',
#        'grammar', 'conventions', 'full_text'],
#       dtype='object')
# fb3_trn_df.columns =  Index(['essay_id', 'full_text', 'cohesion', 'syntax', 'vocabulary',
#        'phraseology', 'grammar', 'conventions'],
#       dtype='object')
# fb3_trn_df.shape =  (3128, 8)
# fb3_trn_df[trn_df.columns].shape =  (3128, 8)
# adding fb3 data, done
# trn_df.shape =  (15241, 8)
# 2022-11-05 12:25:17.486956: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-11-05 12:25:17.486978: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# self.warmup_ratio =  0.1
# self.num_train_steps =  1905
# num_warmup_steps =  190
# lr :  [0.0, 0.0, 0.0]
# 100%|███████████████████████████| 1905/1905 [09:21<00:00,  3.39it/s, loss=0.127]
# 100%|█████████████████████████████████████████| 379/379 [00:57<00:00,  6.56it/s]
# epoch 1: trn_loss = 0.1269, val_loss = 0.0061, trn_score = 0.6493, val_score = 0.1103
# model (best score) saved
#
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.2
# args.mode =  pseudo
# train_df.shape =  (15142, 8)
# load folds...
# trn_df.shape =  (12113, 8)
# val_df.shape =  (3029, 8)
# adding fb3 data...
# trn_df.columns =  Index(['essay_id', 'cohesion', 'syntax', 'vocabulary', 'phraseology',
#        'grammar', 'conventions', 'full_text'],
#       dtype='object')
# fb3_trn_df.columns =  Index(['essay_id', 'full_text', 'cohesion', 'syntax', 'vocabulary',
#        'phraseology', 'grammar', 'conventions'],
#       dtype='object')
# fb3_trn_df.shape =  (3129, 8)
# fb3_trn_df[trn_df.columns].shape =  (3129, 8)
# adding fb3 data, done
# trn_df.shape =  (15242, 8)
# 2022-11-05 12:35:50.841196: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-11-05 12:35:50.841216: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# self.warmup_ratio =  0.1
# self.num_train_steps =  1905
# num_warmup_steps =  190
# lr :  [0.0, 0.0, 0.0]
# 100%|███████████████████████████| 1905/1905 [09:17<00:00,  3.42it/s, loss=0.122]
# 100%|█████████████████████████████████████████| 379/379 [00:56<00:00,  6.66it/s]
# epoch 1: trn_loss = 0.1222, val_loss = 0.0040, trn_score = 0.6325, val_score = 0.0879
# model (best score) saved
#
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.2
# args.mode =  pseudo
# train_df.shape =  (15142, 8)
# load folds...
# trn_df.shape =  (12114, 8)
# val_df.shape =  (3028, 8)
# adding fb3 data...
# trn_df.columns =  Index(['essay_id', 'cohesion', 'syntax', 'vocabulary', 'phraseology',
#        'grammar', 'conventions', 'full_text'],
#       dtype='object')
# fb3_trn_df.columns =  Index(['essay_id', 'full_text', 'cohesion', 'syntax', 'vocabulary',
#        'phraseology', 'grammar', 'conventions'],
#       dtype='object')
# fb3_trn_df.shape =  (3129, 8)
# fb3_trn_df[trn_df.columns].shape =  (3129, 8)
# adding fb3 data, done
# trn_df.shape =  (15243, 8)
# 2022-11-05 12:46:20.358958: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-11-05 12:46:20.358983: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# self.warmup_ratio =  0.1
# self.num_train_steps =  1905
# num_warmup_steps =  190
# lr :  [0.0, 0.0, 0.0]
# 100%|███████████████████████████| 1905/1905 [09:16<00:00,  3.42it/s, loss=0.116]
# 100%|█████████████████████████████████████████| 379/379 [00:57<00:00,  6.60it/s]
# epoch 1: trn_loss = 0.1161, val_loss = 0.0038, trn_score = 0.6122, val_score = 0.0867
# model (best score) saved
#
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.2
# args.mode =  pseudo
# train_df.shape =  (15142, 8)
# load folds...
# trn_df.shape =  (12114, 8)
# val_df.shape =  (3028, 8)
# adding fb3 data...
# trn_df.columns =  Index(['essay_id', 'cohesion', 'syntax', 'vocabulary', 'phraseology',
#        'grammar', 'conventions', 'full_text'],
#       dtype='object')
# fb3_trn_df.columns =  Index(['essay_id', 'full_text', 'cohesion', 'syntax', 'vocabulary',
#        'phraseology', 'grammar', 'conventions'],
#       dtype='object')
# fb3_trn_df.shape =  (3129, 8)
# fb3_trn_df[trn_df.columns].shape =  (3129, 8)
# adding fb3 data, done
# trn_df.shape =  (15243, 8)
# 2022-11-05 12:56:48.376595: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-11-05 12:56:48.376616: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# self.warmup_ratio =  0.1
# self.num_train_steps =  1905
# num_warmup_steps =  190
# lr :  [0.0, 0.0, 0.0]
# 100%|███████████████████████████| 1905/1905 [09:17<00:00,  3.42it/s, loss=0.118]
# 100%|█████████████████████████████████████████| 379/379 [00:57<00:00,  6.63it/s]
# epoch 1: trn_loss = 0.1179, val_loss = 0.0029, trn_score = 0.6337, val_score = 0.0759
# model (best score) saved
#
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.2
# args.mode =  pseudo
# train_df.shape =  (15142, 8)
# load folds...
# trn_df.shape =  (12114, 8)
# val_df.shape =  (3028, 8)
# adding fb3 data...
# trn_df.columns =  Index(['essay_id', 'cohesion', 'syntax', 'vocabulary', 'phraseology',
#        'grammar', 'conventions', 'full_text'],
#       dtype='object')
# fb3_trn_df.columns =  Index(['essay_id', 'full_text', 'cohesion', 'syntax', 'vocabulary',
#        'phraseology', 'grammar', 'conventions'],
#       dtype='object')
# fb3_trn_df.shape =  (3129, 8)
# fb3_trn_df[trn_df.columns].shape =  (3129, 8)
# adding fb3 data, done
# trn_df.shape =  (15243, 8)
# 2022-11-05 13:07:16.823757: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-11-05 13:07:16.823781: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# self.warmup_ratio =  0.1
# self.num_train_steps =  1905
# num_warmup_steps =  190
# lr :  [0.0, 0.0, 0.0]
# 100%|███████████████████████████| 1905/1905 [09:39<00:00,  3.29it/s, loss=0.124]
# 100%|█████████████████████████████████████████| 379/379 [00:58<00:00,  6.52it/s]
# epoch 1: trn_loss = 0.1244, val_loss = 0.0043, trn_score = 0.6349, val_score = 0.0920
# model (best score) saved

# %% [markdown]
# # Finetune

# %% [markdown]
# # OOF

# %%
INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_02/result/'

# %%
for FOLD in [0,1,2,3,4]:
    print("-"*50)
    print("FOLD = ", FOLD)
    print("-"*50)
    #WEIGHT_PATH = f'./result/{VERSION}/model_{CLASS}_seed{SEED}_fold{FOLD}.pth'
    #WEIGHT_PATH = f'result/{VERSION}/model_{CLASS}_seed{SEED}_fold{FOLD}_pseudo.pth'
    WEIGHT_PATH = f'result/{VERSION}/model_seed{SEED}_fold{FOLD}_pseudo.pth'
    # !python ../$VERSION/validation.py --model $MODEL --version $VERSION \
        --fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS \
        --rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH \
        --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --max_length $MAX_LEN \
        --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS
# Out:
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.2
# 2022-11-05 13:18:08.396370: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-11-05 13:18:08.396390: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3128, 8)
# val_df.shape =  (783, 8)
# 100%|███████████████████████████████████████████| 98/98 [00:09<00:00, 10.02it/s]
# val_loss=0.1016, val_score=0.4509
# essay_ids.shape =  (783,)
# preds.shape =  (783, 6)
# labels.shape =  (783, 6)
# losses.shape =  (783, 6)
# embeds.shape =  (783, 768)
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.2
# 2022-11-05 13:18:31.496336: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-11-05 13:18:31.496359: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 100%|███████████████████████████████████████████| 98/98 [00:09<00:00, 10.01it/s]
# val_loss=0.1004, val_score=0.4489
# essay_ids.shape =  (782,)
# preds.shape =  (782, 6)
# labels.shape =  (782, 6)
# losses.shape =  (782, 6)
# embeds.shape =  (782, 768)
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.2
# 2022-11-05 13:18:54.587087: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-11-05 13:18:54.587109: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 100%|███████████████████████████████████████████| 98/98 [00:09<00:00,  9.95it/s]
# val_loss=0.0986, val_score=0.4447
# essay_ids.shape =  (782,)
# preds.shape =  (782, 6)
# labels.shape =  (782, 6)
# losses.shape =  (782, 6)
# embeds.shape =  (782, 768)
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.2
# 2022-11-05 13:19:17.891803: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-11-05 13:19:17.891825: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 100%|███████████████████████████████████████████| 98/98 [00:09<00:00,  9.97it/s]
# val_loss=0.1046, val_score=0.4580
# essay_ids.shape =  (782,)
# preds.shape =  (782, 6)
# labels.shape =  (782, 6)
# losses.shape =  (782, 6)
# embeds.shape =  (782, 768)
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.2
# 2022-11-05 13:19:41.234854: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-11-05 13:19:41.234875: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 100%|███████████████████████████████████████████| 98/98 [00:09<00:00, 10.05it/s]
# val_loss=0.1038, val_score=0.4565
# essay_ids.shape =  (782,)
# preds.shape =  (782, 6)
# labels.shape =  (782, 6)
# losses.shape =  (782, 6)
# embeds.shape =  (782, 768)

# %%
import pandas as pd
import numpy as np

preds = []
for fold in [0,1,2,3,4]:
    print("-"*50)
    print("FOLD = ", fold)
    print("-"*50)
    pred_df = pd.read_csv(f'./result/{VERSION}/pred_fold{fold}.csv')
    preds.append(pred_df)
    
all_pred_df = pd.concat(preds, axis=0).reset_index(drop=True)

train_df = pd.read_csv('../../input/feedback-prize-english-language-learning/train.csv')
oof_df = train_df[['text_id']].merge(all_pred_df, on='text_id', how='left')
oof_df.to_csv(f'./result/{VERSION}/oof_df.csv', index=False)
# Out:
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------

# %%
oof_df.shape, oof_df.isnull().sum()
# Out:
# ((3911, 13),
#  text_id             0
#  cohesion            0
#  syntax              0
#  vocabulary          0
#  phraseology         0
#  grammar             0
#  conventions         0
#  loss_cohesion       0
#  loss_syntax         0
#  loss_vocabulary     0
#  loss_phraseology    0
#  loss_grammar        0
#  loss_conventions    0
#  dtype: int64)

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
oof_df[cols].describe()
# Out:
#           cohesion       syntax   vocabulary  phraseology      grammar  \
# count  3911.000000  3911.000000  3911.000000  3911.000000  3911.000000
# mean      3.158175     3.068241     3.248695     3.136962     3.049117
# std       0.456266     0.477048     0.403828     0.483238     0.536815
# min       1.297602     1.507395     2.006682     1.687656     1.594324
# 25%       2.853248     2.728498     2.970952     2.793640     2.640151
# 50%       3.158201     3.054690     3.220497     3.128836     3.052249
# 75%       3.484917     3.392791     3.505888     3.474917     3.447016
# max       4.781085     4.704274     5.219043     4.650881     4.672513
#
#        conventions
# count  3911.000000
# mean      3.106950
# std       0.506363
# min       1.283548
# 25%       2.759247
# 50%       3.098787
# 75%       3.449199
# max       4.705681

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
train_df[cols].describe()
# Out:
#           cohesion       syntax   vocabulary  phraseology      grammar  \
# count  3911.000000  3911.000000  3911.000000  3911.000000  3911.000000
# mean      3.127077     3.028254     3.235745     3.116850     3.032856
# std       0.662542     0.644399     0.583148     0.655997     0.699841
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%       2.500000     2.500000     3.000000     2.500000     2.500000
# 50%       3.000000     3.000000     3.000000     3.000000     3.000000
# 75%       3.500000     3.500000     3.500000     3.500000     3.500000
# max       5.000000     5.000000     5.000000     5.000000     5.000000
#
#        conventions
# count  3911.000000
# mean      3.081053
# std       0.671450
# min       1.000000
# 25%       2.500000
# 50%       3.000000
# 75%       3.500000
# max       5.000000

# %% [markdown]
# # Error Analysis - Check Corr

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
train_df[cols].corr()
# Out:
#              cohesion    syntax  vocabulary  phraseology   grammar  \
# cohesion     1.000000  0.695459    0.666151     0.690058  0.638689
# syntax       0.695459  1.000000    0.680562     0.725467  0.709525
# vocabulary   0.666151  0.680562    1.000000     0.735261  0.654852
# phraseology  0.690058  0.725467    0.735261     1.000000  0.719746
# grammar      0.638689  0.709525    0.654852     0.719746  1.000000
# conventions  0.666151  0.700025    0.664292     0.666842  0.673301
#
#              conventions
# cohesion        0.666151
# syntax          0.700025
# vocabulary      0.664292
# phraseology     0.666842
# grammar         0.673301
# conventions     1.000000

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
oof_df[cols].corr()
# Out:
#              cohesion    syntax  vocabulary  phraseology   grammar  \
# cohesion     1.000000  0.964461    0.931049     0.932992  0.854444
# syntax       0.964461  1.000000    0.951417     0.971924  0.934439
# vocabulary   0.931049  0.951417    1.000000     0.956974  0.879448
# phraseology  0.932992  0.971924    0.956974     1.000000  0.953684
# grammar      0.854444  0.934439    0.879448     0.953684  1.000000
# conventions  0.893293  0.928170    0.895639     0.899124  0.870080
#
#              conventions
# cohesion        0.893293
# syntax          0.928170
# vocabulary      0.895639
# phraseology     0.899124
# grammar         0.870080
# conventions     1.000000
