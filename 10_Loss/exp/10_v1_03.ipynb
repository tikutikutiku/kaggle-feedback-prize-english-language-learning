# %%
VERSION = '10_v1_03'
MODEL = 'microsoft/deberta-v3-base'
#'google/electra-base-discriminator'
#'roberta-large'
#'roberta-base'
#'microsoft/deberta-v3-large'
#'microsoft/deberta-base'
LR = 2e-5 #8e-6
HEAD_LR = 2e-4 #2e-5 #8e-6 
SEED = 100
TRN_BS = 8
VAL_BS = 8
ACCUM_STEP = 1
HIDDEN_DROP_PROB = 0.1 #0
P_DROP = 0
RNN = 'none'
WARMUP_RATIO = 0.1
HEAD = 'simple'
AUG = 'false'
MIXUP_ALPHA = 0
P_AUG = 0
AUG_STOP_EPOCH = 0
MSD = 'true' #'false'
MULTI_LAYERS = 1
EVAL_STEP_START_EPOCH = -1
EVAL_STEP = -1
NUM_LABELS = 6
NUM_LABELS_2 = -1
FP16 = 'true'
WD = 0.01
FREEZE = 'false'
MULTI_TASK = 'false' 
W_MT = 0 
AWP = 'false'
AWP_LR = 0 #1e-4
AWP_EPS = 0 #1e-4
AWP_START_EPOCH = -1 #3
#PRETRAINED_DETECTOR_PATH = f'../../input/tascj/result/deberta_base_fold0.pth'
PRETRAINED_DETECTOR_PATH = 'none' #f'../../05_Detection/exp/result/05_v2_09/model_seed100_fold0_swa.pth'
MASK_PROB = 0 #0.8
MASK_RATIO = 0 #0.3
SCHEDULER = 'cosine_hard'
CP = 'false'
WINDOW_SIZE = -1 #512
INNER_LEN = -1 #384
EDGE_LEN = -1 #64
MAX_LEN = 512

GRAD_CLIP = 1

LOSS = 'bce' #'smoothl1'#'mse'

CROP_PROB = 0 #1.0

# %%
FOLD = 0
INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_02/result/'
MODE = 'train'
EPOCHS = 5
STOP_EPOCH = 5
RESTART = 1
NUM_CYCLES = EPOCHS
PRETRAIN_PATH = 'none' #f'result/{VERSION}/model_seed{SEED}_fold{FOLD}_epoch{EPOCHS}_pseudo.pth'

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS \
--eval_step_start_epoch $EVAL_STEP_START_EPOCH --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN \
--gradient_clip_val $GRAD_CLIP \
--input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN \
--crop_prob $CROP_PROB
# Out:
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3128, 8)
# val_df.shape =  (783, 8)
# 2022-10-01 17:28:56.052218: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-01 17:28:56.052245: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [01:47<00:00,  3.63it/s, loss=0.678]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.35it/s]
# epoch 1: trn_loss = 0.6775, val_loss = 0.6651, trn_score = 0.5664, val_score = 0.4662
# model (best score) saved
# lr :  [8.224468037456969e-06, 8.224468037456969e-06, 8.224468037456969e-05]
# 100%|█████████████████████████████| 391/391 [01:49<00:00,  3.57it/s, loss=0.665]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.37it/s]
# epoch 2: trn_loss = 0.6652, val_loss = 0.6662, trn_score = 0.4764, val_score = 0.4748
# lr :  [4.974257968932691e-06, 4.974257968932691e-06, 4.974257968932691e-05]
# 100%|█████████████████████████████| 391/391 [01:51<00:00,  3.52it/s, loss=0.665]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.36it/s]
# epoch 3: trn_loss = 0.6648, val_loss = 0.6640, trn_score = 0.4732, val_score = 0.4576
# model (best score) saved
# lr :  [2.3268220525837457e-06, 2.3268220525837457e-06, 2.3268220525837457e-05]
# 100%|█████████████████████████████| 391/391 [01:51<00:00,  3.51it/s, loss=0.663]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.29it/s]
# epoch 4: trn_loss = 0.6632, val_loss = 0.6654, trn_score = 0.4608, val_score = 0.4682
# lr :  [5.996867213330993e-07, 5.996867213330993e-07, 5.996867213330992e-06]
# 100%|█████████████████████████████| 391/391 [01:51<00:00,  3.51it/s, loss=0.662]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.37it/s]
# epoch 5: trn_loss = 0.6615, val_loss = 0.6640, trn_score = 0.4475, val_score = 0.4575
# model (best score) saved

# %%
FOLD = 1
INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_02/result/'
MODE = 'train'
EPOCHS = 5
STOP_EPOCH = 5
RESTART = 1
NUM_CYCLES = EPOCHS
PRETRAIN_PATH = 'none' #f'result/{VERSION}/model_seed{SEED}_fold{FOLD}_epoch{EPOCHS}_pseudo.pth'

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS \
--eval_step_start_epoch $EVAL_STEP_START_EPOCH --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN \
--gradient_clip_val $GRAD_CLIP \
--input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN \
--crop_prob $CROP_PROB
# Out:
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-10-01 17:40:20.577562: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-01 17:40:20.577585: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [01:50<00:00,  3.53it/s, loss=0.681]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.35it/s]
# epoch 1: trn_loss = 0.6808, val_loss = 0.6639, trn_score = 0.5829, val_score = 0.4731
# model (best score) saved
# lr :  [8.224468037456969e-06, 8.224468037456969e-06, 8.224468037456969e-05]
# 100%|█████████████████████████████| 391/391 [01:51<00:00,  3.52it/s, loss=0.667]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.37it/s]
# epoch 2: trn_loss = 0.6667, val_loss = 0.6631, trn_score = 0.4839, val_score = 0.4666
# model (best score) saved
# lr :  [4.974257968932691e-06, 4.974257968932691e-06, 4.974257968932691e-05]
# 100%|█████████████████████████████| 391/391 [01:50<00:00,  3.54it/s, loss=0.666]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.37it/s]
# epoch 3: trn_loss = 0.6660, val_loss = 0.6629, trn_score = 0.4778, val_score = 0.4652
# model (best score) saved
# lr :  [2.3268220525837457e-06, 2.3268220525837457e-06, 2.3268220525837457e-05]
# 100%|█████████████████████████████| 391/391 [01:49<00:00,  3.56it/s, loss=0.664]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.49it/s]
# epoch 4: trn_loss = 0.6643, val_loss = 0.6620, trn_score = 0.4652, val_score = 0.4578
# model (best score) saved
# lr :  [5.996867213330993e-07, 5.996867213330993e-07, 5.996867213330992e-06]
# 100%|█████████████████████████████| 391/391 [01:49<00:00,  3.56it/s, loss=0.663]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.52it/s]
# epoch 5: trn_loss = 0.6633, val_loss = 0.6617, trn_score = 0.4573, val_score = 0.4562
# model (best score) saved

# %%
FOLD = 2
INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_02/result/'
MODE = 'train'
EPOCHS = 5
STOP_EPOCH = 5
RESTART = 1
NUM_CYCLES = EPOCHS
PRETRAIN_PATH = 'none' #f'result/{VERSION}/model_seed{SEED}_fold{FOLD}_epoch{EPOCHS}_pseudo.pth'

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS \
--eval_step_start_epoch $EVAL_STEP_START_EPOCH --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN \
--gradient_clip_val $GRAD_CLIP \
--input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN \
--crop_prob $CROP_PROB
# Out:
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-10-01 17:51:45.587280: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-01 17:51:45.587300: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [01:50<00:00,  3.53it/s, loss=0.677]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.44it/s]
# epoch 1: trn_loss = 0.6772, val_loss = 0.6640, trn_score = 0.5602, val_score = 0.4738
# model (best score) saved
# lr :  [8.224468037456969e-06, 8.224468037456969e-06, 8.224468037456969e-05]
# 100%|█████████████████████████████| 391/391 [01:50<00:00,  3.53it/s, loss=0.666]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.48it/s]
# epoch 2: trn_loss = 0.6658, val_loss = 0.6623, trn_score = 0.4768, val_score = 0.4598
# model (best score) saved
# lr :  [4.974257968932691e-06, 4.974257968932691e-06, 4.974257968932691e-05]
# 100%|█████████████████████████████| 391/391 [01:50<00:00,  3.55it/s, loss=0.664]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.40it/s]
# epoch 3: trn_loss = 0.6641, val_loss = 0.6623, trn_score = 0.4636, val_score = 0.4604
# lr :  [2.3268220525837457e-06, 2.3268220525837457e-06, 2.3268220525837457e-05]
# 100%|█████████████████████████████| 391/391 [01:51<00:00,  3.51it/s, loss=0.663]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.44it/s]
# epoch 4: trn_loss = 0.6627, val_loss = 0.6630, trn_score = 0.4527, val_score = 0.4665
# lr :  [5.996867213330993e-07, 5.996867213330993e-07, 5.996867213330992e-06]
# 100%|█████████████████████████████| 391/391 [01:50<00:00,  3.52it/s, loss=0.662]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.39it/s]
# epoch 5: trn_loss = 0.6618, val_loss = 0.6616, trn_score = 0.4449, val_score = 0.4558
# model (best score) saved

# %%
FOLD = 3
INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_02/result/'
MODE = 'train'
EPOCHS = 5
STOP_EPOCH = 5
RESTART = 1
NUM_CYCLES = EPOCHS
PRETRAIN_PATH = 'none' #f'result/{VERSION}/model_seed{SEED}_fold{FOLD}_epoch{EPOCHS}_pseudo.pth'

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS \
--eval_step_start_epoch $EVAL_STEP_START_EPOCH --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN \
--gradient_clip_val $GRAD_CLIP \
--input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN \
--crop_prob $CROP_PROB
# Out:
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-10-01 18:03:10.935269: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-01 18:03:10.935291: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
#   9%|██▌                           | 34/391 [00:10<01:39,  3.57it/s, loss=0.711]

# %%
FOLD = 4
INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_02/result/'
MODE = 'train'
EPOCHS = 5
STOP_EPOCH = 5
RESTART = 1
NUM_CYCLES = EPOCHS
PRETRAIN_PATH = 'none' #f'result/{VERSION}/model_seed{SEED}_fold{FOLD}_epoch{EPOCHS}_pseudo.pth'

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS \
--eval_step_start_epoch $EVAL_STEP_START_EPOCH --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN \
--gradient_clip_val $GRAD_CLIP \
--input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN \
--crop_prob $CROP_PROB

# %% [markdown]
# # OOF

# %%
FOLD = 0
INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_02/result/'
WEIGHT_PATH = f'./result/{VERSION}/model_seed{SEED}_fold{FOLD}.pth'

# !python ../$VERSION/validation.py --model $MODEL --version $VERSION \
--fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS \
--rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --max_length $MAX_LEN
# Out:
# torch 1.10.1
# 2022-10-01 18:03:38.852147: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-01 18:03:38.852170: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3128, 8)
# val_df.shape =  (783, 8)
# ^C
# Traceback (most recent call last):
#   File "../10_v1_03/validation.py", line 100, in <module>
#     tokenizer = DebertaV2TokenizerFast.from_pretrained(args.model, trim_offsets=False)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/transformers/tokenization_utils_base.py", line 1715, in from_pretrained
#     user_agent=user_agent,
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/transformers/file_utils.py", line 1854, in cached_path
#     local_files_only=local_files_only,
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/transformers/file_utils.py", line 2049, in get_from_cache
#     r = requests.head(url, headers=headers, allow_redirects=False, proxies=proxies, timeout=etag_timeout)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/requests/api.py", line 104, in head
#     return request('head', url, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/requests/api.py", line 61, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/requests/sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/requests/sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/requests/adapters.py", line 449, in send
#     timeout=timeout
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py", line 706, in urlopen
#     chunked=chunked,
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py", line 382, in _make_request
#     self._validate_conn(conn)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py", line 1010, in _validate_conn
#     conn.connect()
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/urllib3/connection.py", line 421, in connect
#     tls_in_tls=tls_in_tls,
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/urllib3/util/ssl_.py", line 429, in ssl_wrap_socket
#     sock, context, tls_in_tls, server_hostname=server_hostname
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/urllib3/util/ssl_.py", line 472, in _ssl_wrap_socket_impl
#     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#   File "/home/takesako/anaconda3/lib/python3.7/ssl.py", line 423, in wrap_socket
#     session=session
#   File "/home/takesako/anaconda3/lib/python3.7/ssl.py", line 870, in _create
#     self.do_handshake()
#   File "/home/takesako/anaconda3/lib/python3.7/ssl.py", line 1139, in do_handshake
#     self._sslobj.do_handshake()
# KeyboardInterrupt

# %%
for FOLD in [1,2,3,4]:
    WEIGHT_PATH = f'./result/{VERSION}/model_seed{SEED}_fold{FOLD}.pth'
    # !python ../$VERSION/validation.py --model $MODEL --version $VERSION \
    --fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS \
    --rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH \
    --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --max_length $MAX_LEN
# Out:
# ^C
# Traceback (most recent call last):
#   File "<frozen importlib._bootstrap_external>", line 87, in _path_is_mode_type
#   File "<frozen importlib._bootstrap_external>", line 81, in _path_stat
# FileNotFoundError: [Errno 2] No such file or directory: '/home/takesako/anaconda3/lib/python3.7/site-packages/google/__init__.pyc'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../10_v1_03/validation.py", line 1, in <module>
#     import torch
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/__init__.py", line 29, in <module>
#     from .torch_version import __version__ as __version__
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/torch_version.py", line 3, in <module>
#     from pkg_resources import packaging  # type: ignore[attr-defined]
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 3266, in <module>
#     @_call_aside
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 3241, in _call_aside
#     f(*args, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 3294, in _initialize_master_working_set
#     for dist in working_set
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 3294, in <genexpr>
#     for dist in working_set
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 2795, in activate
#     fixup_namespace_packages(self.location)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 2307, in fixup_namespace_packages
#     subpath = _handle_ns(package, path_item)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 2208, in _handle_ns
#     loader = importer.find_spec(packageName).loader
#   File "<frozen importlib._bootstrap_external>", line 1383, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 95, in _path_isfile
#   File "<frozen importlib._bootstrap_external>", line 87, in _path_is_mode_type
# KeyboardInterrupt
# torch 1.10.1
# 2022-10-01 18:03:42.971464: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-01 18:03:42.971484: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# torch 1.10.1
# 2022-10-01 18:03:46.660115: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-01 18:03:46.660137: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# torch 1.10.1
# 2022-10-01 18:03:51.335549: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-01 18:03:51.335569: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# ^C
# Traceback (most recent call last):
#   File "../10_v1_03/validation.py", line 100, in <module>
#     tokenizer = DebertaV2TokenizerFast.from_pretrained(args.model, trim_offsets=False)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/transformers/tokenization_utils_base.py", line 1780, in from_pretrained
#     **kwargs,
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/transformers/tokenization_utils_base.py", line 1804, in _from_pretrained
#     **(copy.deepcopy(kwargs)),
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/transformers/tokenization_utils_base.py", line 1834, in _from_pretrained
#     cache_dir=cache_dir,
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/transformers/models/auto/configuration_auto.py", line 612, in from_pretrained
#     config_dict, _ = PretrainedConfig.get_config_dict(pretrained_model_name_or_path, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/transformers/configuration_utils.py", line 537, in get_config_dict
#     config_dict, kwargs = cls._get_config_dict(pretrained_model_name_or_path, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/transformers/configuration_utils.py", line 593, in _get_config_dict
#     user_agent=user_agent,
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/transformers/file_utils.py", line 1854, in cached_path
#     local_files_only=local_files_only,
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/transformers/file_utils.py", line 2049, in get_from_cache
#     r = requests.head(url, headers=headers, allow_redirects=False, proxies=proxies, timeout=etag_timeout)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/requests/api.py", line 104, in head
#     return request('head', url, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/requests/api.py", line 61, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/requests/sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/requests/sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/requests/adapters.py", line 449, in send
#     timeout=timeout
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py", line 706, in urlopen
#     chunked=chunked,
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py", line 382, in _make_request
#     self._validate_conn(conn)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py", line 1010, in _validate_conn
#     conn.connect()
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/urllib3/connection.py", line 421, in connect
#     tls_in_tls=tls_in_tls,
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/urllib3/util/ssl_.py", line 429, in ssl_wrap_socket
#     sock, context, tls_in_tls, server_hostname=server_hostname
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/urllib3/util/ssl_.py", line 472, in _ssl_wrap_socket_impl
#     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#   File "/home/takesako/anaconda3/lib/python3.7/ssl.py", line 423, in wrap_socket
#     session=session
#   File "/home/takesako/anaconda3/lib/python3.7/ssl.py", line 870, in _create
#     self.do_handshake()
#   File "/home/takesako/anaconda3/lib/python3.7/ssl.py", line 1139, in do_handshake
#     self._sslobj.do_handshake()
# KeyboardInterrupt

# %%
import pandas as pd
import numpy as np

num_fold = 5

preds = []
for fold in range(num_fold):
    tmp_df = pd.read_csv(f'./result/{VERSION}/pred_fold{fold}.csv')
    embeds = np.load(f'./result/{VERSION}/embeds_fold{fold}.npz')['arr_0']
    tmp_df['embed'] = embeds.tolist()
    preds.append(tmp_df)
    
pred_df = pd.concat(preds, axis=0).reset_index(drop=True)
train_df = pd.read_csv('../../input/feedback-prize-english-language-learning/train.csv')

oof_df = train_df[['text_id']].merge(pred_df, on='text_id', how='left')
oof_df.to_csv(f'./result/{VERSION}/oof_df.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-99d026ddc0e9> in <module>
#       6 preds = []
#       7 for fold in range(num_fold):
# ----> 8     tmp_df = pd.read_csv(f'./result/{VERSION}/pred_fold{fold}.csv')
#       9     embeds = np.load(f'./result/{VERSION}/embeds_fold{fold}.npz')['arr_0']
#      10     tmp_df['embed'] = embeds.tolist()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     603     kwds.update(kwds_defaults)
#     604
# --> 605     return _read(filepath_or_buffer, kwds)
#     606
#     607
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(filepath_or_buffer, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     812             self.options["has_index_names"] = kwds["has_index_names"]
#     813
# --> 814         self._engine = self._make_engine(self.engine)
#     815
#     816     def close(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1043             )
#    1044         # error: Too many arguments for "ParserBase"
# -> 1045         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1046
#    1047     def _failover_to_python(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1860
#    1861         # open handles
# -> 1862         self._open_handles(src, kwds)
#    1863         assert self.handles is not None
#    1864         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _open_handles(self, src, kwds)
#    1361             compression=kwds.get("compression", None),
#    1362             memory_map=kwds.get("memory_map", False),
# -> 1363             storage_options=kwds.get("storage_options", None),
#    1364         )
#    1365
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     642                 encoding=ioargs.encoding,
#     643                 errors=errors,
# --> 644                 newline="",
#     645             )
#     646         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: './result/10_v1_03/pred_fold0.csv'

# %%
oof_df.shape, oof_df.isnull().sum()
