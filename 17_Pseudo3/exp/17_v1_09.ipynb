# %%
VERSION = '17_v1_09'
MODEL = 'microsoft/deberta-v3-small'
#'microsoft/deberta-v3-base'
#'bert-large-cased'
#'bert-large-cased-whole-word-masking'
#'albert-large-v2'
#'facebook/bart-large'
#'xlm-roberta-large'
#'deepset/roberta-large-squad2'
#'google/electra-large-discriminator'
#'sentence-transformeres/paraphrase-mpnet-base-v2'
#'funnel-transformer/large-base'
#'facebook/bart-base'
#'distilroberta-base'
#'deepset/roberta-base-squad2'
#'microsoft/deberta-v3-base'
#'roberta-large'
#'roberta-base'
#'microsoft/deberta-v3-large'
#'microsoft/deberta-base'
LR = 8e-5 #2e-5 #8e-6
HEAD_LR = 8e-4 #2e-4 #2e-5 #8e-6 
SEED = 100
TRN_BS = 8
VAL_BS = 8
ACCUM_STEP = 1
HIDDEN_DROP_PROB = 0
P_DROP = 0
RNN = 'none'
WARMUP_RATIO = 0.1
HEAD = 'simple'
AUG = 'false'
MIXUP_ALPHA = 0
P_AUG = 0
AUG_STOP_EPOCH = 0
MSD = 'false'
POOLING = 'mean' #'weighted_layer'
NUM_POOLING_LAYERS = 4 #1
MULTI_LAYERS = 1
EVAL_STEP_START_EPOCH = -1
EVAL_STEP = -1
NUM_LABELS = 1 #6
NUM_LABELS_2 = -1
FP16 = 'true'
WD = 0.01
FREEZE = 'false'
MULTI_TASK = 'false' 
W_MT = 0 
AWP = 'false'
AWP_LR = 0
AWP_EPS = 0
AWP_START_EPOCH = -1
#PRETRAINED_DETECTOR_PATH = f'../../input/tascj/result/deberta_base_fold0.pth'
PRETRAINED_DETECTOR_PATH = 'none' #f'../../05_Detection/exp/result/05_v2_09/model_seed100_fold0_swa.pth'
MASK_PROB = 0 #0.8
MASK_RATIO = 0 #0.3
SCHEDULER = 'cosine_hard'
CP = 'true' #'false'
WINDOW_SIZE = -1 #512
INNER_LEN = -1 #384
EDGE_LEN = -1 #64
MAX_LEN = 512

GRAD_CLIP = 1

LOSS = 'smoothl1'#'mse'

CROP_PROB = 0 #1.0

# %% [markdown]
# # Train with Pseudo-Label

# %%
MODE = 'pseudo'
EPOCHS = 1 #8
STOP_EPOCH = 1 #3
RESTART = 1
NUM_CYCLES = 1
EVAL_STEP = -1
ADD_FB3 = 'true'
FB3_FOLD_PATH = '../../00_EDA/00_v1_02/result/'

for CLASS in [
    'cohesion',
    'syntax','vocabulary','phraseology','grammar','conventions'
]:
    print("*"*50)
    print(CLASS)
    print("*"*50)
    for FOLD in [0,1,2,3,4]:
        print("-"*50)
        print("FOLD = ", FOLD)
        print("-"*50)
        #INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
        #FOLD_PATH = '../../00_EDA/00_v1_02/result/'
        INPUT_PATH = f'../../99_Ensemble/99_v1_03/result/99_v1_03_03_pseudo_fold{FOLD}.csv'
        FOLD_PATH = '../../00_EDA/00_v1_08/result/' # for pseudo-label
        PRETRAIN_PATH = 'none'

        # !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
        --lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
        --epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
        --accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
        --mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
        --msd $MSD --multi_layers $MULTI_LAYERS \
        --eval_step_start_epoch $EVAL_STEP_START_EPOCH --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
        --num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
        --restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
        --mt $MULTI_TASK --w_mt $W_MT \
        --awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
        --pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
        --scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
        --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN \
        --gradient_clip_val $GRAD_CLIP \
        --input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN \
        --crop_prob $CROP_PROB --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS --class_name $CLASS \
        --add_fb3 $ADD_FB3 --fb3_fold_path $FB3_FOLD_PATH
# Out:
# **************************************************
# cohesion
# **************************************************
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# args.mode =  pseudo
# train_df.shape =  (15142, 8)
# load folds...
# trn_df.shape =  (12113, 8)
# val_df.shape =  (3029, 8)
# adding fb3 data...
# trn_df.columns =  Index(['essay_id', 'cohesion', 'syntax', 'vocabulary', 'phraseology',
#        'grammar', 'conventions', 'full_text'],
#       dtype='object')
# fb3_trn_df.columns =  Index(['essay_id', 'full_text', 'cohesion', 'syntax', 'vocabulary',
#        'phraseology', 'grammar', 'conventions'],
#       dtype='object')
# fb3_trn_df.shape =  (3128, 8)
# fb3_trn_df[trn_df.columns].shape =  (3128, 8)
# adding fb3 data, done
# trn_df.shape =  (15241, 8)
# 2022-11-03 21:53:09.230465: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-03 21:53:09.230489: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# self.warmup_ratio =  0.1
# self.num_train_steps =  1905
# num_warmup_steps =  190
# lr :  [0.0, 0.0, 0.0]
# 100%|██████████████████████████| 1905/1905 [06:28<00:00,  4.91it/s, loss=0.0688]
# 100%|█████████████████████████████████████████| 379/379 [00:58<00:00,  6.44it/s]
# epoch 1: trn_loss = 0.0688, val_loss = 0.0044, trn_score = 0.4338, val_score = 0.0938
# model_cohesion (best score) saved
#
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# args.mode =  pseudo
# train_df.shape =  (15142, 8)
# load folds...
# trn_df.shape =  (12113, 8)
# val_df.shape =  (3029, 8)
# adding fb3 data...
# trn_df.columns =  Index(['essay_id', 'cohesion', 'syntax', 'vocabulary', 'phraseology',
#        'grammar', 'conventions', 'full_text'],
#       dtype='object')
# fb3_trn_df.columns =  Index(['essay_id', 'full_text', 'cohesion', 'syntax', 'vocabulary',
#        'phraseology', 'grammar', 'conventions'],
#       dtype='object')
# fb3_trn_df.shape =  (3129, 8)
# fb3_trn_df[trn_df.columns].shape =  (3129, 8)
# adding fb3 data, done
# trn_df.shape =  (15242, 8)
# 2022-11-03 22:00:54.259658: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-03 22:00:54.259679: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# self.warmup_ratio =  0.1
# self.num_train_steps =  1905
# num_warmup_steps =  190
# lr :  [0.0, 0.0, 0.0]
# 100%|███████████████████████████| 1905/1905 [06:31<00:00,  4.87it/s, loss=0.079]
# 100%|█████████████████████████████████████████| 379/379 [00:58<00:00,  6.46it/s]
# epoch 1: trn_loss = 0.0790, val_loss = 0.0033, trn_score = 0.5042, val_score = 0.0808
# model_cohesion (best score) saved
#
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# args.mode =  pseudo
# train_df.shape =  (15142, 8)
# load folds...
# trn_df.shape =  (12114, 8)
# val_df.shape =  (3028, 8)
# adding fb3 data...
# trn_df.columns =  Index(['essay_id', 'cohesion', 'syntax', 'vocabulary', 'phraseology',
#        'grammar', 'conventions', 'full_text'],
#       dtype='object')
# fb3_trn_df.columns =  Index(['essay_id', 'full_text', 'cohesion', 'syntax', 'vocabulary',
#        'phraseology', 'grammar', 'conventions'],
#       dtype='object')
# fb3_trn_df.shape =  (3129, 8)
# fb3_trn_df[trn_df.columns].shape =  (3129, 8)
# adding fb3 data, done
# trn_df.shape =  (15243, 8)
# 2022-11-03 22:08:42.436566: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-03 22:08:42.436590: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# self.warmup_ratio =  0.1
# self.num_train_steps =  1905
# num_warmup_steps =  190
# lr :  [0.0, 0.0, 0.0]
# 100%|██████████████████████████| 1905/1905 [06:30<00:00,  4.87it/s, loss=0.0796]
# 100%|█████████████████████████████████████████| 379/379 [00:58<00:00,  6.49it/s]
# epoch 1: trn_loss = 0.0796, val_loss = 0.0035, trn_score = 0.4934, val_score = 0.0837
# model_cohesion (best score) saved
#
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.1
# args.mode =  pseudo
# train_df.shape =  (15142, 8)
# load folds...
# trn_df.shape =  (12114, 8)
# val_df.shape =  (3028, 8)
# adding fb3 data...
# trn_df.columns =  Index(['essay_id', 'cohesion', 'syntax', 'vocabulary', 'phraseology',
#        'grammar', 'conventions', 'full_text'],
#       dtype='object')
# fb3_trn_df.columns =  Index(['essay_id', 'full_text', 'cohesion', 'syntax', 'vocabulary',
#        'phraseology', 'grammar', 'conventions'],
#       dtype='object')
# fb3_trn_df.shape =  (3129, 8)
# fb3_trn_df[trn_df.columns].shape =  (3129, 8)
# adding fb3 data, done
# trn_df.shape =  (15243, 8)
# 2022-11-03 22:16:29.283539: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-03 22:16:29.283563: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ^C
# Traceback (most recent call last):
#   File "../17_v1_09/train.py", line 168, in <module>
#     run(args, trn_df, val_df, pseudo_df=None)
#   File "/home/takesako/programming/kaggle/kaggle-feedback-prize-english-language-learning/17_Pseudo3/17_v1_09/run.py", line 22, in run
#     tokenizer = DebertaV2TokenizerFast.from_pretrained(args.model, trim_offsets=False)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/transformers/tokenization_utils_base.py", line 1664, in from_pretrained
#     local_files_only=local_files_only,
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/transformers/file_utils.py", line 2242, in get_file_from_repo
#     use_auth_token=use_auth_token,
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/transformers/file_utils.py", line 1854, in cached_path
#     local_files_only=local_files_only,
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/transformers/file_utils.py", line 2049, in get_from_cache
#     r = requests.head(url, headers=headers, allow_redirects=False, proxies=proxies, timeout=etag_timeout)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/requests/api.py", line 104, in head
#     return request('head', url, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/requests/api.py", line 61, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/requests/sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/requests/sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/requests/adapters.py", line 449, in send
#     timeout=timeout
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py", line 706, in urlopen
#     chunked=chunked,
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py", line 382, in _make_request
#     self._validate_conn(conn)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py", line 1010, in _validate_conn
#     conn.connect()
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/urllib3/connection.py", line 353, in connect
#     conn = self._new_conn()
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/urllib3/connection.py", line 170, in _new_conn
#     (self._dns_host, self.port), self.timeout, **extra_kw
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/urllib3/util/connection.py", line 73, in create_connection
#     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#   File "/home/takesako/anaconda3/lib/python3.7/socket.py", line 752, in getaddrinfo
#     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# KeyboardInterrupt
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# ^C
# Traceback (most recent call last):
#   File "../17_v1_09/train.py", line 1, in <module>
#     import torch
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/__init__.py", line 29, in <module>
#     from .torch_version import __version__ as __version__
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/torch_version.py", line 3, in <module>
#     from pkg_resources import packaging  # type: ignore[attr-defined]
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 3266, in <module>
#     @_call_aside
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 3241, in _call_aside
#     f(*args, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 3302, in _initialize_master_working_set
#     list(map(working_set.add_entry, sys.path))
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 613, in add_entry
#     for dist in find_distributions(entry, True):
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 2077, in find_on_path
#     for dist in factory(fullpath):
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 2143, in distributions_from_metadata
#     root, entry, metadata, precedence=DEVELOP_DIST,
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 2605, in from_location
#     py_version=py_version, platform=platform, **kw
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 2582, in __init__
#     self.project_name = safe_name(project_name or 'Unknown')
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 1314, in safe_name
#     return re.sub('[^A-Za-z0-9.]+', '-', name)
#   File "/home/takesako/anaconda3/lib/python3.7/re.py", line 194, in sub
#     return _compile(pattern, flags).sub(repl, string, count)
# KeyboardInterrupt
# Exception ignored in: <function _releaseLock at 0x7fc45cd52ef0>
# Traceback (most recent call last):
#   File "/home/takesako/anaconda3/lib/python3.7/logging/__init__.py", line 221, in _releaseLock
#     def _releaseLock():
# KeyboardInterrupt
# **************************************************
# syntax
# **************************************************
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# ^C
# Traceback (most recent call last):
#   File "../17_v1_09/train.py", line 1, in <module>
#     import torch
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/__init__.py", line 29, in <module>
#     from .torch_version import __version__ as __version__
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/torch_version.py", line 3, in <module>
#     from pkg_resources import packaging  # type: ignore[attr-defined]
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 3266, in <module>
#     @_call_aside
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 3241, in _call_aside
#     f(*args, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 3294, in _initialize_master_working_set
#     for dist in working_set
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 3294, in <genexpr>
#     for dist in working_set
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 2795, in activate
#     fixup_namespace_packages(self.location)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 2307, in fixup_namespace_packages
#     subpath = _handle_ns(package, path_item)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 2208, in _handle_ns
#     loader = importer.find_spec(packageName).loader
#   File "<frozen importlib._bootstrap_external>", line 1382, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 59, in _path_join
#   File "<frozen importlib._bootstrap_external>", line 59, in <listcomp>
# KeyboardInterrupt
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# args.mode =  pseudo
# train_df.shape =  (15142, 8)
# load folds...
# trn_df.shape =  (12113, 8)
# val_df.shape =  (3029, 8)
# adding fb3 data...
# trn_df.columns =  Index(['essay_id', 'cohesion', 'syntax', 'vocabulary', 'phraseology',
#        'grammar', 'conventions', 'full_text'],
#       dtype='object')
# fb3_trn_df.columns =  Index(['essay_id', 'full_text', 'cohesion', 'syntax', 'vocabulary',
#        'phraseology', 'grammar', 'conventions'],
#       dtype='object')
# fb3_trn_df.shape =  (3129, 8)
# fb3_trn_df[trn_df.columns].shape =  (3129, 8)
# adding fb3 data, done
# trn_df.shape =  (15242, 8)
# 2022-11-03 22:16:32.643423: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-03 22:16:32.643448: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# args.mode =  pseudo
# train_df.shape =  (15142, 8)
# load folds...
# trn_df.shape =  (12114, 8)
# val_df.shape =  (3028, 8)
# adding fb3 data...
# trn_df.columns =  Index(['essay_id', 'cohesion', 'syntax', 'vocabulary', 'phraseology',
#        'grammar', 'conventions', 'full_text'],
#       dtype='object')
# fb3_trn_df.columns =  Index(['essay_id', 'full_text', 'cohesion', 'syntax', 'vocabulary',
#        'phraseology', 'grammar', 'conventions'],
#       dtype='object')
# fb3_trn_df.shape =  (3129, 8)
# fb3_trn_df[trn_df.columns].shape =  (3129, 8)
# adding fb3 data, done
# trn_df.shape =  (15243, 8)
# 2022-11-03 22:16:36.338758: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-03 22:16:36.338783: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# ^C
# Traceback (most recent call last):
#   File "../17_v1_09/train.py", line 1, in <module>
#     import torch
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/__init__.py", line 29, in <module>
#     from .torch_version import __version__ as __version__
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/torch_version.py", line 3, in <module>
#     from pkg_resources import packaging  # type: ignore[attr-defined]
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 3266, in <module>
#     @_call_aside
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 3241, in _call_aside
#     f(*args, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 3279, in _initialize_master_working_set
#     working_set = WorkingSet._build_master()
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 564, in _build_master
#     ws = cls()
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 557, in __init__
#     self.add_entry(entry)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 613, in add_entry
#     for dist in find_distributions(entry, True):
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 2077, in find_on_path
#     for dist in factory(fullpath):
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 2135, in distributions_from_metadata
#     if len(os.listdir(path)) == 0:
# KeyboardInterrupt
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# ^C
# Traceback (most recent call last):
#   File "../17_v1_09/train.py", line 1, in <module>
#     import torch
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/__init__.py", line 29, in <module>
#     from .torch_version import __version__ as __version__
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/torch_version.py", line 3, in <module>
#     from pkg_resources import packaging  # type: ignore[attr-defined]
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 78, in <module>
#     __import__('pkg_resources.extern.packaging.requirements')
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/_vendor/packaging/requirements.py", line 10, in <module>
#     from pkg_resources.extern.pyparsing import (  # noqa
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 967, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 670, in _load_unlocked
#   File "<frozen importlib._bootstrap>", line 583, in module_from_spec
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/extern/__init__.py", line 52, in create_module
#     return self.load_module(spec.name)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/extern/__init__.py", line 37, in load_module
#     __import__(extant)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/_vendor/pyparsing.py", line 89, in <module>
#     import pprint
#   File "<frozen importlib._bootstrap>", line 980, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 148, in __enter__
#   File "<frozen importlib._bootstrap>", line 187, in _get_module_lock
# KeyboardInterrupt
# **************************************************
# vocabulary
# **************************************************
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# args.mode =  pseudo
# train_df.shape =  (15142, 8)
# load folds...
# trn_df.shape =  (12113, 8)
# val_df.shape =  (3029, 8)
# adding fb3 data...
# trn_df.columns =  Index(['essay_id', 'cohesion', 'syntax', 'vocabulary', 'phraseology',
#        'grammar', 'conventions', 'full_text'],
#       dtype='object')
# fb3_trn_df.columns =  Index(['essay_id', 'full_text', 'cohesion', 'syntax', 'vocabulary',
#        'phraseology', 'grammar', 'conventions'],
#       dtype='object')
# fb3_trn_df.shape =  (3128, 8)
# fb3_trn_df[trn_df.columns].shape =  (3128, 8)
# adding fb3 data, done
# trn_df.shape =  (15241, 8)
# 2022-11-03 22:16:42.642707: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-03 22:16:42.642731: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     156             else:
# --> 157                 child = pexpect.spawn(self.sh, args=['-c', cmd])  # Vanilla Pexpect
#     158             flush = sys.stdout.flush
#
# ~/anaconda3/lib/python3.7/site-packages/pexpect/pty_spawn.py in __init__(self, command, args, timeout, maxread, searchwindowsize, logfile, cwd, env, ignore_sighup, echo, preexec_fn, encoding, codec_errors, dimensions, use_poll)
#     204         else:
# --> 205             self._spawn(command, args, preexec_fn, dimensions)
#     206         self.use_poll = use_poll
#
# ~/anaconda3/lib/python3.7/site-packages/pexpect/pty_spawn.py in _spawn(self, command, args, preexec_fn, dimensions)
#     303         self.ptyproc = self._spawnpty(self.args, env=self.env,
# --> 304                                      cwd=self.cwd, **kwargs)
#     305
#
# ~/anaconda3/lib/python3.7/site-packages/pexpect/pty_spawn.py in _spawnpty(self, args, **kwargs)
#     314         '''Spawn a pty and return an instance of PtyProcess.'''
# --> 315         return ptyprocess.PtyProcess.spawn(args, **kwargs)
#     316
#
# ~/anaconda3/lib/python3.7/site-packages/ptyprocess/ptyprocess.py in spawn(cls, argv, cwd, env, echo, preexec_fn, dimensions, pass_fds)
#     314         os.close(exec_err_pipe_write)
# --> 315         exec_err_data = os.read(exec_err_pipe_read, 4096)
#     316         os.close(exec_err_pipe_read)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-2-cea2ba2b8a0e> in <module>
#      25         PRETRAIN_PATH = 'none'
#      26
# ---> 27         get_ipython().system('python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED          --lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS          --epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP          --accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD          --mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH          --msd $MSD --multi_layers $MULTI_LAYERS          --eval_step_start_epoch $EVAL_STEP_START_EPOCH --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH          --num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2          --restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE          --mt $MULTI_TASK --w_mt $W_MT          --awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH          --pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO          --scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP          --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN          --gradient_clip_val $GRAD_CLIP          --input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN          --crop_prob $CROP_PROB --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS --class_name $CLASS          --add_fb3 $ADD_FB3 --fb3_fold_path $FB3_FOLD_PATH')
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/zmqshell.py in system_piped(self, cmd)
#     636                 self.user_ns['_exit_code'] = system(cmd)
#     637         else:
# --> 638             self.user_ns['_exit_code'] = system(self.var_expand(cmd, depth=1))
#     639
#     640     # Ensure new system_piped implementation is used
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     171             # (the character is known as ETX for 'End of Text', see
#     172             # curses.ascii.ETX).
# --> 173             child.sendline(chr(3))
#     174             # Read and print any more output the program might produce on its
#     175             # way out.
#
# UnboundLocalError: local variable 'child' referenced before assignment

# %% [markdown]
# # Finetune

# %% [markdown]
# # OOF

# %%
INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_02/result/'

# %%
for CLASS in [
    'cohesion',
    #'syntax','vocabulary','phraseology','grammar','conventions'
]:
    print("*"*50)
    print(CLASS)
    print("*"*50)
    for FOLD in [0,1,2,3,4]:
        print("-"*50)
        print("FOLD = ", FOLD)
        print("-"*50)
        #WEIGHT_PATH = f'./result/{VERSION}/model_{CLASS}_seed{SEED}_fold{FOLD}.pth'
        WEIGHT_PATH = f'result/{VERSION}/model_{CLASS}_seed{SEED}_fold{FOLD}_pseudo.pth'
        # !python ../$VERSION/validation.py --model $MODEL --version $VERSION \
        --fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS \
        --rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH \
        --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --max_length $MAX_LEN \
        --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS --class_name $CLASS
# Out:
# **************************************************
# cohesion
# **************************************************
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# 2022-11-03 22:17:21.265982: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-03 22:17:21.266008: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3128, 8)
# val_df.shape =  (783, 8)
# 100%|███████████████████████████████████████████| 98/98 [00:09<00:00, 10.79it/s]
# val_loss=0.1178, val_score=0.4884
# essay_ids.shape =  (783,)
# preds.shape =  (783, 1)
# labels.shape =  (783, 1)
# losses.shape =  (783, 1)
# embeds.shape =  (783, 768)
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# 2022-11-03 22:17:46.788237: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-03 22:17:46.788260: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 100%|███████████████████████████████████████████| 98/98 [00:09<00:00, 10.65it/s]
# val_loss=0.1102, val_score=0.4707
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 768)
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# 2022-11-03 22:18:13.160515: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-03 22:18:13.160539: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 100%|███████████████████████████████████████████| 98/98 [00:09<00:00, 10.49it/s]
# val_loss=0.1148, val_score=0.4813
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 768)
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.1
# 2022-11-03 22:18:39.328744: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-03 22:18:39.328769: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# Traceback (most recent call last):
#   File "../17_v1_09/validation.py", line 150, in <module>
#     model.load_state_dict(torch.load(weight_path))
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/serialization.py", line 594, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/serialization.py", line 230, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/serialization.py", line 211, in __init__
#     super(_open_file, self).__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: 'result/17_v1_09/model_cohesion_seed100_fold3_pseudo.pth'
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.1
# 2022-11-03 22:18:53.269667: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-03 22:18:53.269690: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     161                 # know whether we've finished (if we matched EOF) or not
# --> 162                 res_idx = child.expect_list(patterns, self.read_timeout)
#     163                 print(child.before[out_size:].decode(enc, 'replace'), end='')
#
# ~/anaconda3/lib/python3.7/site-packages/pexpect/spawnbase.py in expect_list(self, pattern_list, timeout, searchwindowsize, async_, **kw)
#     371         else:
# --> 372             return exp.expect_loop(timeout)
#     373
#
# ~/anaconda3/lib/python3.7/site-packages/pexpect/expect.py in expect_loop(self, timeout)
#     168                 # Still have time left, so read more data
# --> 169                 incoming = spawn.read_nonblocking(spawn.maxread, timeout)
#     170                 if self.spawn.delayafterread is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/pexpect/pty_spawn.py in read_nonblocking(self, size, timeout)
#     499         # (possibly timeout=None), we call select() with a timeout.
# --> 500         if (timeout != 0) and select(timeout):
#     501             return super(spawn, self).read_nonblocking(size)
#
# ~/anaconda3/lib/python3.7/site-packages/pexpect/pty_spawn.py in select(timeout)
#     449             def select(timeout):
# --> 450                 return select_ignore_interrupts([self.child_fd], [], [], timeout)[0]
#     451
#
# ~/anaconda3/lib/python3.7/site-packages/pexpect/utils.py in select_ignore_interrupts(iwtd, owtd, ewtd, timeout)
#     142         try:
# --> 143             return select.select(iwtd, owtd, ewtd, timeout)
#     144         except InterruptedError:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-9738cc9810b4> in <module>
#      12         #WEIGHT_PATH = f'./result/{VERSION}/model_{CLASS}_seed{SEED}_fold{FOLD}.pth'
#      13         WEIGHT_PATH = f'result/{VERSION}/model_{CLASS}_seed{SEED}_fold{FOLD}_pseudo.pth'
# ---> 14         get_ipython().system('python ../$VERSION/validation.py --model $MODEL --version $VERSION          --fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS          --rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH          --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --max_length $MAX_LEN          --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS --class_name $CLASS')
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/zmqshell.py in system_piped(self, cmd)
#     636                 self.user_ns['_exit_code'] = system(cmd)
#     637         else:
# --> 638             self.user_ns['_exit_code'] = system(self.var_expand(cmd, depth=1))
#     639
#     640     # Ensure new system_piped implementation is used
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     184             finally:
#     185                 # Ensure the subprocess really is terminated
# --> 186                 child.terminate(force=True)
#     187         # add isalive check, to ensure exitstatus is set:
#     188         child.isalive()
#
# ~/anaconda3/lib/python3.7/site-packages/pexpect/pty_spawn.py in terminate(self, force)
#     640         try:
#     641             self.kill(signal.SIGHUP)
# --> 642             time.sleep(self.delayafterterminate)
#     643             if not self.isalive():
#     644                 return True
#
# KeyboardInterrupt:

# %%
import pandas as pd
import numpy as np

preds = []
for CLASS in [
    'cohesion',
    'syntax','vocabulary','phraseology','grammar','conventions'
]:
    print("*"*50)
    print(CLASS)
    print("*"*50)
    preds_class = []
    for fold in [0,1,2,3,4]:
        print("-"*50)
        print("FOLD = ", fold)
        print("-"*50)
        tmp_df = pd.read_csv(f'./result/{VERSION}/pred_{CLASS}_fold{fold}.csv')
        embeds = np.load(f'./result/{VERSION}/embeds_{CLASS}_fold{fold}.npz')['arr_0']
        tmp_df[f'embed_{CLASS}'] = embeds.tolist()
        preds_class.append(tmp_df)
    pred_df = pd.concat(preds_class, axis=0).reset_index(drop=True)
    if len(preds)==0:
        preds.append(pred_df)
    else:
        del pred_df["text_id"]
        preds.append(pred_df)
    
all_pred_df = pd.concat(preds, axis=1)

train_df = pd.read_csv('../../input/feedback-prize-english-language-learning/train.csv')
oof_df = train_df[['text_id']].merge(all_pred_df, on='text_id', how='left')
oof_df.to_csv(f'./result/{VERSION}/oof_df.csv', index=False)

# %%
oof_df.shape, oof_df.isnull().sum()

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
oof_df[cols].describe()

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
train_df[cols].describe()

# %% [markdown]
# # Error Analysis - Check Corr

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
train_df[cols].corr()

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
oof_df[cols].corr()
