# %%
VERSION = '17_v1_08'
MODEL = 'microsoft/deberta-v3-small'
#'microsoft/deberta-v3-base'
#'bert-large-cased'
#'bert-large-cased-whole-word-masking'
#'albert-large-v2'
#'facebook/bart-large'
#'xlm-roberta-large'
#'deepset/roberta-large-squad2'
#'google/electra-large-discriminator'
#'sentence-transformeres/paraphrase-mpnet-base-v2'
#'funnel-transformer/large-base'
#'facebook/bart-base'
#'distilroberta-base'
#'deepset/roberta-base-squad2'
#'microsoft/deberta-v3-base'
#'roberta-large'
#'roberta-base'
#'microsoft/deberta-v3-large'
#'microsoft/deberta-base'
LR = 1e-4 #2e-5 #8e-6
HEAD_LR = 1e-3 #2e-4 #2e-5 #8e-6 
SEED = 100
TRN_BS = 8
VAL_BS = 8
ACCUM_STEP = 1
HIDDEN_DROP_PROB = 0
P_DROP = 0
RNN = 'none'
WARMUP_RATIO = 0.1
HEAD = 'simple'
AUG = 'false'
MIXUP_ALPHA = 0
P_AUG = 0
AUG_STOP_EPOCH = 0
MSD = 'false'
POOLING = 'mean' #'weighted_layer'
NUM_POOLING_LAYERS = 4 #1
MULTI_LAYERS = 1
EVAL_STEP_START_EPOCH = -1
EVAL_STEP = -1
NUM_LABELS = 1 #6
NUM_LABELS_2 = -1
FP16 = 'true'
WD = 0.01
FREEZE = 'false'
MULTI_TASK = 'false' 
W_MT = 0 
AWP = 'false'
AWP_LR = 0
AWP_EPS = 0
AWP_START_EPOCH = -1
#PRETRAINED_DETECTOR_PATH = f'../../input/tascj/result/deberta_base_fold0.pth'
PRETRAINED_DETECTOR_PATH = 'none' #f'../../05_Detection/exp/result/05_v2_09/model_seed100_fold0_swa.pth'
MASK_PROB = 0 #0.8
MASK_RATIO = 0 #0.3
SCHEDULER = 'cosine_hard'
CP = 'true' #'false'
WINDOW_SIZE = -1 #512
INNER_LEN = -1 #384
EDGE_LEN = -1 #64
MAX_LEN = 512

GRAD_CLIP = 1

LOSS = 'smoothl1'#'mse'

CROP_PROB = 0 #1.0

# %% [markdown]
# # Train with Pseudo-Label

# %%
MODE = 'pseudo'
EPOCHS = 1 #8
STOP_EPOCH = 1 #3
RESTART = 1
NUM_CYCLES = 1
EVAL_STEP = -1
ADD_FB3 = 'true'
FB3_FOLD_PATH = '../../00_EDA/00_v1_02/result/'

for CLASS in [
    'cohesion',
    'syntax','vocabulary','phraseology','grammar','conventions'
]:
    print("*"*50)
    print(CLASS)
    print("*"*50)
    for FOLD in [0,1,2,3,4]:
        print("-"*50)
        print("FOLD = ", FOLD)
        print("-"*50)
        #INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
        #FOLD_PATH = '../../00_EDA/00_v1_02/result/'
        INPUT_PATH = f'../../99_Ensemble/99_v1_03/result/99_v1_03_03_pseudo_fold{FOLD}.csv'
        FOLD_PATH = '../../00_EDA/00_v1_08/result/' # for pseudo-label
        PRETRAIN_PATH = 'none'

        # !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
        --lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
        --epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
        --accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
        --mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
        --msd $MSD --multi_layers $MULTI_LAYERS \
        --eval_step_start_epoch $EVAL_STEP_START_EPOCH --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
        --num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
        --restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
        --mt $MULTI_TASK --w_mt $W_MT \
        --awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
        --pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
        --scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
        --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN \
        --gradient_clip_val $GRAD_CLIP \
        --input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN \
        --crop_prob $CROP_PROB --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS --class_name $CLASS \
        --add_fb3 $ADD_FB3 --fb3_fold_path $FB3_FOLD_PATH
# Out:
# **************************************************
# cohesion
# **************************************************
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# args.mode =  pseudo
# train_df.shape =  (15142, 8)
# load folds...
# trn_df.shape =  (12113, 8)
# val_df.shape =  (3029, 8)
# adding fb3 data...
# trn_df.columns =  Index(['essay_id', 'cohesion', 'syntax', 'vocabulary', 'phraseology',
#        'grammar', 'conventions', 'full_text'],
#       dtype='object')
# fb3_trn_df.columns =  Index(['essay_id', 'full_text', 'cohesion', 'syntax', 'vocabulary',
#        'phraseology', 'grammar', 'conventions'],
#       dtype='object')
# fb3_trn_df.shape =  (3128, 8)
# fb3_trn_df[trn_df.columns].shape =  (3128, 8)
# adding fb3 data, done
# trn_df.shape =  (15241, 8)
# 2022-11-03 21:27:49.490490: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-03 21:27:49.490515: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# self.warmup_ratio =  0.1
# self.num_train_steps =  1905
# num_warmup_steps =  190
# lr :  [0.0, 0.0, 0.0]
# 100%|██████████████████████████| 1905/1905 [06:28<00:00,  4.90it/s, loss=0.0693]
# 100%|█████████████████████████████████████████| 379/379 [00:58<00:00,  6.47it/s]
# epoch 1: trn_loss = 0.0693, val_loss = 0.0045, trn_score = 0.4303, val_score = 0.0953
# model_cohesion (best score) saved
#
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# args.mode =  pseudo
# train_df.shape =  (15142, 8)
# load folds...
# trn_df.shape =  (12113, 8)
# val_df.shape =  (3029, 8)
# adding fb3 data...
# trn_df.columns =  Index(['essay_id', 'cohesion', 'syntax', 'vocabulary', 'phraseology',
#        'grammar', 'conventions', 'full_text'],
#       dtype='object')
# fb3_trn_df.columns =  Index(['essay_id', 'full_text', 'cohesion', 'syntax', 'vocabulary',
#        'phraseology', 'grammar', 'conventions'],
#       dtype='object')
# fb3_trn_df.shape =  (3129, 8)
# fb3_trn_df[trn_df.columns].shape =  (3129, 8)
# adding fb3 data, done
# trn_df.shape =  (15242, 8)
# 2022-11-03 21:35:34.646420: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-03 21:35:34.646444: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# self.warmup_ratio =  0.1
# self.num_train_steps =  1905
# num_warmup_steps =  190
# lr :  [0.0, 0.0, 0.0]
# 100%|██████████████████████████| 1905/1905 [06:32<00:00,  4.85it/s, loss=0.0822]
# 100%|█████████████████████████████████████████| 379/379 [00:58<00:00,  6.47it/s]
# epoch 1: trn_loss = 0.0822, val_loss = 0.0033, trn_score = 0.5025, val_score = 0.0818
# model_cohesion (best score) saved
#
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# args.mode =  pseudo
# train_df.shape =  (15142, 8)
# load folds...
# trn_df.shape =  (12114, 8)
# val_df.shape =  (3028, 8)
# adding fb3 data...
# trn_df.columns =  Index(['essay_id', 'cohesion', 'syntax', 'vocabulary', 'phraseology',
#        'grammar', 'conventions', 'full_text'],
#       dtype='object')
# fb3_trn_df.columns =  Index(['essay_id', 'full_text', 'cohesion', 'syntax', 'vocabulary',
#        'phraseology', 'grammar', 'conventions'],
#       dtype='object')
# fb3_trn_df.shape =  (3129, 8)
# fb3_trn_df[trn_df.columns].shape =  (3129, 8)
# adding fb3 data, done
# trn_df.shape =  (15243, 8)
# 2022-11-03 21:43:23.197694: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-03 21:43:23.197718: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ^C
# Traceback (most recent call last):
#   File "../17_v1_08/train.py", line 168, in <module>
#     run(args, trn_df, val_df, pseudo_df=None)
#   File "/home/takesako/programming/kaggle/kaggle-feedback-prize-english-language-learning/17_Pseudo3/17_v1_08/run.py", line 22, in run
#     tokenizer = DebertaV2TokenizerFast.from_pretrained(args.model, trim_offsets=False)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/transformers/tokenization_utils_base.py", line 1715, in from_pretrained
#     user_agent=user_agent,
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/transformers/file_utils.py", line 1854, in cached_path
#     local_files_only=local_files_only,
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/transformers/file_utils.py", line 2049, in get_from_cache
#     r = requests.head(url, headers=headers, allow_redirects=False, proxies=proxies, timeout=etag_timeout)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/requests/api.py", line 104, in head
#     return request('head', url, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/requests/api.py", line 61, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/requests/sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/requests/sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/requests/adapters.py", line 449, in send
#     timeout=timeout
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py", line 706, in urlopen
#     chunked=chunked,
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "/home/takesako/anaconda3/lib/python3.7/http/client.py", line 1354, in getresponse
#     response.begin()
#   File "/home/takesako/anaconda3/lib/python3.7/http/client.py", line 306, in begin
#     version, status, reason = self._read_status()
#   File "/home/takesako/anaconda3/lib/python3.7/http/client.py", line 267, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/home/takesako/anaconda3/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
#   File "/home/takesako/anaconda3/lib/python3.7/ssl.py", line 1071, in recv_into
#     return self.read(nbytes, buffer)
#   File "/home/takesako/anaconda3/lib/python3.7/ssl.py", line 929, in read
#     return self._sslobj.read(len, buffer)
# KeyboardInterrupt
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.1
# args.mode =  pseudo
# train_df.shape =  (15142, 8)
# load folds...
# trn_df.shape =  (12114, 8)
# val_df.shape =  (3028, 8)
# adding fb3 data...
# trn_df.columns =  Index(['essay_id', 'cohesion', 'syntax', 'vocabulary', 'phraseology',
#        'grammar', 'conventions', 'full_text'],
#       dtype='object')
# fb3_trn_df.columns =  Index(['essay_id', 'full_text', 'cohesion', 'syntax', 'vocabulary',
#        'phraseology', 'grammar', 'conventions'],
#       dtype='object')
# fb3_trn_df.shape =  (3129, 8)
# fb3_trn_df[trn_df.columns].shape =  (3129, 8)
# adding fb3 data, done
# trn_df.shape =  (15243, 8)
# 2022-11-03 21:43:28.534673: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-03 21:43:28.534696: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# ^C
# Traceback (most recent call last):
#   File "../17_v1_08/train.py", line 1, in <module>
#     import torch
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/__init__.py", line 29, in <module>
#     from .torch_version import __version__ as __version__
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/torch_version.py", line 3, in <module>
#     from pkg_resources import packaging  # type: ignore[attr-defined]
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 3266, in <module>
#     @_call_aside
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 3241, in _call_aside
#     f(*args, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 3294, in _initialize_master_working_set
#     for dist in working_set
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 3294, in <genexpr>
#     for dist in working_set
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 2795, in activate
#     fixup_namespace_packages(self.location)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 2307, in fixup_namespace_packages
#     subpath = _handle_ns(package, path_item)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 2208, in _handle_ns
#     loader = importer.find_spec(packageName).loader
#   File "<frozen importlib._bootstrap_external>", line 1391, in find_spec
# KeyboardInterrupt
# **************************************************
# syntax
# **************************************************
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# args.mode =  pseudo
# train_df.shape =  (15142, 8)
# load folds...
# trn_df.shape =  (12113, 8)
# val_df.shape =  (3029, 8)
# adding fb3 data...
# trn_df.columns =  Index(['essay_id', 'cohesion', 'syntax', 'vocabulary', 'phraseology',
#        'grammar', 'conventions', 'full_text'],
#       dtype='object')
# fb3_trn_df.columns =  Index(['essay_id', 'full_text', 'cohesion', 'syntax', 'vocabulary',
#        'phraseology', 'grammar', 'conventions'],
#       dtype='object')
# fb3_trn_df.shape =  (3128, 8)
# fb3_trn_df[trn_df.columns].shape =  (3128, 8)
# adding fb3 data, done
# trn_df.shape =  (15241, 8)
# 2022-11-03 21:43:31.999443: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-03 21:43:31.999468: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/IPython/utils/_process_posix.py", line 162, in system
#     res_idx = child.expect_list(patterns, self.read_timeout)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pexpect/spawnbase.py", line 372, in expect_list
#     return exp.expect_loop(timeout)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pexpect/expect.py", line 169, in expect_loop
#     incoming = spawn.read_nonblocking(spawn.maxread, timeout)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pexpect/pty_spawn.py", line 500, in read_nonblocking
#     if (timeout != 0) and select(timeout):
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pexpect/pty_spawn.py", line 450, in select
#     return select_ignore_interrupts([self.child_fd], [], [], timeout)[0]
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pexpect/utils.py", line 143, in select_ignore_interrupts
#     return select.select(iwtd, owtd, ewtd, timeout)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3418, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-cea2ba2b8a0e>", line 27, in <module>
#     get_ipython().system('python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED          --lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS          --epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP          --accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD          --mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH          --msd $MSD --multi_layers $MULTI_LAYERS          --eval_step_start_epoch $EVAL_STEP_START_EPOCH --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH          --num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2          --restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE          --mt $MULTI_TASK --w_mt $W_MT          --awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH          --pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO          --scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP          --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN          --gradient_clip_val $GRAD_CLIP          --input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN          --crop_prob $CROP_PROB --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS --class_name $CLASS          --add_fb3 $ADD_FB3 --fb3_fold_path $FB3_FOLD_PATH')
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 638, in system_piped
#     self.user_ns['_exit_code'] = system(self.var_expand(cmd, depth=1))
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/IPython/utils/_process_posix.py", line 186, in system
#     child.terminate(force=True)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pexpect/pty_spawn.py", line 642, in terminate
#     time.sleep(self.delayafterterminate)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2045, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1170, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/takesako/anaconda3/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/takesako/anaconda3/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/takesako/anaconda3/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/takesako/anaconda3/lib/python3.7/inspect.py", line 742, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/home/takesako/anaconda3/lib/python3.7/posixpath.py", line 396, in realpath
#     return abspath(path)
#   File "/home/takesako/anaconda3/lib/python3.7/posixpath.py", line 385, in abspath
#     return normpath(path)
#   File "/home/takesako/anaconda3/lib/python3.7/posixpath.py", line 370, in normpath
#     path = sep.join(comps)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     161                 # know whether we've finished (if we matched EOF) or not
# --> 162                 res_idx = child.expect_list(patterns, self.read_timeout)
#     163                 print(child.before[out_size:].decode(enc, 'replace'), end='')
#
# ~/anaconda3/lib/python3.7/site-packages/pexpect/spawnbase.py in expect_list(self, pattern_list, timeout, searchwindowsize, async_, **kw)
#     371         else:
# --> 372             return exp.expect_loop(timeout)
#     373
#
# ~/anaconda3/lib/python3.7/site-packages/pexpect/expect.py in expect_loop(self, timeout)
#     168                 # Still have time left, so read more data
# --> 169                 incoming = spawn.read_nonblocking(spawn.maxread, timeout)
#     170                 if self.spawn.delayafterread is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/pexpect/pty_spawn.py in read_nonblocking(self, size, timeout)
#     499         # (possibly timeout=None), we call select() with a timeout.
# --> 500         if (timeout != 0) and select(timeout):
#     501             return super(spawn, self).read_nonblocking(size)
#
# ~/anaconda3/lib/python3.7/site-packages/pexpect/pty_spawn.py in select(timeout)
#     449             def select(timeout):
# --> 450                 return select_ignore_interrupts([self.child_fd], [], [], timeout)[0]
#     451
#
# ~/anaconda3/lib/python3.7/site-packages/pexpect/utils.py in select_ignore_interrupts(iwtd, owtd, ewtd, timeout)
#     142         try:
# --> 143             return select.select(iwtd, owtd, ewtd, timeout)
#     144         except InterruptedError:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-2-cea2ba2b8a0e> in <module>
#      26
# ---> 27         get_ipython().system('python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED          --lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS          --epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP          --accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD          --mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH          --msd $MSD --multi_layers $MULTI_LAYERS          --eval_step_start_epoch $EVAL_STEP_START_EPOCH --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH          --num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2          --restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE          --mt $MULTI_TASK --w_mt $W_MT          --awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH          --pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO          --scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP          --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN          --gradient_clip_val $GRAD_CLIP          --input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN          --crop_prob $CROP_PROB --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS --class_name $CLASS          --add_fb3 $ADD_FB3 --fb3_fold_path $FB3_FOLD_PATH')
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/zmqshell.py in system_piped(self, cmd)
#     637         else:
# --> 638             self.user_ns['_exit_code'] = system(self.var_expand(cmd, depth=1))
#     639
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     185                 # Ensure the subprocess really is terminated
# --> 186                 child.terminate(force=True)
#     187         # add isalive check, to ensure exitstatus is set:
#
# ~/anaconda3/lib/python3.7/site-packages/pexpect/pty_spawn.py in terminate(self, force)
#     641             self.kill(signal.SIGHUP)
# --> 642             time.sleep(self.delayafterterminate)
#     643             if not self.isalive():
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2044                         # in the engines. This should return a list of strings.
# -> 2045                         stb = value._render_traceback_()
#    2046                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2046                     except Exception:
#    2047                         stb = self.InteractiveTB.structured_traceback(etype,
# -> 2048                                             value, tb, tb_offset=tb_offset)
#    2049
#    2050                     self._showtraceback(etype, value, stb)
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1435             self.tb = tb
#    1436         return FormattedTB.structured_traceback(
# -> 1437             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1438
#    1439
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1335             # Verbose modes need a full traceback
#    1336             return VerboseTB.structured_traceback(
# -> 1337                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1338             )
#    1339         elif mode == 'Minimal':
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1192
#    1193         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
# -> 1194                                                                tb_offset)
#    1195
#    1196         colors = self.Colors  # just a shorthand + quicker name lookup
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1149
#    1150
# -> 1151         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1152
#    1153         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     449     # first frame (from in to out) that looks different.
#     450     if not is_recursion_error(etype, value, records):
# --> 451         return len(records), 0
#     452
#     453     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %% [markdown]
# # Finetune

# %% [markdown]
# # OOF

# %%
INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_02/result/'

# %%
for CLASS in [
    'cohesion',
    'syntax','vocabulary','phraseology','grammar','conventions'
]:
    print("*"*50)
    print(CLASS)
    print("*"*50)
    for FOLD in [0,1,2,3,4]:
        print("-"*50)
        print("FOLD = ", FOLD)
        print("-"*50)
        #WEIGHT_PATH = f'./result/{VERSION}/model_{CLASS}_seed{SEED}_fold{FOLD}.pth'
        WEIGHT_PATH = f'result/{VERSION}/model_{CLASS}_seed{SEED}_fold{FOLD}_pseudo.pth'
        # !python ../$VERSION/validation.py --model $MODEL --version $VERSION \
        --fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS \
        --rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH \
        --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --max_length $MAX_LEN \
        --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS --class_name $CLASS
# Out:
# **************************************************
# cohesion
# **************************************************
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# 2022-11-03 21:43:41.801112: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-03 21:43:41.801136: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3128, 8)
# val_df.shape =  (783, 8)
# 100%|███████████████████████████████████████████| 98/98 [00:09<00:00, 10.67it/s]
# val_loss=0.1195, val_score=0.4918
# essay_ids.shape =  (783,)
# preds.shape =  (783, 1)
# labels.shape =  (783, 1)
# losses.shape =  (783, 1)
# embeds.shape =  (783, 768)
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# 2022-11-03 21:44:07.999545: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-03 21:44:07.999566: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 100%|███████████████████████████████████████████| 98/98 [00:09<00:00, 10.61it/s]
# val_loss=0.1105, val_score=0.4715
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 768)
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# 2022-11-03 21:44:34.178279: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-03 21:44:34.178304: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# Traceback (most recent call last):
#   File "../17_v1_08/validation.py", line 150, in <module>
#     model.load_state_dict(torch.load(weight_path))
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/serialization.py", line 594, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/serialization.py", line 230, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/serialization.py", line 211, in __init__
#     super(_open_file, self).__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: 'result/17_v1_08/model_cohesion_seed100_fold2_pseudo.pth'
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.1
# 2022-11-03 21:44:48.341748: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-03 21:44:48.341771: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# **************************************************
# syntax
# **************************************************
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# 2022-11-03 21:44:54.236012: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-03 21:44:54.236037: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3128, 8)
# val_df.shape =  (783, 8)
# ^C
# Traceback (most recent call last):
#   File "../17_v1_08/validation.py", line 104, in <module>
#     tokenizer = DebertaV2TokenizerFast.from_pretrained(args.model, trim_offsets=False)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/transformers/tokenization_utils_base.py", line 1780, in from_pretrained
#     **kwargs,
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/transformers/tokenization_utils_base.py", line 1834, in _from_pretrained
#     cache_dir=cache_dir,
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/transformers/models/auto/configuration_auto.py", line 612, in from_pretrained
#     config_dict, _ = PretrainedConfig.get_config_dict(pretrained_model_name_or_path, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/transformers/configuration_utils.py", line 537, in get_config_dict
#     config_dict, kwargs = cls._get_config_dict(pretrained_model_name_or_path, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/transformers/configuration_utils.py", line 593, in _get_config_dict
#     user_agent=user_agent,
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/transformers/file_utils.py", line 1854, in cached_path
#     local_files_only=local_files_only,
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/transformers/file_utils.py", line 2049, in get_from_cache
#     r = requests.head(url, headers=headers, allow_redirects=False, proxies=proxies, timeout=etag_timeout)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/requests/api.py", line 104, in head
#     return request('head', url, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/requests/api.py", line 61, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/requests/sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/requests/sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/requests/adapters.py", line 449, in send
#     timeout=timeout
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py", line 706, in urlopen
#     chunked=chunked,
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "/home/takesako/anaconda3/lib/python3.7/http/client.py", line 1354, in getresponse
#     response.begin()
#   File "/home/takesako/anaconda3/lib/python3.7/http/client.py", line 306, in begin
#     version, status, reason = self._read_status()
#   File "/home/takesako/anaconda3/lib/python3.7/http/client.py", line 267, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/home/takesako/anaconda3/lib/python3.7/socket.py", line 589, in readinto
#     return self._sock.recv_into(b)
#   File "/home/takesako/anaconda3/lib/python3.7/ssl.py", line 1071, in recv_into
#     return self.read(nbytes, buffer)
#   File "/home/takesako/anaconda3/lib/python3.7/ssl.py", line 929, in read
#     return self._sslobj.read(len, buffer)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     161                 # know whether we've finished (if we matched EOF) or not
# --> 162                 res_idx = child.expect_list(patterns, self.read_timeout)
#     163                 print(child.before[out_size:].decode(enc, 'replace'), end='')
#
# ~/anaconda3/lib/python3.7/site-packages/pexpect/spawnbase.py in expect_list(self, pattern_list, timeout, searchwindowsize, async_, **kw)
#     371         else:
# --> 372             return exp.expect_loop(timeout)
#     373
#
# ~/anaconda3/lib/python3.7/site-packages/pexpect/expect.py in expect_loop(self, timeout)
#     168                 # Still have time left, so read more data
# --> 169                 incoming = spawn.read_nonblocking(spawn.maxread, timeout)
#     170                 if self.spawn.delayafterread is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/pexpect/pty_spawn.py in read_nonblocking(self, size, timeout)
#     499         # (possibly timeout=None), we call select() with a timeout.
# --> 500         if (timeout != 0) and select(timeout):
#     501             return super(spawn, self).read_nonblocking(size)
#
# ~/anaconda3/lib/python3.7/site-packages/pexpect/pty_spawn.py in select(timeout)
#     449             def select(timeout):
# --> 450                 return select_ignore_interrupts([self.child_fd], [], [], timeout)[0]
#     451
#
# ~/anaconda3/lib/python3.7/site-packages/pexpect/utils.py in select_ignore_interrupts(iwtd, owtd, ewtd, timeout)
#     142         try:
# --> 143             return select.select(iwtd, owtd, ewtd, timeout)
#     144         except InterruptedError:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-e271d4760acf> in <module>
#      12         #WEIGHT_PATH = f'./result/{VERSION}/model_{CLASS}_seed{SEED}_fold{FOLD}.pth'
#      13         WEIGHT_PATH = f'result/{VERSION}/model_{CLASS}_seed{SEED}_fold{FOLD}_pseudo.pth'
# ---> 14         get_ipython().system('python ../$VERSION/validation.py --model $MODEL --version $VERSION          --fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS          --rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH          --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --max_length $MAX_LEN          --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS --class_name $CLASS')
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/zmqshell.py in system_piped(self, cmd)
#     636                 self.user_ns['_exit_code'] = system(cmd)
#     637         else:
# --> 638             self.user_ns['_exit_code'] = system(self.var_expand(cmd, depth=1))
#     639
#     640     # Ensure new system_piped implementation is used
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     184             finally:
#     185                 # Ensure the subprocess really is terminated
# --> 186                 child.terminate(force=True)
#     187         # add isalive check, to ensure exitstatus is set:
#     188         child.isalive()
#
# ~/anaconda3/lib/python3.7/site-packages/pexpect/pty_spawn.py in terminate(self, force)
#     640         try:
#     641             self.kill(signal.SIGHUP)
# --> 642             time.sleep(self.delayafterterminate)
#     643             if not self.isalive():
#     644                 return True
#
# KeyboardInterrupt:

# %%
import pandas as pd
import numpy as np

preds = []
for CLASS in [
    'cohesion',
    'syntax','vocabulary','phraseology','grammar','conventions'
]:
    print("*"*50)
    print(CLASS)
    print("*"*50)
    preds_class = []
    for fold in [0,1,2,3,4]:
        print("-"*50)
        print("FOLD = ", fold)
        print("-"*50)
        tmp_df = pd.read_csv(f'./result/{VERSION}/pred_{CLASS}_fold{fold}.csv')
        embeds = np.load(f'./result/{VERSION}/embeds_{CLASS}_fold{fold}.npz')['arr_0']
        tmp_df[f'embed_{CLASS}'] = embeds.tolist()
        preds_class.append(tmp_df)
    pred_df = pd.concat(preds_class, axis=0).reset_index(drop=True)
    if len(preds)==0:
        preds.append(pred_df)
    else:
        del pred_df["text_id"]
        preds.append(pred_df)
    
all_pred_df = pd.concat(preds, axis=1)

train_df = pd.read_csv('../../input/feedback-prize-english-language-learning/train.csv')
oof_df = train_df[['text_id']].merge(all_pred_df, on='text_id', how='left')
oof_df.to_csv(f'./result/{VERSION}/oof_df.csv', index=False)

# %%
oof_df.shape, oof_df.isnull().sum()

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
oof_df[cols].describe()

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
train_df[cols].describe()

# %% [markdown]
# # Error Analysis - Check Corr

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
train_df[cols].corr()

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
oof_df[cols].corr()
