# %%
VERSION = '21_v2_01'
MODEL = 'microsoft/deberta-v3-base'
#TEACHER_VERSION = '14_v1_15' # deverta-v2-xlarge
#'bert-large-cased'
#'bert-large-cased-whole-word-masking'
#'albert-large-v2'
#'facebook/bart-large'
#'xlm-roberta-large'
#'deepset/roberta-large-squad2'
#'google/electra-large-discriminator'
#'sentence-transformeres/paraphrase-mpnet-base-v2'
#'funnel-transformer/large-base'
#'facebook/bart-base'
#'distilroberta-base'
#'deepset/roberta-base-squad2'
#'microsoft/deberta-v3-base'
#'roberta-large'
#'roberta-base'
#'microsoft/deberta-v3-large'
#'microsoft/deberta-base'
LR = 2e-5 #8e-6
HEAD_LR = 2e-4 #2e-5 #8e-6 
SEED = 100
TRN_BS = 8
VAL_BS = 8
ACCUM_STEP = 1
HIDDEN_DROP_PROB = 0
P_DROP = 0
RNN = 'none'
WARMUP_RATIO = 0.1
HEAD = 'simple'
AUG = 'false'
MIXUP_ALPHA = 0
P_AUG = 0
AUG_STOP_EPOCH = 0
MSD = 'false'
POOLING = 'mean' #'weighted_layer'
NUM_POOLING_LAYERS = 4 #1
MULTI_LAYERS = 1
EVAL_STEP_START_EPOCH = -1
EVAL_STEP = -1
NUM_LABELS = 1 #6
NUM_LABELS_2 = -1
FP16 = 'true'
WD = 0.01
FREEZE = 'false'
MULTI_TASK = 'false' 
W_MT = 0 
AWP = 'false'
AWP_LR = 0
AWP_EPS = 0
AWP_START_EPOCH = -1
#PRETRAINED_DETECTOR_PATH = f'../../input/tascj/result/deberta_base_fold0.pth'
PRETRAINED_DETECTOR_PATH = 'none' #f'../../05_Detection/exp/result/05_v2_09/model_seed100_fold0_swa.pth'
MASK_PROB = 0 #0.8
MASK_RATIO = 0 #0.3
SCHEDULER = 'cosine_hard'
CP = 'true' #'false'
WINDOW_SIZE = -1 #512
INNER_LEN = -1 #384
EDGE_LEN = -1 #64
MAX_LEN = 512

GRAD_CLIP = 1

LOSS = 'smoothl1'#'mse'

CROP_PROB = 0 #1.0

# %% [markdown]
# # Train

# %%
MODE = 'train'
EPOCHS = 5
STOP_EPOCH = 5
RESTART = 1
NUM_CYCLES = 5
EVAL_STEP = -1
ADD_FB3 = 'false'
FB3_FOLD_PATH = '../../00_EDA/00_v1_02/result/'

for CLASS in [
    'avg',
    #'cohesion',
    #'syntax','vocabulary','phraseology','grammar','conventions'
]:
    print("*"*50)
    print(CLASS)
    print("*"*50)
    for FOLD in [0,1,2,3,4]:
#         if CLASS=='cohesion':
#             continue
#         if CLASS=='syntax' and FOLD in [0,1,2]:
#             continue
        print("-"*50)
        print("FOLD = ", FOLD)
        print("-"*50)
        INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
        FOLD_PATH = '../../00_EDA/00_v1_02/result/'
        #INPUT_PATH = f'../../99_Ensemble/99_v1_03/result/99_v1_03_03_pseudo_fold{FOLD}.csv'
        #INPUT_PATH = f'../../99_Ensemble/99_v1_03/result/99_v1_03_03_{TEACHER_VERSION}_pseudo_fold{FOLD}.csv'
        #FOLD_PATH = '../../00_EDA/00_v1_08/result/' # for pseudo-label
        PRETRAIN_PATH = 'none'

        # !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
        --lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
        --epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
        --accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
        --mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
        --msd $MSD --multi_layers $MULTI_LAYERS \
        --eval_step_start_epoch $EVAL_STEP_START_EPOCH --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
        --num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
        --restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
        --mt $MULTI_TASK --w_mt $W_MT \
        --awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
        --pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
        --scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
        --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN \
        --gradient_clip_val $GRAD_CLIP \
        --input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN \
        --crop_prob $CROP_PROB --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS --class_name $CLASS \
        --add_fb3 $ADD_FB3 --fb3_fold_path $FB3_FOLD_PATH
# Out:
# **************************************************
# avg
# **************************************************
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.2
# 2022-11-06 11:08:25.188693: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-11-06 11:08:25.188716: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3128, 8)
# val_df.shape =  (783, 8)
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [01:53<00:00,  3.46it/s, loss=0.313]
# 100%|███████████████████████████████████████████| 98/98 [00:14<00:00,  6.53it/s]
# epoch 1: trn_loss = 0.3129, val_loss = 0.0548, trn_score = 1.0242, val_score = 0.3312
# model_avg (best score) saved
# lr :  [8.224468037456969e-06, 8.224468037456969e-06, 8.224468037456969e-05]
# 100%|████████████████████████████| 391/391 [01:51<00:00,  3.49it/s, loss=0.0561]
# 100%|███████████████████████████████████████████| 98/98 [00:15<00:00,  6.52it/s]
# epoch 2: trn_loss = 0.0561, val_loss = 0.0560, trn_score = 0.3351, val_score = 0.3346
# lr :  [4.974257968932691e-06, 4.974257968932691e-06, 4.974257968932691e-05]
# 100%|████████████████████████████| 391/391 [01:51<00:00,  3.49it/s, loss=0.0501]
# 100%|███████████████████████████████████████████| 98/98 [00:14<00:00,  6.55it/s]
# epoch 3: trn_loss = 0.0501, val_loss = 0.0613, trn_score = 0.3164, val_score = 0.3502
# lr :  [2.3268220525837457e-06, 2.3268220525837457e-06, 2.3268220525837457e-05]
# 100%|████████████████████████████| 391/391 [01:51<00:00,  3.49it/s, loss=0.0461]
# 100%|███████████████████████████████████████████| 98/98 [00:15<00:00,  6.52it/s]
# epoch 4: trn_loss = 0.0461, val_loss = 0.0542, trn_score = 0.3036, val_score = 0.3293
# model_avg (best score) saved
# lr :  [5.996867213330993e-07, 5.996867213330993e-07, 5.996867213330992e-06]
# 100%|████████████████████████████| 391/391 [01:52<00:00,  3.48it/s, loss=0.0409]
# 100%|███████████████████████████████████████████| 98/98 [00:15<00:00,  6.53it/s]
# epoch 5: trn_loss = 0.0409, val_loss = 0.0553, trn_score = 0.2861, val_score = 0.3325
#
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.2
# 2022-11-06 11:19:17.054799: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-11-06 11:19:17.054827: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [01:53<00:00,  3.45it/s, loss=0.206]
# 100%|███████████████████████████████████████████| 98/98 [00:14<00:00,  6.54it/s]
# epoch 1: trn_loss = 0.2061, val_loss = 0.0555, trn_score = 0.7305, val_score = 0.3335
# model_avg (best score) saved
# lr :  [8.224468037456969e-06, 8.224468037456969e-06, 8.224468037456969e-05]
# 100%|████████████████████████████| 391/391 [01:53<00:00,  3.45it/s, loss=0.0534]
# 100%|███████████████████████████████████████████| 98/98 [00:14<00:00,  6.54it/s]
# epoch 2: trn_loss = 0.0534, val_loss = 0.0558, trn_score = 0.3267, val_score = 0.3344
# lr :  [4.974257968932691e-06, 4.974257968932691e-06, 4.974257968932691e-05]
#   2%|▋                             | 9/391 [00:02<01:53,  3.37it/s, loss=0.0521]^C
#   3%|▋                            | 10/391 [00:03<02:00,  3.15it/s, loss=0.0523]
# Traceback (most recent call last):
#   File "../21_v2_01/train.py", line 177, in <module>
#     run(args, trn_df, val_df, pseudo_df=None)
#   File "/home/takesako2/programming/kaggle/kaggle-feedback-prize-english-language-learning/21_Baseline5/21_v2_01/run.py", line 187, in run
#     pred, label, loss = model.training_step(data)
#   File "/home/takesako2/programming/kaggle/kaggle-feedback-prize-english-language-learning/21_Baseline5/21_v2_01/models.py", line 414, in training_step
#     logits = self.forward_logits(**input_data)
#   File "/home/takesako2/programming/kaggle/kaggle-feedback-prize-english-language-learning/21_Baseline5/21_v2_01/models.py", line 313, in forward_logits
#     attention_mask=attention_mask)
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/transformers/models/deberta_v2/modeling_deberta_v2.py", line 1054, in forward
#     return_dict=return_dict,
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/transformers/models/deberta_v2/modeling_deberta_v2.py", line 495, in forward
#     rel_embeddings,
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/torch/utils/checkpoint.py", line 211, in checkpoint
#     return CheckpointFunction.apply(function, preserve, *args)
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/torch/utils/checkpoint.py", line 90, in forward
#     outputs = run_function(*args)
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/transformers/models/deberta_v2/modeling_deberta_v2.py", line 485, in custom_forward
#     return module(*inputs, output_attentions)
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/transformers/models/deberta_v2/modeling_deberta_v2.py", line 348, in forward
#     rel_embeddings=rel_embeddings,
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/transformers/models/deberta_v2/modeling_deberta_v2.py", line 279, in forward
#     rel_embeddings=rel_embeddings,
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/transformers/models/deberta_v2/modeling_deberta_v2.py", line 699, in forward
#     query_layer, key_layer, relative_pos, rel_embeddings, scale_factor
#   File "/home/takesako2/anaconda3/lib/python3.7/site-packages/transformers/models/deberta_v2/modeling_deberta_v2.py", line 742, in disentangled_attention_bias
#     relative_pos = relative_pos.long().to(query_layer.device)
# KeyboardInterrupt
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.2
# 2022-11-06 11:23:50.900153: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2022-11-06 11:23:50.900174: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     161                 # know whether we've finished (if we matched EOF) or not
# --> 162                 res_idx = child.expect_list(patterns, self.read_timeout)
#     163                 print(child.before[out_size:].decode(enc, 'replace'), end='')
#
# ~/anaconda3/lib/python3.7/site-packages/pexpect/spawnbase.py in expect_list(self, pattern_list, timeout, searchwindowsize, async_, **kw)
#     371         else:
# --> 372             return exp.expect_loop(timeout)
#     373
#
# ~/anaconda3/lib/python3.7/site-packages/pexpect/expect.py in expect_loop(self, timeout)
#     168                 # Still have time left, so read more data
# --> 169                 incoming = spawn.read_nonblocking(spawn.maxread, timeout)
#     170                 if self.spawn.delayafterread is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/pexpect/pty_spawn.py in read_nonblocking(self, size, timeout)
#     499         # (possibly timeout=None), we call select() with a timeout.
# --> 500         if (timeout != 0) and select(timeout):
#     501             return super(spawn, self).read_nonblocking(size)
#
# ~/anaconda3/lib/python3.7/site-packages/pexpect/pty_spawn.py in select(timeout)
#     449             def select(timeout):
# --> 450                 return select_ignore_interrupts([self.child_fd], [], [], timeout)[0]
#     451
#
# ~/anaconda3/lib/python3.7/site-packages/pexpect/utils.py in select_ignore_interrupts(iwtd, owtd, ewtd, timeout)
#     142         try:
# --> 143             return select.select(iwtd, owtd, ewtd, timeout)
#     144         except InterruptedError:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_26142/406332202.py in <module>
#      31         PRETRAIN_PATH = 'none'
#      32
# ---> 33         get_ipython().system('python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED          --lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS          --epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP          --accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD          --mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH          --msd $MSD --multi_layers $MULTI_LAYERS          --eval_step_start_epoch $EVAL_STEP_START_EPOCH --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH          --num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2          --restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE          --mt $MULTI_TASK --w_mt $W_MT          --awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH          --pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO          --scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP          --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN          --gradient_clip_val $GRAD_CLIP          --input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN          --crop_prob $CROP_PROB --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS --class_name $CLASS          --add_fb3 $ADD_FB3 --fb3_fold_path $FB3_FOLD_PATH')
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/zmqshell.py in system_piped(self, cmd)
#     635                 self.user_ns['_exit_code'] = system(cmd)
#     636         else:
# --> 637             self.user_ns['_exit_code'] = system(self.var_expand(cmd, depth=1))
#     638
#     639     # Ensure new system_piped implementation is used
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     184             finally:
#     185                 # Ensure the subprocess really is terminated
# --> 186                 child.terminate(force=True)
#     187         # add isalive check, to ensure exitstatus is set:
#     188         child.isalive()
#
# ~/anaconda3/lib/python3.7/site-packages/pexpect/pty_spawn.py in terminate(self, force)
#     640         try:
#     641             self.kill(signal.SIGHUP)
# --> 642             time.sleep(self.delayafterterminate)
#     643             if not self.isalive():
#     644                 return True
#
# KeyboardInterrupt:

# %% [markdown]
# # Finetune

# %% [markdown]
# # OOF

# %%
INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_02/result/'

# %%
for CLASS in [
    'avg',
    #'cohesion',
    #'syntax','vocabulary','phraseology','grammar','conventions'
]:
    print("*"*50)
    print(CLASS)
    print("*"*50)
    for FOLD in [0,1,2,3,4]:
        print("-"*50)
        print("FOLD = ", FOLD)
        print("-"*50)
        WEIGHT_PATH = f'./result/{VERSION}/model_{CLASS}_seed{SEED}_fold{FOLD}.pth'
        #WEIGHT_PATH = f'result/{VERSION}/model_{CLASS}_seed{SEED}_fold{FOLD}_pseudo.pth'
        # !python ../$VERSION/validation.py --model $MODEL --version $VERSION \
        --fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS \
        --rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH \
        --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --max_length $MAX_LEN \
        --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS --class_name $CLASS

# %%
import pandas as pd
import numpy as np

preds = []
for fold in [0,1,2,3,4]:
    print("-"*50)
    print("FOLD = ", fold)
    print("-"*50)
    pred_df = pd.read_csv(f'./result/{VERSION}/pred_fold{fold}.csv')
    preds.append(pred_df)
    
all_pred_df = pd.concat(preds, axis=0).reset_index(drop=True)

train_df = pd.read_csv('../../input/feedback-prize-english-language-learning/train.csv')
oof_df = train_df[['text_id']].merge(all_pred_df, on='text_id', how='left')
oof_df.to_csv(f'./result/{VERSION}/oof_df.csv', index=False)

# %%
oof_df.shape, oof_df.isnull().sum()

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
oof_df[cols].describe()

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
train_df[cols].describe()

# %% [markdown]
# # Error Analysis - Check Corr

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
train_df[cols].corr()

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
oof_df[cols].corr()
