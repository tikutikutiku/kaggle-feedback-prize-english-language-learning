# %%
VERSION = '01_v1_32'
MODEL = 'microsoft/deberta-v3-base'
#'microsoft/deberta-base'
#'microsoft/deberta-v3-large'
LR = 2e-5 #8e-6
HEAD_LR = 2e-4 #2e-5 #8e-6 
SEED = 100
TRN_BS = 8
VAL_BS = 8
ACCUM_STEP = 1
HIDDEN_DROP_PROB = 0
P_DROP = 0
RNN = 'none'
WARMUP_RATIO = 0.1
HEAD = 'simple'
AUG = 'false'
MIXUP_ALPHA = 0
P_AUG = 0
AUG_STOP_EPOCH = 0
MSD = 'false'
MULTI_LAYERS = 1
EVAL_STEP_START_EPOCH = 3
EVAL_STEP = 30 #-1
NUM_LABELS = 6
NUM_LABELS_2 = -1
FP16 = 'true'
WD = 0.01
FREEZE = 'false'
MULTI_TASK = 'false' 
W_MT = 0 
AWP = 'false'
AWP_LR = 0
AWP_EPS = 0
AWP_START_EPOCH = -1
#PRETRAINED_DETECTOR_PATH = f'../../input/tascj/result/deberta_base_fold0.pth'
PRETRAINED_DETECTOR_PATH = 'none' #f'../../05_Detection/exp/result/05_v2_09/model_seed100_fold0_swa.pth'
MASK_PROB = 0 #0.8
MASK_RATIO = 0 #0.3
SCHEDULER = 'cosine_hard'
CP = 'false'
WINDOW_SIZE = -1 #512
INNER_LEN = -1 #384
EDGE_LEN = -1 #64
MAX_LEN = 512

GRAD_CLIP = 1

LOSS = 'smoothl1'#'mse'

# %%
FOLD = 0
INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_02/result/'
MODE = 'train'
EPOCHS = 5
STOP_EPOCH = 5
RESTART = 1
NUM_CYCLES = 1 #EPOCHS
PRETRAIN_PATH = 'none' #f'result/{VERSION}/model_seed{SEED}_fold{FOLD}_epoch{EPOCHS}_pseudo.pth'

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS \
--eval_step_start_epoch $EVAL_STEP_START_EPOCH --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN \
--gradient_clip_val $GRAD_CLIP \
--input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN
# Out:
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3128, 8)
# val_df.shape =  (783, 8)
# 2022-09-16 00:10:55.019135: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-09-16 00:10:55.019158: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [01:43<00:00,  3.78it/s, loss=0.468]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.49it/s]
# epoch 1: trn_loss = 0.4683, val_loss = 0.1141, trn_score = 1.1943, val_score = 0.4783
# model (best score) saved
# lr :  [1.9394209897590707e-05, 1.9394209897590707e-05, 0.00019394209897590704]
# 100%|█████████████████████████████| 391/391 [01:45<00:00,  3.72it/s, loss=0.112]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.52it/s]
# epoch 2: trn_loss = 0.1120, val_loss = 0.1042, trn_score = 0.4746, val_score = 0.4567
# model (best score) saved
# lr :  [1.4994846276142766e-05, 1.4994846276142766e-05, 0.00014994846276142766]
#   7%|██▏                           | 29/391 [00:08<01:37,  3.71it/s, loss=0.107]
# epoch 3: trn_loss = 0.1070, val_loss = 0.1217, trn_score = 0.4639, val_score = 0.4945
#  15%|████▋                          | 59/391 [00:37<01:29,  3.72it/s, loss=0.11]
# epoch 3: trn_loss = 0.1102, val_loss = 0.1069, trn_score = 0.4709, val_score = 0.4628
#  23%|███████                        | 89/391 [01:07<01:20,  3.75it/s, loss=0.11]
# epoch 3: trn_loss = 0.1101, val_loss = 0.1060, trn_score = 0.4702, val_score = 0.4609
#  30%|████████▊                    | 119/391 [01:37<01:12,  3.74it/s, loss=0.109]
# epoch 3: trn_loss = 0.1094, val_loss = 0.1254, trn_score = 0.4689, val_score = 0.5023
#  38%|███████████                  | 149/391 [02:06<01:04,  3.75it/s, loss=0.106]
# epoch 3: trn_loss = 0.1065, val_loss = 0.1057, trn_score = 0.4624, val_score = 0.4602
#  46%|█████████████▎               | 179/391 [02:36<00:57,  3.71it/s, loss=0.106]
# epoch 3: trn_loss = 0.1059, val_loss = 0.1054, trn_score = 0.4610, val_score = 0.4595
#  53%|███████████████▌             | 209/391 [03:05<00:49,  3.68it/s, loss=0.105]
# epoch 3: trn_loss = 0.1048, val_loss = 0.1063, trn_score = 0.4585, val_score = 0.4616
#  61%|█████████████████▋           | 239/391 [03:35<00:41,  3.64it/s, loss=0.104]
# epoch 3: trn_loss = 0.1042, val_loss = 0.1132, trn_score = 0.4572, val_score = 0.4759
#  69%|███████████████████▉         | 269/391 [04:05<00:33,  3.65it/s, loss=0.103]
# epoch 3: trn_loss = 0.1034, val_loss = 0.1067, trn_score = 0.4554, val_score = 0.4618
#  76%|██████████████████████▏      | 299/391 [04:34<00:25,  3.66it/s, loss=0.102]
# epoch 3: trn_loss = 0.1025, val_loss = 0.1092, trn_score = 0.4534, val_score = 0.4676
#  84%|████████████████████████▍    | 329/391 [05:04<00:16,  3.66it/s, loss=0.102]
# epoch 3: trn_loss = 0.1025, val_loss = 0.1046, trn_score = 0.4534, val_score = 0.4573
#  92%|██████████████████████████▋  | 359/391 [05:34<00:08,  3.69it/s, loss=0.102]
# epoch 3: trn_loss = 0.1020, val_loss = 0.1107, trn_score = 0.4525, val_score = 0.4706
#  99%|████████████████████████████▊| 389/391 [06:03<00:00,  3.76it/s, loss=0.102]
# epoch 3: trn_loss = 0.1022, val_loss = 0.1077, trn_score = 0.4529, val_score = 0.4645
# 100%|█████████████████████████████| 391/391 [06:25<00:00,  1.01it/s, loss=0.102]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.34it/s]
# epoch 3: trn_loss = 0.1022, val_loss = 0.1073, trn_score = 0.4530, val_score = 0.4639
# lr :  [8.259611965093282e-06, 8.259611965093282e-06, 8.259611965093282e-05]
#   7%|██▏                          | 29/391 [00:08<01:38,  3.67it/s, loss=0.0996]
# epoch 4: trn_loss = 0.0996, val_loss = 0.1049, trn_score = 0.4465, val_score = 0.4581
#  15%|████▍                        | 59/391 [00:37<01:29,  3.70it/s, loss=0.0966]
# epoch 4: trn_loss = 0.0966, val_loss = 0.1057, trn_score = 0.4397, val_score = 0.4599
#  23%|██████▌                      | 89/391 [01:07<01:21,  3.69it/s, loss=0.0967]
# epoch 4: trn_loss = 0.0967, val_loss = 0.1061, trn_score = 0.4403, val_score = 0.4608
#  30%|████████▌                   | 119/391 [01:36<01:14,  3.64it/s, loss=0.0968]
# epoch 4: trn_loss = 0.0968, val_loss = 0.1134, trn_score = 0.4407, val_score = 0.4769
#  38%|██████████▋                 | 149/391 [02:06<01:05,  3.72it/s, loss=0.0972]
# epoch 4: trn_loss = 0.0972, val_loss = 0.1072, trn_score = 0.4415, val_score = 0.4628
#  46%|████████████▊               | 179/391 [02:35<00:57,  3.70it/s, loss=0.0967]
# epoch 4: trn_loss = 0.0967, val_loss = 0.1199, trn_score = 0.4404, val_score = 0.4910
#  53%|██████████████▉             | 209/391 [03:05<00:49,  3.71it/s, loss=0.0965]
# epoch 4: trn_loss = 0.0965, val_loss = 0.1032, trn_score = 0.4400, val_score = 0.4544
# model (best score) saved
#  61%|█████████████████           | 239/391 [03:35<00:41,  3.70it/s, loss=0.0964]
# epoch 4: trn_loss = 0.0964, val_loss = 0.1041, trn_score = 0.4397, val_score = 0.4565
#  69%|███████████████████▎        | 269/391 [04:05<00:32,  3.73it/s, loss=0.0966]
# epoch 4: trn_loss = 0.0966, val_loss = 0.1041, trn_score = 0.4401, val_score = 0.4566
#  76%|█████████████████████▍      | 299/391 [04:34<00:24,  3.68it/s, loss=0.0968]
# epoch 4: trn_loss = 0.0968, val_loss = 0.1031, trn_score = 0.4407, val_score = 0.4543
# model (best score) saved
#  84%|███████████████████████▌    | 329/391 [05:05<00:16,  3.70it/s, loss=0.0964]
# epoch 4: trn_loss = 0.0964, val_loss = 0.1039, trn_score = 0.4399, val_score = 0.4560
#  92%|█████████████████████████▋  | 359/391 [05:34<00:08,  3.67it/s, loss=0.0966]
# epoch 4: trn_loss = 0.0966, val_loss = 0.1033, trn_score = 0.4402, val_score = 0.4545
#  99%|███████████████████████████▊| 389/391 [06:04<00:00,  3.73it/s, loss=0.0969]
# epoch 4: trn_loss = 0.0969, val_loss = 0.1099, trn_score = 0.4408, val_score = 0.4694
# 100%|████████████████████████████| 391/391 [06:25<00:00,  1.01it/s, loss=0.0968]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.39it/s]
# epoch 4: trn_loss = 0.0968, val_loss = 0.1093, trn_score = 0.4407, val_score = 0.4681
# lr :  [2.3382808603725494e-06, 2.3382808603725494e-06, 2.3382808603725492e-05]
#   7%|██▏                          | 29/391 [00:08<01:37,  3.70it/s, loss=0.0942]
# epoch 5: trn_loss = 0.0942, val_loss = 0.1028, trn_score = 0.4343, val_score = 0.4535
# model (best score) saved
#  15%|████▍                        | 59/391 [00:38<01:29,  3.73it/s, loss=0.0929]
# epoch 5: trn_loss = 0.0929, val_loss = 0.1037, trn_score = 0.4311, val_score = 0.4557
#  23%|██████▊                       | 89/391 [01:08<01:23,  3.64it/s, loss=0.091]
# epoch 5: trn_loss = 0.0910, val_loss = 0.1058, trn_score = 0.4270, val_score = 0.4606
#  30%|████████▌                   | 119/391 [01:37<01:13,  3.68it/s, loss=0.0912]
# epoch 5: trn_loss = 0.0912, val_loss = 0.1040, trn_score = 0.4272, val_score = 0.4563
#  38%|██████████▋                 | 149/391 [02:07<01:05,  3.71it/s, loss=0.0898]
# epoch 5: trn_loss = 0.0898, val_loss = 0.1045, trn_score = 0.4241, val_score = 0.4576
#  46%|████████████▊               | 179/391 [02:36<00:56,  3.72it/s, loss=0.0896]
# epoch 5: trn_loss = 0.0896, val_loss = 0.1078, trn_score = 0.4238, val_score = 0.4647
#  53%|██████████████▉             | 209/391 [03:06<00:49,  3.71it/s, loss=0.0904]
# epoch 5: trn_loss = 0.0904, val_loss = 0.1031, trn_score = 0.4255, val_score = 0.4543
#  61%|█████████████████           | 239/391 [03:35<00:40,  3.73it/s, loss=0.0904]
# epoch 5: trn_loss = 0.0904, val_loss = 0.1030, trn_score = 0.4256, val_score = 0.4540
#  69%|███████████████████▎        | 269/391 [04:05<00:32,  3.70it/s, loss=0.0892]
# epoch 5: trn_loss = 0.0892, val_loss = 0.1030, trn_score = 0.4228, val_score = 0.4541
#  76%|█████████████████████▍      | 299/391 [04:34<00:24,  3.71it/s, loss=0.0897]
# epoch 5: trn_loss = 0.0897, val_loss = 0.1034, trn_score = 0.4238, val_score = 0.4551
#  84%|███████████████████████▌    | 329/391 [05:04<00:16,  3.68it/s, loss=0.0894]
# epoch 5: trn_loss = 0.0894, val_loss = 0.1031, trn_score = 0.4233, val_score = 0.4543
#  92%|█████████████████████████▋  | 359/391 [05:33<00:08,  3.77it/s, loss=0.0894]
# epoch 5: trn_loss = 0.0894, val_loss = 0.1029, trn_score = 0.4232, val_score = 0.4540
#  99%|█████████████████████████████▊| 389/391 [06:03<00:00,  3.76it/s, loss=0.09]
# epoch 5: trn_loss = 0.0900, val_loss = 0.1029, trn_score = 0.4245, val_score = 0.4539
# 100%|██████████████████████████████| 391/391 [06:24<00:00,  1.02it/s, loss=0.09]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.56it/s]
# epoch 5: trn_loss = 0.0900, val_loss = 0.1029, trn_score = 0.4245, val_score = 0.4539

# %% [markdown]
# # OOF

# %%
FOLD = 0
INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_02/result/'
WEIGHT_PATH = f'./result/{VERSION}/model_seed{SEED}_fold{FOLD}.pth'

# !python ../$VERSION/validation.py --model $MODEL --version $VERSION \
--fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS \
--rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --max_length $MAX_LEN

# %%
import pandas as pd

num_fold = 5

preds = []
for fold in range(num_fold):
    tmp_df = pd.read_csv(f'./result/{VERSION}/pred_fold{fold}.csv')
    preds.append(tmp_df)
    
pred_df = pd.concat(preds, axis=0).reset_index(drop=True)
train_df = pd.read_csv('../../input/feedback-prize-english-language-learning/train.csv')

oof_df = train_df[['text_id']].merge(pred_df, on='text_id', how='left')
oof_df.to_csv(f'./result/{VERSION}/oof_df.csv', index=False)

# %%
oof_df.shape, oof_df.isnull().sum()
