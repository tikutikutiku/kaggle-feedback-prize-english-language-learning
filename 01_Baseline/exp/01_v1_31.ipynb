# %%
VERSION = '01_v1_31'
MODEL = 'microsoft/deberta-v3-base'
#'microsoft/deberta-base'
#'microsoft/deberta-v3-large'
LR = 2e-5 #8e-6
HEAD_LR = 2e-4 #2e-5 #8e-6 
SEED = 100
TRN_BS = 8
VAL_BS = 8
ACCUM_STEP = 1
HIDDEN_DROP_PROB = 0
P_DROP = 0
RNN = 'none'
WARMUP_RATIO = 0.1
HEAD = 'simple'
AUG = 'false'
MIXUP_ALPHA = 0
P_AUG = 0
AUG_STOP_EPOCH = 0
MSD = 'false'
MULTI_LAYERS = 1
EVAL_STEP_START_EPOCH = 3
EVAL_STEP = 30 #-1
NUM_LABELS = 6
NUM_LABELS_2 = -1
FP16 = 'true'
WD = 0.01
FREEZE = 'false'
MULTI_TASK = 'false' 
W_MT = 0 
AWP = 'false'
AWP_LR = 0
AWP_EPS = 0
AWP_START_EPOCH = -1
#PRETRAINED_DETECTOR_PATH = f'../../input/tascj/result/deberta_base_fold0.pth'
PRETRAINED_DETECTOR_PATH = 'none' #f'../../05_Detection/exp/result/05_v2_09/model_seed100_fold0_swa.pth'
MASK_PROB = 0 #0.8
MASK_RATIO = 0 #0.3
SCHEDULER = 'cosine_hard'
CP = 'false'
WINDOW_SIZE = -1 #512
INNER_LEN = -1 #384
EDGE_LEN = -1 #64
MAX_LEN = 512

GRAD_CLIP = 1

LOSS = 'smoothl1'#'mse'

# %%
FOLD = 0
INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_02/result/'
MODE = 'train'
EPOCHS = 5
STOP_EPOCH = 5
RESTART = 1
NUM_CYCLES = EPOCHS
PRETRAIN_PATH = 'none' #f'result/{VERSION}/model_seed{SEED}_fold{FOLD}_epoch{EPOCHS}_pseudo.pth'

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS \
--eval_step_start_epoch $EVAL_STEP_START_EPOCH --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN \
--gradient_clip_val $GRAD_CLIP \
--input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN
# Out:
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3128, 8)
# val_df.shape =  (783, 8)
# 2022-09-15 23:44:38.705247: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-09-15 23:44:38.705271: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [01:42<00:00,  3.80it/s, loss=0.467]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.50it/s]
# epoch 1: trn_loss = 0.4668, val_loss = 0.1093, trn_score = 1.1926, val_score = 0.4681
# model (best score) saved
# lr :  [8.224468037456969e-06, 8.224468037456969e-06, 8.224468037456969e-05]
# 100%|█████████████████████████████| 391/391 [01:46<00:00,  3.68it/s, loss=0.107]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.43it/s]
# epoch 2: trn_loss = 0.1072, val_loss = 0.1067, trn_score = 0.4640, val_score = 0.4621
# model (best score) saved
# lr :  [4.974257968932691e-06, 4.974257968932691e-06, 4.974257968932691e-05]
#   7%|██▏                           | 29/391 [00:08<01:37,  3.73it/s, loss=0.101]
# epoch 3: trn_loss = 0.1008, val_loss = 0.1045, trn_score = 0.4499, val_score = 0.4574
# model (best score) saved
#  15%|████▌                         | 59/391 [00:38<01:30,  3.67it/s, loss=0.103]
# epoch 3: trn_loss = 0.1031, val_loss = 0.1040, trn_score = 0.4550, val_score = 0.4562
# model (best score) saved
#  23%|██████▊                       | 89/391 [01:09<01:22,  3.67it/s, loss=0.102]
# epoch 3: trn_loss = 0.1019, val_loss = 0.1037, trn_score = 0.4521, val_score = 0.4557
# model (best score) saved
#  30%|████████▊                    | 119/391 [01:40<01:14,  3.65it/s, loss=0.102]
# epoch 3: trn_loss = 0.1023, val_loss = 0.1936, trn_score = 0.4532, val_score = 0.6265
#  38%|███████████                  | 149/391 [02:09<01:05,  3.67it/s, loss=0.104]
# epoch 3: trn_loss = 0.1036, val_loss = 0.1062, trn_score = 0.4559, val_score = 0.4614
#  46%|█████████████▎               | 179/391 [02:39<00:57,  3.69it/s, loss=0.104]
# epoch 3: trn_loss = 0.1039, val_loss = 0.1150, trn_score = 0.4567, val_score = 0.4803
#  53%|███████████████▌             | 209/391 [03:08<00:49,  3.69it/s, loss=0.103]
# epoch 3: trn_loss = 0.1028, val_loss = 0.1137, trn_score = 0.4541, val_score = 0.4773
#  61%|█████████████████▋           | 239/391 [03:38<00:41,  3.65it/s, loss=0.103]
# epoch 3: trn_loss = 0.1032, val_loss = 0.1212, trn_score = 0.4550, val_score = 0.4928
#  69%|███████████████████▉         | 269/391 [04:07<00:33,  3.69it/s, loss=0.103]
# epoch 3: trn_loss = 0.1031, val_loss = 0.1314, trn_score = 0.4548, val_score = 0.5138
#  76%|██████████████████████▏      | 299/391 [04:37<00:24,  3.70it/s, loss=0.103]
# epoch 3: trn_loss = 0.1026, val_loss = 0.1111, trn_score = 0.4539, val_score = 0.4719
#  84%|████████████████████████▍    | 329/391 [05:06<00:16,  3.69it/s, loss=0.103]
# epoch 3: trn_loss = 0.1028, val_loss = 0.1038, trn_score = 0.4542, val_score = 0.4556
# model (best score) saved
#  92%|██████████████████████████▋  | 359/391 [05:37<00:08,  3.69it/s, loss=0.102]
# epoch 3: trn_loss = 0.1021, val_loss = 0.1097, trn_score = 0.4528, val_score = 0.4684
#  99%|████████████████████████████▊| 389/391 [06:06<00:00,  3.69it/s, loss=0.102]
# epoch 3: trn_loss = 0.1023, val_loss = 0.1025, trn_score = 0.4532, val_score = 0.4527
# model (best score) saved
# 100%|█████████████████████████████| 391/391 [06:29<00:00,  1.00it/s, loss=0.102]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.35it/s]
# epoch 3: trn_loss = 0.1023, val_loss = 0.1026, trn_score = 0.4532, val_score = 0.4529
# lr :  [2.3268220525837457e-06, 2.3268220525837457e-06, 2.3268220525837457e-05]
#   7%|██▏                          | 29/391 [00:08<01:37,  3.70it/s, loss=0.0932]
# epoch 4: trn_loss = 0.0932, val_loss = 0.1026, trn_score = 0.4312, val_score = 0.4531
#  15%|████▍                        | 59/391 [00:37<01:29,  3.69it/s, loss=0.0919]
# epoch 4: trn_loss = 0.0919, val_loss = 0.1024, trn_score = 0.4286, val_score = 0.4526
# model (best score) saved
#  23%|██████▌                      | 89/391 [01:08<01:22,  3.67it/s, loss=0.0905]
# epoch 4: trn_loss = 0.0905, val_loss = 0.1118, trn_score = 0.4256, val_score = 0.4721
#  30%|████████▌                   | 119/391 [01:37<01:14,  3.65it/s, loss=0.0931]
# epoch 4: trn_loss = 0.0931, val_loss = 0.1425, trn_score = 0.4319, val_score = 0.5328
#  38%|██████████▋                 | 149/391 [02:07<01:05,  3.70it/s, loss=0.0974]
# epoch 4: trn_loss = 0.0974, val_loss = 0.1075, trn_score = 0.4419, val_score = 0.4643
#  46%|█████████████▎               | 179/391 [02:36<00:57,  3.70it/s, loss=0.098]
# epoch 4: trn_loss = 0.0980, val_loss = 0.1160, trn_score = 0.4436, val_score = 0.4826
#  53%|██████████████▉             | 209/391 [03:05<00:48,  3.73it/s, loss=0.0984]
# epoch 4: trn_loss = 0.0984, val_loss = 0.1197, trn_score = 0.4444, val_score = 0.4891
#  61%|█████████████████           | 239/391 [03:34<00:40,  3.74it/s, loss=0.0983]
# epoch 4: trn_loss = 0.0983, val_loss = 0.1060, trn_score = 0.4443, val_score = 0.4606
#  69%|███████████████████▎        | 269/391 [04:04<00:32,  3.73it/s, loss=0.0986]
# epoch 4: trn_loss = 0.0986, val_loss = 0.1090, trn_score = 0.4450, val_score = 0.4674
#  76%|█████████████████████▍      | 299/391 [04:33<00:24,  3.72it/s, loss=0.0989]
# epoch 4: trn_loss = 0.0989, val_loss = 0.1040, trn_score = 0.4457, val_score = 0.4561
#  84%|███████████████████████▌    | 329/391 [05:03<00:16,  3.72it/s, loss=0.0981]
# epoch 4: trn_loss = 0.0981, val_loss = 0.1040, trn_score = 0.4439, val_score = 0.4562
#  92%|██████████████████████████▋  | 359/391 [05:32<00:08,  3.70it/s, loss=0.098]
# epoch 4: trn_loss = 0.0980, val_loss = 0.1030, trn_score = 0.4435, val_score = 0.4540
#  99%|███████████████████████████▊| 389/391 [06:02<00:00,  3.69it/s, loss=0.0977]
# epoch 4: trn_loss = 0.0977, val_loss = 0.1033, trn_score = 0.4428, val_score = 0.4547
# 100%|████████████████████████████| 391/391 [06:24<00:00,  1.02it/s, loss=0.0976]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.31it/s]
# epoch 4: trn_loss = 0.0976, val_loss = 0.1032, trn_score = 0.4426, val_score = 0.4545
# lr :  [5.996867213330993e-07, 5.996867213330993e-07, 5.996867213330992e-06]
#   7%|██▏                          | 29/391 [00:08<01:38,  3.68it/s, loss=0.0877]
# epoch 5: trn_loss = 0.0877, val_loss = 0.1031, trn_score = 0.4189, val_score = 0.4541
#  15%|████▍                        | 59/391 [00:37<01:28,  3.76it/s, loss=0.0934]
# epoch 5: trn_loss = 0.0934, val_loss = 0.1085, trn_score = 0.4324, val_score = 0.4664
#  23%|██████▌                      | 89/391 [01:07<01:21,  3.69it/s, loss=0.0934]
# epoch 5: trn_loss = 0.0934, val_loss = 0.1033, trn_score = 0.4325, val_score = 0.4545
#  30%|████████▌                   | 119/391 [01:37<01:13,  3.69it/s, loss=0.0927]
# epoch 5: trn_loss = 0.0927, val_loss = 0.1103, trn_score = 0.4308, val_score = 0.4700
#  38%|██████████▋                 | 149/391 [02:06<01:05,  3.70it/s, loss=0.0922]
# epoch 5: trn_loss = 0.0922, val_loss = 0.1080, trn_score = 0.4299, val_score = 0.4651
#  46%|████████████▊               | 179/391 [02:36<00:57,  3.66it/s, loss=0.0927]
# epoch 5: trn_loss = 0.0927, val_loss = 0.1204, trn_score = 0.4312, val_score = 0.4908
#  53%|██████████████▉             | 209/391 [03:05<00:49,  3.66it/s, loss=0.0945]
# epoch 5: trn_loss = 0.0945, val_loss = 0.1066, trn_score = 0.4353, val_score = 0.4620
#  61%|█████████████████           | 239/391 [03:35<00:41,  3.70it/s, loss=0.0945]
# epoch 5: trn_loss = 0.0945, val_loss = 0.1030, trn_score = 0.4353, val_score = 0.4538
#  69%|███████████████████▎        | 269/391 [04:04<00:32,  3.71it/s, loss=0.0932]
# epoch 5: trn_loss = 0.0932, val_loss = 0.1041, trn_score = 0.4322, val_score = 0.4565
#  76%|█████████████████████▍      | 299/391 [04:34<00:24,  3.69it/s, loss=0.0934]
# epoch 5: trn_loss = 0.0934, val_loss = 0.1036, trn_score = 0.4327, val_score = 0.4554
#  84%|███████████████████████▌    | 329/391 [05:04<00:17,  3.60it/s, loss=0.0927]
# epoch 5: trn_loss = 0.0927, val_loss = 0.1041, trn_score = 0.4310, val_score = 0.4566
#  92%|█████████████████████████▋  | 359/391 [05:34<00:08,  3.69it/s, loss=0.0924]
# epoch 5: trn_loss = 0.0924, val_loss = 0.1029, trn_score = 0.4304, val_score = 0.4538
#  99%|███████████████████████████▊| 389/391 [06:03<00:00,  3.75it/s, loss=0.0926]
# epoch 5: trn_loss = 0.0926, val_loss = 0.1027, trn_score = 0.4308, val_score = 0.4534
# 100%|████████████████████████████| 391/391 [06:25<00:00,  1.01it/s, loss=0.0926]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.46it/s]
# epoch 5: trn_loss = 0.0926, val_loss = 0.1027, trn_score = 0.4307, val_score = 0.4534

# %% [markdown]
# # OOF

# %%
FOLD = 0
INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_02/result/'
WEIGHT_PATH = f'./result/{VERSION}/model_seed{SEED}_fold{FOLD}.pth'

# !python ../$VERSION/validation.py --model $MODEL --version $VERSION \
--fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS \
--rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --max_length $MAX_LEN

# %%
import pandas as pd

num_fold = 5

preds = []
for fold in range(num_fold):
    tmp_df = pd.read_csv(f'./result/{VERSION}/pred_fold{fold}.csv')
    preds.append(tmp_df)
    
pred_df = pd.concat(preds, axis=0).reset_index(drop=True)
train_df = pd.read_csv('../../input/feedback-prize-english-language-learning/train.csv')

oof_df = train_df[['text_id']].merge(pred_df, on='text_id', how='left')
oof_df.to_csv(f'./result/{VERSION}/oof_df.csv', index=False)

# %%
oof_df.shape, oof_df.isnull().sum()
