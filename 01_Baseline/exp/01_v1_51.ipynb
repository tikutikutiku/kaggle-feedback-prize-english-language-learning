# %%
VERSION = '01_v1_51'
MODEL = 'facebook/bart-base'
#'distilroberta-base'
#'deepset/roberta-base-squad2'
#'microsoft/deberta-v3-base'
#'roberta-large'
#'roberta-base'
#'microsoft/deberta-v3-large'
#'microsoft/deberta-v3-base'
#'microsoft/deberta-base'
LR = 2e-5 #8e-6
HEAD_LR = 2e-4 #2e-5 #8e-6 
SEED = 100
TRN_BS = 8
VAL_BS = 8
ACCUM_STEP = 1
HIDDEN_DROP_PROB = 0
P_DROP = 0
RNN = 'none'
WARMUP_RATIO = 0.1
HEAD = 'simple'
AUG = 'false'
MIXUP_ALPHA = 0
P_AUG = 0
AUG_STOP_EPOCH = 0
MSD = 'false'
MULTI_LAYERS = 1
EVAL_STEP_START_EPOCH = -1
EVAL_STEP = -1
NUM_LABELS = 6
NUM_LABELS_2 = -1
FP16 = 'true'
WD = 0.01
FREEZE = 'false'
MULTI_TASK = 'false' 
W_MT = 0 
AWP = 'false'
AWP_LR = 0
AWP_EPS = 0
AWP_START_EPOCH = -1
#PRETRAINED_DETECTOR_PATH = f'../../input/tascj/result/deberta_base_fold0.pth'
PRETRAINED_DETECTOR_PATH = 'none' #f'../../05_Detection/exp/result/05_v2_09/model_seed100_fold0_swa.pth'
MASK_PROB = 0 #0.8
MASK_RATIO = 0 #0.3
SCHEDULER = 'cosine_hard'
CP = 'false'
WINDOW_SIZE = -1 #512
INNER_LEN = -1 #384
EDGE_LEN = -1 #64
MAX_LEN = 512

GRAD_CLIP = 1

LOSS = 'smoothl1'#'mse'

CROP_PROB = 0 #1.0

# %%
FOLD = 0
INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_02/result/'
MODE = 'train'
EPOCHS = 5
STOP_EPOCH = 5
RESTART = 1
NUM_CYCLES = EPOCHS
PRETRAIN_PATH = 'none' #f'result/{VERSION}/model_seed{SEED}_fold{FOLD}_epoch{EPOCHS}_pseudo.pth'

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS \
--eval_step_start_epoch $EVAL_STEP_START_EPOCH --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN \
--gradient_clip_val $GRAD_CLIP \
--input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN \
--crop_prob $CROP_PROB
# Out:
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3128, 8)
# val_df.shape =  (783, 8)
# 2022-10-08 22:51:16.755286: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-08 22:51:16.755309: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [01:15<00:00,  5.18it/s, loss=0.393]
# 100%|███████████████████████████████████████████| 98/98 [00:17<00:00,  5.60it/s]
# epoch 1: trn_loss = 0.3931, val_loss = 0.1576, trn_score = 1.0777, val_score = 0.5655
# model (best score) saved
# lr :  [8.224468037456969e-06, 8.224468037456969e-06, 8.224468037456969e-05]
# 100%|█████████████████████████████| 391/391 [01:16<00:00,  5.10it/s, loss=0.115]
# 100%|███████████████████████████████████████████| 98/98 [00:17<00:00,  5.55it/s]
# epoch 2: trn_loss = 0.1151, val_loss = 0.2183, trn_score = 0.4815, val_score = 0.6666
# lr :  [4.974257968932691e-06, 4.974257968932691e-06, 4.974257968932691e-05]
# 100%|█████████████████████████████| 391/391 [01:17<00:00,  5.06it/s, loss=0.113]
# 100%|███████████████████████████████████████████| 98/98 [00:17<00:00,  5.56it/s]
# epoch 3: trn_loss = 0.1128, val_loss = 0.1929, trn_score = 0.4764, val_score = 0.6272
# lr :  [2.3268220525837457e-06, 2.3268220525837457e-06, 2.3268220525837457e-05]
# 100%|█████████████████████████████| 391/391 [01:16<00:00,  5.10it/s, loss=0.109]
# 100%|███████████████████████████████████████████| 98/98 [00:17<00:00,  5.61it/s]
# epoch 4: trn_loss = 0.1089, val_loss = 0.2211, trn_score = 0.4678, val_score = 0.6747
# lr :  [5.996867213330993e-07, 5.996867213330993e-07, 5.996867213330992e-06]
# 100%|█████████████████████████████| 391/391 [01:16<00:00,  5.11it/s, loss=0.106]
# 100%|███████████████████████████████████████████| 98/98 [00:17<00:00,  5.56it/s]
# epoch 5: trn_loss = 0.1060, val_loss = 0.2154, trn_score = 0.4615, val_score = 0.6654

# %%
FOLD = 1
INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_02/result/'
MODE = 'train'
EPOCHS = 5
STOP_EPOCH = 5
RESTART = 1
NUM_CYCLES = EPOCHS
PRETRAIN_PATH = 'none' #f'result/{VERSION}/model_seed{SEED}_fold{FOLD}_epoch{EPOCHS}_pseudo.pth'

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS \
--eval_step_start_epoch $EVAL_STEP_START_EPOCH --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN \
--gradient_clip_val $GRAD_CLIP \
--input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN \
--crop_prob $CROP_PROB
# Out:
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-10-08 22:59:25.670966: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-08 22:59:25.670986: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [01:15<00:00,  5.17it/s, loss=0.367]
# 100%|███████████████████████████████████████████| 98/98 [00:17<00:00,  5.64it/s]
# epoch 1: trn_loss = 0.3674, val_loss = 0.1979, trn_score = 1.0338, val_score = 0.6332
# model (best score) saved
# lr :  [8.224468037456969e-06, 8.224468037456969e-06, 8.224468037456969e-05]
# 100%|█████████████████████████████| 391/391 [01:16<00:00,  5.09it/s, loss=0.118]
# 100%|███████████████████████████████████████████| 98/98 [00:17<00:00,  5.62it/s]
# epoch 2: trn_loss = 0.1176, val_loss = 0.1847, trn_score = 0.4866, val_score = 0.6111
# model (best score) saved
# lr :  [4.974257968932691e-06, 4.974257968932691e-06, 4.974257968932691e-05]
# 100%|██████████████████████████████| 391/391 [01:16<00:00,  5.11it/s, loss=0.11]
# 100%|███████████████████████████████████████████| 98/98 [00:17<00:00,  5.54it/s]
# epoch 3: trn_loss = 0.1105, val_loss = 0.1861, trn_score = 0.4712, val_score = 0.6145
# lr :  [2.3268220525837457e-06, 2.3268220525837457e-06, 2.3268220525837457e-05]
# 100%|█████████████████████████████| 391/391 [01:16<00:00,  5.12it/s, loss=0.107]
# 100%|███████████████████████████████████████████| 98/98 [00:17<00:00,  5.67it/s]
# epoch 4: trn_loss = 0.1067, val_loss = 0.1953, trn_score = 0.4633, val_score = 0.6305
# lr :  [5.996867213330993e-07, 5.996867213330993e-07, 5.996867213330992e-06]
# 100%|█████████████████████████████| 391/391 [01:16<00:00,  5.14it/s, loss=0.104]
# 100%|███████████████████████████████████████████| 98/98 [00:17<00:00,  5.62it/s]
# epoch 5: trn_loss = 0.1037, val_loss = 0.2171, trn_score = 0.4564, val_score = 0.6661

# %%
FOLD = 2
INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_02/result/'
MODE = 'train'
EPOCHS = 5
STOP_EPOCH = 5
RESTART = 1
NUM_CYCLES = EPOCHS
PRETRAIN_PATH = 'none' #f'result/{VERSION}/model_seed{SEED}_fold{FOLD}_epoch{EPOCHS}_pseudo.pth'

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS \
--eval_step_start_epoch $EVAL_STEP_START_EPOCH --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN \
--gradient_clip_val $GRAD_CLIP \
--input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN \
--crop_prob $CROP_PROB
# Out:
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-10-08 23:07:33.306855: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-08 23:07:33.306878: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
#  15%|████▌                          | 58/391 [00:11<01:04,  5.16it/s, loss=1.88]^C
#  15%|████▌                          | 58/391 [00:11<01:08,  4.84it/s, loss=1.88]
# Traceback (most recent call last):
#   File "../01_v1_51/train.py", line 144, in <module>
#     run(args, trn_df, val_df, pseudo_df=None)
#   File "/home/takesako/programming/kaggle/kaggle-feedback-prize-english-language-learning/01_Baseline/01_v1_51/run.py", line 179, in run
#     scaler.scale(loss).backward()
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/_tensor.py", line 307, in backward
#     torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/autograd/__init__.py", line 156, in backward
#     allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/takesako/anaconda3/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
#   File "/home/takesako/anaconda3/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/home/takesako/anaconda3/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/home/takesako/anaconda3/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe

# %%
FOLD = 3
INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_02/result/'
MODE = 'train'
EPOCHS = 5
STOP_EPOCH = 5
RESTART = 1
NUM_CYCLES = EPOCHS
PRETRAIN_PATH = 'none' #f'result/{VERSION}/model_seed{SEED}_fold{FOLD}_epoch{EPOCHS}_pseudo.pth'

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS \
--eval_step_start_epoch $EVAL_STEP_START_EPOCH --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN \
--gradient_clip_val $GRAD_CLIP \
--input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN \
--crop_prob $CROP_PROB
# Out:
# ^C
# Traceback (most recent call last):
#   File "../01_v1_51/train.py", line 1, in <module>
#     import torch
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/__init__.py", line 29, in <module>
#     from .torch_version import __version__ as __version__
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/torch_version.py", line 3, in <module>
#     from pkg_resources import packaging  # type: ignore[attr-defined]
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 3266, in <module>
#     @_call_aside
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 3241, in _call_aside
#     f(*args, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 3302, in _initialize_master_working_set
#     list(map(working_set.add_entry, sys.path))
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 613, in add_entry
#     for dist in find_distributions(entry, True):
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 2077, in find_on_path
#     for dist in factory(fullpath):
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 2135, in distributions_from_metadata
#     if len(os.listdir(path)) == 0:
# KeyboardInterrupt

# %%
FOLD = 4
INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_02/result/'
MODE = 'train'
EPOCHS = 5
STOP_EPOCH = 5
RESTART = 1
NUM_CYCLES = EPOCHS
PRETRAIN_PATH = 'none' #f'result/{VERSION}/model_seed{SEED}_fold{FOLD}_epoch{EPOCHS}_pseudo.pth'

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS \
--eval_step_start_epoch $EVAL_STEP_START_EPOCH --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN \
--gradient_clip_val $GRAD_CLIP \
--input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN \
--crop_prob $CROP_PROB
# Out:
# ^C
# Traceback (most recent call last):
#   File "<frozen importlib._bootstrap_external>", line 87, in _path_is_mode_type
#   File "<frozen importlib._bootstrap_external>", line 81, in _path_stat
# FileNotFoundError: [Errno 2] No such file or directory: '/home/takesako/anaconda3/lib/python3.7/site-packages/repoze/__init__.cpython-37m-x86_64-linux-gnu.so'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../01_v1_51/train.py", line 1, in <module>
#     import torch
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/__init__.py", line 29, in <module>
#     from .torch_version import __version__ as __version__
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/torch_version.py", line 3, in <module>
#     from pkg_resources import packaging  # type: ignore[attr-defined]
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 3266, in <module>
#     @_call_aside
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 3241, in _call_aside
#     f(*args, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 3294, in _initialize_master_working_set
#     for dist in working_set
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 3294, in <genexpr>
#     for dist in working_set
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 2795, in activate
#     fixup_namespace_packages(self.location)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 2307, in fixup_namespace_packages
#     subpath = _handle_ns(package, path_item)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 2208, in _handle_ns
#     loader = importer.find_spec(packageName).loader
#   File "<frozen importlib._bootstrap_external>", line 1383, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 95, in _path_isfile
#   File "<frozen importlib._bootstrap_external>", line 87, in _path_is_mode_type
# KeyboardInterrupt

# %% [markdown]
# # OOF

# %%
FOLD = 0
INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_02/result/'
WEIGHT_PATH = f'./result/{VERSION}/model_seed{SEED}_fold{FOLD}.pth'

# !python ../$VERSION/validation.py --model $MODEL --version $VERSION \
--fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS \
--rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --max_length $MAX_LEN
# Out:
# ^C
# Traceback (most recent call last):
#   File "../01_v1_51/validation.py", line 1, in <module>
#     import torch
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/__init__.py", line 29, in <module>
#     from .torch_version import __version__ as __version__
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/torch_version.py", line 3, in <module>
#     from pkg_resources import packaging  # type: ignore[attr-defined]
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 3266, in <module>
#     @_call_aside
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 3241, in _call_aside
#     f(*args, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 3294, in _initialize_master_working_set
#     for dist in working_set
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 3294, in <genexpr>
#     for dist in working_set
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 2795, in activate
#     fixup_namespace_packages(self.location)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 2307, in fixup_namespace_packages
#     subpath = _handle_ns(package, path_item)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 2208, in _handle_ns
#     loader = importer.find_spec(packageName).loader
#   File "<frozen importlib._bootstrap_external>", line 1383, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 95, in _path_isfile
#   File "<frozen importlib._bootstrap_external>", line 87, in _path_is_mode_type
#   File "<frozen importlib._bootstrap_external>", line 81, in _path_stat
# KeyboardInterrupt

# %%
for FOLD in [1,2,3,4]:
    WEIGHT_PATH = f'./result/{VERSION}/model_seed{SEED}_fold{FOLD}.pth'
    # !python ../$VERSION/validation.py --model $MODEL --version $VERSION \
    --fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS \
    --rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH \
    --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --max_length $MAX_LEN
# Out:
# ^C
# Traceback (most recent call last):
#   File "../01_v1_51/validation.py", line 1, in <module>
#     import torch
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/__init__.py", line 197, in <module>
#     from torch._C import *  # noqa: F403
# RuntimeError: KeyboardInterrupt:
# torch 1.10.1
# 2022-10-08 23:08:03.327759: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-08 23:08:03.327783: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# ^C
# Traceback (most recent call last):
#   File "<frozen importlib._bootstrap_external>", line 87, in _path_is_mode_type
#   File "<frozen importlib._bootstrap_external>", line 81, in _path_stat
# FileNotFoundError: [Errno 2] No such file or directory: '/home/takesako/anaconda3/lib/python3.7/site-packages/zope/__init__.cpython-37m-x86_64-linux-gnu.so'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../01_v1_51/validation.py", line 1, in <module>
#     import torch
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/__init__.py", line 29, in <module>
#     from .torch_version import __version__ as __version__
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/torch_version.py", line 3, in <module>
#     from pkg_resources import packaging  # type: ignore[attr-defined]
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 3266, in <module>
#     @_call_aside
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 3241, in _call_aside
#     f(*args, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 3294, in _initialize_master_working_set
#     for dist in working_set
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 3294, in <genexpr>
#     for dist in working_set
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 2795, in activate
#     fixup_namespace_packages(self.location)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 2307, in fixup_namespace_packages
#     subpath = _handle_ns(package, path_item)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 2208, in _handle_ns
#     loader = importer.find_spec(packageName).loader
#   File "<frozen importlib._bootstrap_external>", line 1383, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 95, in _path_isfile
#   File "<frozen importlib._bootstrap_external>", line 87, in _path_is_mode_type
# KeyboardInterrupt
# torch 1.10.1
# 2022-10-08 23:08:07.705914: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-10-08 23:08:07.705943: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     161                 # know whether we've finished (if we matched EOF) or not
# --> 162                 res_idx = child.expect_list(patterns, self.read_timeout)
#     163                 print(child.before[out_size:].decode(enc, 'replace'), end='')
#
# ~/anaconda3/lib/python3.7/site-packages/pexpect/spawnbase.py in expect_list(self, pattern_list, timeout, searchwindowsize, async_, **kw)
#     371         else:
# --> 372             return exp.expect_loop(timeout)
#     373
#
# ~/anaconda3/lib/python3.7/site-packages/pexpect/expect.py in expect_loop(self, timeout)
#     168                 # Still have time left, so read more data
# --> 169                 incoming = spawn.read_nonblocking(spawn.maxread, timeout)
#     170                 if self.spawn.delayafterread is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/pexpect/pty_spawn.py in read_nonblocking(self, size, timeout)
#     499         # (possibly timeout=None), we call select() with a timeout.
# --> 500         if (timeout != 0) and select(timeout):
#     501             return super(spawn, self).read_nonblocking(size)
#
# ~/anaconda3/lib/python3.7/site-packages/pexpect/pty_spawn.py in select(timeout)
#     449             def select(timeout):
# --> 450                 return select_ignore_interrupts([self.child_fd], [], [], timeout)[0]
#     451
#
# ~/anaconda3/lib/python3.7/site-packages/pexpect/utils.py in select_ignore_interrupts(iwtd, owtd, ewtd, timeout)
#     142         try:
# --> 143             return select.select(iwtd, owtd, ewtd, timeout)
#     144         except InterruptedError:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-c6a765e6a0fb> in <module>
#       1 for FOLD in [1,2,3,4]:
#       2     WEIGHT_PATH = f'./result/{VERSION}/model_seed{SEED}_fold{FOLD}.pth'
# ----> 3     get_ipython().system('python ../$VERSION/validation.py --model $MODEL --version $VERSION      --fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS      --rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH      --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --max_length $MAX_LEN')
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/zmqshell.py in system_piped(self, cmd)
#     636                 self.user_ns['_exit_code'] = system(cmd)
#     637         else:
# --> 638             self.user_ns['_exit_code'] = system(self.var_expand(cmd, depth=1))
#     639
#     640     # Ensure new system_piped implementation is used
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     184             finally:
#     185                 # Ensure the subprocess really is terminated
# --> 186                 child.terminate(force=True)
#     187         # add isalive check, to ensure exitstatus is set:
#     188         child.isalive()
#
# ~/anaconda3/lib/python3.7/site-packages/pexpect/pty_spawn.py in terminate(self, force)
#     640         try:
#     641             self.kill(signal.SIGHUP)
# --> 642             time.sleep(self.delayafterterminate)
#     643             if not self.isalive():
#     644                 return True
#
# KeyboardInterrupt:

# %%
import pandas as pd
import numpy as np

num_fold = 5

preds = []
for fold in range(num_fold):
    tmp_df = pd.read_csv(f'./result/{VERSION}/pred_fold{fold}.csv')
    embeds = np.load(f'./result/{VERSION}/embeds_fold{fold}.npz')['arr_0']
    tmp_df['embed'] = embeds.tolist()
    preds.append(tmp_df)
    
pred_df = pd.concat(preds, axis=0).reset_index(drop=True)
train_df = pd.read_csv('../../input/feedback-prize-english-language-learning/train.csv')

oof_df = train_df[['text_id']].merge(pred_df, on='text_id', how='left')
oof_df.to_csv(f'./result/{VERSION}/oof_df.csv', index=False)

# %%
oof_df.shape, oof_df.isnull().sum()
