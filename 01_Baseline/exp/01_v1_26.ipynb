# %%
VERSION = '01_v1_26'
MODEL = 'microsoft/deberta-v3-base'
#'microsoft/deberta-base'
#'microsoft/deberta-v3-large'
LR = 2e-5 #8e-6
HEAD_LR = 2e-5 #8e-6 
SEED = 100
TRN_BS = 8
VAL_BS = 8
ACCUM_STEP = 1
HIDDEN_DROP_PROB = 0
P_DROP = 0
RNN = 'none'
WARMUP_RATIO = 0.1
HEAD = 'simple'
AUG = 'false'
MIXUP_ALPHA = 0
P_AUG = 0
AUG_STOP_EPOCH = 0
MSD = 'false'
MULTI_LAYERS = 1
EVAL_STEP = -1
NUM_LABELS = 6
NUM_LABELS_2 = -1
FP16 = 'true'
WD = 0.01
FREEZE = 'false'
MULTI_TASK = 'false' 
W_MT = 0 
AWP = 'false'
AWP_LR = 0
AWP_EPS = 0
AWP_START_EPOCH = -1
#PRETRAINED_DETECTOR_PATH = f'../../input/tascj/result/deberta_base_fold0.pth'
PRETRAINED_DETECTOR_PATH = 'none' #f'../../05_Detection/exp/result/05_v2_09/model_seed100_fold0_swa.pth'
MASK_PROB = 0 #0.8
MASK_RATIO = 0 #0.3
SCHEDULER = 'cosine_hard'
CP = 'false'
WINDOW_SIZE = -1 #512
INNER_LEN = -1 #384
EDGE_LEN = -1 #64
MAX_LEN = 512

GRAD_CLIP = 1

LOSS = 'smoothl1'#'mse'

# %%
FOLD = 0
INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_02/result/'
MODE = 'train'
EPOCHS = 5
STOP_EPOCH = 5
RESTART = 1
NUM_CYCLES = EPOCHS
PRETRAIN_PATH = 'none' #f'result/{VERSION}/model_seed{SEED}_fold{FOLD}_epoch{EPOCHS}_pseudo.pth'

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN \
--gradient_clip_val $GRAD_CLIP \
--input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN
# Out:
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3128, 8)
# val_df.shape =  (783, 8)
# 2022-09-14 22:39:54.971978: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-09-14 22:39:54.972002: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [01:44<00:00,  3.74it/s, loss=0.401]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.53it/s]
# epoch 1: trn_loss = 0.4011, val_loss = 0.1132, trn_score = 1.0877, val_score = 0.4755
# lr :  [8.224468037456969e-06, 8.224468037456969e-06, 8.224468037456969e-06]
# 100%|█████████████████████████████| 391/391 [01:44<00:00,  3.76it/s, loss=0.108]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.53it/s]
# epoch 2: trn_loss = 0.1078, val_loss = 0.1062, trn_score = 0.4655, val_score = 0.4614
# lr :  [4.974257968932691e-06, 4.974257968932691e-06, 4.974257968932691e-06]
# 100%|████████████████████████████| 391/391 [01:45<00:00,  3.70it/s, loss=0.0994]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.42it/s]
# epoch 3: trn_loss = 0.0994, val_loss = 0.1052, trn_score = 0.4465, val_score = 0.4591
# lr :  [2.3268220525837457e-06, 2.3268220525837457e-06, 2.3268220525837457e-06]
# 100%|████████████████████████████| 391/391 [01:46<00:00,  3.67it/s, loss=0.0908]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.43it/s]
# epoch 4: trn_loss = 0.0908, val_loss = 0.1064, trn_score = 0.4265, val_score = 0.4622
# lr :  [5.996867213330993e-07, 5.996867213330993e-07, 5.996867213330993e-07]
# 100%|████████████████████████████| 391/391 [01:44<00:00,  3.73it/s, loss=0.0861]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.51it/s]
# epoch 5: trn_loss = 0.0861, val_loss = 0.1069, trn_score = 0.4152, val_score = 0.4631

# %%
FOLD = 1
INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_02/result/'
MODE = 'train'
EPOCHS = 5
STOP_EPOCH = 5
RESTART = 1
NUM_CYCLES = EPOCHS
PRETRAIN_PATH = 'none' #f'result/{VERSION}/model_seed{SEED}_fold{FOLD}_epoch{EPOCHS}_pseudo.pth'

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN \
--gradient_clip_val $GRAD_CLIP \
--input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN
# Out:
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-09-14 22:50:51.952272: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-09-14 22:50:51.952295: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [01:44<00:00,  3.75it/s, loss=0.393]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.52it/s]
# epoch 1: trn_loss = 0.3932, val_loss = 0.1138, trn_score = 1.0813, val_score = 0.4784
# lr :  [8.224468037456969e-06, 8.224468037456969e-06, 8.224468037456969e-06]
# 100%|█████████████████████████████| 391/391 [01:44<00:00,  3.76it/s, loss=0.113]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.57it/s]
# epoch 2: trn_loss = 0.1126, val_loss = 0.1089, trn_score = 0.4757, val_score = 0.4677
# lr :  [4.974257968932691e-06, 4.974257968932691e-06, 4.974257968932691e-06]
# 100%|█████████████████████████████| 391/391 [01:43<00:00,  3.77it/s, loss=0.101]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.60it/s]
# epoch 3: trn_loss = 0.1009, val_loss = 0.1105, trn_score = 0.4499, val_score = 0.4716
# lr :  [2.3268220525837457e-06, 2.3268220525837457e-06, 2.3268220525837457e-06]
# 100%|████████████████████████████| 391/391 [01:43<00:00,  3.78it/s, loss=0.0919]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.60it/s]
# epoch 4: trn_loss = 0.0919, val_loss = 0.1054, trn_score = 0.4289, val_score = 0.4603
# lr :  [5.996867213330993e-07, 5.996867213330993e-07, 5.996867213330993e-07]
# 100%|████████████████████████████| 391/391 [01:43<00:00,  3.78it/s, loss=0.0846]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.64it/s]
# epoch 5: trn_loss = 0.0846, val_loss = 0.1082, trn_score = 0.4115, val_score = 0.4665

# %%
FOLD = 2
INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_02/result/'
MODE = 'train'
EPOCHS = 5
STOP_EPOCH = 5
RESTART = 1
NUM_CYCLES = EPOCHS
PRETRAIN_PATH = 'none' #f'result/{VERSION}/model_seed{SEED}_fold{FOLD}_epoch{EPOCHS}_pseudo.pth'

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN \
--gradient_clip_val $GRAD_CLIP \
--input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN
# Out:
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-09-14 23:01:38.436740: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-09-14 23:01:38.436762: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [01:44<00:00,  3.73it/s, loss=0.377]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.51it/s]
# epoch 1: trn_loss = 0.3770, val_loss = 0.1127, trn_score = 1.0570, val_score = 0.4762
# lr :  [8.224468037456969e-06, 8.224468037456969e-06, 8.224468037456969e-06]
# 100%|█████████████████████████████| 391/391 [01:44<00:00,  3.74it/s, loss=0.109]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.57it/s]
# epoch 2: trn_loss = 0.1088, val_loss = 0.1048, trn_score = 0.4675, val_score = 0.4587
# lr :  [4.974257968932691e-06, 4.974257968932691e-06, 4.974257968932691e-06]
# 100%|█████████████████████████████| 391/391 [01:43<00:00,  3.76it/s, loss=0.102]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.57it/s]
# epoch 3: trn_loss = 0.1023, val_loss = 0.1029, trn_score = 0.4532, val_score = 0.4542
# lr :  [2.3268220525837457e-06, 2.3268220525837457e-06, 2.3268220525837457e-06]
# 100%|████████████████████████████| 391/391 [01:43<00:00,  3.76it/s, loss=0.0941]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.55it/s]
# epoch 4: trn_loss = 0.0941, val_loss = 0.1037, trn_score = 0.4342, val_score = 0.4560
# lr :  [5.996867213330993e-07, 5.996867213330993e-07, 5.996867213330993e-07]
# 100%|████████████████████████████| 391/391 [01:44<00:00,  3.74it/s, loss=0.0875]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.58it/s]
# epoch 5: trn_loss = 0.0875, val_loss = 0.1033, trn_score = 0.4186, val_score = 0.4550

# %%
FOLD = 3
INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_02/result/'
MODE = 'train'
EPOCHS = 5
STOP_EPOCH = 5
RESTART = 1
NUM_CYCLES = EPOCHS
PRETRAIN_PATH = 'none' #f'result/{VERSION}/model_seed{SEED}_fold{FOLD}_epoch{EPOCHS}_pseudo.pth'

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN \
--gradient_clip_val $GRAD_CLIP \
--input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN
# Out:
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-09-14 23:12:28.493628: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-09-14 23:12:28.493648: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [01:44<00:00,  3.75it/s, loss=0.401]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.51it/s]
# epoch 1: trn_loss = 0.4013, val_loss = 0.1163, trn_score = 1.1196, val_score = 0.4831
# lr :  [8.224468037456969e-06, 8.224468037456969e-06, 8.224468037456969e-06]
# 100%|█████████████████████████████| 391/391 [01:44<00:00,  3.76it/s, loss=0.105]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.48it/s]
# epoch 2: trn_loss = 0.1050, val_loss = 0.1076, trn_score = 0.4592, val_score = 0.4646
# lr :  [4.974257968932691e-06, 4.974257968932691e-06, 4.974257968932691e-06]
# 100%|████████████████████████████| 391/391 [01:43<00:00,  3.79it/s, loss=0.0975]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.39it/s]
# epoch 3: trn_loss = 0.0975, val_loss = 0.1064, trn_score = 0.4423, val_score = 0.4621
# lr :  [2.3268220525837457e-06, 2.3268220525837457e-06, 2.3268220525837457e-06]
# 100%|████████████████████████████| 391/391 [01:43<00:00,  3.76it/s, loss=0.0899]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.36it/s]
# epoch 4: trn_loss = 0.0899, val_loss = 0.1105, trn_score = 0.4245, val_score = 0.4711
# lr :  [5.996867213330993e-07, 5.996867213330993e-07, 5.996867213330993e-07]
# 100%|█████████████████████████████| 391/391 [01:44<00:00,  3.76it/s, loss=0.081]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.36it/s]
# epoch 5: trn_loss = 0.0810, val_loss = 0.1096, trn_score = 0.4029, val_score = 0.4693

# %%
FOLD = 4
INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_02/result/'
MODE = 'train'
EPOCHS = 5
STOP_EPOCH = 5
RESTART = 1
NUM_CYCLES = EPOCHS
PRETRAIN_PATH = 'none' #f'result/{VERSION}/model_seed{SEED}_fold{FOLD}_epoch{EPOCHS}_pseudo.pth'

# !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
--lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
--epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
--accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
--mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
--msd $MSD --multi_layers $MULTI_LAYERS --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
--num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
--restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
--mt $MULTI_TASK --w_mt $W_MT \
--awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
--pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
--scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN \
--gradient_clip_val $GRAD_CLIP \
--input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN
# Out:
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 8)
# load folds...
# trn_df.shape =  (3129, 8)
# val_df.shape =  (782, 8)
# 2022-09-14 23:23:19.670343: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-09-14 23:23:19.670368: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# self.warmup_ratio =  0.1
# self.num_train_steps =  1955
# num_warmup_steps =  195
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 391/391 [01:45<00:00,  3.71it/s, loss=0.358]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.30it/s]
# epoch 1: trn_loss = 0.3585, val_loss = 0.1084, trn_score = 1.0146, val_score = 0.4664
# lr :  [8.224468037456969e-06, 8.224468037456969e-06, 8.224468037456969e-06]
# 100%|█████████████████████████████| 391/391 [01:44<00:00,  3.73it/s, loss=0.105]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.32it/s]
# epoch 2: trn_loss = 0.1054, val_loss = 0.1068, trn_score = 0.4600, val_score = 0.4626
# lr :  [4.974257968932691e-06, 4.974257968932691e-06, 4.974257968932691e-06]
# 100%|████████████████████████████| 391/391 [01:44<00:00,  3.75it/s, loss=0.0971]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.36it/s]
# epoch 3: trn_loss = 0.0971, val_loss = 0.1060, trn_score = 0.4413, val_score = 0.4613
# lr :  [2.3268220525837457e-06, 2.3268220525837457e-06, 2.3268220525837457e-06]
# 100%|████████████████████████████| 391/391 [01:44<00:00,  3.75it/s, loss=0.0893]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.33it/s]
# epoch 4: trn_loss = 0.0893, val_loss = 0.1053, trn_score = 0.4229, val_score = 0.4595
# lr :  [5.996867213330993e-07, 5.996867213330993e-07, 5.996867213330993e-07]
# 100%|████████████████████████████| 391/391 [01:43<00:00,  3.76it/s, loss=0.0816]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.34it/s]
# epoch 5: trn_loss = 0.0816, val_loss = 0.1086, trn_score = 0.4041, val_score = 0.4670

# %% [markdown]
# # SWA

# %%
# !python ../$VERSION/swa.py --work_dir ./result/$VERSION/ --fold 0 --seed $SEED --epochs '5'
# !python ../$VERSION/swa.py --work_dir ./result/$VERSION/ --fold 1 --seed $SEED --epochs '4'
# !python ../$VERSION/swa.py --work_dir ./result/$VERSION/ --fold 2 --seed $SEED --epochs '5'
# !python ../$VERSION/swa.py --work_dir ./result/$VERSION/ --fold 3 --seed $SEED --epochs '3'
# !python ../$VERSION/swa.py --work_dir ./result/$VERSION/ --fold 4 --seed $SEED --epochs '4'

# %%
FOLD = 0
INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_02/result/'
WEIGHT_PATH = f'./result/{VERSION}/model_seed{SEED}_fold{FOLD}_swa.pth'

# !python ../$VERSION/validation.py --model $MODEL --version $VERSION \
--fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS \
--rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --max_length $MAX_LEN

# %%
FOLD = 1
INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_02/result/'
WEIGHT_PATH = f'./result/{VERSION}/model_seed{SEED}_fold{FOLD}_swa.pth'

# !python ../$VERSION/validation.py --model $MODEL --version $VERSION \
--fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS \
--rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --max_length $MAX_LEN

# %%
FOLD = 2
INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_02/result/'
WEIGHT_PATH = f'./result/{VERSION}/model_seed{SEED}_fold{FOLD}_swa.pth'

# !python ../$VERSION/validation.py --model $MODEL --version $VERSION \
--fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS \
--rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --max_length $MAX_LEN

# %%
FOLD = 3
INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_02/result/'
WEIGHT_PATH = f'./result/{VERSION}/model_seed{SEED}_fold{FOLD}_swa.pth'

# !python ../$VERSION/validation.py --model $MODEL --version $VERSION \
--fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS \
--rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --max_length $MAX_LEN

# %%
FOLD = 4
INPUT_PATH = '../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_02/result/'
WEIGHT_PATH = f'./result/{VERSION}/model_seed{SEED}_fold{FOLD}_swa.pth'

# !python ../$VERSION/validation.py --model $MODEL --version $VERSION \
--fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS \
--rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH \
--window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --max_length $MAX_LEN

# %%
import pandas as pd

preds = []
for fold in range(5):
    tmp_df = pd.read_csv(f'./result/{VERSION}/pred_fold{fold}.csv')
    preds.append(tmp_df)
    
pred_df = pd.concat(preds, axis=0).reset_index(drop=True)
train_df = pd.read_csv('../../input/feedback-prize-english-language-learning/train.csv')

oof_df = train_df[['text_id']].merge(pred_df, on='text_id', how='left')
oof_df.to_csv(f'./result/{VERSION}/oof_df.csv', index=False)

# %%
oof_df.shape, oof_df.isnull().sum()
