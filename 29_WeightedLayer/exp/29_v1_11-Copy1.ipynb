# %%
VERSION = '29_v1_11'
MODEL = 'deepset/deberta-v3-large-squad2'
#'microsoft/deberta-v3-large'
#'microsoft/deberta-v3-base'
#TEACHER_VERSION = '14_v1_15' # deverta-v2-xlarge
#'bert-large-cased'
#'bert-large-cased-whole-word-masking'
#'albert-large-v2'
#'facebook/bart-large'
#'xlm-roberta-large'
#'deepset/roberta-large-squad2'
#'google/electra-large-discriminator'
#'sentence-transformeres/paraphrase-mpnet-base-v2'
#'funnel-transformer/large-base'
#'facebook/bart-base'
#'distilroberta-base'
#'deepset/roberta-base-squad2'
#'microsoft/deberta-v3-base'
#'roberta-large'
#'roberta-base'
#'microsoft/deberta-base'
LR = 4e-5 #8e-5 #8e-6
HEAD_LR = 4e-4 #8e-4 #2e-5 #8e-6 
SEED = 100
TRN_BS = 64 #8
VAL_BS = 64 #8
ACCUM_STEP = 1
HIDDEN_DROP_PROB = 0
P_DROP = 0
RNN = 'none'
WARMUP_RATIO = 0.1
HEAD = 'simple'
AUG = 'false'
MIXUP_ALPHA = 0
P_AUG = 0
AUG_STOP_EPOCH = 0
MSD = 'false'
POOLING = 'weighted_layer'  #'mean' #'transformer+mean' #'attention'
NUM_POOLING_LAYERS = 4 #1
MULTI_LAYERS = 1
EVAL_STEP_START_EPOCH = -1
EVAL_STEP = -1
NUM_LABELS = 6
NUM_LABELS_2 = -1
FP16 = 'true'
WD = 0.01
FREEZE = 'true' #'false'
MULTI_TASK = 'false' 
W_MT = 0 
AWP = 'false'
AWP_LR = 0
AWP_EPS = 0
AWP_START_EPOCH = -1
#PRETRAINED_DETECTOR_PATH = f'../../input/tascj/result/deberta_base_fold0.pth'
PRETRAINED_DETECTOR_PATH = 'none' #f'../../05_Detection/exp/result/05_v2_09/model_seed100_fold0_swa.pth'
MASK_PROB = 0 #0.8
MASK_RATIO = 0 #0.3
SCHEDULER = 'cosine_hard'
CP = 'true' #'false'
WINDOW_SIZE = -1
INNER_LEN = -1
EDGE_LEN = -1
MAX_LEN = 512

GRAD_CLIP = 1

LOSS = 'smoothl1'#'mse'

CROP_PROB = 0 #1.0

USE_STATS = 'false' #'true'
USE_SEPARATE_HEAD = 'true'

LOW_LOSS_THR = -1 #0.8 #0.5
HIGH_LOSS_THR = -1 #0.0001
OOF_DF_PATH = 'none' #'../../14_Baseline4/exp/result/14_v1_01/oof_df.csv'

# %% [markdown]
# # Train

# %% [markdown]
# # OOF

# %%
INPUT_PATH = '../../00_EDA/00_v1_12/result/' #'../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_02/result/'

# %%
# for CLASS in [
#     'cohesion',
#     'syntax','vocabulary','phraseology','grammar','conventions'
# ]:
#     print("*"*50)
#     print(CLASS)
#     print("*"*50)
if True:
    CLASS = 'none'
    for FOLD in [0,1,2,3,4]:
        print("-"*50)
        print("FOLD = ", FOLD)
        print("-"*50)
        WEIGHT_PATH = f'./result/{VERSION}/model_seed{SEED}_fold{FOLD}.pth'
        #WEIGHT_PATH = f'./result/{VERSION}/model_{CLASS}_seed{SEED}_fold{FOLD}.pth'
        #WEIGHT_PATH = f'result/{VERSION}/model_{CLASS}_seed{SEED}_fold{FOLD}_pseudo.pth'
        # !python ../$VERSION/validation.py --model $MODEL --version $VERSION \
        --fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS \
        --rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH \
        --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --max_length $MAX_LEN \
        --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS \
        --class_name $CLASS --input_path $INPUT_PATH --use_stats $USE_STATS \
        --use_separate_head $USE_SEPARATE_HEAD
# Out:
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# 2022-11-26 10:38:23.612693: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-26 10:38:23.612715: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3128, 13)
# val_df.shape =  (783, 13)
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
#  77%|█████████████████████████████████          | 10/13 [00:34<00:10,  3.40s/it]^C
#  77%|█████████████████████████████████          | 10/13 [00:35<00:10,  3.54s/it]
# Traceback (most recent call last):
#   File "../29_v1_11/validation.py", line 203, in <module>
#     output = model.validation_step(batch)
#   File "/home/takesako/programming/kaggle/kaggle-feedback-prize-english-language-learning/29_WeightedLayer/29_v1_11/models.py", line 502, in validation_step
#     logits, pred_seq, embed = self.forward_logits(**input_data)
#   File "/home/takesako/programming/kaggle/kaggle-feedback-prize-english-language-learning/29_WeightedLayer/29_v1_11/models.py", line 365, in forward_logits
#     attention_mask=attention_mask)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/transformers/models/deberta_v2/modeling_deberta_v2.py", line 1071, in forward
#     return_dict=return_dict,
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/transformers/models/deberta_v2/modeling_deberta_v2.py", line 503, in forward
#     output_attentions=output_attentions,
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/transformers/models/deberta_v2/modeling_deberta_v2.py", line 347, in forward
#     rel_embeddings=rel_embeddings,
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/transformers/models/deberta_v2/modeling_deberta_v2.py", line 278, in forward
#     rel_embeddings=rel_embeddings,
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/transformers/models/deberta_v2/modeling_deberta_v2.py", line 700, in forward
#     query_layer, key_layer, relative_pos, rel_embeddings, scale_factor
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/transformers/models/deberta_v2/modeling_deberta_v2.py", line 743, in disentangled_attention_bias
#     relative_pos = relative_pos.long().to(query_layer.device)
# KeyboardInterrupt
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# 2022-11-26 10:39:16.248895: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-26 10:39:16.248916: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# ^C
# Traceback (most recent call last):
#   File "../29_v1_11/validation.py", line 1, in <module>
#     import torch
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/__init__.py", line 23, in <module>
#     from ._utils_internal import get_file_path, prepare_multiprocessing_environment, \
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/_utils_internal.py", line 3, in <module>
#     import tempfile
#   File "/home/takesako/anaconda3/lib/python3.7/tempfile.py", line 43, in <module>
#     import shutil as _shutil
#   File "/home/takesako/anaconda3/lib/python3.7/shutil.py", line 22, in <module>
#     import bz2
#   File "/home/takesako/anaconda3/lib/python3.7/bz2.py", line 16, in <module>
#     import _compression
#   File "/home/takesako/anaconda3/lib/python3.7/_compression.py", line 9, in <module>
#     class BaseStream(io.BufferedIOBase):
#   File "/home/takesako/anaconda3/lib/python3.7/abc.py", line 126, in __new__
#     cls = super().__new__(mcls, name, bases, namespace, **kwargs)
# KeyboardInterrupt
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# ^C
# Traceback (most recent call last):
#   File "../29_v1_11/validation.py", line 1, in <module>
#     import torch
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/__init__.py", line 29, in <module>
#     from .torch_version import __version__ as __version__
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/torch_version.py", line 3, in <module>
#     from pkg_resources import packaging  # type: ignore[attr-defined]
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 78, in <module>
#     __import__('pkg_resources.extern.packaging.requirements')
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/_vendor/packaging/requirements.py", line 10, in <module>
#     from pkg_resources.extern.pyparsing import (  # noqa
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 967, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 670, in _load_unlocked
#   File "<frozen importlib._bootstrap>", line 583, in module_from_spec
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/extern/__init__.py", line 52, in create_module
#     return self.load_module(spec.name)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/extern/__init__.py", line 37, in load_module
#     __import__(extant)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/_vendor/pyparsing.py", line 4026, in <module>
#     class SkipTo(ParseElementEnhance):
# KeyboardInterrupt
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.1
# 2022-11-26 10:39:19.394770: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-26 10:39:19.394792: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)

# %%
import pandas as pd
import numpy as np

preds = []
# for CLASS in [
#     'cohesion',
#     'syntax','vocabulary','phraseology','grammar','conventions'
# ]:
#     print("*"*50)
#     print(CLASS)
#     print("*"*50)
#     preds_class = []
if True:
    for fold in [0,1,2,3,4]:
        tmp_df = pd.read_csv(f'./result/{VERSION}/pred_fold{fold}.csv')
        #tmp_df = pd.read_csv(f'./result/{VERSION}/pred_{CLASS}_fold{fold}.csv')
        #embeds = np.load(f'./result/{VERSION}/embeds_{CLASS}_fold{fold}.npz')['arr_0']
        #tmp_df[f'embed_{CLASS}'] = embeds.tolist()
        #preds_class.append(tmp_df)
        preds.append(tmp_df)
#     pred_df = pd.concat(preds_class, axis=0).reset_index(drop=True)
#     if len(preds)==0:
#         preds.append(pred_df)
#     else:
#         del pred_df["text_id"]
#         preds.append(pred_df)
    
#all_pred_df = pd.concat(preds, axis=1)
all_pred_df = pd.concat(preds, axis=0).reset_index(drop=True)

train_df = pd.read_csv('../../input/feedback-prize-english-language-learning/train.csv')
oof_df = train_df[['text_id']].merge(all_pred_df, on='text_id', how='left')
oof_df.to_csv(f'./result/{VERSION}/oof_df.csv', index=False)

# %%
oof_df.shape, oof_df.isnull().sum()
# Out:
# ((3911, 13),
#  text_id             0
#  cohesion            0
#  syntax              0
#  vocabulary          0
#  phraseology         0
#  grammar             0
#  conventions         0
#  loss_cohesion       0
#  loss_syntax         0
#  loss_vocabulary     0
#  loss_phraseology    0
#  loss_grammar        0
#  loss_conventions    0
#  dtype: int64)

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
oof_df[cols].describe()
# Out:
#           cohesion       syntax   vocabulary  phraseology      grammar  \
# count  3911.000000  3911.000000  3911.000000  3911.000000  3911.000000
# mean      3.148131     3.040735     3.237642     3.145658     3.057660
# std       0.471813     0.482350     0.427539     0.486377     0.537276
# min       0.627526     1.132753     1.415377     1.105238     1.483929
# 25%       2.837671     2.704769     2.946314     2.814954     2.671554
# 50%       3.152156     3.034071     3.220576     3.137155     3.053386
# 75%       3.473503     3.363844     3.512035     3.470931     3.415134
# max       4.829994     4.579453     4.843190     4.705826     4.886085
#
#        conventions
# count  3911.000000
# mean      3.089020
# std       0.516335
# min       1.001384
# 25%       2.740429
# 50%       3.091108
# 75%       3.449158
# max       4.641819

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
train_df[cols].describe()
# Out:
#           cohesion       syntax   vocabulary  phraseology      grammar  \
# count  3911.000000  3911.000000  3911.000000  3911.000000  3911.000000
# mean      3.127077     3.028254     3.235745     3.116850     3.032856
# std       0.662542     0.644399     0.583148     0.655997     0.699841
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%       2.500000     2.500000     3.000000     2.500000     2.500000
# 50%       3.000000     3.000000     3.000000     3.000000     3.000000
# 75%       3.500000     3.500000     3.500000     3.500000     3.500000
# max       5.000000     5.000000     5.000000     5.000000     5.000000
#
#        conventions
# count  3911.000000
# mean      3.081053
# std       0.671450
# min       1.000000
# 25%       2.500000
# 50%       3.000000
# 75%       3.500000
# max       5.000000

# %% [markdown]
# # Error Analysis - Check Corr

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
train_df[cols].corr()
# Out:
#              cohesion    syntax  vocabulary  phraseology   grammar  \
# cohesion     1.000000  0.695459    0.666151     0.690058  0.638689
# syntax       0.695459  1.000000    0.680562     0.725467  0.709525
# vocabulary   0.666151  0.680562    1.000000     0.735261  0.654852
# phraseology  0.690058  0.725467    0.735261     1.000000  0.719746
# grammar      0.638689  0.709525    0.654852     0.719746  1.000000
# conventions  0.666151  0.700025    0.664292     0.666842  0.673301
#
#              conventions
# cohesion        0.666151
# syntax          0.700025
# vocabulary      0.664292
# phraseology     0.666842
# grammar         0.673301
# conventions     1.000000

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
oof_df[cols].corr()
# Out:
#              cohesion    syntax  vocabulary  phraseology   grammar  \
# cohesion     1.000000  0.955644    0.942689     0.919420  0.847986
# syntax       0.955644  1.000000    0.957478     0.966286  0.936242
# vocabulary   0.942689  0.957478    1.000000     0.962343  0.894792
# phraseology  0.919420  0.966286    0.962343     1.000000  0.947922
# grammar      0.847986  0.936242    0.894792     0.947922  1.000000
# conventions  0.904311  0.939537    0.908969     0.890777  0.883069
#
#              conventions
# cohesion        0.904311
# syntax          0.939537
# vocabulary      0.908969
# phraseology     0.890777
# grammar         0.883069
# conventions     1.000000
