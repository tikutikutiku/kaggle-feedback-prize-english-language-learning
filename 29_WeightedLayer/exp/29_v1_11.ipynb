# %%
VERSION = '29_v1_11'
MODEL = 'deepset/deberta-v3-large-squad2'
#'microsoft/deberta-v3-large'
#'microsoft/deberta-v3-base'
#TEACHER_VERSION = '14_v1_15' # deverta-v2-xlarge
#'bert-large-cased'
#'bert-large-cased-whole-word-masking'
#'albert-large-v2'
#'facebook/bart-large'
#'xlm-roberta-large'
#'deepset/roberta-large-squad2'
#'google/electra-large-discriminator'
#'sentence-transformeres/paraphrase-mpnet-base-v2'
#'funnel-transformer/large-base'
#'facebook/bart-base'
#'distilroberta-base'
#'deepset/roberta-base-squad2'
#'microsoft/deberta-v3-base'
#'roberta-large'
#'roberta-base'
#'microsoft/deberta-base'
LR = 4e-5 #8e-5 #8e-6
HEAD_LR = 4e-4 #8e-4 #2e-5 #8e-6 
SEED = 100
TRN_BS = 64 #8
VAL_BS = 64 #8
ACCUM_STEP = 1
HIDDEN_DROP_PROB = 0
P_DROP = 0
RNN = 'none'
WARMUP_RATIO = 0.1
HEAD = 'simple'
AUG = 'false'
MIXUP_ALPHA = 0
P_AUG = 0
AUG_STOP_EPOCH = 0
MSD = 'false'
POOLING = 'weighted_layer'  #'mean' #'transformer+mean' #'attention'
NUM_POOLING_LAYERS = 4 #1
MULTI_LAYERS = 1
EVAL_STEP_START_EPOCH = -1
EVAL_STEP = -1
NUM_LABELS = 6
NUM_LABELS_2 = -1
FP16 = 'true'
WD = 0.01
FREEZE = 'true' #'false'
MULTI_TASK = 'false' 
W_MT = 0 
AWP = 'false'
AWP_LR = 0
AWP_EPS = 0
AWP_START_EPOCH = -1
#PRETRAINED_DETECTOR_PATH = f'../../input/tascj/result/deberta_base_fold0.pth'
PRETRAINED_DETECTOR_PATH = 'none' #f'../../05_Detection/exp/result/05_v2_09/model_seed100_fold0_swa.pth'
MASK_PROB = 0 #0.8
MASK_RATIO = 0 #0.3
SCHEDULER = 'cosine_hard'
CP = 'true' #'false'
WINDOW_SIZE = -1
INNER_LEN = -1
EDGE_LEN = -1
MAX_LEN = 512

GRAD_CLIP = 1

LOSS = 'smoothl1'#'mse'

CROP_PROB = 0 #1.0

USE_STATS = 'false' #'true'
USE_SEPARATE_HEAD = 'true'

LOW_LOSS_THR = -1 #0.8 #0.5
HIGH_LOSS_THR = -1 #0.0001
OOF_DF_PATH = 'none' #'../../14_Baseline4/exp/result/14_v1_01/oof_df.csv'

# %% [markdown]
# # Train

# %%
MODE = 'train'
EPOCHS = 10 #5
STOP_EPOCH = 10 #5
RESTART = 1
NUM_CYCLES = 1 #EPOCHS
EVAL_STEP = -1
ADD_FB3 = 'false'
FB3_FOLD_PATH = 'none' #'../../00_EDA/00_v1_02/result/'

# for CLASS in [
#     'cohesion',
#     #'syntax','vocabulary','phraseology','grammar','conventions'
# ]:
#     print("*"*50)
#     print(CLASS)
#     print("*"*50)
if True:
    CLASS = 'none'
    for FOLD in [0,1,2,3,4]:
        print("-"*50)
        print("FOLD = ", FOLD)
        print("-"*50)
        INPUT_PATH = '../../00_EDA/00_v1_12/result/' #'../../input/feedback-prize-english-language-learning/'
        FOLD_PATH = '../../00_EDA/00_v1_02/result/'
        #INPUT_PATH = f'../../99_Ensemble/99_v1_03/result/99_v1_03_03_pseudo_fold{FOLD}.csv'
        #INPUT_PATH = f'../../99_Ensemble/99_v1_03/result/99_v1_03_03_{TEACHER_VERSION}_pseudo_fold{FOLD}.csv'
        #FOLD_PATH = '../../00_EDA/00_v1_08/result/' # for pseudo-label
        PRETRAIN_PATH = 'none'
        # !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
        --lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
        --epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
        --accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
        --mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
        --msd $MSD --multi_layers $MULTI_LAYERS \
        --eval_step_start_epoch $EVAL_STEP_START_EPOCH --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
        --num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
        --restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
        --mt $MULTI_TASK --w_mt $W_MT \
        --awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
        --pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
        --scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
        --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN \
        --gradient_clip_val $GRAD_CLIP \
        --input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN \
        --crop_prob $CROP_PROB --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS --class_name $CLASS \
        --add_fb3 $ADD_FB3 --fb3_fold_path $FB3_FOLD_PATH --use_stats $USE_STATS \
        --use_separate_head $USE_SEPARATE_HEAD --low_loss_thr $LOW_LOSS_THR --high_loss_thr $HIGH_LOSS_THR \
        --oof_df_path $OOF_DF_PATH
# Out:
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3128, 13)
# val_df.shape =  (783, 13)
# 2022-11-19 12:25:04.150196: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-19 12:25:04.150216: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Downloading: 100%|██████████████████████████████| 367/367 [00:00<00:00, 224kB/s]
# Downloading: 100%|█████████████████████████| 2.35M/2.35M [00:00<00:00, 2.52MB/s]
# Downloading: 100%|███████████████████████████| 18.0/18.0 [00:00<00:00, 8.44kB/s]
# Downloading: 100%|█████████████████████████████| 156/156 [00:00<00:00, 65.6kB/s]
# Downloading: 100%|█████████████████████████| 8.25M/8.25M [00:01<00:00, 5.54MB/s]
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# Downloading: 100%|██████████████████████████| 1.04k/1.04k [00:00<00:00, 462kB/s]
# Downloading: 100%|█████████████████████████| 1.62G/1.62G [02:46<00:00, 10.4MB/s]
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  488
# num_warmup_steps =  48
# lr :  [0.0, 0.0, 0.0]
# 100%|███████████████████████████████| 48/48 [05:23<00:00,  6.75s/it, loss=0.884]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.50s/it]
# epoch 1: trn_loss = 0.8843, val_loss = 0.1879, trn_score = 1.6663, val_score = 0.6203
# model (best score) saved
# lr :  [4e-05, 4e-05, 0.0004]
# 100%|███████████████████████████████| 48/48 [05:24<00:00,  6.76s/it, loss=0.147]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.47s/it]
# epoch 2: trn_loss = 0.1465, val_loss = 0.1160, trn_score = 0.5465, val_score = 0.4825
# model (best score) saved
# lr :  [3.88368872727905e-05, 3.88368872727905e-05, 0.00038836887272790496]
# 100%|███████████████████████████████| 48/48 [05:24<00:00,  6.76s/it, loss=0.116]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.48s/it]
# epoch 3: trn_loss = 0.1159, val_loss = 0.1097, trn_score = 0.4830, val_score = 0.4692
# model (best score) saved
# lr :  [3.5482832212781655e-05, 3.5482832212781655e-05, 0.0003548283221278165]
# 100%|███████████████████████████████| 48/48 [05:24<00:00,  6.76s/it, loss=0.111]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.47s/it]
# epoch 4: trn_loss = 0.1114, val_loss = 0.1122, trn_score = 0.4732, val_score = 0.4747
# lr :  [3.0327949232779242e-05, 3.0327949232779242e-05, 0.0003032794923277924]
# 100%|███████████████████████████████| 48/48 [05:24<00:00,  6.75s/it, loss=0.103]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.47s/it]
# epoch 5: trn_loss = 0.1025, val_loss = 0.1106, trn_score = 0.4536, val_score = 0.4704
# lr :  [2.397180933291491e-05, 2.397180933291491e-05, 0.0002397180933291491]
# 100%|██████████████████████████████| 48/48 [05:24<00:00,  6.76s/it, loss=0.0995]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.47s/it]
# epoch 6: trn_loss = 0.0995, val_loss = 0.1076, trn_score = 0.4466, val_score = 0.4638
# model (best score) saved
# lr :  [1.7153703234534302e-05, 1.7153703234534302e-05, 0.000171537032345343]
# 100%|██████████████████████████████| 48/48 [05:24<00:00,  6.75s/it, loss=0.0961]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.47s/it]
# epoch 7: trn_loss = 0.0961, val_loss = 0.1062, trn_score = 0.4387, val_score = 0.4613
# model (best score) saved
# lr :  [1.0666653535486527e-05, 1.0666653535486527e-05, 0.00010666653535486525]
# 100%|██████████████████████████████| 48/48 [05:24<00:00,  6.75s/it, loss=0.0935]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.47s/it]
# epoch 8: trn_loss = 0.0935, val_loss = 0.1083, trn_score = 0.4327, val_score = 0.4661
# lr :  [5.265177242471899e-06, 5.265177242471899e-06, 5.2651772424718996e-05]
# 100%|██████████████████████████████| 48/48 [05:23<00:00,  6.75s/it, loss=0.0916]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.47s/it]
# epoch 9: trn_loss = 0.0916, val_loss = 0.1035, trn_score = 0.4281, val_score = 0.4552
# model (best score) saved
# lr :  [1.577526937703e-06, 1.577526937703e-06, 1.577526937703e-05]
# 100%|██████████████████████████████| 48/48 [05:24<00:00,  6.76s/it, loss=0.0909]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.47s/it]
# epoch 10: trn_loss = 0.0909, val_loss = 0.1030, trn_score = 0.4265, val_score = 0.4543
#  elapsed_time = 61.8 min
# model (best score) saved
#
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# 2022-11-19 13:30:05.537225: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-19 13:30:05.537247: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  488
# num_warmup_steps =  48
# lr :  [0.0, 0.0, 0.0]
# 100%|████████████████████████████████| 48/48 [05:26<00:00,  6.81s/it, loss=1.07]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.47s/it]
# epoch 1: trn_loss = 1.0681, val_loss = 0.1580, trn_score = 1.9222, val_score = 0.5669
# model (best score) saved
# lr :  [4e-05, 4e-05, 0.0004]
# 100%|███████████████████████████████| 48/48 [05:23<00:00,  6.75s/it, loss=0.124]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.47s/it]
# epoch 2: trn_loss = 0.1239, val_loss = 0.1327, trn_score = 0.5000, val_score = 0.5166
# model (best score) saved
# lr :  [3.88368872727905e-05, 3.88368872727905e-05, 0.00038836887272790496]
# 100%|███████████████████████████████| 48/48 [05:24<00:00,  6.75s/it, loss=0.114]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.46s/it]
# epoch 3: trn_loss = 0.1144, val_loss = 0.1142, trn_score = 0.4794, val_score = 0.4792
# model (best score) saved
# lr :  [3.5482832212781655e-05, 3.5482832212781655e-05, 0.0003548283221278165]
# 100%|███████████████████████████████| 48/48 [05:23<00:00,  6.75s/it, loss=0.106]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.47s/it]
# epoch 4: trn_loss = 0.1064, val_loss = 0.1052, trn_score = 0.4622, val_score = 0.4599
# model (best score) saved
# lr :  [3.0327949232779242e-05, 3.0327949232779242e-05, 0.0003032794923277924]
# 100%|███████████████████████████████| 48/48 [05:24<00:00,  6.75s/it, loss=0.102]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.47s/it]
# epoch 5: trn_loss = 0.1023, val_loss = 0.1020, trn_score = 0.4530, val_score = 0.4526
# model (best score) saved
# lr :  [2.397180933291491e-05, 2.397180933291491e-05, 0.0002397180933291491]
# 100%|██████████████████████████████| 48/48 [05:23<00:00,  6.75s/it, loss=0.0991]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.47s/it]
# epoch 6: trn_loss = 0.0991, val_loss = 0.1006, trn_score = 0.4457, val_score = 0.4495
# model (best score) saved
# lr :  [1.7153703234534302e-05, 1.7153703234534302e-05, 0.000171537032345343]
# 100%|██████████████████████████████| 48/48 [05:23<00:00,  6.75s/it, loss=0.0948]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.47s/it]
# epoch 7: trn_loss = 0.0948, val_loss = 0.1055, trn_score = 0.4357, val_score = 0.4603
# lr :  [1.0666653535486527e-05, 1.0666653535486527e-05, 0.00010666653535486525]
# 100%|███████████████████████████████| 48/48 [05:24<00:00,  6.75s/it, loss=0.091]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.46s/it]
# epoch 8: trn_loss = 0.0910, val_loss = 0.1008, trn_score = 0.4269, val_score = 0.4498
# lr :  [5.265177242471899e-06, 5.265177242471899e-06, 5.2651772424718996e-05]
# 100%|██████████████████████████████| 48/48 [05:23<00:00,  6.74s/it, loss=0.0889]
# 100%|███████████████████████████████████████████| 13/13 [00:44<00:00,  3.45s/it]
# epoch 9: trn_loss = 0.0889, val_loss = 0.1014, trn_score = 0.4219, val_score = 0.4511
# lr :  [1.577526937703e-06, 1.577526937703e-06, 1.577526937703e-05]
# 100%|██████████████████████████████| 48/48 [05:23<00:00,  6.73s/it, loss=0.0871]
# 100%|███████████████████████████████████████████| 13/13 [00:44<00:00,  3.45s/it]
# epoch 10: trn_loss = 0.0871, val_loss = 0.1023, trn_score = 0.4175, val_score = 0.4532
#  elapsed_time = 61.8 min
#
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# 2022-11-19 14:32:07.014144: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-19 14:32:07.014166: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  488
# num_warmup_steps =  48
# lr :  [0.0, 0.0, 0.0]
# 100%|████████████████████████████████| 48/48 [05:26<00:00,  6.79s/it, loss=1.06]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.46s/it]
# epoch 1: trn_loss = 1.0560, val_loss = 0.1592, trn_score = 1.9112, val_score = 0.5713
# model (best score) saved
# lr :  [4e-05, 4e-05, 0.0004]
# 100%|███████████████████████████████| 48/48 [05:23<00:00,  6.74s/it, loss=0.127]
# 100%|███████████████████████████████████████████| 13/13 [00:44<00:00,  3.45s/it]
# epoch 2: trn_loss = 0.1272, val_loss = 0.1200, trn_score = 0.5066, val_score = 0.4909
# model (best score) saved
# lr :  [3.88368872727905e-05, 3.88368872727905e-05, 0.00038836887272790496]
# 100%|███████████████████████████████| 48/48 [05:23<00:00,  6.73s/it, loss=0.116]
# 100%|███████████████████████████████████████████| 13/13 [00:44<00:00,  3.46s/it]
# epoch 3: trn_loss = 0.1158, val_loss = 0.1244, trn_score = 0.4828, val_score = 0.5006
# lr :  [3.5482832212781655e-05, 3.5482832212781655e-05, 0.0003548283221278165]
# 100%|███████████████████████████████| 48/48 [05:23<00:00,  6.73s/it, loss=0.107]
# 100%|███████████████████████████████████████████| 13/13 [00:44<00:00,  3.46s/it]
# epoch 4: trn_loss = 0.1067, val_loss = 0.1046, trn_score = 0.4628, val_score = 0.4582
# model (best score) saved
# lr :  [3.0327949232779242e-05, 3.0327949232779242e-05, 0.0003032794923277924]
# 100%|███████████████████████████████| 48/48 [05:23<00:00,  6.73s/it, loss=0.104]
# 100%|███████████████████████████████████████████| 13/13 [00:44<00:00,  3.46s/it]
# epoch 5: trn_loss = 0.1042, val_loss = 0.1067, trn_score = 0.4572, val_score = 0.4628
# lr :  [2.397180933291491e-05, 2.397180933291491e-05, 0.0002397180933291491]
# 100%|██████████████████████████████| 48/48 [05:23<00:00,  6.73s/it, loss=0.0983]
# 100%|███████████████████████████████████████████| 13/13 [00:44<00:00,  3.46s/it]
# epoch 6: trn_loss = 0.0983, val_loss = 0.1024, trn_score = 0.4439, val_score = 0.4534
# model (best score) saved
# lr :  [1.7153703234534302e-05, 1.7153703234534302e-05, 0.000171537032345343]
# 100%|██████████████████████████████| 48/48 [05:23<00:00,  6.73s/it, loss=0.0957]
# 100%|███████████████████████████████████████████| 13/13 [00:44<00:00,  3.45s/it]
# epoch 7: trn_loss = 0.0957, val_loss = 0.1003, trn_score = 0.4378, val_score = 0.4487
# model (best score) saved
# lr :  [1.0666653535486527e-05, 1.0666653535486527e-05, 0.00010666653535486525]
# 100%|██████████████████████████████| 48/48 [05:23<00:00,  6.74s/it, loss=0.0937]
# 100%|███████████████████████████████████████████| 13/13 [00:44<00:00,  3.46s/it]
# epoch 8: trn_loss = 0.0937, val_loss = 0.1003, trn_score = 0.4332, val_score = 0.4487
# lr :  [5.265177242471899e-06, 5.265177242471899e-06, 5.2651772424718996e-05]
# 100%|██████████████████████████████| 48/48 [05:23<00:00,  6.74s/it, loss=0.0909]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.54s/it]
# epoch 9: trn_loss = 0.0909, val_loss = 0.0996, trn_score = 0.4264, val_score = 0.4470
# model (best score) saved
# lr :  [1.577526937703e-06, 1.577526937703e-06, 1.577526937703e-05]
# 100%|██████████████████████████████| 48/48 [05:26<00:00,  6.81s/it, loss=0.0892]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.48s/it]
# epoch 10: trn_loss = 0.0892, val_loss = 0.0997, trn_score = 0.4225, val_score = 0.4472
#  elapsed_time = 61.7 min
#
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# 2022-11-19 15:34:06.662099: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-19 15:34:06.662118: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  488
# num_warmup_steps =  48
# lr :  [0.0, 0.0, 0.0]
# 100%|███████████████████████████████| 48/48 [05:29<00:00,  6.86s/it, loss=0.959]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.49s/it]
# epoch 1: trn_loss = 0.9595, val_loss = 0.1687, trn_score = 1.7853, val_score = 0.5850
# model (best score) saved
# lr :  [4e-05, 4e-05, 0.0004]
# 100%|███████████████████████████████| 48/48 [05:25<00:00,  6.78s/it, loss=0.131]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.48s/it]
# epoch 2: trn_loss = 0.1306, val_loss = 0.1278, trn_score = 0.5137, val_score = 0.5078
# model (best score) saved
# lr :  [3.88368872727905e-05, 3.88368872727905e-05, 0.00038836887272790496]
# 100%|███████████████████████████████| 48/48 [05:25<00:00,  6.78s/it, loss=0.113]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.47s/it]
# epoch 3: trn_loss = 0.1133, val_loss = 0.1175, trn_score = 0.4775, val_score = 0.4855
# model (best score) saved
# lr :  [3.5482832212781655e-05, 3.5482832212781655e-05, 0.0003548283221278165]
# 100%|███████████████████████████████| 48/48 [05:25<00:00,  6.78s/it, loss=0.109]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.47s/it]
# epoch 4: trn_loss = 0.1091, val_loss = 0.1058, trn_score = 0.4685, val_score = 0.4604
# model (best score) saved
# lr :  [3.0327949232779242e-05, 3.0327949232779242e-05, 0.0003032794923277924]
# 100%|███████████████████████████████| 48/48 [05:25<00:00,  6.78s/it, loss=0.103]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.48s/it]
# epoch 5: trn_loss = 0.1029, val_loss = 0.1055, trn_score = 0.4546, val_score = 0.4599
# model (best score) saved
# lr :  [2.397180933291491e-05, 2.397180933291491e-05, 0.0002397180933291491]
# 100%|██████████████████████████████| 48/48 [05:26<00:00,  6.79s/it, loss=0.0982]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.47s/it]
# epoch 6: trn_loss = 0.0982, val_loss = 0.1126, trn_score = 0.4436, val_score = 0.4752
# lr :  [1.7153703234534302e-05, 1.7153703234534302e-05, 0.000171537032345343]
# 100%|██████████████████████████████| 48/48 [05:25<00:00,  6.79s/it, loss=0.0982]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.48s/it]
# epoch 7: trn_loss = 0.0982, val_loss = 0.1039, trn_score = 0.4437, val_score = 0.4565
# model (best score) saved
# lr :  [1.0666653535486527e-05, 1.0666653535486527e-05, 0.00010666653535486525]
# 100%|██████████████████████████████| 48/48 [05:25<00:00,  6.79s/it, loss=0.0932]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.48s/it]
# epoch 8: trn_loss = 0.0932, val_loss = 0.1036, trn_score = 0.4320, val_score = 0.4557
# model (best score) saved
# lr :  [5.265177242471899e-06, 5.265177242471899e-06, 5.2651772424718996e-05]
# 100%|██████████████████████████████| 48/48 [05:25<00:00,  6.78s/it, loss=0.0905]
# 100%|███████████████████████████████████████████| 13/13 [00:44<00:00,  3.46s/it]
# epoch 9: trn_loss = 0.0905, val_loss = 0.1038, trn_score = 0.4257, val_score = 0.4561
# lr :  [1.577526937703e-06, 1.577526937703e-06, 1.577526937703e-05]
# 100%|███████████████████████████████| 48/48 [05:24<00:00,  6.75s/it, loss=0.089]
# 100%|███████████████████████████████████████████| 13/13 [00:44<00:00,  3.46s/it]
# epoch 10: trn_loss = 0.0890, val_loss = 0.1039, trn_score = 0.4222, val_score = 0.4564
#  elapsed_time = 62.1 min
#
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# 2022-11-19 16:36:29.119873: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-19 16:36:29.119895: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  488
# num_warmup_steps =  48
# lr :  [0.0, 0.0, 0.0]
# 100%|███████████████████████████████| 48/48 [05:27<00:00,  6.83s/it, loss=0.872]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.48s/it]
# epoch 1: trn_loss = 0.8720, val_loss = 0.1306, trn_score = 1.6521, val_score = 0.5139
# model (best score) saved
# lr :  [4e-05, 4e-05, 0.0004]
# 100%|████████████████████████████████| 48/48 [05:24<00:00,  6.76s/it, loss=0.12]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.47s/it]
# epoch 2: trn_loss = 0.1205, val_loss = 0.1076, trn_score = 0.4925, val_score = 0.4648
# model (best score) saved
# lr :  [3.88368872727905e-05, 3.88368872727905e-05, 0.00038836887272790496]
# 100%|███████████████████████████████| 48/48 [05:25<00:00,  6.77s/it, loss=0.108]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.46s/it]
# epoch 3: trn_loss = 0.1080, val_loss = 0.1101, trn_score = 0.4658, val_score = 0.4706
# lr :  [3.5482832212781655e-05, 3.5482832212781655e-05, 0.0003548283221278165]
# 100%|███████████████████████████████| 48/48 [05:25<00:00,  6.77s/it, loss=0.108]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.47s/it]
# epoch 4: trn_loss = 0.1079, val_loss = 0.1333, trn_score = 0.4656, val_score = 0.5175
# lr :  [3.0327949232779242e-05, 3.0327949232779242e-05, 0.0003032794923277924]
# 100%|███████████████████████████████| 48/48 [05:25<00:00,  6.77s/it, loss=0.102]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.47s/it]
# epoch 5: trn_loss = 0.1023, val_loss = 0.1142, trn_score = 0.4532, val_score = 0.4795
# lr :  [2.397180933291491e-05, 2.397180933291491e-05, 0.0002397180933291491]
# 100%|██████████████████████████████| 48/48 [05:25<00:00,  6.77s/it, loss=0.0969]
# 100%|███████████████████████████████████████████| 13/13 [00:44<00:00,  3.46s/it]
# epoch 6: trn_loss = 0.0969, val_loss = 0.1161, trn_score = 0.4407, val_score = 0.4830
# lr :  [1.7153703234534302e-05, 1.7153703234534302e-05, 0.000171537032345343]
# 100%|██████████████████████████████| 48/48 [05:25<00:00,  6.77s/it, loss=0.0967]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.46s/it]
# epoch 7: trn_loss = 0.0967, val_loss = 0.1039, trn_score = 0.4402, val_score = 0.4565
# model (best score) saved
# lr :  [1.0666653535486527e-05, 1.0666653535486527e-05, 0.00010666653535486525]
# 100%|███████████████████████████████| 48/48 [05:25<00:00,  6.77s/it, loss=0.091]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.46s/it]
# epoch 8: trn_loss = 0.0910, val_loss = 0.1043, trn_score = 0.4269, val_score = 0.4575
# lr :  [5.265177242471899e-06, 5.265177242471899e-06, 5.2651772424718996e-05]
# 100%|██████████████████████████████| 48/48 [05:25<00:00,  6.78s/it, loss=0.0882]
# 100%|███████████████████████████████████████████| 13/13 [00:44<00:00,  3.46s/it]
# epoch 9: trn_loss = 0.0882, val_loss = 0.1041, trn_score = 0.4201, val_score = 0.4572
# lr :  [1.577526937703e-06, 1.577526937703e-06, 1.577526937703e-05]
# 100%|███████████████████████████████| 48/48 [05:25<00:00,  6.77s/it, loss=0.087]
# 100%|███████████████████████████████████████████| 13/13 [00:44<00:00,  3.46s/it]
# epoch 10: trn_loss = 0.0870, val_loss = 0.1043, trn_score = 0.4172, val_score = 0.4576
#  elapsed_time = 61.8 min

# %% [markdown]
# # OOF

# %%
# INPUT_PATH = '../../00_EDA/00_v1_12/result/' #'../../input/feedback-prize-english-language-learning/'
# FOLD_PATH = '../../00_EDA/00_v1_02/result/'

# %%
# for CLASS in [
#     'cohesion',
#     'syntax','vocabulary','phraseology','grammar','conventions'
# ]:
#     print("*"*50)
#     print(CLASS)
#     print("*"*50)
if True:
    CLASS = 'none'
    for FOLD in [0,1,2,3,4]:
        print("-"*50)
        print("FOLD = ", FOLD)
        print("-"*50)
        WEIGHT_PATH = f'./result/{VERSION}/model_seed{SEED}_fold{FOLD}.pth'
        #WEIGHT_PATH = f'./result/{VERSION}/model_{CLASS}_seed{SEED}_fold{FOLD}.pth'
        #WEIGHT_PATH = f'result/{VERSION}/model_{CLASS}_seed{SEED}_fold{FOLD}_pseudo.pth'
        # !python ../$VERSION/validation.py --model $MODEL --version $VERSION \
        --fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS \
        --rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH \
        --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --max_length $MAX_LEN \
        --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS \
        --class_name $CLASS --input_path $INPUT_PATH --use_stats $USE_STATS \
        --use_separate_head $USE_SEPARATE_HEAD
# Out:
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# 2022-11-19 18:02:58.009841: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-19 18:02:58.009865: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3128, 13)
# val_df.shape =  (783, 13)
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# 100%|███████████████████████████████████████████| 13/13 [00:42<00:00,  3.25s/it]
# val_loss=0.1030, val_score=0.4543
# essay_ids.shape =  (783,)
# preds.shape =  (783, 6)
# labels.shape =  (783, 6)
# losses.shape =  (783, 6)
# embeds.shape =  (783, 1024, 6)
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# 2022-11-19 18:03:57.675643: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-19 18:03:57.675664: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# 100%|███████████████████████████████████████████| 13/13 [00:42<00:00,  3.27s/it]
# val_loss=0.1006, val_score=0.4495
# essay_ids.shape =  (782,)
# preds.shape =  (782, 6)
# labels.shape =  (782, 6)
# losses.shape =  (782, 6)
# embeds.shape =  (782, 1024, 6)
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# 2022-11-19 18:04:57.296786: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-19 18:04:57.296808: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# 100%|███████████████████████████████████████████| 13/13 [00:42<00:00,  3.28s/it]
# val_loss=0.0996, val_score=0.4470
# essay_ids.shape =  (782,)
# preds.shape =  (782, 6)
# labels.shape =  (782, 6)
# losses.shape =  (782, 6)
# embeds.shape =  (782, 1024, 6)
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.1
# 2022-11-19 18:05:57.470543: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-19 18:05:57.470566: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# 100%|███████████████████████████████████████████| 13/13 [00:42<00:00,  3.30s/it]
# val_loss=0.1036, val_score=0.4557
# essay_ids.shape =  (782,)
# preds.shape =  (782, 6)
# labels.shape =  (782, 6)
# losses.shape =  (782, 6)
# embeds.shape =  (782, 1024, 6)
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.1
# 2022-11-19 18:06:57.672441: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-19 18:06:57.672463: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# 100%|███████████████████████████████████████████| 13/13 [00:43<00:00,  3.32s/it]
# val_loss=0.1039, val_score=0.4565
# essay_ids.shape =  (782,)
# preds.shape =  (782, 6)
# labels.shape =  (782, 6)
# losses.shape =  (782, 6)
# embeds.shape =  (782, 1024, 6)

# %%
import pandas as pd
import numpy as np

preds = []
# for CLASS in [
#     'cohesion',
#     'syntax','vocabulary','phraseology','grammar','conventions'
# ]:
#     print("*"*50)
#     print(CLASS)
#     print("*"*50)
#     preds_class = []
if True:
    for fold in [0,1,2,3,4]:
        tmp_df = pd.read_csv(f'./result/{VERSION}/pred_fold{fold}.csv')
        #tmp_df = pd.read_csv(f'./result/{VERSION}/pred_{CLASS}_fold{fold}.csv')
        #embeds = np.load(f'./result/{VERSION}/embeds_{CLASS}_fold{fold}.npz')['arr_0']
        #tmp_df[f'embed_{CLASS}'] = embeds.tolist()
        #preds_class.append(tmp_df)
        preds.append(tmp_df)
#     pred_df = pd.concat(preds_class, axis=0).reset_index(drop=True)
#     if len(preds)==0:
#         preds.append(pred_df)
#     else:
#         del pred_df["text_id"]
#         preds.append(pred_df)
    
#all_pred_df = pd.concat(preds, axis=1)
all_pred_df = pd.concat(preds, axis=0).reset_index(drop=True)

train_df = pd.read_csv('../../input/feedback-prize-english-language-learning/train.csv')
oof_df = train_df[['text_id']].merge(all_pred_df, on='text_id', how='left')
oof_df.to_csv(f'./result/{VERSION}/oof_df.csv', index=False)

# %%
oof_df.shape, oof_df.isnull().sum()
# Out:
# ((3911, 13),
#  text_id             0
#  cohesion            0
#  syntax              0
#  vocabulary          0
#  phraseology         0
#  grammar             0
#  conventions         0
#  loss_cohesion       0
#  loss_syntax         0
#  loss_vocabulary     0
#  loss_phraseology    0
#  loss_grammar        0
#  loss_conventions    0
#  dtype: int64)

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
oof_df[cols].describe()
# Out:
#           cohesion       syntax   vocabulary  phraseology      grammar  \
# count  3911.000000  3911.000000  3911.000000  3911.000000  3911.000000
# mean      3.148131     3.040735     3.237642     3.145658     3.057660
# std       0.471813     0.482350     0.427539     0.486377     0.537276
# min       0.627526     1.132753     1.415377     1.105238     1.483929
# 25%       2.837671     2.704769     2.946314     2.814954     2.671554
# 50%       3.152156     3.034071     3.220576     3.137155     3.053386
# 75%       3.473503     3.363844     3.512035     3.470931     3.415134
# max       4.829994     4.579453     4.843190     4.705826     4.886085
#
#        conventions
# count  3911.000000
# mean      3.089020
# std       0.516335
# min       1.001384
# 25%       2.740429
# 50%       3.091108
# 75%       3.449158
# max       4.641819

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
train_df[cols].describe()
# Out:
#           cohesion       syntax   vocabulary  phraseology      grammar  \
# count  3911.000000  3911.000000  3911.000000  3911.000000  3911.000000
# mean      3.127077     3.028254     3.235745     3.116850     3.032856
# std       0.662542     0.644399     0.583148     0.655997     0.699841
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%       2.500000     2.500000     3.000000     2.500000     2.500000
# 50%       3.000000     3.000000     3.000000     3.000000     3.000000
# 75%       3.500000     3.500000     3.500000     3.500000     3.500000
# max       5.000000     5.000000     5.000000     5.000000     5.000000
#
#        conventions
# count  3911.000000
# mean      3.081053
# std       0.671450
# min       1.000000
# 25%       2.500000
# 50%       3.000000
# 75%       3.500000
# max       5.000000

# %% [markdown]
# # Error Analysis - Check Corr

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
train_df[cols].corr()
# Out:
#              cohesion    syntax  vocabulary  phraseology   grammar  \
# cohesion     1.000000  0.695459    0.666151     0.690058  0.638689
# syntax       0.695459  1.000000    0.680562     0.725467  0.709525
# vocabulary   0.666151  0.680562    1.000000     0.735261  0.654852
# phraseology  0.690058  0.725467    0.735261     1.000000  0.719746
# grammar      0.638689  0.709525    0.654852     0.719746  1.000000
# conventions  0.666151  0.700025    0.664292     0.666842  0.673301
#
#              conventions
# cohesion        0.666151
# syntax          0.700025
# vocabulary      0.664292
# phraseology     0.666842
# grammar         0.673301
# conventions     1.000000

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
oof_df[cols].corr()
# Out:
#              cohesion    syntax  vocabulary  phraseology   grammar  \
# cohesion     1.000000  0.955644    0.942689     0.919420  0.847986
# syntax       0.955644  1.000000    0.957478     0.966286  0.936242
# vocabulary   0.942689  0.957478    1.000000     0.962343  0.894792
# phraseology  0.919420  0.966286    0.962343     1.000000  0.947922
# grammar      0.847986  0.936242    0.894792     0.947922  1.000000
# conventions  0.904311  0.939537    0.908969     0.890777  0.883069
#
#              conventions
# cohesion        0.904311
# syntax          0.939537
# vocabulary      0.908969
# phraseology     0.890777
# grammar         0.883069
# conventions     1.000000
