# %%
VERSION = '29_v1_14'
MODEL = 'microsoft/deberta-v2-xlarge'
#'deepset/deberta-v3-large-squad2'
#'microsoft/deberta-v3-large'
#'microsoft/deberta-v3-base'
#TEACHER_VERSION = '14_v1_15' # deverta-v2-xlarge
#'bert-large-cased'
#'bert-large-cased-whole-word-masking'
#'albert-large-v2'
#'facebook/bart-large'
#'xlm-roberta-large'
#'deepset/roberta-large-squad2'
#'google/electra-large-discriminator'
#'sentence-transformeres/paraphrase-mpnet-base-v2'
#'funnel-transformer/large-base'
#'facebook/bart-base'
#'distilroberta-base'
#'deepset/roberta-base-squad2'
#'microsoft/deberta-v3-base'
#'roberta-large'
#'roberta-base'
#'microsoft/deberta-base'
LR = 2e-5 #4e-5 #8e-5 #8e-6
HEAD_LR = 2e-4 #4e-4 #8e-4 #2e-5 #8e-6 
SEED = 100
TRN_BS = 32 #64 #8
VAL_BS = 64 #8
ACCUM_STEP = 1
HIDDEN_DROP_PROB = 0
P_DROP = 0
RNN = 'none'
WARMUP_RATIO = 0.1
HEAD = 'simple'
AUG = 'false'
MIXUP_ALPHA = 0
P_AUG = 0
AUG_STOP_EPOCH = 0
MSD = 'false'
POOLING = 'weighted_layer'  #'mean' #'transformer+mean' #'attention'
NUM_POOLING_LAYERS = 4 #1
MULTI_LAYERS = 1
EVAL_STEP_START_EPOCH = -1
EVAL_STEP = -1
NUM_LABELS = 6
NUM_LABELS_2 = -1
FP16 = 'true'
WD = 0.01
FREEZE = 'true' #'false'
MULTI_TASK = 'false' 
W_MT = 0 
AWP = 'false'
AWP_LR = 0
AWP_EPS = 0
AWP_START_EPOCH = -1
#PRETRAINED_DETECTOR_PATH = f'../../input/tascj/result/deberta_base_fold0.pth'
PRETRAINED_DETECTOR_PATH = 'none' #f'../../05_Detection/exp/result/05_v2_09/model_seed100_fold0_swa.pth'
MASK_PROB = 0 #0.8
MASK_RATIO = 0 #0.3
SCHEDULER = 'cosine_hard'
CP = 'true' #'false'
WINDOW_SIZE = -1
INNER_LEN = -1
EDGE_LEN = -1
MAX_LEN = 512

GRAD_CLIP = 1

LOSS = 'smoothl1'#'mse'

CROP_PROB = 0 #1.0

USE_STATS = 'false' #'true'
USE_SEPARATE_HEAD = 'true'

LOW_LOSS_THR = -1 #0.8 #0.5
HIGH_LOSS_THR = -1 #0.0001
OOF_DF_PATH = 'none' #'../../14_Baseline4/exp/result/14_v1_01/oof_df.csv'

# %% [markdown]
# # Train

# %% [markdown]
# # OOF

# %%
INPUT_PATH = '../../00_EDA/00_v1_12/result/' #'../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_02/result/'

# %%
# for CLASS in [
#     'cohesion',
#     'syntax','vocabulary','phraseology','grammar','conventions'
# ]:
#     print("*"*50)
#     print(CLASS)
#     print("*"*50)
if True:
    CLASS = 'none'
    for FOLD in [0,1,2,3,4]:
        print("-"*50)
        print("FOLD = ", FOLD)
        print("-"*50)
        WEIGHT_PATH = f'./result/{VERSION}/model_seed{SEED}_fold{FOLD}.pth'
        #WEIGHT_PATH = f'./result/{VERSION}/model_{CLASS}_seed{SEED}_fold{FOLD}.pth'
        #WEIGHT_PATH = f'result/{VERSION}/model_{CLASS}_seed{SEED}_fold{FOLD}_pseudo.pth'
        # !python ../$VERSION/validation.py --model $MODEL --version $VERSION \
        --fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS \
        --rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH \
        --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --max_length $MAX_LEN \
        --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS \
        --class_name $CLASS --input_path $INPUT_PATH --use_stats $USE_STATS \
        --use_separate_head $USE_SEPARATE_HEAD
# Out:
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# 2022-11-26 12:27:15.434972: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-26 12:27:15.434993: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3128, 13)
# val_df.shape =  (783, 13)
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
#  23%|██████████▏                                 | 3/13 [00:19<01:03,  6.33s/it]^C
#  23%|██████████▏                                 | 3/13 [00:22<01:15,  7.56s/it]
# Traceback (most recent call last):
#   File "../29_v1_14/validation.py", line 203, in <module>
#     output = model.validation_step(batch)
#   File "/home/takesako/programming/kaggle/kaggle-feedback-prize-english-language-learning/29_WeightedLayer/29_v1_14/models.py", line 502, in validation_step
#     logits, pred_seq, embed = self.forward_logits(**input_data)
#   File "/home/takesako/programming/kaggle/kaggle-feedback-prize-english-language-learning/29_WeightedLayer/29_v1_14/models.py", line 365, in forward_logits
#     attention_mask=attention_mask)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/transformers/models/deberta_v2/modeling_deberta_v2.py", line 1071, in forward
#     return_dict=return_dict,
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/transformers/models/deberta_v2/modeling_deberta_v2.py", line 503, in forward
#     output_attentions=output_attentions,
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/transformers/models/deberta_v2/modeling_deberta_v2.py", line 347, in forward
#     rel_embeddings=rel_embeddings,
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/transformers/models/deberta_v2/modeling_deberta_v2.py", line 278, in forward
#     rel_embeddings=rel_embeddings,
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/transformers/models/deberta_v2/modeling_deberta_v2.py", line 700, in forward
#     query_layer, key_layer, relative_pos, rel_embeddings, scale_factor
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/transformers/models/deberta_v2/modeling_deberta_v2.py", line 743, in disentangled_attention_bias
#     relative_pos = relative_pos.long().to(query_layer.device)
# KeyboardInterrupt
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# ^C
# Traceback (most recent call last):
#   File "../29_v1_14/validation.py", line 1, in <module>
#     import torch
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/__init__.py", line 29, in <module>
#     from .torch_version import __version__ as __version__
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/torch/torch_version.py", line 3, in <module>
#     from pkg_resources import packaging  # type: ignore[attr-defined]
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 3266, in <module>
#     @_call_aside
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 3241, in _call_aside
#     f(*args, **kwargs)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 3302, in _initialize_master_working_set
#     list(map(working_set.add_entry, sys.path))
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 613, in add_entry
#     for dist in find_distributions(entry, True):
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 2073, in find_on_path
#     path_item_entries = _by_version_descending(filtered)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 2043, in _by_version_descending
#     return sorted(names, key=_by_version, reverse=True)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 2069, in <genexpr>
#     if dist_factory(path_item, entry, only)
#   File "/home/takesako/anaconda3/lib/python3.7/site-packages/pkg_resources/__init__.py", line 2092, in dist_factory
#     if is_meta else
# KeyboardInterrupt
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     156             else:
# --> 157                 child = pexpect.spawn(self.sh, args=['-c', cmd])  # Vanilla Pexpect
#     158             flush = sys.stdout.flush
#
# ~/anaconda3/lib/python3.7/site-packages/pexpect/pty_spawn.py in __init__(self, command, args, timeout, maxread, searchwindowsize, logfile, cwd, env, ignore_sighup, echo, preexec_fn, encoding, codec_errors, dimensions, use_poll)
#     204         else:
# --> 205             self._spawn(command, args, preexec_fn, dimensions)
#     206         self.use_poll = use_poll
#
# ~/anaconda3/lib/python3.7/site-packages/pexpect/pty_spawn.py in _spawn(self, command, args, preexec_fn, dimensions)
#     303         self.ptyproc = self._spawnpty(self.args, env=self.env,
# --> 304                                      cwd=self.cwd, **kwargs)
#     305
#
# ~/anaconda3/lib/python3.7/site-packages/pexpect/pty_spawn.py in _spawnpty(self, args, **kwargs)
#     314         '''Spawn a pty and return an instance of PtyProcess.'''
# --> 315         return ptyprocess.PtyProcess.spawn(args, **kwargs)
#     316
#
# ~/anaconda3/lib/python3.7/site-packages/ptyprocess/ptyprocess.py in spawn(cls, argv, cwd, env, echo, preexec_fn, dimensions, pass_fds)
#     314         os.close(exec_err_pipe_write)
# --> 315         exec_err_data = os.read(exec_err_pipe_read, 4096)
#     316         os.close(exec_err_pipe_read)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-3-4ba1f8c39373> in <module>
#      15         #WEIGHT_PATH = f'./result/{VERSION}/model_{CLASS}_seed{SEED}_fold{FOLD}.pth'
#      16         #WEIGHT_PATH = f'result/{VERSION}/model_{CLASS}_seed{SEED}_fold{FOLD}_pseudo.pth'
# ---> 17         get_ipython().system('python ../$VERSION/validation.py --model $MODEL --version $VERSION          --fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS          --rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH          --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --max_length $MAX_LEN          --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS          --class_name $CLASS --input_path $INPUT_PATH --use_stats $USE_STATS          --use_separate_head $USE_SEPARATE_HEAD')
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/zmqshell.py in system_piped(self, cmd)
#     636                 self.user_ns['_exit_code'] = system(cmd)
#     637         else:
# --> 638             self.user_ns['_exit_code'] = system(self.var_expand(cmd, depth=1))
#     639
#     640     # Ensure new system_piped implementation is used
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     171             # (the character is known as ETX for 'End of Text', see
#     172             # curses.ascii.ETX).
# --> 173             child.sendline(chr(3))
#     174             # Read and print any more output the program might produce on its
#     175             # way out.
#
# UnboundLocalError: local variable 'child' referenced before assignment

# %%
import pandas as pd
import numpy as np

preds = []
# for CLASS in [
#     'cohesion',
#     'syntax','vocabulary','phraseology','grammar','conventions'
# ]:
#     print("*"*50)
#     print(CLASS)
#     print("*"*50)
#     preds_class = []
if True:
    for fold in [0,1,2,3,4]:
        tmp_df = pd.read_csv(f'./result/{VERSION}/pred_fold{fold}.csv')
        #tmp_df = pd.read_csv(f'./result/{VERSION}/pred_{CLASS}_fold{fold}.csv')
        #embeds = np.load(f'./result/{VERSION}/embeds_{CLASS}_fold{fold}.npz')['arr_0']
        #tmp_df[f'embed_{CLASS}'] = embeds.tolist()
        #preds_class.append(tmp_df)
        preds.append(tmp_df)
#     pred_df = pd.concat(preds_class, axis=0).reset_index(drop=True)
#     if len(preds)==0:
#         preds.append(pred_df)
#     else:
#         del pred_df["text_id"]
#         preds.append(pred_df)
    
#all_pred_df = pd.concat(preds, axis=1)
all_pred_df = pd.concat(preds, axis=0).reset_index(drop=True)

train_df = pd.read_csv('../../input/feedback-prize-english-language-learning/train.csv')
oof_df = train_df[['text_id']].merge(all_pred_df, on='text_id', how='left')
oof_df.to_csv(f'./result/{VERSION}/oof_df.csv', index=False)

# %%
oof_df.shape, oof_df.isnull().sum()
# Out:
# ((3911, 13),
#  text_id             0
#  cohesion            0
#  syntax              0
#  vocabulary          0
#  phraseology         0
#  grammar             0
#  conventions         0
#  loss_cohesion       0
#  loss_syntax         0
#  loss_vocabulary     0
#  loss_phraseology    0
#  loss_grammar        0
#  loss_conventions    0
#  dtype: int64)

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
oof_df[cols].describe()
# Out:
#           cohesion       syntax   vocabulary  phraseology      grammar  \
# count  3911.000000  3911.000000  3911.000000  3911.000000  3911.000000
# mean      3.133458     3.040899     3.249763     3.121807     3.059602
# std       0.469432     0.478569     0.409871     0.478799     0.524893
# min       1.499834     1.418557     2.029174     1.678671     1.686857
# 25%       2.819707     2.709692     2.968489     2.792674     2.673240
# 50%       3.127222     3.022984     3.222696     3.111710     3.043662
# 75%       3.443690     3.372861     3.501176     3.446589     3.415731
# max       4.947530     4.764126     5.160777     4.881864     4.799074
#
#        conventions
# count  3911.000000
# mean      3.072675
# std       0.519294
# min       0.978777
# 25%       2.719323
# 50%       3.073902
# 75%       3.425136
# max       4.783917

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
train_df[cols].describe()
# Out:
#           cohesion       syntax   vocabulary  phraseology      grammar  \
# count  3911.000000  3911.000000  3911.000000  3911.000000  3911.000000
# mean      3.127077     3.028254     3.235745     3.116850     3.032856
# std       0.662542     0.644399     0.583148     0.655997     0.699841
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%       2.500000     2.500000     3.000000     2.500000     2.500000
# 50%       3.000000     3.000000     3.000000     3.000000     3.000000
# 75%       3.500000     3.500000     3.500000     3.500000     3.500000
# max       5.000000     5.000000     5.000000     5.000000     5.000000
#
#        conventions
# count  3911.000000
# mean      3.081053
# std       0.671450
# min       1.000000
# 25%       2.500000
# 50%       3.000000
# 75%       3.500000
# max       5.000000

# %% [markdown]
# # Error Analysis - Check Corr

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
train_df[cols].corr()
# Out:
#              cohesion    syntax  vocabulary  phraseology   grammar  \
# cohesion     1.000000  0.695459    0.666151     0.690058  0.638689
# syntax       0.695459  1.000000    0.680562     0.725467  0.709525
# vocabulary   0.666151  0.680562    1.000000     0.735261  0.654852
# phraseology  0.690058  0.725467    0.735261     1.000000  0.719746
# grammar      0.638689  0.709525    0.654852     0.719746  1.000000
# conventions  0.666151  0.700025    0.664292     0.666842  0.673301
#
#              conventions
# cohesion        0.666151
# syntax          0.700025
# vocabulary      0.664292
# phraseology     0.666842
# grammar         0.673301
# conventions     1.000000

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
oof_df[cols].corr()
# Out:
#              cohesion    syntax  vocabulary  phraseology   grammar  \
# cohesion     1.000000  0.955305    0.931669     0.917548  0.835191
# syntax       0.955305  1.000000    0.941992     0.950087  0.911687
# vocabulary   0.931669  0.941992    1.000000     0.948627  0.876186
# phraseology  0.917548  0.950087    0.948627     1.000000  0.935491
# grammar      0.835191  0.911687    0.876186     0.935491  1.000000
# conventions  0.901316  0.922952    0.888604     0.874461  0.847946
#
#              conventions
# cohesion        0.901316
# syntax          0.922952
# vocabulary      0.888604
# phraseology     0.874461
# grammar         0.847946
# conventions     1.000000
