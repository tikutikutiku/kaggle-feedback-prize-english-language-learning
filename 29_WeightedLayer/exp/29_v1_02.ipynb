# %%
VERSION = '29_v1_02'
MODEL = 'microsoft/deberta-v3-base'
#TEACHER_VERSION = '14_v1_15' # deverta-v2-xlarge
#'bert-large-cased'
#'bert-large-cased-whole-word-masking'
#'albert-large-v2'
#'facebook/bart-large'
#'xlm-roberta-large'
#'deepset/roberta-large-squad2'
#'google/electra-large-discriminator'
#'sentence-transformeres/paraphrase-mpnet-base-v2'
#'funnel-transformer/large-base'
#'facebook/bart-base'
#'distilroberta-base'
#'deepset/roberta-base-squad2'
#'microsoft/deberta-v3-base'
#'roberta-large'
#'roberta-base'
#'microsoft/deberta-v3-large'
#'microsoft/deberta-base'
LR = 2e-5 #8e-6
HEAD_LR = 2e-4 #2e-5 #8e-6 
SEED = 100
TRN_BS = 64 #8
VAL_BS = 64 #8
ACCUM_STEP = 1
HIDDEN_DROP_PROB = 0
P_DROP = 0
RNN = 'none'
WARMUP_RATIO = 0.1
HEAD = 'simple'
AUG = 'false'
MIXUP_ALPHA = 0
P_AUG = 0
AUG_STOP_EPOCH = 0
MSD = 'false'
POOLING = 'weighted_layer'  #'mean' #'transformer+mean' #'attention'
NUM_POOLING_LAYERS = 4 #1
MULTI_LAYERS = 1
EVAL_STEP_START_EPOCH = -1
EVAL_STEP = -1
NUM_LABELS = 6
NUM_LABELS_2 = -1
FP16 = 'true'
WD = 0.01
FREEZE = 'false'
MULTI_TASK = 'false' 
W_MT = 0 
AWP = 'false'
AWP_LR = 0
AWP_EPS = 0
AWP_START_EPOCH = -1
#PRETRAINED_DETECTOR_PATH = f'../../input/tascj/result/deberta_base_fold0.pth'
PRETRAINED_DETECTOR_PATH = 'none' #f'../../05_Detection/exp/result/05_v2_09/model_seed100_fold0_swa.pth'
MASK_PROB = 0 #0.8
MASK_RATIO = 0 #0.3
SCHEDULER = 'cosine_hard'
CP = 'true' #'false'
WINDOW_SIZE = -1
INNER_LEN = -1
EDGE_LEN = -1
MAX_LEN = 512

GRAD_CLIP = 1

LOSS = 'smoothl1'#'mse'

CROP_PROB = 0 #1.0

USE_STATS = 'false' #'true'
USE_SEPARATE_HEAD = 'true'

LOW_LOSS_THR = -1 #0.8 #0.5
HIGH_LOSS_THR = -1 #0.0001
OOF_DF_PATH = 'none' #'../../14_Baseline4/exp/result/14_v1_01/oof_df.csv'

# %% [markdown]
# # Train

# %%
MODE = 'train'
EPOCHS = 10 #5
STOP_EPOCH = 10 #5
RESTART = 1
NUM_CYCLES = 1 #EPOCHS
EVAL_STEP = -1
ADD_FB3 = 'false'
FB3_FOLD_PATH = 'none' #'../../00_EDA/00_v1_02/result/'

LR = 8e-5 #8e-6
HEAD_LR = 8e-4 #2e-5 #8e-6 
SEED = 100
TRN_BS = 64 #8
VAL_BS = 64 #8

# for CLASS in [
#     'cohesion',
#     #'syntax','vocabulary','phraseology','grammar','conventions'
# ]:
#     print("*"*50)
#     print(CLASS)
#     print("*"*50)
if True:
    CLASS = 'none'
    for FOLD in [0]: #[0,1,2,3,4]:
        print("-"*50)
        print("FOLD = ", FOLD)
        print("-"*50)
        INPUT_PATH = '../../00_EDA/00_v1_12/result/' #'../../input/feedback-prize-english-language-learning/'
        FOLD_PATH = '../../00_EDA/00_v1_02/result/'
        #INPUT_PATH = f'../../99_Ensemble/99_v1_03/result/99_v1_03_03_pseudo_fold{FOLD}.csv'
        #INPUT_PATH = f'../../99_Ensemble/99_v1_03/result/99_v1_03_03_{TEACHER_VERSION}_pseudo_fold{FOLD}.csv'
        #FOLD_PATH = '../../00_EDA/00_v1_08/result/' # for pseudo-label
        PRETRAIN_PATH = 'none'
        # !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
        --lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
        --epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
        --accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
        --mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
        --msd $MSD --multi_layers $MULTI_LAYERS \
        --eval_step_start_epoch $EVAL_STEP_START_EPOCH --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
        --num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
        --restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
        --mt $MULTI_TASK --w_mt $W_MT \
        --awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
        --pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
        --scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
        --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN \
        --gradient_clip_val $GRAD_CLIP \
        --input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN \
        --crop_prob $CROP_PROB --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS --class_name $CLASS \
        --add_fb3 $ADD_FB3 --fb3_fold_path $FB3_FOLD_PATH --use_stats $USE_STATS \
        --use_separate_head $USE_SEPARATE_HEAD --low_loss_thr $LOW_LOSS_THR --high_loss_thr $HIGH_LOSS_THR \
        --oof_df_path $OOF_DF_PATH
# Out:
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3128, 13)
# val_df.shape =  (783, 13)
# 2022-11-16 22:48:58.351900: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-16 22:48:58.351922: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# self.warmup_ratio =  0.1
# self.num_train_steps =  488
# num_warmup_steps =  48
# lr :  [0.0, 0.0, 0.0]
# 100%|████████████████████████████████| 48/48 [02:06<00:00,  2.63s/it, loss=1.11]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.28s/it]
# epoch 1: trn_loss = 1.1123, val_loss = 0.1335, trn_score = 1.9823, val_score = 0.5183
# model (best score) saved
# lr :  [8e-05, 8e-05, 0.0008]
# 100%|████████████████████████████████| 48/48 [02:06<00:00,  2.63s/it, loss=0.12]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.25s/it]
# epoch 2: trn_loss = 0.1202, val_loss = 0.1080, trn_score = 0.4922, val_score = 0.4654
# model (best score) saved
# lr :  [7.7673774545581e-05, 7.7673774545581e-05, 0.0007767377454558099]
# 100%|████████████████████████████████| 48/48 [02:05<00:00,  2.61s/it, loss=0.11]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.25s/it]
# epoch 3: trn_loss = 0.1102, val_loss = 0.1090, trn_score = 0.4705, val_score = 0.4672
# lr :  [7.096566442556331e-05, 7.096566442556331e-05, 0.000709656644255633]
# 100%|███████████████████████████████| 48/48 [02:05<00:00,  2.61s/it, loss=0.103]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.25s/it]
# epoch 4: trn_loss = 0.1029, val_loss = 0.1177, trn_score = 0.4545, val_score = 0.4868
# lr :  [6.0655898465558484e-05, 6.0655898465558484e-05, 0.0006065589846555848]
# 100%|███████████████████████████████| 48/48 [02:05<00:00,  2.61s/it, loss=0.096]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.25s/it]
# epoch 5: trn_loss = 0.0960, val_loss = 0.1047, trn_score = 0.4387, val_score = 0.4583
# model (best score) saved
# lr :  [4.794361866582982e-05, 4.794361866582982e-05, 0.0004794361866582982]
# 100%|███████████████████████████████| 48/48 [02:05<00:00,  2.61s/it, loss=0.091]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.25s/it]
# epoch 6: trn_loss = 0.0910, val_loss = 0.1044, trn_score = 0.4269, val_score = 0.4572
# model (best score) saved
# lr :  [3.4307406469068604e-05, 3.4307406469068604e-05, 0.000343074064690686]
# 100%|██████████████████████████████| 48/48 [02:05<00:00,  2.61s/it, loss=0.0894]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.25s/it]
# epoch 7: trn_loss = 0.0894, val_loss = 0.1073, trn_score = 0.4232, val_score = 0.4640
# lr :  [2.1333307070973054e-05, 2.1333307070973054e-05, 0.0002133330707097305]
# 100%|██████████████████████████████| 48/48 [02:05<00:00,  2.61s/it, loss=0.0839]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.25s/it]
# epoch 8: trn_loss = 0.0839, val_loss = 0.1044, trn_score = 0.4098, val_score = 0.4576
# lr :  [1.0530354484943798e-05, 1.0530354484943798e-05, 0.00010530354484943799]
# 100%|██████████████████████████████| 48/48 [02:05<00:00,  2.61s/it, loss=0.0803]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.27s/it]
# epoch 9: trn_loss = 0.0803, val_loss = 0.1051, trn_score = 0.4007, val_score = 0.4589
# lr :  [3.155053875406e-06, 3.155053875406e-06, 3.155053875406e-05]
# 100%|██████████████████████████████| 48/48 [02:05<00:00,  2.61s/it, loss=0.0792]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.25s/it]
# epoch 10: trn_loss = 0.0792, val_loss = 0.1038, trn_score = 0.3980, val_score = 0.4561
#  elapsed_time = 23.7 min
# model (best score) saved

# %%
MODE = 'train'
EPOCHS = 10 #5
STOP_EPOCH = 10 #5
RESTART = 1
NUM_CYCLES = 1 #EPOCHS
EVAL_STEP = -1
ADD_FB3 = 'false'
FB3_FOLD_PATH = 'none' #'../../00_EDA/00_v1_02/result/'

LR = 8e-5 #8e-6
HEAD_LR = 8e-4 #2e-5 #8e-6 
SEED = 100
TRN_BS = 64 #8
VAL_BS = 64 #8

# for CLASS in [
#     'cohesion',
#     #'syntax','vocabulary','phraseology','grammar','conventions'
# ]:
#     print("*"*50)
#     print(CLASS)
#     print("*"*50)
if True:
    CLASS = 'none'
    for FOLD in [1,2,3,4]:
        print("-"*50)
        print("FOLD = ", FOLD)
        print("-"*50)
        INPUT_PATH = '../../00_EDA/00_v1_12/result/' #'../../input/feedback-prize-english-language-learning/'
        FOLD_PATH = '../../00_EDA/00_v1_02/result/'
        #INPUT_PATH = f'../../99_Ensemble/99_v1_03/result/99_v1_03_03_pseudo_fold{FOLD}.csv'
        #INPUT_PATH = f'../../99_Ensemble/99_v1_03/result/99_v1_03_03_{TEACHER_VERSION}_pseudo_fold{FOLD}.csv'
        #FOLD_PATH = '../../00_EDA/00_v1_08/result/' # for pseudo-label
        PRETRAIN_PATH = 'none'
        # !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
        --lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
        --epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
        --accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
        --mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
        --msd $MSD --multi_layers $MULTI_LAYERS \
        --eval_step_start_epoch $EVAL_STEP_START_EPOCH --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
        --num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
        --restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
        --mt $MULTI_TASK --w_mt $W_MT \
        --awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
        --pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
        --scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
        --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN \
        --gradient_clip_val $GRAD_CLIP \
        --input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN \
        --crop_prob $CROP_PROB --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS --class_name $CLASS \
        --add_fb3 $ADD_FB3 --fb3_fold_path $FB3_FOLD_PATH --use_stats $USE_STATS \
        --use_separate_head $USE_SEPARATE_HEAD --low_loss_thr $LOW_LOSS_THR --high_loss_thr $HIGH_LOSS_THR \
        --oof_df_path $OOF_DF_PATH
# Out:
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# 2022-11-16 23:17:44.390621: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-16 23:17:44.390643: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# self.warmup_ratio =  0.1
# self.num_train_steps =  488
# num_warmup_steps =  48
# lr :  [0.0, 0.0, 0.0]
# 100%|███████████████████████████████| 48/48 [02:04<00:00,  2.59s/it, loss=0.904]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.24s/it]
# epoch 1: trn_loss = 0.9043, val_loss = 0.1368, trn_score = 1.7107, val_score = 0.5266
# model (best score) saved
# lr :  [8e-05, 8e-05, 0.0008]
# 100%|███████████████████████████████| 48/48 [02:06<00:00,  2.63s/it, loss=0.127]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.25s/it]
# epoch 2: trn_loss = 0.1272, val_loss = 0.1111, trn_score = 0.5064, val_score = 0.4725
# model (best score) saved
# lr :  [7.7673774545581e-05, 7.7673774545581e-05, 0.0007767377454558099]
# 100%|████████████████████████████████| 48/48 [02:05<00:00,  2.62s/it, loss=0.11]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.24s/it]
# epoch 3: trn_loss = 0.1101, val_loss = 0.1394, trn_score = 0.4701, val_score = 0.5290
# lr :  [7.096566442556331e-05, 7.096566442556331e-05, 0.000709656644255633]
# 100%|███████████████████████████████| 48/48 [02:05<00:00,  2.61s/it, loss=0.106]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.24s/it]
# epoch 4: trn_loss = 0.1055, val_loss = 0.1193, trn_score = 0.4601, val_score = 0.4895
# lr :  [6.0655898465558484e-05, 6.0655898465558484e-05, 0.0006065589846555848]
# 100%|██████████████████████████████| 48/48 [02:05<00:00,  2.62s/it, loss=0.0988]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.25s/it]
# epoch 5: trn_loss = 0.0988, val_loss = 0.1042, trn_score = 0.4450, val_score = 0.4573
# model (best score) saved
# lr :  [4.794361866582982e-05, 4.794361866582982e-05, 0.0004794361866582982]
# 100%|███████████████████████████████| 48/48 [02:05<00:00,  2.61s/it, loss=0.095]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.25s/it]
# epoch 6: trn_loss = 0.0950, val_loss = 0.1037, trn_score = 0.4362, val_score = 0.4559
# model (best score) saved
# lr :  [3.4307406469068604e-05, 3.4307406469068604e-05, 0.000343074064690686]
# 100%|██████████████████████████████| 48/48 [02:05<00:00,  2.61s/it, loss=0.0915]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.25s/it]
# epoch 7: trn_loss = 0.0915, val_loss = 0.1037, trn_score = 0.4280, val_score = 0.4560
# lr :  [2.1333307070973054e-05, 2.1333307070973054e-05, 0.0002133330707097305]
# 100%|██████████████████████████████| 48/48 [02:05<00:00,  2.61s/it, loss=0.0883]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.25s/it]
# epoch 8: trn_loss = 0.0883, val_loss = 0.1028, trn_score = 0.4203, val_score = 0.4542
# model (best score) saved
# lr :  [1.0530354484943798e-05, 1.0530354484943798e-05, 0.00010530354484943799]
# 100%|██████████████████████████████| 48/48 [02:05<00:00,  2.61s/it, loss=0.0846]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.25s/it]
# epoch 9: trn_loss = 0.0846, val_loss = 0.1062, trn_score = 0.4113, val_score = 0.4621
# lr :  [3.155053875406e-06, 3.155053875406e-06, 3.155053875406e-05]
# 100%|██████████████████████████████| 48/48 [02:05<00:00,  2.61s/it, loss=0.0826]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.25s/it]
# epoch 10: trn_loss = 0.0826, val_loss = 0.1034, trn_score = 0.4064, val_score = 0.4555
#  elapsed_time = 23.7 min
#
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# 2022-11-16 23:41:41.411638: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-16 23:41:41.411660: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# self.warmup_ratio =  0.1
# self.num_train_steps =  488
# num_warmup_steps =  48
# lr :  [0.0, 0.0, 0.0]
# 100%|███████████████████████████████| 48/48 [02:07<00:00,  2.66s/it, loss=0.947]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.27s/it]
# epoch 1: trn_loss = 0.9474, val_loss = 0.1319, trn_score = 1.7778, val_score = 0.5158
# model (best score) saved
# lr :  [8e-05, 8e-05, 0.0008]
# 100%|███████████████████████████████| 48/48 [02:06<00:00,  2.63s/it, loss=0.129]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.25s/it]
# epoch 2: trn_loss = 0.1288, val_loss = 0.1447, trn_score = 0.5098, val_score = 0.5375
# lr :  [7.7673774545581e-05, 7.7673774545581e-05, 0.0007767377454558099]
# 100%|███████████████████████████████| 48/48 [02:05<00:00,  2.61s/it, loss=0.117]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.25s/it]
# epoch 3: trn_loss = 0.1174, val_loss = 0.1086, trn_score = 0.4863, val_score = 0.4670
# model (best score) saved
# lr :  [7.096566442556331e-05, 7.096566442556331e-05, 0.000709656644255633]
# 100%|███████████████████████████████| 48/48 [02:05<00:00,  2.61s/it, loss=0.107]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.25s/it]
# epoch 4: trn_loss = 0.1075, val_loss = 0.1225, trn_score = 0.4647, val_score = 0.4956
# lr :  [6.0655898465558484e-05, 6.0655898465558484e-05, 0.0006065589846555848]
# 100%|███████████████████████████████| 48/48 [02:05<00:00,  2.62s/it, loss=0.111]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.25s/it]
# epoch 5: trn_loss = 0.1108, val_loss = 0.1069, trn_score = 0.4719, val_score = 0.4630
# model (best score) saved
# lr :  [4.794361866582982e-05, 4.794361866582982e-05, 0.0004794361866582982]
# 100%|██████████████████████████████| 48/48 [02:05<00:00,  2.61s/it, loss=0.0994]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.23s/it]
# epoch 6: trn_loss = 0.0994, val_loss = 0.1049, trn_score = 0.4463, val_score = 0.4590
# model (best score) saved
# lr :  [3.4307406469068604e-05, 3.4307406469068604e-05, 0.000343074064690686]
# 100%|██████████████████████████████| 48/48 [02:05<00:00,  2.61s/it, loss=0.0955]
# 100%|███████████████████████████████████████████| 13/13 [00:17<00:00,  1.31s/it]
# epoch 7: trn_loss = 0.0955, val_loss = 0.1027, trn_score = 0.4377, val_score = 0.4539
# model (best score) saved
# lr :  [2.1333307070973054e-05, 2.1333307070973054e-05, 0.0002133330707097305]
# 100%|██████████████████████████████| 48/48 [02:06<00:00,  2.63s/it, loss=0.0891]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.25s/it]
# epoch 8: trn_loss = 0.0891, val_loss = 0.1076, trn_score = 0.4225, val_score = 0.4650
# lr :  [1.0530354484943798e-05, 1.0530354484943798e-05, 0.00010530354484943799]
# 100%|██████████████████████████████| 48/48 [02:05<00:00,  2.61s/it, loss=0.0855]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.25s/it]
# epoch 9: trn_loss = 0.0855, val_loss = 0.1042, trn_score = 0.4138, val_score = 0.4570
# lr :  [3.155053875406e-06, 3.155053875406e-06, 3.155053875406e-05]
# 100%|██████████████████████████████| 48/48 [02:05<00:00,  2.61s/it, loss=0.0832]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.24s/it]
# epoch 10: trn_loss = 0.0832, val_loss = 0.1005, trn_score = 0.4081, val_score = 0.4488
#  elapsed_time = 23.8 min
# model (best score) saved
#
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# 2022-11-17 00:05:43.504883: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-17 00:05:43.504905: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# self.warmup_ratio =  0.1
# self.num_train_steps =  488
# num_warmup_steps =  48
# lr :  [0.0, 0.0, 0.0]
# 100%|███████████████████████████████| 48/48 [02:07<00:00,  2.65s/it, loss=0.978]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.26s/it]
# epoch 1: trn_loss = 0.9775, val_loss = 0.1839, trn_score = 1.8252, val_score = 0.6100
# model (best score) saved
# lr :  [8e-05, 8e-05, 0.0008]
# 100%|███████████████████████████████| 48/48 [02:06<00:00,  2.63s/it, loss=0.138]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.24s/it]
# epoch 2: trn_loss = 0.1379, val_loss = 0.1299, trn_score = 0.5281, val_score = 0.5108
# model (best score) saved
# lr :  [7.7673774545581e-05, 7.7673774545581e-05, 0.0007767377454558099]
# 100%|███████████████████████████████| 48/48 [02:06<00:00,  2.63s/it, loss=0.111]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.25s/it]
# epoch 3: trn_loss = 0.1111, val_loss = 0.1100, trn_score = 0.4726, val_score = 0.4696
# model (best score) saved
# lr :  [7.096566442556331e-05, 7.096566442556331e-05, 0.000709656644255633]
# 100%|███████████████████████████████| 48/48 [02:05<00:00,  2.61s/it, loss=0.103]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.25s/it]
# epoch 4: trn_loss = 0.1030, val_loss = 0.1191, trn_score = 0.4547, val_score = 0.4896
# lr :  [6.0655898465558484e-05, 6.0655898465558484e-05, 0.0006065589846555848]
# 100%|██████████████████████████████| 48/48 [02:05<00:00,  2.61s/it, loss=0.0995]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.25s/it]
# epoch 5: trn_loss = 0.0995, val_loss = 0.1096, trn_score = 0.4467, val_score = 0.4690
# model (best score) saved
# lr :  [4.794361866582982e-05, 4.794361866582982e-05, 0.0004794361866582982]
# 100%|██████████████████████████████| 48/48 [02:05<00:00,  2.61s/it, loss=0.0947]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.25s/it]
# epoch 6: trn_loss = 0.0947, val_loss = 0.1067, trn_score = 0.4358, val_score = 0.4628
# model (best score) saved
# lr :  [3.4307406469068604e-05, 3.4307406469068604e-05, 0.000343074064690686]
# 100%|██████████████████████████████| 48/48 [02:05<00:00,  2.61s/it, loss=0.0909]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.25s/it]
# epoch 7: trn_loss = 0.0909, val_loss = 0.1052, trn_score = 0.4267, val_score = 0.4592
# model (best score) saved
# lr :  [2.1333307070973054e-05, 2.1333307070973054e-05, 0.0002133330707097305]
# 100%|██████████████████████████████| 48/48 [02:05<00:00,  2.61s/it, loss=0.0868]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.25s/it]
# epoch 8: trn_loss = 0.0868, val_loss = 0.1075, trn_score = 0.4168, val_score = 0.4645
# lr :  [1.0530354484943798e-05, 1.0530354484943798e-05, 0.00010530354484943799]
# 100%|██████████████████████████████| 48/48 [02:05<00:00,  2.61s/it, loss=0.0847]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.25s/it]
# epoch 9: trn_loss = 0.0847, val_loss = 0.1067, trn_score = 0.4117, val_score = 0.4628
# lr :  [3.155053875406e-06, 3.155053875406e-06, 3.155053875406e-05]
# 100%|██████████████████████████████| 48/48 [02:05<00:00,  2.61s/it, loss=0.0824]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.25s/it]
# epoch 10: trn_loss = 0.0824, val_loss = 0.1062, trn_score = 0.4060, val_score = 0.4616
#  elapsed_time = 23.8 min
#
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# 2022-11-17 00:29:45.735548: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-17 00:29:45.735568: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# self.warmup_ratio =  0.1
# self.num_train_steps =  488
# num_warmup_steps =  48
# lr :  [0.0, 0.0, 0.0]
# 100%|███████████████████████████████| 48/48 [02:07<00:00,  2.65s/it, loss=0.914]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.27s/it]
# epoch 1: trn_loss = 0.9140, val_loss = 0.1376, trn_score = 1.7143, val_score = 0.5227
# model (best score) saved
# lr :  [8e-05, 8e-05, 0.0008]
# 100%|███████████████████████████████| 48/48 [02:06<00:00,  2.64s/it, loss=0.123]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.26s/it]
# epoch 2: trn_loss = 0.1233, val_loss = 0.1095, trn_score = 0.4987, val_score = 0.4686
# model (best score) saved
# lr :  [7.7673774545581e-05, 7.7673774545581e-05, 0.0007767377454558099]
# 100%|███████████████████████████████| 48/48 [02:05<00:00,  2.62s/it, loss=0.113]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.25s/it]
# epoch 3: trn_loss = 0.1133, val_loss = 0.1140, trn_score = 0.4774, val_score = 0.4785
# lr :  [7.096566442556331e-05, 7.096566442556331e-05, 0.000709656644255633]
# 100%|███████████████████████████████| 48/48 [02:05<00:00,  2.62s/it, loss=0.105]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.25s/it]
# epoch 4: trn_loss = 0.1046, val_loss = 0.1081, trn_score = 0.4583, val_score = 0.4661
# model (best score) saved
# lr :  [6.0655898465558484e-05, 6.0655898465558484e-05, 0.0006065589846555848]
# 100%|██████████████████████████████| 48/48 [02:05<00:00,  2.62s/it, loss=0.0969]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.24s/it]
# epoch 5: trn_loss = 0.0969, val_loss = 0.1133, trn_score = 0.4405, val_score = 0.4771
# lr :  [4.794361866582982e-05, 4.794361866582982e-05, 0.0004794361866582982]
# 100%|██████████████████████████████| 48/48 [02:05<00:00,  2.62s/it, loss=0.0923]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.25s/it]
# epoch 6: trn_loss = 0.0923, val_loss = 0.1055, trn_score = 0.4301, val_score = 0.4605
# model (best score) saved
# lr :  [3.4307406469068604e-05, 3.4307406469068604e-05, 0.000343074064690686]
# 100%|██████████████████████████████| 48/48 [02:05<00:00,  2.62s/it, loss=0.0846]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.25s/it]
# epoch 7: trn_loss = 0.0846, val_loss = 0.1149, trn_score = 0.4114, val_score = 0.4812
# lr :  [2.1333307070973054e-05, 2.1333307070973054e-05, 0.0002133330707097305]
# 100%|██████████████████████████████| 48/48 [02:05<00:00,  2.62s/it, loss=0.0779]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.25s/it]
# epoch 8: trn_loss = 0.0779, val_loss = 0.1063, trn_score = 0.3947, val_score = 0.4624
# lr :  [1.0530354484943798e-05, 1.0530354484943798e-05, 0.00010530354484943799]
# 100%|██████████████████████████████| 48/48 [02:05<00:00,  2.62s/it, loss=0.0735]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.25s/it]
# epoch 9: trn_loss = 0.0735, val_loss = 0.1065, trn_score = 0.3834, val_score = 0.4628
# lr :  [3.155053875406e-06, 3.155053875406e-06, 3.155053875406e-05]
# 100%|██████████████████████████████| 48/48 [02:05<00:00,  2.62s/it, loss=0.0708]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.25s/it]
# epoch 10: trn_loss = 0.0708, val_loss = 0.1072, trn_score = 0.3762, val_score = 0.4645
#  elapsed_time = 23.8 min

# %% [markdown]
# # OOF

# %%
INPUT_PATH = '../../00_EDA/00_v1_12/result/' #'../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_02/result/'

# %%
# for CLASS in [
#     'cohesion',
#     'syntax','vocabulary','phraseology','grammar','conventions'
# ]:
#     print("*"*50)
#     print(CLASS)
#     print("*"*50)
if True:
    CLASS = 'none'
    for FOLD in [0,1,2,3,4]:
        print("-"*50)
        print("FOLD = ", FOLD)
        print("-"*50)
        WEIGHT_PATH = f'./result/{VERSION}/model_seed{SEED}_fold{FOLD}.pth'
        #WEIGHT_PATH = f'./result/{VERSION}/model_{CLASS}_seed{SEED}_fold{FOLD}.pth'
        #WEIGHT_PATH = f'result/{VERSION}/model_{CLASS}_seed{SEED}_fold{FOLD}_pseudo.pth'
        # !python ../$VERSION/validation.py --model $MODEL --version $VERSION \
        --fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS \
        --rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH \
        --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --max_length $MAX_LEN \
        --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS \
        --class_name $CLASS --input_path $INPUT_PATH --use_stats $USE_STATS \
        --use_separate_head $USE_SEPARATE_HEAD
# Out:
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# 2022-11-17 07:44:14.065121: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-17 07:44:14.065143: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3128, 13)
# val_df.shape =  (783, 13)
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# 100%|███████████████████████████████████████████| 13/13 [00:14<00:00,  1.13s/it]
# val_loss=0.1038, val_score=0.4561
# essay_ids.shape =  (783,)
# preds.shape =  (783, 6)
# labels.shape =  (783, 6)
# losses.shape =  (783, 6)
# embeds.shape =  (783, 768, 6)
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# 2022-11-17 07:44:45.430921: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-17 07:44:45.430952: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# 100%|███████████████████████████████████████████| 13/13 [00:14<00:00,  1.14s/it]
# val_loss=0.1028, val_score=0.4542
# essay_ids.shape =  (782,)
# preds.shape =  (782, 6)
# labels.shape =  (782, 6)
# losses.shape =  (782, 6)
# embeds.shape =  (782, 768, 6)
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# 2022-11-17 07:45:16.370827: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-17 07:45:16.370848: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# 100%|███████████████████████████████████████████| 13/13 [00:14<00:00,  1.14s/it]
# val_loss=0.1005, val_score=0.4488
# essay_ids.shape =  (782,)
# preds.shape =  (782, 6)
# labels.shape =  (782, 6)
# losses.shape =  (782, 6)
# embeds.shape =  (782, 768, 6)
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.1
# 2022-11-17 07:45:47.676930: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-17 07:45:47.676951: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# 100%|███████████████████████████████████████████| 13/13 [00:14<00:00,  1.14s/it]
# val_loss=0.1052, val_score=0.4592
# essay_ids.shape =  (782,)
# preds.shape =  (782, 6)
# labels.shape =  (782, 6)
# losses.shape =  (782, 6)
# embeds.shape =  (782, 768, 6)
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.1
# 2022-11-17 07:46:18.643273: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-17 07:46:18.643293: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# 100%|███████████████████████████████████████████| 13/13 [00:14<00:00,  1.14s/it]
# val_loss=0.1055, val_score=0.4605
# essay_ids.shape =  (782,)
# preds.shape =  (782, 6)
# labels.shape =  (782, 6)
# losses.shape =  (782, 6)
# embeds.shape =  (782, 768, 6)

# %%
import pandas as pd
import numpy as np

preds = []
# for CLASS in [
#     'cohesion',
#     'syntax','vocabulary','phraseology','grammar','conventions'
# ]:
#     print("*"*50)
#     print(CLASS)
#     print("*"*50)
#     preds_class = []
if True:
    for fold in [0,1,2,3,4]:
        tmp_df = pd.read_csv(f'./result/{VERSION}/pred_fold{fold}.csv')
        #tmp_df = pd.read_csv(f'./result/{VERSION}/pred_{CLASS}_fold{fold}.csv')
        #embeds = np.load(f'./result/{VERSION}/embeds_{CLASS}_fold{fold}.npz')['arr_0']
        #tmp_df[f'embed_{CLASS}'] = embeds.tolist()
        #preds_class.append(tmp_df)
        preds.append(tmp_df)
#     pred_df = pd.concat(preds_class, axis=0).reset_index(drop=True)
#     if len(preds)==0:
#         preds.append(pred_df)
#     else:
#         del pred_df["text_id"]
#         preds.append(pred_df)
    
#all_pred_df = pd.concat(preds, axis=1)
all_pred_df = pd.concat(preds, axis=0).reset_index(drop=True)

train_df = pd.read_csv('../../input/feedback-prize-english-language-learning/train.csv')
oof_df = train_df[['text_id']].merge(all_pred_df, on='text_id', how='left')
oof_df.to_csv(f'./result/{VERSION}/oof_df.csv', index=False)

# %%
oof_df.shape, oof_df.isnull().sum()
# Out:
# ((3911, 13),
#  text_id             0
#  cohesion            0
#  syntax              0
#  vocabulary          0
#  phraseology         0
#  grammar             0
#  conventions         0
#  loss_cohesion       0
#  loss_syntax         0
#  loss_vocabulary     0
#  loss_phraseology    0
#  loss_grammar        0
#  loss_conventions    0
#  dtype: int64)

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
oof_df[cols].describe()
# Out:
#           cohesion       syntax   vocabulary  phraseology      grammar  \
# count  3911.000000  3911.000000  3911.000000  3911.000000  3911.000000
# mean      3.123736     3.043774     3.264787     3.140387     3.052934
# std       0.492146     0.505300     0.437541     0.514558     0.562584
# min       1.019307     1.394867     1.576967     1.523679     1.345576
# 25%       2.794591     2.686453     2.972450     2.787008     2.637173
# 50%       3.114350     3.023394     3.244146     3.119624     3.032564
# 75%       3.452687     3.382377     3.538134     3.489818     3.440013
# max       4.808518     4.859581     5.136846     4.893205     4.912339
#
#        conventions
# count  3911.000000
# mean      3.090872
# std       0.538172
# min       1.203396
# 25%       2.712389
# 50%       3.080748
# 75%       3.452071
# max       4.849243

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
train_df[cols].describe()
# Out:
#           cohesion       syntax   vocabulary  phraseology      grammar  \
# count  3911.000000  3911.000000  3911.000000  3911.000000  3911.000000
# mean      3.127077     3.028254     3.235745     3.116850     3.032856
# std       0.662542     0.644399     0.583148     0.655997     0.699841
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%       2.500000     2.500000     3.000000     2.500000     2.500000
# 50%       3.000000     3.000000     3.000000     3.000000     3.000000
# 75%       3.500000     3.500000     3.500000     3.500000     3.500000
# max       5.000000     5.000000     5.000000     5.000000     5.000000
#
#        conventions
# count  3911.000000
# mean      3.081053
# std       0.671450
# min       1.000000
# 25%       2.500000
# 50%       3.000000
# 75%       3.500000
# max       5.000000

# %% [markdown]
# # Error Analysis - Check Corr

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
train_df[cols].corr()
# Out:
#              cohesion    syntax  vocabulary  phraseology   grammar  \
# cohesion     1.000000  0.695459    0.666151     0.690058  0.638689
# syntax       0.695459  1.000000    0.680562     0.725467  0.709525
# vocabulary   0.666151  0.680562    1.000000     0.735261  0.654852
# phraseology  0.690058  0.725467    0.735261     1.000000  0.719746
# grammar      0.638689  0.709525    0.654852     0.719746  1.000000
# conventions  0.666151  0.700025    0.664292     0.666842  0.673301
#
#              conventions
# cohesion        0.666151
# syntax          0.700025
# vocabulary      0.664292
# phraseology     0.666842
# grammar         0.673301
# conventions     1.000000

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
oof_df[cols].corr()
# Out:
#              cohesion    syntax  vocabulary  phraseology   grammar  \
# cohesion     1.000000  0.963703    0.940552     0.926634  0.858546
# syntax       0.963703  1.000000    0.941955     0.954540  0.927206
# vocabulary   0.940552  0.941955    1.000000     0.966747  0.894164
# phraseology  0.926634  0.954540    0.966747     1.000000  0.948134
# grammar      0.858546  0.927206    0.894164     0.948134  1.000000
# conventions  0.914617  0.935549    0.908704     0.888876  0.873546
#
#              conventions
# cohesion        0.914617
# syntax          0.935549
# vocabulary      0.908704
# phraseology     0.888876
# grammar         0.873546
# conventions     1.000000
