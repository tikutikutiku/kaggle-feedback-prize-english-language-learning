# %%
VERSION = '29_v1_18'
MODEL = 'microsoft/deberta-v3-base'
#'deepset/deberta-v3-base-squad2'
#'microsoft/deberta-v3-base'
#TEACHER_VERSION = '14_v1_15' # deverta-v2-xlarge
#'bert-large-cased'
#'bert-large-cased-whole-word-masking'
#'albert-large-v2'
#'facebook/bart-large'
#'xlm-roberta-large'
#'deepset/roberta-large-squad2'
#'google/electra-large-discriminator'
#'sentence-transformeres/paraphrase-mpnet-base-v2'
#'funnel-transformer/large-base'
#'facebook/bart-base'
#'distilroberta-base'
#'deepset/roberta-base-squad2'
#'microsoft/deberta-v3-base'
#'roberta-large'
#'roberta-base'
#'microsoft/deberta-v3-large'
#'microsoft/deberta-base'
LR = 8e-5 #8e-6
HEAD_LR = 8e-4 #2e-5 #8e-6 
SEED = 100
TRN_BS = 64 #8
VAL_BS = 64 #8
ACCUM_STEP = 1
HIDDEN_DROP_PROB = 0
P_DROP = 0
RNN = 'none'
WARMUP_RATIO = 0.1
HEAD = 'simple'
AUG = 'false'
MIXUP_ALPHA = 0
P_AUG = 0
AUG_STOP_EPOCH = 0
MSD = 'false'
POOLING = 'weighted_layer'  #'mean' #'transformer+mean' #'attention'
NUM_POOLING_LAYERS = 8 #4 #1
MULTI_LAYERS = 1
EVAL_STEP_START_EPOCH = -1
EVAL_STEP = -1
NUM_LABELS = 6
NUM_LABELS_2 = -1
FP16 = 'true'
WD = 0.01
FREEZE = 'false'
MULTI_TASK = 'false' 
W_MT = 0 
AWP = 'false'
AWP_LR = 0
AWP_EPS = 0
AWP_START_EPOCH = -1
#PRETRAINED_DETECTOR_PATH = f'../../input/tascj/result/deberta_base_fold0.pth'
PRETRAINED_DETECTOR_PATH = 'none' #f'../../05_Detection/exp/result/05_v2_09/model_seed100_fold0_swa.pth'
MASK_PROB = 0 #0.8
MASK_RATIO = 0 #0.3
SCHEDULER = 'cosine_hard'
CP = 'true' #'false'
WINDOW_SIZE = -1
INNER_LEN = -1
EDGE_LEN = -1
MAX_LEN = 512

GRAD_CLIP = 1

LOSS = 'smoothl1'#'mse'

CROP_PROB = 0 #1.0

USE_STATS = 'false' #'true'
USE_SEPARATE_HEAD = 'true'

LOW_LOSS_THR = -1 #0.8 #0.5
HIGH_LOSS_THR = -1 #0.0001
OOF_DF_PATH = 'none' #'../../14_Baseline4/exp/result/14_v1_01/oof_df.csv'

# %% [markdown]
# # Train

# %%
MODE = 'train'
EPOCHS = 10 #5
STOP_EPOCH = 10 #5
RESTART = 1
NUM_CYCLES = 1 #EPOCHS
EVAL_STEP = -1
ADD_FB3 = 'false'
FB3_FOLD_PATH = 'none' #'../../00_EDA/00_v1_02/result/'

# for CLASS in [
#     'cohesion',
#     #'syntax','vocabulary','phraseology','grammar','conventions'
# ]:
#     print("*"*50)
#     print(CLASS)
#     print("*"*50)
if True:
    CLASS = 'none'
    for FOLD in [0,1,2,3,4]:
        print("-"*50)
        print("FOLD = ", FOLD)
        print("-"*50)
        INPUT_PATH = '../../00_EDA/00_v1_12/result/' #'../../input/feedback-prize-english-language-learning/'
        FOLD_PATH = '../../00_EDA/00_v1_02/result/'
        #INPUT_PATH = f'../../99_Ensemble/99_v1_03/result/99_v1_03_03_pseudo_fold{FOLD}.csv'
        #INPUT_PATH = f'../../99_Ensemble/99_v1_03/result/99_v1_03_03_{TEACHER_VERSION}_pseudo_fold{FOLD}.csv'
        #FOLD_PATH = '../../00_EDA/00_v1_08/result/' # for pseudo-label
        PRETRAIN_PATH = 'none'
        # !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
        --lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
        --epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
        --accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
        --mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
        --msd $MSD --multi_layers $MULTI_LAYERS \
        --eval_step_start_epoch $EVAL_STEP_START_EPOCH --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
        --num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
        --restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
        --mt $MULTI_TASK --w_mt $W_MT \
        --awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
        --pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
        --scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
        --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN \
        --gradient_clip_val $GRAD_CLIP \
        --input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN \
        --crop_prob $CROP_PROB --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS --class_name $CLASS \
        --add_fb3 $ADD_FB3 --fb3_fold_path $FB3_FOLD_PATH --use_stats $USE_STATS \
        --use_separate_head $USE_SEPARATE_HEAD --low_loss_thr $LOW_LOSS_THR --high_loss_thr $HIGH_LOSS_THR \
        --oof_df_path $OOF_DF_PATH
# Out:
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3128, 13)
# val_df.shape =  (783, 13)
# 2022-11-23 11:51:52.299760: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-23 11:51:52.299783: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# self.warmup_ratio =  0.1
# self.num_train_steps =  488
# num_warmup_steps =  48
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████████| 48/48 [02:07<00:00,  2.65s/it, loss=1.1]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.24s/it]
# epoch 1: trn_loss = 1.1048, val_loss = 0.1426, trn_score = 1.9707, val_score = 0.5359
# model (best score) saved
# lr :  [8e-05, 8e-05, 0.0008]
# 100%|███████████████████████████████| 48/48 [02:07<00:00,  2.66s/it, loss=0.129]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.28s/it]
# epoch 2: trn_loss = 0.1285, val_loss = 0.1117, trn_score = 0.5098, val_score = 0.4735
# model (best score) saved
# lr :  [7.7673774545581e-05, 7.7673774545581e-05, 0.0007767377454558099]
# 100%|███████████████████████████████| 48/48 [02:08<00:00,  2.67s/it, loss=0.111]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.28s/it]
# epoch 3: trn_loss = 0.1114, val_loss = 0.1089, trn_score = 0.4730, val_score = 0.4678
# model (best score) saved
# lr :  [7.096566442556331e-05, 7.096566442556331e-05, 0.000709656644255633]
# 100%|███████████████████████████████| 48/48 [02:07<00:00,  2.67s/it, loss=0.103]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.27s/it]
# epoch 4: trn_loss = 0.1029, val_loss = 0.1108, trn_score = 0.4546, val_score = 0.4722
# lr :  [6.0655898465558484e-05, 6.0655898465558484e-05, 0.0006065589846555848]
# 100%|██████████████████████████████| 48/48 [02:07<00:00,  2.66s/it, loss=0.0961]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.27s/it]
# epoch 5: trn_loss = 0.0961, val_loss = 0.1087, trn_score = 0.4391, val_score = 0.4665
# model (best score) saved
# lr :  [4.794361866582982e-05, 4.794361866582982e-05, 0.0004794361866582982]
# 100%|██████████████████████████████| 48/48 [02:07<00:00,  2.66s/it, loss=0.0898]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.28s/it]
# epoch 6: trn_loss = 0.0898, val_loss = 0.1059, trn_score = 0.4240, val_score = 0.4605
# model (best score) saved
# lr :  [3.4307406469068604e-05, 3.4307406469068604e-05, 0.000343074064690686]
# 100%|███████████████████████████████| 48/48 [02:08<00:00,  2.67s/it, loss=0.089]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.27s/it]
# epoch 7: trn_loss = 0.0890, val_loss = 0.1049, trn_score = 0.4220, val_score = 0.4588
# model (best score) saved
# lr :  [2.1333307070973054e-05, 2.1333307070973054e-05, 0.0002133330707097305]
# 100%|██████████████████████████████| 48/48 [02:07<00:00,  2.67s/it, loss=0.0824]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.28s/it]
# epoch 8: trn_loss = 0.0824, val_loss = 0.1049, trn_score = 0.4060, val_score = 0.4587
# model (best score) saved
# lr :  [1.0530354484943798e-05, 1.0530354484943798e-05, 0.00010530354484943799]
# 100%|██████████████████████████████| 48/48 [02:08<00:00,  2.67s/it, loss=0.0785]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.27s/it]
# epoch 9: trn_loss = 0.0785, val_loss = 0.1049, trn_score = 0.3963, val_score = 0.4585
# model (best score) saved
# lr :  [3.155053875406e-06, 3.155053875406e-06, 3.155053875406e-05]
# 100%|██████████████████████████████| 48/48 [02:08<00:00,  2.68s/it, loss=0.0768]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.27s/it]
# epoch 10: trn_loss = 0.0768, val_loss = 0.1041, trn_score = 0.3918, val_score = 0.4568
#  elapsed_time = 24.2 min
# model (best score) saved
#
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# 2022-11-23 12:16:23.277667: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-23 12:16:23.277690: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# self.warmup_ratio =  0.1
# self.num_train_steps =  488
# num_warmup_steps =  48
# lr :  [0.0, 0.0, 0.0]
# 100%|███████████████████████████████| 48/48 [02:10<00:00,  2.71s/it, loss=0.929]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.29s/it]
# epoch 1: trn_loss = 0.9289, val_loss = 0.1426, trn_score = 1.7381, val_score = 0.5375
# model (best score) saved
# lr :  [8e-05, 8e-05, 0.0008]
# 100%|███████████████████████████████| 48/48 [02:09<00:00,  2.69s/it, loss=0.127]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.28s/it]
# epoch 2: trn_loss = 0.1267, val_loss = 0.1098, trn_score = 0.5055, val_score = 0.4697
# model (best score) saved
# lr :  [7.7673774545581e-05, 7.7673774545581e-05, 0.0007767377454558099]
# 100%|███████████████████████████████| 48/48 [02:08<00:00,  2.68s/it, loss=0.113]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.28s/it]
# epoch 3: trn_loss = 0.1134, val_loss = 0.1481, trn_score = 0.4775, val_score = 0.5469
# lr :  [7.096566442556331e-05, 7.096566442556331e-05, 0.000709656644255633]
# 100%|████████████████████████████████| 48/48 [02:08<00:00,  2.68s/it, loss=0.11]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.28s/it]
# epoch 4: trn_loss = 0.1103, val_loss = 0.1493, trn_score = 0.4709, val_score = 0.5478
# lr :  [6.0655898465558484e-05, 6.0655898465558484e-05, 0.0006065589846555848]
# 100%|███████████████████████████████| 48/48 [02:08<00:00,  2.68s/it, loss=0.103]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.27s/it]
# epoch 5: trn_loss = 0.1032, val_loss = 0.1060, trn_score = 0.4551, val_score = 0.4614
# model (best score) saved
# lr :  [4.794361866582982e-05, 4.794361866582982e-05, 0.0004794361866582982]
# 100%|██████████████████████████████| 48/48 [02:08<00:00,  2.69s/it, loss=0.0972]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.27s/it]
# epoch 6: trn_loss = 0.0972, val_loss = 0.1089, trn_score = 0.4414, val_score = 0.4676
# lr :  [3.4307406469068604e-05, 3.4307406469068604e-05, 0.000343074064690686]
# 100%|██████████████████████████████| 48/48 [02:08<00:00,  2.68s/it, loss=0.0943]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.27s/it]
# epoch 7: trn_loss = 0.0943, val_loss = 0.1066, trn_score = 0.4345, val_score = 0.4625
# lr :  [2.1333307070973054e-05, 2.1333307070973054e-05, 0.0002133330707097305]
# 100%|██████████████████████████████| 48/48 [02:08<00:00,  2.67s/it, loss=0.0908]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.27s/it]
# epoch 8: trn_loss = 0.0908, val_loss = 0.1054, trn_score = 0.4263, val_score = 0.4598
# model (best score) saved
# lr :  [1.0530354484943798e-05, 1.0530354484943798e-05, 0.00010530354484943799]
# 100%|██████████████████████████████| 48/48 [02:08<00:00,  2.68s/it, loss=0.0878]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.27s/it]
# epoch 9: trn_loss = 0.0878, val_loss = 0.1113, trn_score = 0.4192, val_score = 0.4732
# lr :  [3.155053875406e-06, 3.155053875406e-06, 3.155053875406e-05]
# 100%|███████████████████████████████| 48/48 [02:08<00:00,  2.68s/it, loss=0.086]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.26s/it]
# epoch 10: trn_loss = 0.0860, val_loss = 0.1073, trn_score = 0.4148, val_score = 0.4643
#  elapsed_time = 24.3 min
#
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# 2022-11-23 12:40:57.631345: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-23 12:40:57.631366: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# self.warmup_ratio =  0.1
# self.num_train_steps =  488
# num_warmup_steps =  48
# lr :  [0.0, 0.0, 0.0]
# 100%|████████████████████████████████| 48/48 [02:09<00:00,  2.70s/it, loss=0.94]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.28s/it]
# epoch 1: trn_loss = 0.9402, val_loss = 0.1428, trn_score = 1.7592, val_score = 0.5378
# model (best score) saved
# lr :  [8e-05, 8e-05, 0.0008]
# 100%|███████████████████████████████| 48/48 [02:08<00:00,  2.68s/it, loss=0.124]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.27s/it]
# epoch 2: trn_loss = 0.1243, val_loss = 0.1161, trn_score = 0.5007, val_score = 0.4826
# model (best score) saved
# lr :  [7.7673774545581e-05, 7.7673774545581e-05, 0.0007767377454558099]
# 100%|███████████████████████████████| 48/48 [02:07<00:00,  2.66s/it, loss=0.108]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.27s/it]
# epoch 3: trn_loss = 0.1078, val_loss = 0.1150, trn_score = 0.4653, val_score = 0.4796
# model (best score) saved
# lr :  [7.096566442556331e-05, 7.096566442556331e-05, 0.000709656644255633]
# 100%|█████████████████████████████████| 48/48 [02:07<00:00,  2.66s/it, loss=0.1]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.26s/it]
# epoch 4: trn_loss = 0.1004, val_loss = 0.1054, trn_score = 0.4488, val_score = 0.4603
# model (best score) saved
# lr :  [6.0655898465558484e-05, 6.0655898465558484e-05, 0.0006065589846555848]
# 100%|██████████████████████████████| 48/48 [02:07<00:00,  2.66s/it, loss=0.0952]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.27s/it]
# epoch 5: trn_loss = 0.0952, val_loss = 0.1018, trn_score = 0.4367, val_score = 0.4518
# model (best score) saved
# lr :  [4.794361866582982e-05, 4.794361866582982e-05, 0.0004794361866582982]
# 100%|██████████████████████████████| 48/48 [02:07<00:00,  2.66s/it, loss=0.0875]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.27s/it]
# epoch 6: trn_loss = 0.0875, val_loss = 0.1013, trn_score = 0.4187, val_score = 0.4506
# model (best score) saved
# lr :  [3.4307406469068604e-05, 3.4307406469068604e-05, 0.000343074064690686]
# 100%|██████████████████████████████| 48/48 [02:07<00:00,  2.66s/it, loss=0.0857]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.26s/it]
# epoch 7: trn_loss = 0.0857, val_loss = 0.1043, trn_score = 0.4141, val_score = 0.4575
# lr :  [2.1333307070973054e-05, 2.1333307070973054e-05, 0.0002133330707097305]
# 100%|██████████████████████████████| 48/48 [02:07<00:00,  2.66s/it, loss=0.0796]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.27s/it]
# epoch 8: trn_loss = 0.0796, val_loss = 0.1073, trn_score = 0.3990, val_score = 0.4641
# lr :  [1.0530354484943798e-05, 1.0530354484943798e-05, 0.00010530354484943799]
# 100%|██████████████████████████████| 48/48 [02:07<00:00,  2.66s/it, loss=0.0755]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.27s/it]
# epoch 9: trn_loss = 0.0755, val_loss = 0.1061, trn_score = 0.3885, val_score = 0.4614
# lr :  [3.155053875406e-06, 3.155053875406e-06, 3.155053875406e-05]
# 100%|██████████████████████████████| 48/48 [02:08<00:00,  2.68s/it, loss=0.0733]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.27s/it]
# epoch 10: trn_loss = 0.0733, val_loss = 0.1031, trn_score = 0.3828, val_score = 0.4546
#  elapsed_time = 24.2 min
#
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# 2022-11-23 13:05:26.319904: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-23 13:05:26.319926: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# self.warmup_ratio =  0.1
# self.num_train_steps =  488
# num_warmup_steps =  48
# lr :  [0.0, 0.0, 0.0]
# 100%|███████████████████████████████| 48/48 [02:10<00:00,  2.71s/it, loss=0.961]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.28s/it]
# epoch 1: trn_loss = 0.9609, val_loss = 0.1622, trn_score = 1.7809, val_score = 0.5713
# model (best score) saved
# lr :  [8e-05, 8e-05, 0.0008]
# 100%|████████████████████████████████| 48/48 [02:09<00:00,  2.69s/it, loss=0.13]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.29s/it]
# epoch 2: trn_loss = 0.1296, val_loss = 0.1196, trn_score = 0.5115, val_score = 0.4902
# model (best score) saved
# lr :  [7.7673774545581e-05, 7.7673774545581e-05, 0.0007767377454558099]
# 100%|███████████████████████████████| 48/48 [02:08<00:00,  2.68s/it, loss=0.111]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.28s/it]
# epoch 3: trn_loss = 0.1113, val_loss = 0.1102, trn_score = 0.4730, val_score = 0.4702
# model (best score) saved
# lr :  [7.096566442556331e-05, 7.096566442556331e-05, 0.000709656644255633]
# 100%|███████████████████████████████| 48/48 [02:08<00:00,  2.68s/it, loss=0.102]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.28s/it]
# epoch 4: trn_loss = 0.1024, val_loss = 0.1153, trn_score = 0.4535, val_score = 0.4813
# lr :  [6.0655898465558484e-05, 6.0655898465558484e-05, 0.0006065589846555848]
# 100%|███████████████████████████████| 48/48 [02:08<00:00,  2.68s/it, loss=0.102]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.28s/it]
# epoch 5: trn_loss = 0.1020, val_loss = 0.1065, trn_score = 0.4527, val_score = 0.4625
# model (best score) saved
# lr :  [4.794361866582982e-05, 4.794361866582982e-05, 0.0004794361866582982]
# 100%|██████████████████████████████| 48/48 [02:08<00:00,  2.68s/it, loss=0.0954]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.28s/it]
# epoch 6: trn_loss = 0.0954, val_loss = 0.1130, trn_score = 0.4374, val_score = 0.4771
# lr :  [3.4307406469068604e-05, 3.4307406469068604e-05, 0.000343074064690686]
# 100%|██████████████████████████████| 48/48 [02:09<00:00,  2.70s/it, loss=0.0917]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.28s/it]
# epoch 7: trn_loss = 0.0917, val_loss = 0.1052, trn_score = 0.4285, val_score = 0.4594
# model (best score) saved
# lr :  [2.1333307070973054e-05, 2.1333307070973054e-05, 0.0002133330707097305]
# 100%|██████████████████████████████| 48/48 [02:08<00:00,  2.68s/it, loss=0.0884]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.28s/it]
# epoch 8: trn_loss = 0.0884, val_loss = 0.1062, trn_score = 0.4206, val_score = 0.4616
# lr :  [1.0530354484943798e-05, 1.0530354484943798e-05, 0.00010530354484943799]
# 100%|██████████████████████████████| 48/48 [02:08<00:00,  2.68s/it, loss=0.0872]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.28s/it]
# epoch 9: trn_loss = 0.0872, val_loss = 0.1081, trn_score = 0.4177, val_score = 0.4660
# lr :  [3.155053875406e-06, 3.155053875406e-06, 3.155053875406e-05]
# 100%|██████████████████████████████| 48/48 [02:07<00:00,  2.66s/it, loss=0.0859]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.26s/it]
# epoch 10: trn_loss = 0.0859, val_loss = 0.1056, trn_score = 0.4146, val_score = 0.4604
#  elapsed_time = 24.3 min
#
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# 2022-11-23 13:30:02.626869: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-23 13:30:02.626890: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# self.warmup_ratio =  0.1
# self.num_train_steps =  488
# num_warmup_steps =  48
# lr :  [0.0, 0.0, 0.0]
# 100%|███████████████████████████████| 48/48 [02:10<00:00,  2.72s/it, loss=0.888]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.28s/it]
# epoch 1: trn_loss = 0.8878, val_loss = 0.1533, trn_score = 1.6879, val_score = 0.5570
# model (best score) saved
# lr :  [8e-05, 8e-05, 0.0008]
# 100%|███████████████████████████████| 48/48 [02:09<00:00,  2.69s/it, loss=0.136]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.28s/it]
# epoch 2: trn_loss = 0.1359, val_loss = 0.1148, trn_score = 0.5245, val_score = 0.4807
# model (best score) saved
# lr :  [7.7673774545581e-05, 7.7673774545581e-05, 0.0007767377454558099]
# 100%|███████████████████████████████| 48/48 [02:08<00:00,  2.68s/it, loss=0.113]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.28s/it]
# epoch 3: trn_loss = 0.1132, val_loss = 0.1205, trn_score = 0.4772, val_score = 0.4912
# lr :  [7.096566442556331e-05, 7.096566442556331e-05, 0.000709656644255633]
# 100%|████████████████████████████████| 48/48 [02:08<00:00,  2.68s/it, loss=0.11]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.27s/it]
# epoch 4: trn_loss = 0.1096, val_loss = 0.1113, trn_score = 0.4694, val_score = 0.4729
# model (best score) saved
# lr :  [6.0655898465558484e-05, 6.0655898465558484e-05, 0.0006065589846555848]
# 100%|███████████████████████████████| 48/48 [02:08<00:00,  2.68s/it, loss=0.106]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.28s/it]
# epoch 5: trn_loss = 0.1055, val_loss = 0.1127, trn_score = 0.4601, val_score = 0.4755
# lr :  [4.794361866582982e-05, 4.794361866582982e-05, 0.0004794361866582982]
# 100%|██████████████████████████████| 48/48 [02:08<00:00,  2.68s/it, loss=0.0984]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.28s/it]
# epoch 6: trn_loss = 0.0984, val_loss = 0.1183, trn_score = 0.4441, val_score = 0.4877
# lr :  [3.4307406469068604e-05, 3.4307406469068604e-05, 0.000343074064690686]
# 100%|██████████████████████████████| 48/48 [02:08<00:00,  2.68s/it, loss=0.0941]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.28s/it]
# epoch 7: trn_loss = 0.0941, val_loss = 0.1068, trn_score = 0.4341, val_score = 0.4629
# model (best score) saved
# lr :  [2.1333307070973054e-05, 2.1333307070973054e-05, 0.0002133330707097305]
# 100%|██████████████████████████████| 48/48 [02:08<00:00,  2.68s/it, loss=0.0918]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.28s/it]
# epoch 8: trn_loss = 0.0918, val_loss = 0.1065, trn_score = 0.4286, val_score = 0.4621
# model (best score) saved
# lr :  [1.0530354484943798e-05, 1.0530354484943798e-05, 0.00010530354484943799]
# 100%|██████████████████████████████| 48/48 [02:08<00:00,  2.69s/it, loss=0.0889]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.28s/it]
# epoch 9: trn_loss = 0.0889, val_loss = 0.1066, trn_score = 0.4217, val_score = 0.4624
# lr :  [3.155053875406e-06, 3.155053875406e-06, 3.155053875406e-05]
# 100%|██████████████████████████████| 48/48 [02:08<00:00,  2.68s/it, loss=0.0869]
# 100%|███████████████████████████████████████████| 13/13 [00:16<00:00,  1.27s/it]
# epoch 10: trn_loss = 0.0869, val_loss = 0.1068, trn_score = 0.4168, val_score = 0.4629
#  elapsed_time = 24.3 min

# %% [markdown]
# # OOF

# %%
# INPUT_PATH = '../../00_EDA/00_v1_12/result/' #'../../input/feedback-prize-english-language-learning/'
# FOLD_PATH = '../../00_EDA/00_v1_02/result/'

# %%
# for CLASS in [
#     'cohesion',
#     'syntax','vocabulary','phraseology','grammar','conventions'
# ]:
#     print("*"*50)
#     print(CLASS)
#     print("*"*50)
if True:
    CLASS = 'none'
    for FOLD in [0,1,2,3,4]:
        print("-"*50)
        print("FOLD = ", FOLD)
        print("-"*50)
        WEIGHT_PATH = f'./result/{VERSION}/model_seed{SEED}_fold{FOLD}.pth'
        #WEIGHT_PATH = f'./result/{VERSION}/model_{CLASS}_seed{SEED}_fold{FOLD}.pth'
        #WEIGHT_PATH = f'result/{VERSION}/model_{CLASS}_seed{SEED}_fold{FOLD}_pseudo.pth'
        # !python ../$VERSION/validation.py --model $MODEL --version $VERSION \
        --fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS \
        --rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH \
        --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --max_length $MAX_LEN \
        --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS \
        --class_name $CLASS --input_path $INPUT_PATH --use_stats $USE_STATS \
        --use_separate_head $USE_SEPARATE_HEAD
# Out:
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# 2022-11-23 13:54:39.403206: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-23 13:54:39.403229: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3128, 13)
# val_df.shape =  (783, 13)
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# 100%|███████████████████████████████████████████| 13/13 [00:15<00:00,  1.19s/it]
# val_loss=0.1041, val_score=0.4568
# essay_ids.shape =  (783,)
# preds.shape =  (783, 6)
# labels.shape =  (783, 6)
# losses.shape =  (783, 6)
# embeds.shape =  (783, 768, 6)
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# 2022-11-23 13:55:11.997079: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-23 13:55:11.997101: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# 100%|███████████████████████████████████████████| 13/13 [00:15<00:00,  1.18s/it]
# val_loss=0.1054, val_score=0.4598
# essay_ids.shape =  (782,)
# preds.shape =  (782, 6)
# labels.shape =  (782, 6)
# losses.shape =  (782, 6)
# embeds.shape =  (782, 768, 6)
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# 2022-11-23 13:55:44.018171: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-23 13:55:44.018193: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# 100%|███████████████████████████████████████████| 13/13 [00:15<00:00,  1.18s/it]
# val_loss=0.1013, val_score=0.4506
# essay_ids.shape =  (782,)
# preds.shape =  (782, 6)
# labels.shape =  (782, 6)
# losses.shape =  (782, 6)
# embeds.shape =  (782, 768, 6)
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.1
# 2022-11-23 13:56:16.043245: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-23 13:56:16.043268: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# 100%|███████████████████████████████████████████| 13/13 [00:15<00:00,  1.18s/it]
# val_loss=0.1052, val_score=0.4594
# essay_ids.shape =  (782,)
# preds.shape =  (782, 6)
# labels.shape =  (782, 6)
# losses.shape =  (782, 6)
# embeds.shape =  (782, 768, 6)
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.1
# 2022-11-23 13:56:48.075001: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-23 13:56:48.075022: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# 100%|███████████████████████████████████████████| 13/13 [00:15<00:00,  1.18s/it]
# val_loss=0.1065, val_score=0.4621
# essay_ids.shape =  (782,)
# preds.shape =  (782, 6)
# labels.shape =  (782, 6)
# losses.shape =  (782, 6)
# embeds.shape =  (782, 768, 6)

# %%
import pandas as pd
import numpy as np

preds = []
# for CLASS in [
#     'cohesion',
#     'syntax','vocabulary','phraseology','grammar','conventions'
# ]:
#     print("*"*50)
#     print(CLASS)
#     print("*"*50)
#     preds_class = []
if True:
    for fold in [0,1,2,3,4]:
        tmp_df = pd.read_csv(f'./result/{VERSION}/pred_fold{fold}.csv')
        #tmp_df = pd.read_csv(f'./result/{VERSION}/pred_{CLASS}_fold{fold}.csv')
        #embeds = np.load(f'./result/{VERSION}/embeds_{CLASS}_fold{fold}.npz')['arr_0']
        #tmp_df[f'embed_{CLASS}'] = embeds.tolist()
        #preds_class.append(tmp_df)
        preds.append(tmp_df)
#     pred_df = pd.concat(preds_class, axis=0).reset_index(drop=True)
#     if len(preds)==0:
#         preds.append(pred_df)
#     else:
#         del pred_df["text_id"]
#         preds.append(pred_df)
    
#all_pred_df = pd.concat(preds, axis=1)
all_pred_df = pd.concat(preds, axis=0).reset_index(drop=True)

train_df = pd.read_csv('../../input/feedback-prize-english-language-learning/train.csv')
oof_df = train_df[['text_id']].merge(all_pred_df, on='text_id', how='left')
oof_df.to_csv(f'./result/{VERSION}/oof_df.csv', index=False)

# %%
oof_df.shape, oof_df.isnull().sum()
# Out:
# ((3911, 13),
#  text_id             0
#  cohesion            0
#  syntax              0
#  vocabulary          0
#  phraseology         0
#  grammar             0
#  conventions         0
#  loss_cohesion       0
#  loss_syntax         0
#  loss_vocabulary     0
#  loss_phraseology    0
#  loss_grammar        0
#  loss_conventions    0
#  dtype: int64)

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
oof_df[cols].describe()
# Out:
#           cohesion       syntax   vocabulary  phraseology      grammar  \
# count  3911.000000  3911.000000  3911.000000  3911.000000  3911.000000
# mean      3.147099     3.040424     3.237123     3.154598     3.056558
# std       0.489575     0.499534     0.442682     0.518219     0.559288
# min       1.152286     1.421001     1.658949     1.509199     1.535202
# 25%       2.815534     2.690443     2.935600     2.786559     2.638193
# 50%       3.137739     3.036154     3.211222     3.143128     3.046906
# 75%       3.482720     3.375237     3.524063     3.504634     3.450943
# max       4.709085     4.697414     4.861610     4.885169     4.823172
#
#        conventions
# count  3911.000000
# mean      3.089943
# std       0.535280
# min       0.974333
# 25%       2.738433
# 50%       3.081786
# 75%       3.450229
# max       4.765047

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
train_df[cols].describe()
# Out:
#           cohesion       syntax   vocabulary  phraseology      grammar  \
# count  3911.000000  3911.000000  3911.000000  3911.000000  3911.000000
# mean      3.127077     3.028254     3.235745     3.116850     3.032856
# std       0.662542     0.644399     0.583148     0.655997     0.699841
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%       2.500000     2.500000     3.000000     2.500000     2.500000
# 50%       3.000000     3.000000     3.000000     3.000000     3.000000
# 75%       3.500000     3.500000     3.500000     3.500000     3.500000
# max       5.000000     5.000000     5.000000     5.000000     5.000000
#
#        conventions
# count  3911.000000
# mean      3.081053
# std       0.671450
# min       1.000000
# 25%       2.500000
# 50%       3.000000
# 75%       3.500000
# max       5.000000

# %% [markdown]
# # Error Analysis - Check Corr

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
train_df[cols].corr()
# Out:
#              cohesion    syntax  vocabulary  phraseology   grammar  \
# cohesion     1.000000  0.695459    0.666151     0.690058  0.638689
# syntax       0.695459  1.000000    0.680562     0.725467  0.709525
# vocabulary   0.666151  0.680562    1.000000     0.735261  0.654852
# phraseology  0.690058  0.725467    0.735261     1.000000  0.719746
# grammar      0.638689  0.709525    0.654852     0.719746  1.000000
# conventions  0.666151  0.700025    0.664292     0.666842  0.673301
#
#              conventions
# cohesion        0.666151
# syntax          0.700025
# vocabulary      0.664292
# phraseology     0.666842
# grammar         0.673301
# conventions     1.000000

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
oof_df[cols].corr()
# Out:
#              cohesion    syntax  vocabulary  phraseology   grammar  \
# cohesion     1.000000  0.956761    0.938736     0.918562  0.851682
# syntax       0.956761  1.000000    0.947532     0.957997  0.925717
# vocabulary   0.938736  0.947532    1.000000     0.961862  0.893069
# phraseology  0.918562  0.957997    0.961862     1.000000  0.949050
# grammar      0.851682  0.925717    0.893069     0.949050  1.000000
# conventions  0.907555  0.934262    0.906021     0.890374  0.872525
#
#              conventions
# cohesion        0.907555
# syntax          0.934262
# vocabulary      0.906021
# phraseology     0.890374
# grammar         0.872525
# conventions     1.000000
