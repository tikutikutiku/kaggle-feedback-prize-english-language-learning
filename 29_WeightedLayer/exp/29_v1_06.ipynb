# %%
VERSION = '29_v1_06'
MODEL = 'microsoft/deberta-large'
#'microsoft/deberta-v3-large'
#'microsoft/deberta-v3-base'
#TEACHER_VERSION = '14_v1_15' # deverta-v2-xlarge
#'bert-large-cased'
#'bert-large-cased-whole-word-masking'
#'albert-large-v2'
#'facebook/bart-large'
#'xlm-roberta-large'
#'deepset/roberta-large-squad2'
#'google/electra-large-discriminator'
#'sentence-transformeres/paraphrase-mpnet-base-v2'
#'funnel-transformer/large-base'
#'facebook/bart-base'
#'distilroberta-base'
#'deepset/roberta-base-squad2'
#'microsoft/deberta-v3-base'
#'roberta-large'
#'roberta-base'
#'microsoft/deberta-base'
LR = 4e-5 #8e-5 #8e-6
HEAD_LR = 4e-4 #8e-4 #2e-5 #8e-6 
SEED = 100
TRN_BS = 64 #8
VAL_BS = 64 #8
ACCUM_STEP = 1
HIDDEN_DROP_PROB = 0
P_DROP = 0
RNN = 'none'
WARMUP_RATIO = 0.1
HEAD = 'simple'
AUG = 'false'
MIXUP_ALPHA = 0
P_AUG = 0
AUG_STOP_EPOCH = 0
MSD = 'false'
POOLING = 'weighted_layer'  #'mean' #'transformer+mean' #'attention'
NUM_POOLING_LAYERS = 4 #1
MULTI_LAYERS = 1
EVAL_STEP_START_EPOCH = -1
EVAL_STEP = -1
NUM_LABELS = 6
NUM_LABELS_2 = -1
FP16 = 'true'
WD = 0.01
FREEZE = 'true' #'false'
MULTI_TASK = 'false' 
W_MT = 0 
AWP = 'false'
AWP_LR = 0
AWP_EPS = 0
AWP_START_EPOCH = -1
#PRETRAINED_DETECTOR_PATH = f'../../input/tascj/result/deberta_base_fold0.pth'
PRETRAINED_DETECTOR_PATH = 'none' #f'../../05_Detection/exp/result/05_v2_09/model_seed100_fold0_swa.pth'
MASK_PROB = 0 #0.8
MASK_RATIO = 0 #0.3
SCHEDULER = 'cosine_hard'
CP = 'true' #'false'
WINDOW_SIZE = -1
INNER_LEN = -1
EDGE_LEN = -1
MAX_LEN = 512

GRAD_CLIP = 1

LOSS = 'smoothl1'#'mse'

CROP_PROB = 0 #1.0

USE_STATS = 'false' #'true'
USE_SEPARATE_HEAD = 'true'

LOW_LOSS_THR = -1 #0.8 #0.5
HIGH_LOSS_THR = -1 #0.0001
OOF_DF_PATH = 'none' #'../../14_Baseline4/exp/result/14_v1_01/oof_df.csv'

# %% [markdown]
# # Train

# %%
MODE = 'train'
EPOCHS = 10 #5
STOP_EPOCH = 10 #5
RESTART = 1
NUM_CYCLES = 1 #EPOCHS
EVAL_STEP = -1
ADD_FB3 = 'false'
FB3_FOLD_PATH = 'none' #'../../00_EDA/00_v1_02/result/'

# for CLASS in [
#     'cohesion',
#     #'syntax','vocabulary','phraseology','grammar','conventions'
# ]:
#     print("*"*50)
#     print(CLASS)
#     print("*"*50)
if True:
    CLASS = 'none'
    for FOLD in [0]: #[0,1,2,3,4]:
        print("-"*50)
        print("FOLD = ", FOLD)
        print("-"*50)
        INPUT_PATH = '../../00_EDA/00_v1_12/result/' #'../../input/feedback-prize-english-language-learning/'
        FOLD_PATH = '../../00_EDA/00_v1_02/result/'
        #INPUT_PATH = f'../../99_Ensemble/99_v1_03/result/99_v1_03_03_pseudo_fold{FOLD}.csv'
        #INPUT_PATH = f'../../99_Ensemble/99_v1_03/result/99_v1_03_03_{TEACHER_VERSION}_pseudo_fold{FOLD}.csv'
        #FOLD_PATH = '../../00_EDA/00_v1_08/result/' # for pseudo-label
        PRETRAIN_PATH = 'none'
        # !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
        --lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
        --epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
        --accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
        --mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
        --msd $MSD --multi_layers $MULTI_LAYERS \
        --eval_step_start_epoch $EVAL_STEP_START_EPOCH --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
        --num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
        --restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
        --mt $MULTI_TASK --w_mt $W_MT \
        --awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
        --pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
        --scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
        --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN \
        --gradient_clip_val $GRAD_CLIP \
        --input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN \
        --crop_prob $CROP_PROB --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS --class_name $CLASS \
        --add_fb3 $ADD_FB3 --fb3_fold_path $FB3_FOLD_PATH --use_stats $USE_STATS \
        --use_separate_head $USE_SEPARATE_HEAD --low_loss_thr $LOW_LOSS_THR --high_loss_thr $HIGH_LOSS_THR \
        --oof_df_path $OOF_DF_PATH
# Out:
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3128, 13)
# val_df.shape =  (783, 13)
# 2022-11-17 22:43:50.060229: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-17 22:43:50.060251: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  488
# num_warmup_steps =  48
# lr :  [0.0, 0.0, 0.0]
# 100%|███████████████████████████████| 48/48 [05:53<00:00,  7.36s/it, loss=0.816]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.50s/it]
# epoch 1: trn_loss = 0.8159, val_loss = 0.1419, trn_score = 1.5685, val_score = 0.5357
# model (best score) saved
# lr :  [4e-05, 4e-05, 0.0004]
# 100%|███████████████████████████████| 48/48 [05:53<00:00,  7.37s/it, loss=0.131]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.50s/it]
# epoch 2: trn_loss = 0.1312, val_loss = 0.1156, trn_score = 0.5155, val_score = 0.4809
# model (best score) saved
# lr :  [3.88368872727905e-05, 3.88368872727905e-05, 0.00038836887272790496]
# 100%|███████████████████████████████| 48/48 [05:54<00:00,  7.39s/it, loss=0.113]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.50s/it]
# epoch 3: trn_loss = 0.1132, val_loss = 0.1091, trn_score = 0.4775, val_score = 0.4676
# model (best score) saved
# lr :  [3.5482832212781655e-05, 3.5482832212781655e-05, 0.0003548283221278165]
# 100%|███████████████████████████████| 48/48 [05:54<00:00,  7.38s/it, loss=0.106]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.50s/it]
# epoch 4: trn_loss = 0.1059, val_loss = 0.1056, trn_score = 0.4611, val_score = 0.4600
# model (best score) saved
# lr :  [3.0327949232779242e-05, 3.0327949232779242e-05, 0.0003032794923277924]
# 100%|███████████████████████████████| 48/48 [05:54<00:00,  7.38s/it, loss=0.099]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.50s/it]
# epoch 5: trn_loss = 0.0990, val_loss = 0.1041, trn_score = 0.4455, val_score = 0.4566
# model (best score) saved
# lr :  [2.397180933291491e-05, 2.397180933291491e-05, 0.0002397180933291491]
# 100%|██████████████████████████████| 48/48 [05:54<00:00,  7.38s/it, loss=0.0961]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.51s/it]
# epoch 6: trn_loss = 0.0961, val_loss = 0.1145, trn_score = 0.4388, val_score = 0.4795
# lr :  [1.7153703234534302e-05, 1.7153703234534302e-05, 0.000171537032345343]
# 100%|██████████████████████████████| 48/48 [05:54<00:00,  7.39s/it, loss=0.0931]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.51s/it]
# epoch 7: trn_loss = 0.0931, val_loss = 0.1046, trn_score = 0.4319, val_score = 0.4578
# lr :  [1.0666653535486527e-05, 1.0666653535486527e-05, 0.00010666653535486525]
# 100%|████████████████████████████████| 48/48 [05:54<00:00,  7.38s/it, loss=0.09]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.51s/it]
# epoch 8: trn_loss = 0.0900, val_loss = 0.1023, trn_score = 0.4246, val_score = 0.4528
# model (best score) saved
# lr :  [5.265177242471899e-06, 5.265177242471899e-06, 5.2651772424718996e-05]
# 100%|███████████████████████████████| 48/48 [05:54<00:00,  7.38s/it, loss=0.088]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.52s/it]
# epoch 9: trn_loss = 0.0880, val_loss = 0.1031, trn_score = 0.4199, val_score = 0.4546
# lr :  [1.577526937703e-06, 1.577526937703e-06, 1.577526937703e-05]
# 100%|██████████████████████████████| 48/48 [05:54<00:00,  7.39s/it, loss=0.0868]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.51s/it]
# epoch 10: trn_loss = 0.0868, val_loss = 0.1037, trn_score = 0.4169, val_score = 0.4558
#  elapsed_time = 66.8 min

# %%
MODE = 'train'
EPOCHS = 10 #5
STOP_EPOCH = 10 #5
RESTART = 1
NUM_CYCLES = 1 #EPOCHS
EVAL_STEP = -1
ADD_FB3 = 'false'
FB3_FOLD_PATH = 'none' #'../../00_EDA/00_v1_02/result/'

# for CLASS in [
#     'cohesion',
#     #'syntax','vocabulary','phraseology','grammar','conventions'
# ]:
#     print("*"*50)
#     print(CLASS)
#     print("*"*50)
if True:
    CLASS = 'none'
    for FOLD in [1,2,3,4]:
        print("-"*50)
        print("FOLD = ", FOLD)
        print("-"*50)
        INPUT_PATH = '../../00_EDA/00_v1_12/result/' #'../../input/feedback-prize-english-language-learning/'
        FOLD_PATH = '../../00_EDA/00_v1_02/result/'
        #INPUT_PATH = f'../../99_Ensemble/99_v1_03/result/99_v1_03_03_pseudo_fold{FOLD}.csv'
        #INPUT_PATH = f'../../99_Ensemble/99_v1_03/result/99_v1_03_03_{TEACHER_VERSION}_pseudo_fold{FOLD}.csv'
        #FOLD_PATH = '../../00_EDA/00_v1_08/result/' # for pseudo-label
        PRETRAIN_PATH = 'none'
        # !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
        --lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
        --epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
        --accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
        --mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
        --msd $MSD --multi_layers $MULTI_LAYERS \
        --eval_step_start_epoch $EVAL_STEP_START_EPOCH --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
        --num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
        --restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
        --mt $MULTI_TASK --w_mt $W_MT \
        --awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
        --pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
        --scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
        --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN \
        --gradient_clip_val $GRAD_CLIP \
        --input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN \
        --crop_prob $CROP_PROB --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS --class_name $CLASS \
        --add_fb3 $ADD_FB3 --fb3_fold_path $FB3_FOLD_PATH --use_stats $USE_STATS \
        --use_separate_head $USE_SEPARATE_HEAD --low_loss_thr $LOW_LOSS_THR --high_loss_thr $HIGH_LOSS_THR \
        --oof_df_path $OOF_DF_PATH
# Out:
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# 2022-11-17 23:50:59.428423: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-17 23:50:59.428445: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  488
# num_warmup_steps =  48
# lr :  [0.0, 0.0, 0.0]
# 100%|███████████████████████████████| 48/48 [05:56<00:00,  7.43s/it, loss=0.998]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.51s/it]
# epoch 1: trn_loss = 0.9979, val_loss = 0.1453, trn_score = 1.8418, val_score = 0.5441
# model (best score) saved
# lr :  [4e-05, 4e-05, 0.0004]
# 100%|███████████████████████████████| 48/48 [05:57<00:00,  7.45s/it, loss=0.123]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.51s/it]
# epoch 2: trn_loss = 0.1235, val_loss = 0.1097, trn_score = 0.4990, val_score = 0.4705
# model (best score) saved
# lr :  [3.88368872727905e-05, 3.88368872727905e-05, 0.00038836887272790496]
# 100%|███████████████████████████████| 48/48 [05:54<00:00,  7.39s/it, loss=0.111]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.51s/it]
# epoch 3: trn_loss = 0.1111, val_loss = 0.1081, trn_score = 0.4725, val_score = 0.4664
# model (best score) saved
# lr :  [3.5482832212781655e-05, 3.5482832212781655e-05, 0.0003548283221278165]
# 100%|███████████████████████████████| 48/48 [05:54<00:00,  7.39s/it, loss=0.106]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.51s/it]
# epoch 4: trn_loss = 0.1059, val_loss = 0.1073, trn_score = 0.4611, val_score = 0.4641
# model (best score) saved
# lr :  [3.0327949232779242e-05, 3.0327949232779242e-05, 0.0003032794923277924]
# 100%|███████████████████████████████| 48/48 [05:53<00:00,  7.37s/it, loss=0.107]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.51s/it]
# epoch 5: trn_loss = 0.1067, val_loss = 0.1098, trn_score = 0.4628, val_score = 0.4694
# lr :  [2.397180933291491e-05, 2.397180933291491e-05, 0.0002397180933291491]
# 100%|██████████████████████████████| 48/48 [05:53<00:00,  7.37s/it, loss=0.0999]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.50s/it]
# epoch 6: trn_loss = 0.0999, val_loss = 0.1128, trn_score = 0.4477, val_score = 0.4765
# lr :  [1.7153703234534302e-05, 1.7153703234534302e-05, 0.000171537032345343]
# 100%|██████████████████████████████| 48/48 [05:53<00:00,  7.37s/it, loss=0.0972]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.51s/it]
# epoch 7: trn_loss = 0.0972, val_loss = 0.1023, trn_score = 0.4415, val_score = 0.4533
# model (best score) saved
# lr :  [1.0666653535486527e-05, 1.0666653535486527e-05, 0.00010666653535486525]
# 100%|██████████████████████████████| 48/48 [05:53<00:00,  7.37s/it, loss=0.0934]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.51s/it]
# epoch 8: trn_loss = 0.0934, val_loss = 0.1007, trn_score = 0.4326, val_score = 0.4497
# model (best score) saved
# lr :  [5.265177242471899e-06, 5.265177242471899e-06, 5.2651772424718996e-05]
# 100%|██████████████████████████████| 48/48 [05:53<00:00,  7.37s/it, loss=0.0917]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.52s/it]
# epoch 9: trn_loss = 0.0917, val_loss = 0.1011, trn_score = 0.4286, val_score = 0.4507
# lr :  [1.577526937703e-06, 1.577526937703e-06, 1.577526937703e-05]
# 100%|████████████████████████████████| 48/48 [05:53<00:00,  7.37s/it, loss=0.09]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.50s/it]
# epoch 10: trn_loss = 0.0900, val_loss = 0.0996, trn_score = 0.4245, val_score = 0.4472
#  elapsed_time = 66.9 min
# model (best score) saved
#
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# 2022-11-18 00:58:12.996108: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-18 00:58:12.996128: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  488
# num_warmup_steps =  48
# lr :  [0.0, 0.0, 0.0]
# 100%|███████████████████████████████| 48/48 [05:55<00:00,  7.41s/it, loss=0.906]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.51s/it]
# epoch 1: trn_loss = 0.9064, val_loss = 0.1614, trn_score = 1.7135, val_score = 0.5728
# model (best score) saved
# lr :  [4e-05, 4e-05, 0.0004]
# 100%|███████████████████████████████| 48/48 [05:54<00:00,  7.38s/it, loss=0.121]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.51s/it]
# epoch 2: trn_loss = 0.1209, val_loss = 0.1171, trn_score = 0.4940, val_score = 0.4851
# model (best score) saved
# lr :  [3.88368872727905e-05, 3.88368872727905e-05, 0.00038836887272790496]
# 100%|███████████████████████████████| 48/48 [05:54<00:00,  7.38s/it, loss=0.108]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.51s/it]
# epoch 3: trn_loss = 0.1083, val_loss = 0.1133, trn_score = 0.4665, val_score = 0.4769
# model (best score) saved
# lr :  [3.5482832212781655e-05, 3.5482832212781655e-05, 0.0003548283221278165]
# 100%|███████████████████████████████| 48/48 [05:54<00:00,  7.38s/it, loss=0.105]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.51s/it]
# epoch 4: trn_loss = 0.1049, val_loss = 0.1056, trn_score = 0.4587, val_score = 0.4610
# model (best score) saved
# lr :  [3.0327949232779242e-05, 3.0327949232779242e-05, 0.0003032794923277924]
# 100%|███████████████████████████████| 48/48 [05:53<00:00,  7.37s/it, loss=0.101]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.51s/it]
# epoch 5: trn_loss = 0.1012, val_loss = 0.1083, trn_score = 0.4506, val_score = 0.4659
# lr :  [2.397180933291491e-05, 2.397180933291491e-05, 0.0002397180933291491]
# 100%|██████████████████████████████| 48/48 [05:53<00:00,  7.37s/it, loss=0.0967]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.50s/it]
# epoch 6: trn_loss = 0.0967, val_loss = 0.1017, trn_score = 0.4404, val_score = 0.4520
# model (best score) saved
# lr :  [1.7153703234534302e-05, 1.7153703234534302e-05, 0.000171537032345343]
# 100%|██████████████████████████████| 48/48 [05:53<00:00,  7.37s/it, loss=0.0925]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.50s/it]
# epoch 7: trn_loss = 0.0925, val_loss = 0.1023, trn_score = 0.4304, val_score = 0.4533
# lr :  [1.0666653535486527e-05, 1.0666653535486527e-05, 0.00010666653535486525]
# 100%|██████████████████████████████| 48/48 [05:53<00:00,  7.37s/it, loss=0.0899]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.51s/it]
# epoch 8: trn_loss = 0.0899, val_loss = 0.1013, trn_score = 0.4242, val_score = 0.4510
# model (best score) saved
# lr :  [5.265177242471899e-06, 5.265177242471899e-06, 5.2651772424718996e-05]
# 100%|██████████████████████████████| 48/48 [05:53<00:00,  7.37s/it, loss=0.0879]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.50s/it]
# epoch 9: trn_loss = 0.0879, val_loss = 0.1006, trn_score = 0.4195, val_score = 0.4494
# model (best score) saved
# lr :  [1.577526937703e-06, 1.577526937703e-06, 1.577526937703e-05]
# 100%|██████████████████████████████| 48/48 [05:53<00:00,  7.36s/it, loss=0.0871]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.51s/it]
# epoch 10: trn_loss = 0.0871, val_loss = 0.1011, trn_score = 0.4174, val_score = 0.4507
#  elapsed_time = 66.8 min
#
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# 2022-11-18 02:05:21.282715: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-18 02:05:21.282736: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  488
# num_warmup_steps =  48
# lr :  [0.0, 0.0, 0.0]
# 100%|███████████████████████████████| 48/48 [05:55<00:00,  7.40s/it, loss=0.915]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.51s/it]
# epoch 1: trn_loss = 0.9153, val_loss = 0.1330, trn_score = 1.7256, val_score = 0.5191
# model (best score) saved
# lr :  [4e-05, 4e-05, 0.0004]
# 100%|███████████████████████████████| 48/48 [05:53<00:00,  7.36s/it, loss=0.119]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.51s/it]
# epoch 2: trn_loss = 0.1191, val_loss = 0.1275, trn_score = 0.4905, val_score = 0.5066
# model (best score) saved
# lr :  [3.88368872727905e-05, 3.88368872727905e-05, 0.00038836887272790496]
# 100%|████████████████████████████████| 48/48 [05:53<00:00,  7.36s/it, loss=0.11]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.49s/it]
# epoch 3: trn_loss = 0.1097, val_loss = 0.1120, trn_score = 0.4697, val_score = 0.4737
# model (best score) saved
# lr :  [3.5482832212781655e-05, 3.5482832212781655e-05, 0.0003548283221278165]
# 100%|███████████████████████████████| 48/48 [05:52<00:00,  7.35s/it, loss=0.112]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.50s/it]
# epoch 4: trn_loss = 0.1121, val_loss = 0.1096, trn_score = 0.4749, val_score = 0.4693
# model (best score) saved
# lr :  [3.0327949232779242e-05, 3.0327949232779242e-05, 0.0003032794923277924]
# 100%|██████████████████████████████| 48/48 [05:53<00:00,  7.36s/it, loss=0.0998]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.50s/it]
# epoch 5: trn_loss = 0.0998, val_loss = 0.1081, trn_score = 0.4475, val_score = 0.4658
# model (best score) saved
# lr :  [2.397180933291491e-05, 2.397180933291491e-05, 0.0002397180933291491]
# 100%|██████████████████████████████| 48/48 [05:53<00:00,  7.36s/it, loss=0.0973]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.49s/it]
# epoch 6: trn_loss = 0.0973, val_loss = 0.1050, trn_score = 0.4416, val_score = 0.4590
# model (best score) saved
# lr :  [1.7153703234534302e-05, 1.7153703234534302e-05, 0.000171537032345343]
# 100%|██████████████████████████████| 48/48 [05:53<00:00,  7.35s/it, loss=0.0932]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.49s/it]
# epoch 7: trn_loss = 0.0932, val_loss = 0.1053, trn_score = 0.4320, val_score = 0.4597
# lr :  [1.0666653535486527e-05, 1.0666653535486527e-05, 0.00010666653535486525]
# 100%|██████████████████████████████| 48/48 [05:53<00:00,  7.36s/it, loss=0.0903]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.49s/it]
# epoch 8: trn_loss = 0.0903, val_loss = 0.1040, trn_score = 0.4253, val_score = 0.4568
# model (best score) saved
# lr :  [5.265177242471899e-06, 5.265177242471899e-06, 5.2651772424718996e-05]
# 100%|██████████████████████████████| 48/48 [05:53<00:00,  7.36s/it, loss=0.0888]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.50s/it]
# epoch 9: trn_loss = 0.0888, val_loss = 0.1057, trn_score = 0.4217, val_score = 0.4606
# lr :  [1.577526937703e-06, 1.577526937703e-06, 1.577526937703e-05]
# 100%|██████████████████████████████| 48/48 [05:53<00:00,  7.36s/it, loss=0.0875]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.50s/it]
# epoch 10: trn_loss = 0.0875, val_loss = 0.1038, trn_score = 0.4186, val_score = 0.4563
#  elapsed_time = 66.7 min
# model (best score) saved
#
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# 2022-11-18 03:12:23.463973: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-18 03:12:23.463995: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  488
# num_warmup_steps =  48
# lr :  [0.0, 0.0, 0.0]
# 100%|███████████████████████████████| 48/48 [05:55<00:00,  7.40s/it, loss=0.845]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.51s/it]
# epoch 1: trn_loss = 0.8447, val_loss = 0.1528, trn_score = 1.6287, val_score = 0.5555
# model (best score) saved
# lr :  [4e-05, 4e-05, 0.0004]
# 100%|███████████████████████████████| 48/48 [05:53<00:00,  7.36s/it, loss=0.122]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.50s/it]
# epoch 2: trn_loss = 0.1220, val_loss = 0.1243, trn_score = 0.4959, val_score = 0.5006
# model (best score) saved
# lr :  [3.88368872727905e-05, 3.88368872727905e-05, 0.00038836887272790496]
# 100%|███████████████████████████████| 48/48 [05:53<00:00,  7.36s/it, loss=0.111]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.49s/it]
# epoch 3: trn_loss = 0.1110, val_loss = 0.1161, trn_score = 0.4723, val_score = 0.4833
# model (best score) saved
# lr :  [3.5482832212781655e-05, 3.5482832212781655e-05, 0.0003548283221278165]
# 100%|███████████████████████████████| 48/48 [05:53<00:00,  7.36s/it, loss=0.102]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.50s/it]
# epoch 4: trn_loss = 0.1020, val_loss = 0.1077, trn_score = 0.4524, val_score = 0.4652
# model (best score) saved
# lr :  [3.0327949232779242e-05, 3.0327949232779242e-05, 0.0003032794923277924]
# 100%|██████████████████████████████| 48/48 [05:53<00:00,  7.36s/it, loss=0.0972]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.50s/it]
# epoch 5: trn_loss = 0.0972, val_loss = 0.1055, trn_score = 0.4412, val_score = 0.4602
# model (best score) saved
# lr :  [2.397180933291491e-05, 2.397180933291491e-05, 0.0002397180933291491]
# 100%|██████████████████████████████| 48/48 [05:53<00:00,  7.36s/it, loss=0.0944]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.50s/it]
# epoch 6: trn_loss = 0.0944, val_loss = 0.1072, trn_score = 0.4350, val_score = 0.4640
# lr :  [1.7153703234534302e-05, 1.7153703234534302e-05, 0.000171537032345343]
# 100%|██████████████████████████████| 48/48 [05:53<00:00,  7.36s/it, loss=0.0923]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.49s/it]
# epoch 7: trn_loss = 0.0923, val_loss = 0.1077, trn_score = 0.4300, val_score = 0.4653
# lr :  [1.0666653535486527e-05, 1.0666653535486527e-05, 0.00010666653535486525]
# 100%|██████████████████████████████| 48/48 [05:53<00:00,  7.36s/it, loss=0.0876]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.50s/it]
# epoch 8: trn_loss = 0.0876, val_loss = 0.1071, trn_score = 0.4189, val_score = 0.4640
# lr :  [5.265177242471899e-06, 5.265177242471899e-06, 5.2651772424718996e-05]
# 100%|██████████████████████████████| 48/48 [05:53<00:00,  7.36s/it, loss=0.0856]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.49s/it]
# epoch 9: trn_loss = 0.0856, val_loss = 0.1064, trn_score = 0.4139, val_score = 0.4625
# lr :  [1.577526937703e-06, 1.577526937703e-06, 1.577526937703e-05]
# 100%|██████████████████████████████| 48/48 [05:53<00:00,  7.36s/it, loss=0.0846]
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.50s/it]
# epoch 10: trn_loss = 0.0846, val_loss = 0.1063, trn_score = 0.4114, val_score = 0.4623
#  elapsed_time = 66.6 min

# %% [markdown]
# # OOF

# %%
INPUT_PATH = '../../00_EDA/00_v1_12/result/' #'../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_02/result/'

# %%
# for CLASS in [
#     'cohesion',
#     'syntax','vocabulary','phraseology','grammar','conventions'
# ]:
#     print("*"*50)
#     print(CLASS)
#     print("*"*50)
if True:
    CLASS = 'none'
    for FOLD in [0,1,2,3,4]:
        print("-"*50)
        print("FOLD = ", FOLD)
        print("-"*50)
        WEIGHT_PATH = f'./result/{VERSION}/model_seed{SEED}_fold{FOLD}.pth'
        #WEIGHT_PATH = f'./result/{VERSION}/model_{CLASS}_seed{SEED}_fold{FOLD}.pth'
        #WEIGHT_PATH = f'result/{VERSION}/model_{CLASS}_seed{SEED}_fold{FOLD}_pseudo.pth'
        # !python ../$VERSION/validation.py --model $MODEL --version $VERSION \
        --fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS \
        --rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH \
        --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --max_length $MAX_LEN \
        --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS \
        --class_name $CLASS --input_path $INPUT_PATH --use_stats $USE_STATS \
        --use_separate_head $USE_SEPARATE_HEAD
# Out:
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# 2022-11-18 04:19:20.880834: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-18 04:19:20.880857: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3128, 13)
# val_df.shape =  (783, 13)
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# 100%|███████████████████████████████████████████| 13/13 [00:44<00:00,  3.43s/it]
# val_loss=0.1023, val_score=0.4528
# essay_ids.shape =  (783,)
# preds.shape =  (783, 6)
# labels.shape =  (783, 6)
# losses.shape =  (783, 6)
# embeds.shape =  (783, 1024, 6)
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# 2022-11-18 04:20:25.590543: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-18 04:20:25.590566: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# 100%|███████████████████████████████████████████| 13/13 [00:44<00:00,  3.46s/it]
# val_loss=0.0996, val_score=0.4472
# essay_ids.shape =  (782,)
# preds.shape =  (782, 6)
# labels.shape =  (782, 6)
# losses.shape =  (782, 6)
# embeds.shape =  (782, 1024, 6)
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# 2022-11-18 04:21:29.998145: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-18 04:21:29.998166: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# 100%|███████████████████████████████████████████| 13/13 [00:45<00:00,  3.46s/it]
# val_loss=0.1006, val_score=0.4494
# essay_ids.shape =  (782,)
# preds.shape =  (782, 6)
# labels.shape =  (782, 6)
# losses.shape =  (782, 6)
# embeds.shape =  (782, 1024, 6)
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.1
# 2022-11-18 04:22:34.299177: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-18 04:22:34.299213: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# 100%|███████████████████████████████████████████| 13/13 [00:44<00:00,  3.46s/it]
# val_loss=0.1038, val_score=0.4563
# essay_ids.shape =  (782,)
# preds.shape =  (782, 6)
# labels.shape =  (782, 6)
# losses.shape =  (782, 6)
# embeds.shape =  (782, 1024, 6)
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.1
# 2022-11-18 04:23:39.124994: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-18 04:23:39.125013: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# 100%|███████████████████████████████████████████| 13/13 [00:44<00:00,  3.45s/it]
# val_loss=0.1055, val_score=0.4602
# essay_ids.shape =  (782,)
# preds.shape =  (782, 6)
# labels.shape =  (782, 6)
# losses.shape =  (782, 6)
# embeds.shape =  (782, 1024, 6)

# %%
import pandas as pd
import numpy as np

preds = []
# for CLASS in [
#     'cohesion',
#     'syntax','vocabulary','phraseology','grammar','conventions'
# ]:
#     print("*"*50)
#     print(CLASS)
#     print("*"*50)
#     preds_class = []
if True:
    for fold in [0,1,2,3,4]:
        tmp_df = pd.read_csv(f'./result/{VERSION}/pred_fold{fold}.csv')
        #tmp_df = pd.read_csv(f'./result/{VERSION}/pred_{CLASS}_fold{fold}.csv')
        #embeds = np.load(f'./result/{VERSION}/embeds_{CLASS}_fold{fold}.npz')['arr_0']
        #tmp_df[f'embed_{CLASS}'] = embeds.tolist()
        #preds_class.append(tmp_df)
        preds.append(tmp_df)
#     pred_df = pd.concat(preds_class, axis=0).reset_index(drop=True)
#     if len(preds)==0:
#         preds.append(pred_df)
#     else:
#         del pred_df["text_id"]
#         preds.append(pred_df)
    
#all_pred_df = pd.concat(preds, axis=1)
all_pred_df = pd.concat(preds, axis=0).reset_index(drop=True)

train_df = pd.read_csv('../../input/feedback-prize-english-language-learning/train.csv')
oof_df = train_df[['text_id']].merge(all_pred_df, on='text_id', how='left')
oof_df.to_csv(f'./result/{VERSION}/oof_df.csv', index=False)

# %%
oof_df.shape, oof_df.isnull().sum()
# Out:
# ((3911, 13),
#  text_id             0
#  cohesion            0
#  syntax              0
#  vocabulary          0
#  phraseology         0
#  grammar             0
#  conventions         0
#  loss_cohesion       0
#  loss_syntax         0
#  loss_vocabulary     0
#  loss_phraseology    0
#  loss_grammar        0
#  loss_conventions    0
#  dtype: int64)

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
oof_df[cols].describe()
# Out:
#           cohesion       syntax   vocabulary  phraseology      grammar  \
# count  3911.000000  3911.000000  3911.000000  3911.000000  3911.000000
# mean      3.147504     3.041142     3.239762     3.109016     3.039896
# std       0.476325     0.480489     0.419235     0.494382     0.538075
# min       1.278829     1.141945     1.651354     1.466617     1.310049
# 25%       2.821324     2.712045     2.950739     2.768722     2.630227
# 50%       3.134897     3.019010     3.210793     3.089277     3.010488
# 75%       3.469439     3.367246     3.515838     3.439246     3.408806
# max       4.954367     4.790361     5.076855     4.882861     4.744920
#
#        conventions
# count  3911.000000
# mean      3.096824
# std       0.519425
# min       1.228263
# 25%       2.737160
# 50%       3.085172
# 75%       3.450155
# max       4.768315

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
train_df[cols].describe()
# Out:
#           cohesion       syntax   vocabulary  phraseology      grammar  \
# count  3911.000000  3911.000000  3911.000000  3911.000000  3911.000000
# mean      3.127077     3.028254     3.235745     3.116850     3.032856
# std       0.662542     0.644399     0.583148     0.655997     0.699841
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%       2.500000     2.500000     3.000000     2.500000     2.500000
# 50%       3.000000     3.000000     3.000000     3.000000     3.000000
# 75%       3.500000     3.500000     3.500000     3.500000     3.500000
# max       5.000000     5.000000     5.000000     5.000000     5.000000
#
#        conventions
# count  3911.000000
# mean      3.081053
# std       0.671450
# min       1.000000
# 25%       2.500000
# 50%       3.000000
# 75%       3.500000
# max       5.000000

# %% [markdown]
# # Error Analysis - Check Corr

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
train_df[cols].corr()
# Out:
#              cohesion    syntax  vocabulary  phraseology   grammar  \
# cohesion     1.000000  0.695459    0.666151     0.690058  0.638689
# syntax       0.695459  1.000000    0.680562     0.725467  0.709525
# vocabulary   0.666151  0.680562    1.000000     0.735261  0.654852
# phraseology  0.690058  0.725467    0.735261     1.000000  0.719746
# grammar      0.638689  0.709525    0.654852     0.719746  1.000000
# conventions  0.666151  0.700025    0.664292     0.666842  0.673301
#
#              conventions
# cohesion        0.666151
# syntax          0.700025
# vocabulary      0.664292
# phraseology     0.666842
# grammar         0.673301
# conventions     1.000000

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
oof_df[cols].corr()
# Out:
#              cohesion    syntax  vocabulary  phraseology   grammar  \
# cohesion     1.000000  0.954584    0.927073     0.919291  0.841935
# syntax       0.954584  1.000000    0.949783     0.964174  0.930609
# vocabulary   0.927073  0.949783    1.000000     0.955425  0.886535
# phraseology  0.919291  0.964174    0.955425     1.000000  0.950767
# grammar      0.841935  0.930609    0.886535     0.950767  1.000000
# conventions  0.891307  0.925325    0.906040     0.883264  0.864210
#
#              conventions
# cohesion        0.891307
# syntax          0.925325
# vocabulary      0.906040
# phraseology     0.883264
# grammar         0.864210
# conventions     1.000000
