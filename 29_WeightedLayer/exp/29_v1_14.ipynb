# %%
VERSION = '29_v1_14'
MODEL = 'microsoft/deberta-v2-xlarge'
#'deepset/deberta-v3-large-squad2'
#'microsoft/deberta-v3-large'
#'microsoft/deberta-v3-base'
#TEACHER_VERSION = '14_v1_15' # deverta-v2-xlarge
#'bert-large-cased'
#'bert-large-cased-whole-word-masking'
#'albert-large-v2'
#'facebook/bart-large'
#'xlm-roberta-large'
#'deepset/roberta-large-squad2'
#'google/electra-large-discriminator'
#'sentence-transformeres/paraphrase-mpnet-base-v2'
#'funnel-transformer/large-base'
#'facebook/bart-base'
#'distilroberta-base'
#'deepset/roberta-base-squad2'
#'microsoft/deberta-v3-base'
#'roberta-large'
#'roberta-base'
#'microsoft/deberta-base'
LR = 2e-5 #4e-5 #8e-5 #8e-6
HEAD_LR = 2e-4 #4e-4 #8e-4 #2e-5 #8e-6 
SEED = 100
TRN_BS = 32 #64 #8
VAL_BS = 32 #64 #8
ACCUM_STEP = 1
HIDDEN_DROP_PROB = 0
P_DROP = 0
RNN = 'none'
WARMUP_RATIO = 0.1
HEAD = 'simple'
AUG = 'false'
MIXUP_ALPHA = 0
P_AUG = 0
AUG_STOP_EPOCH = 0
MSD = 'false'
POOLING = 'weighted_layer'  #'mean' #'transformer+mean' #'attention'
NUM_POOLING_LAYERS = 4 #1
MULTI_LAYERS = 1
EVAL_STEP_START_EPOCH = -1
EVAL_STEP = -1
NUM_LABELS = 6
NUM_LABELS_2 = -1
FP16 = 'true'
WD = 0.01
FREEZE = 'true' #'false'
MULTI_TASK = 'false' 
W_MT = 0 
AWP = 'false'
AWP_LR = 0
AWP_EPS = 0
AWP_START_EPOCH = -1
#PRETRAINED_DETECTOR_PATH = f'../../input/tascj/result/deberta_base_fold0.pth'
PRETRAINED_DETECTOR_PATH = 'none' #f'../../05_Detection/exp/result/05_v2_09/model_seed100_fold0_swa.pth'
MASK_PROB = 0 #0.8
MASK_RATIO = 0 #0.3
SCHEDULER = 'cosine_hard'
CP = 'true' #'false'
WINDOW_SIZE = -1
INNER_LEN = -1
EDGE_LEN = -1
MAX_LEN = 512

GRAD_CLIP = 1

LOSS = 'smoothl1'#'mse'

CROP_PROB = 0 #1.0

USE_STATS = 'false' #'true'
USE_SEPARATE_HEAD = 'true'

LOW_LOSS_THR = -1 #0.8 #0.5
HIGH_LOSS_THR = -1 #0.0001
OOF_DF_PATH = 'none' #'../../14_Baseline4/exp/result/14_v1_01/oof_df.csv'

# %% [markdown]
# # Train

# %%
MODE = 'train'
EPOCHS = 10 #5
STOP_EPOCH = 10 #5
RESTART = 1
NUM_CYCLES = 1 #EPOCHS
EVAL_STEP = -1
ADD_FB3 = 'false'
FB3_FOLD_PATH = 'none' #'../../00_EDA/00_v1_02/result/'

# for CLASS in [
#     'cohesion',
#     #'syntax','vocabulary','phraseology','grammar','conventions'
# ]:
#     print("*"*50)
#     print(CLASS)
#     print("*"*50)
if True:
    CLASS = 'none'
    for FOLD in [0,1,2,3,4]:
        print("-"*50)
        print("FOLD = ", FOLD)
        print("-"*50)
        INPUT_PATH = '../../00_EDA/00_v1_12/result/' #'../../input/feedback-prize-english-language-learning/'
        FOLD_PATH = '../../00_EDA/00_v1_02/result/'
        #INPUT_PATH = f'../../99_Ensemble/99_v1_03/result/99_v1_03_03_pseudo_fold{FOLD}.csv'
        #INPUT_PATH = f'../../99_Ensemble/99_v1_03/result/99_v1_03_03_{TEACHER_VERSION}_pseudo_fold{FOLD}.csv'
        #FOLD_PATH = '../../00_EDA/00_v1_08/result/' # for pseudo-label
        PRETRAIN_PATH = 'none'
        # !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
        --lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
        --epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
        --accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
        --mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
        --msd $MSD --multi_layers $MULTI_LAYERS \
        --eval_step_start_epoch $EVAL_STEP_START_EPOCH --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
        --num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
        --restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
        --mt $MULTI_TASK --w_mt $W_MT \
        --awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
        --pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
        --scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
        --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN \
        --gradient_clip_val $GRAD_CLIP \
        --input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN \
        --crop_prob $CROP_PROB --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS --class_name $CLASS \
        --add_fb3 $ADD_FB3 --fb3_fold_path $FB3_FOLD_PATH --use_stats $USE_STATS \
        --use_separate_head $USE_SEPARATE_HEAD --low_loss_thr $LOW_LOSS_THR --high_loss_thr $HIGH_LOSS_THR \
        --oof_df_path $OOF_DF_PATH
# Out:
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3128, 13)
# val_df.shape =  (783, 13)
# 2022-11-20 08:49:01.922322: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-20 08:49:01.922342: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  977
# num_warmup_steps =  97
# lr :  [0.0, 0.0, 0.0]
# 100%|████████████████████████████████| 97/97 [08:38<00:00,  5.35s/it, loss=1.06]
# 100%|███████████████████████████████████████████| 25/25 [01:22<00:00,  3.31s/it]
# epoch 1: trn_loss = 1.0551, val_loss = 0.1245, trn_score = 1.9541, val_score = 0.5000
# model (best score) saved
# lr :  [2e-05, 2e-05, 0.0002]
# 100%|███████████████████████████████| 97/97 [08:40<00:00,  5.37s/it, loss=0.115]
# 100%|███████████████████████████████████████████| 25/25 [01:22<00:00,  3.31s/it]
# epoch 2: trn_loss = 0.1147, val_loss = 0.1144, trn_score = 0.4806, val_score = 0.4775
# model (best score) saved
# lr :  [1.9406386708377956e-05, 1.9406386708377956e-05, 0.00019406386708377955]
# 100%|███████████████████████████████| 97/97 [08:41<00:00,  5.38s/it, loss=0.109]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.32s/it]
# epoch 3: trn_loss = 0.1087, val_loss = 0.1054, trn_score = 0.4674, val_score = 0.4598
# model (best score) saved
# lr :  [1.7696022181509892e-05, 1.7696022181509892e-05, 0.00017696022181509894]
# 100%|███████████████████████████████| 97/97 [08:42<00:00,  5.38s/it, loss=0.104]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.32s/it]
# epoch 4: trn_loss = 0.1036, val_loss = 0.1037, trn_score = 0.4559, val_score = 0.4563
# model (best score) saved
# lr :  [1.5071965442729358e-05, 1.5071965442729358e-05, 0.00015071965442729356]
# 100%|██████████████████████████████| 97/97 [08:42<00:00,  5.38s/it, loss=0.0979]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.32s/it]
# epoch 5: trn_loss = 0.0979, val_loss = 0.1122, trn_score = 0.4432, val_score = 0.4746
# lr :  [1.1845751483658454e-05, 1.1845751483658454e-05, 0.00011845751483658453]
# 100%|██████████████████████████████| 97/97 [08:42<00:00,  5.39s/it, loss=0.0936]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.33s/it]
# epoch 6: trn_loss = 0.0936, val_loss = 0.1076, trn_score = 0.4331, val_score = 0.4645
# lr :  [8.4004050018414e-06, 8.4004050018414e-06, 8.400405001841399e-05]
# 100%|██████████████████████████████| 97/97 [08:42<00:00,  5.39s/it, loss=0.0898]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.33s/it]
# epoch 7: trn_loss = 0.0898, val_loss = 0.1059, trn_score = 0.4241, val_score = 0.4608
# lr :  [5.144966690448159e-06, 5.144966690448159e-06, 5.1449666904481585e-05]
# 100%|██████████████████████████████| 97/97 [08:45<00:00,  5.42s/it, loss=0.0869]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.33s/it]
# epoch 8: trn_loss = 0.0869, val_loss = 0.1061, trn_score = 0.4172, val_score = 0.4612
# lr :  [2.46593083981847e-06, 2.46593083981847e-06, 2.46593083981847e-05]
# 100%|██████████████████████████████| 97/97 [08:42<00:00,  5.39s/it, loss=0.0837]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.33s/it]
# epoch 9: trn_loss = 0.0837, val_loss = 0.1052, trn_score = 0.4093, val_score = 0.4594
# lr :  [6.813597078854772e-07, 6.813597078854772e-07, 6.813597078854772e-06]
# 100%|██████████████████████████████| 97/97 [08:42<00:00,  5.39s/it, loss=0.0823]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.33s/it]
# epoch 10: trn_loss = 0.0823, val_loss = 0.1052, trn_score = 0.4057, val_score = 0.4593
#  elapsed_time = 101.3 min
#
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# 2022-11-20 10:30:39.530755: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-20 10:30:39.530775: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  977
# num_warmup_steps =  97
# lr :  [0.0, 0.0, 0.0]
# 100%|███████████████████████████████| 97/97 [08:46<00:00,  5.42s/it, loss=0.743]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.35s/it]
# epoch 1: trn_loss = 0.7426, val_loss = 0.1142, trn_score = 1.4977, val_score = 0.4795
# model (best score) saved
# lr :  [2e-05, 2e-05, 0.0002]
# 100%|███████████████████████████████| 97/97 [08:43<00:00,  5.39s/it, loss=0.113]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.33s/it]
# epoch 2: trn_loss = 0.1130, val_loss = 0.1071, trn_score = 0.4770, val_score = 0.4640
# model (best score) saved
# lr :  [1.9406386708377956e-05, 1.9406386708377956e-05, 0.00019406386708377955]
# 100%|███████████████████████████████| 97/97 [08:43<00:00,  5.39s/it, loss=0.106]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.34s/it]
# epoch 3: trn_loss = 0.1062, val_loss = 0.1027, trn_score = 0.4618, val_score = 0.4540
# model (best score) saved
# lr :  [1.7696022181509892e-05, 1.7696022181509892e-05, 0.00017696022181509894]
# 100%|███████████████████████████████| 97/97 [08:43<00:00,  5.40s/it, loss=0.102]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.34s/it]
# epoch 4: trn_loss = 0.1016, val_loss = 0.1044, trn_score = 0.4515, val_score = 0.4579
# lr :  [1.5071965442729358e-05, 1.5071965442729358e-05, 0.00015071965442729356]
# 100%|███████████████████████████████| 97/97 [08:43<00:00,  5.40s/it, loss=0.098]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.34s/it]
# epoch 5: trn_loss = 0.0980, val_loss = 0.1023, trn_score = 0.4434, val_score = 0.4529
# model (best score) saved
# lr :  [1.1845751483658454e-05, 1.1845751483658454e-05, 0.00011845751483658453]
# 100%|██████████████████████████████| 97/97 [08:43<00:00,  5.39s/it, loss=0.0946]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.34s/it]
# epoch 6: trn_loss = 0.0946, val_loss = 0.1014, trn_score = 0.4354, val_score = 0.4511
# model (best score) saved
# lr :  [8.4004050018414e-06, 8.4004050018414e-06, 8.400405001841399e-05]
# 100%|██████████████████████████████| 97/97 [08:43<00:00,  5.39s/it, loss=0.0919]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.35s/it]
# epoch 7: trn_loss = 0.0919, val_loss = 0.1113, trn_score = 0.4290, val_score = 0.4734
# lr :  [5.144966690448159e-06, 5.144966690448159e-06, 5.1449666904481585e-05]
# 100%|██████████████████████████████| 97/97 [08:42<00:00,  5.39s/it, loss=0.0875]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.33s/it]
# epoch 8: trn_loss = 0.0875, val_loss = 0.1031, trn_score = 0.4186, val_score = 0.4550
# lr :  [2.46593083981847e-06, 2.46593083981847e-06, 2.46593083981847e-05]
# 100%|██████████████████████████████| 97/97 [08:41<00:00,  5.38s/it, loss=0.0822]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.32s/it]
# epoch 9: trn_loss = 0.0822, val_loss = 0.1024, trn_score = 0.4055, val_score = 0.4534
# lr :  [6.813597078854772e-07, 6.813597078854772e-07, 6.813597078854772e-06]
# 100%|██████████████████████████████| 97/97 [08:42<00:00,  5.39s/it, loss=0.0798]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.34s/it]
# epoch 10: trn_loss = 0.0798, val_loss = 0.1027, trn_score = 0.3994, val_score = 0.4542
#  elapsed_time = 101.5 min
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# 2022-11-20 12:12:34.297191: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-20 12:12:34.297213: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  977
# num_warmup_steps =  97
# lr :  [0.0, 0.0, 0.0]
# 100%|███████████████████████████████| 97/97 [08:46<00:00,  5.43s/it, loss=0.964]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.34s/it]
# epoch 1: trn_loss = 0.9645, val_loss = 0.1179, trn_score = 1.8087, val_score = 0.4872
# model (best score) saved
# lr :  [2e-05, 2e-05, 0.0002]
# 100%|███████████████████████████████| 97/97 [08:45<00:00,  5.42s/it, loss=0.114]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.33s/it]
# epoch 2: trn_loss = 0.1137, val_loss = 0.1124, trn_score = 0.4782, val_score = 0.4746
# model (best score) saved
# lr :  [1.9406386708377956e-05, 1.9406386708377956e-05, 0.00019406386708377955]
# 100%|███████████████████████████████| 97/97 [08:43<00:00,  5.39s/it, loss=0.107]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.33s/it]
# epoch 3: trn_loss = 0.1072, val_loss = 0.1173, trn_score = 0.4639, val_score = 0.4856
# lr :  [1.7696022181509892e-05, 1.7696022181509892e-05, 0.00017696022181509894]
# 100%|███████████████████████████████| 97/97 [08:43<00:00,  5.40s/it, loss=0.101]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.34s/it]
# epoch 4: trn_loss = 0.1013, val_loss = 0.1032, trn_score = 0.4507, val_score = 0.4551
# model (best score) saved
# lr :  [1.5071965442729358e-05, 1.5071965442729358e-05, 0.00015071965442729356]
# 100%|██████████████████████████████| 97/97 [08:43<00:00,  5.39s/it, loss=0.0966]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.34s/it]
# epoch 5: trn_loss = 0.0966, val_loss = 0.1040, trn_score = 0.4400, val_score = 0.4570
# lr :  [1.1845751483658454e-05, 1.1845751483658454e-05, 0.00011845751483658453]
# 100%|██████████████████████████████| 97/97 [08:42<00:00,  5.39s/it, loss=0.0888]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.35s/it]
# epoch 6: trn_loss = 0.0888, val_loss = 0.1020, trn_score = 0.4218, val_score = 0.4524
# model (best score) saved
# lr :  [8.4004050018414e-06, 8.4004050018414e-06, 8.400405001841399e-05]
# 100%|███████████████████████████████| 97/97 [08:43<00:00,  5.40s/it, loss=0.078]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.34s/it]
# epoch 7: trn_loss = 0.0780, val_loss = 0.1247, trn_score = 0.3951, val_score = 0.5019
# lr :  [5.144966690448159e-06, 5.144966690448159e-06, 5.1449666904481585e-05]
# 100%|██████████████████████████████| 97/97 [08:43<00:00,  5.39s/it, loss=0.0696]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.33s/it]
# epoch 8: trn_loss = 0.0696, val_loss = 0.1067, trn_score = 0.3731, val_score = 0.4630
# lr :  [2.46593083981847e-06, 2.46593083981847e-06, 2.46593083981847e-05]
# 100%|██████████████████████████████| 97/97 [08:43<00:00,  5.40s/it, loss=0.0632]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.35s/it]
# epoch 9: trn_loss = 0.0632, val_loss = 0.1075, trn_score = 0.3555, val_score = 0.4645
# lr :  [6.813597078854772e-07, 6.813597078854772e-07, 6.813597078854772e-06]
# 100%|██████████████████████████████| 97/97 [08:43<00:00,  5.40s/it, loss=0.0591]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.34s/it]
# epoch 10: trn_loss = 0.0591, val_loss = 0.1076, trn_score = 0.3437, val_score = 0.4649
#  elapsed_time = 101.5 min
#
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# 2022-11-20 13:54:28.376521: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-20 13:54:28.376544: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  977
# num_warmup_steps =  97
# lr :  [0.0, 0.0, 0.0]
# 100%|███████████████████████████████| 97/97 [08:46<00:00,  5.43s/it, loss=0.916]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.35s/it]
# epoch 1: trn_loss = 0.9157, val_loss = 0.1349, trn_score = 1.7237, val_score = 0.5221
# model (best score) saved
# lr :  [2e-05, 2e-05, 0.0002]
# 100%|███████████████████████████████| 97/97 [08:43<00:00,  5.39s/it, loss=0.113]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.34s/it]
# epoch 2: trn_loss = 0.1129, val_loss = 0.1076, trn_score = 0.4767, val_score = 0.4646
# model (best score) saved
# lr :  [1.9406386708377956e-05, 1.9406386708377956e-05, 0.00019406386708377955]
# 100%|███████████████████████████████| 97/97 [08:42<00:00,  5.39s/it, loss=0.104]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.34s/it]
# epoch 3: trn_loss = 0.1044, val_loss = 0.1103, trn_score = 0.4577, val_score = 0.4702
# lr :  [1.7696022181509892e-05, 1.7696022181509892e-05, 0.00017696022181509894]
# 100%|██████████████████████████████| 97/97 [08:43<00:00,  5.40s/it, loss=0.0995]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.34s/it]
# epoch 4: trn_loss = 0.0995, val_loss = 0.1107, trn_score = 0.4467, val_score = 0.4715
# lr :  [1.5071965442729358e-05, 1.5071965442729358e-05, 0.00015071965442729356]
# 100%|██████████████████████████████| 97/97 [08:43<00:00,  5.40s/it, loss=0.0949]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.34s/it]
# epoch 5: trn_loss = 0.0949, val_loss = 0.1072, trn_score = 0.4361, val_score = 0.4636
# model (best score) saved
# lr :  [1.1845751483658454e-05, 1.1845751483658454e-05, 0.00011845751483658453]
# 100%|██████████████████████████████| 97/97 [08:43<00:00,  5.40s/it, loss=0.0886]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.33s/it]
# epoch 6: trn_loss = 0.0886, val_loss = 0.1109, trn_score = 0.4209, val_score = 0.4719
# lr :  [8.4004050018414e-06, 8.4004050018414e-06, 8.400405001841399e-05]
# 100%|██████████████████████████████| 97/97 [08:43<00:00,  5.40s/it, loss=0.0817]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.34s/it]
# epoch 7: trn_loss = 0.0817, val_loss = 0.1104, trn_score = 0.4041, val_score = 0.4706
# lr :  [5.144966690448159e-06, 5.144966690448159e-06, 5.1449666904481585e-05]
# 100%|██████████████████████████████| 97/97 [08:43<00:00,  5.40s/it, loss=0.0758]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.34s/it]
# epoch 8: trn_loss = 0.0758, val_loss = 0.1109, trn_score = 0.3891, val_score = 0.4716
# lr :  [2.46593083981847e-06, 2.46593083981847e-06, 2.46593083981847e-05]
# 100%|██████████████████████████████| 97/97 [08:43<00:00,  5.40s/it, loss=0.0724]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.33s/it]
# epoch 9: trn_loss = 0.0724, val_loss = 0.1115, trn_score = 0.3802, val_score = 0.4728
# lr :  [6.813597078854772e-07, 6.813597078854772e-07, 6.813597078854772e-06]
# 100%|██████████████████████████████| 97/97 [08:43<00:00,  5.40s/it, loss=0.0701]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.34s/it]
# epoch 10: trn_loss = 0.0701, val_loss = 0.1124, trn_score = 0.3742, val_score = 0.4749
#  elapsed_time = 101.5 min
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# 2022-11-20 15:36:21.129083: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-20 15:36:21.129107: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# freeze 12/24
# self.warmup_ratio =  0.1
# self.num_train_steps =  977
# num_warmup_steps =  97
# lr :  [0.0, 0.0, 0.0]
# 100%|████████████████████████████████| 97/97 [08:44<00:00,  5.41s/it, loss=0.93]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.32s/it]
# epoch 1: trn_loss = 0.9300, val_loss = 0.1176, trn_score = 1.7675, val_score = 0.4862
# model (best score) saved
# lr :  [2e-05, 2e-05, 0.0002]
# 100%|███████████████████████████████| 97/97 [08:40<00:00,  5.37s/it, loss=0.115]
# 100%|███████████████████████████████████████████| 25/25 [01:22<00:00,  3.31s/it]
# epoch 2: trn_loss = 0.1150, val_loss = 0.1184, trn_score = 0.4814, val_score = 0.4878
# lr :  [1.9406386708377956e-05, 1.9406386708377956e-05, 0.00019406386708377955]
# 100%|███████████████████████████████| 97/97 [08:41<00:00,  5.38s/it, loss=0.105]
# 100%|███████████████████████████████████████████| 25/25 [01:22<00:00,  3.32s/it]
# epoch 3: trn_loss = 0.1050, val_loss = 0.1244, trn_score = 0.4595, val_score = 0.5001
# lr :  [1.7696022181509892e-05, 1.7696022181509892e-05, 0.00017696022181509894]
# 100%|███████████████████████████████| 97/97 [08:41<00:00,  5.38s/it, loss=0.101]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.33s/it]
# epoch 4: trn_loss = 0.1009, val_loss = 0.1097, trn_score = 0.4500, val_score = 0.4696
# model (best score) saved
# lr :  [1.5071965442729358e-05, 1.5071965442729358e-05, 0.00015071965442729356]
# 100%|██████████████████████████████| 97/97 [08:41<00:00,  5.38s/it, loss=0.0981]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.32s/it]
# epoch 5: trn_loss = 0.0981, val_loss = 0.1067, trn_score = 0.4437, val_score = 0.4629
# model (best score) saved
# lr :  [1.1845751483658454e-05, 1.1845751483658454e-05, 0.00011845751483658453]
# 100%|███████████████████████████████| 97/97 [08:41<00:00,  5.38s/it, loss=0.091]
# 100%|███████████████████████████████████████████| 25/25 [01:22<00:00,  3.32s/it]
# epoch 6: trn_loss = 0.0910, val_loss = 0.1072, trn_score = 0.4270, val_score = 0.4638
# lr :  [8.4004050018414e-06, 8.4004050018414e-06, 8.400405001841399e-05]
# 100%|██████████████████████████████| 97/97 [08:42<00:00,  5.38s/it, loss=0.0888]
# 100%|███████████████████████████████████████████| 25/25 [01:22<00:00,  3.32s/it]
# epoch 7: trn_loss = 0.0888, val_loss = 0.1129, trn_score = 0.4218, val_score = 0.4765
# lr :  [5.144966690448159e-06, 5.144966690448159e-06, 5.1449666904481585e-05]
# 100%|██████████████████████████████| 97/97 [08:43<00:00,  5.40s/it, loss=0.0841]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.33s/it]
# epoch 8: trn_loss = 0.0841, val_loss = 0.1061, trn_score = 0.4101, val_score = 0.4614
# model (best score) saved
# lr :  [2.46593083981847e-06, 2.46593083981847e-06, 2.46593083981847e-05]
# 100%|██████████████████████████████| 97/97 [08:43<00:00,  5.39s/it, loss=0.0808]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.34s/it]
# epoch 9: trn_loss = 0.0808, val_loss = 0.1062, trn_score = 0.4019, val_score = 0.4617
# lr :  [6.813597078854772e-07, 6.813597078854772e-07, 6.813597078854772e-06]
# 100%|██████████████████████████████| 97/97 [08:43<00:00,  5.39s/it, loss=0.0788]
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.33s/it]
# epoch 10: trn_loss = 0.0788, val_loss = 0.1064, trn_score = 0.3969, val_score = 0.4621
#  elapsed_time = 101.2 min

# %% [markdown]
# # OOF

# %%
# INPUT_PATH = '../../00_EDA/00_v1_12/result/' #'../../input/feedback-prize-english-language-learning/'
# FOLD_PATH = '../../00_EDA/00_v1_02/result/'

# %%
# for CLASS in [
#     'cohesion',
#     'syntax','vocabulary','phraseology','grammar','conventions'
# ]:
#     print("*"*50)
#     print(CLASS)
#     print("*"*50)
if True:
    CLASS = 'none'
    for FOLD in [0,1,2,3,4]:
        print("-"*50)
        print("FOLD = ", FOLD)
        print("-"*50)
        WEIGHT_PATH = f'./result/{VERSION}/model_seed{SEED}_fold{FOLD}.pth'
        #WEIGHT_PATH = f'./result/{VERSION}/model_{CLASS}_seed{SEED}_fold{FOLD}.pth'
        #WEIGHT_PATH = f'result/{VERSION}/model_{CLASS}_seed{SEED}_fold{FOLD}_pseudo.pth'
        # !python ../$VERSION/validation.py --model $MODEL --version $VERSION \
        --fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS \
        --rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH \
        --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --max_length $MAX_LEN \
        --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS \
        --class_name $CLASS --input_path $INPUT_PATH --use_stats $USE_STATS \
        --use_separate_head $USE_SEPARATE_HEAD
# Out:
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# 2022-11-20 17:17:57.314488: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-20 17:17:57.314510: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3128, 13)
# val_df.shape =  (783, 13)
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# 100%|███████████████████████████████████████████| 25/25 [01:25<00:00,  3.43s/it]
# val_loss=0.1037, val_score=0.4563
# essay_ids.shape =  (783,)
# preds.shape =  (783, 6)
# labels.shape =  (783, 6)
# losses.shape =  (783, 6)
# embeds.shape =  (783, 1536, 6)
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# 2022-11-20 17:19:47.283818: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-20 17:19:47.283840: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# 100%|███████████████████████████████████████████| 25/25 [01:22<00:00,  3.32s/it]
# val_loss=0.1014, val_score=0.4511
# essay_ids.shape =  (782,)
# preds.shape =  (782, 6)
# labels.shape =  (782, 6)
# losses.shape =  (782, 6)
# embeds.shape =  (782, 1536, 6)
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# 2022-11-20 17:21:34.324932: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-20 17:21:34.324954: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# 100%|███████████████████████████████████████████| 25/25 [01:24<00:00,  3.38s/it]
# val_loss=0.1020, val_score=0.4524
# essay_ids.shape =  (782,)
# preds.shape =  (782, 6)
# labels.shape =  (782, 6)
# losses.shape =  (782, 6)
# embeds.shape =  (782, 1536, 6)
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.1
# 2022-11-20 17:23:23.037804: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-20 17:23:23.037825: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.34s/it]
# val_loss=0.1072, val_score=0.4636
# essay_ids.shape =  (782,)
# preds.shape =  (782, 6)
# labels.shape =  (782, 6)
# losses.shape =  (782, 6)
# embeds.shape =  (782, 1536, 6)
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.1
# 2022-11-20 17:25:10.490805: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-20 17:25:10.490825: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['cohesion', 'syntax', 'vocabulary', 'phraseology', 'grammar', 'conventions']
# 100%|███████████████████████████████████████████| 25/25 [01:23<00:00,  3.33s/it]
# val_loss=0.1061, val_score=0.4614
# essay_ids.shape =  (782,)
# preds.shape =  (782, 6)
# labels.shape =  (782, 6)
# losses.shape =  (782, 6)
# embeds.shape =  (782, 1536, 6)

# %%
import pandas as pd
import numpy as np

preds = []
# for CLASS in [
#     'cohesion',
#     'syntax','vocabulary','phraseology','grammar','conventions'
# ]:
#     print("*"*50)
#     print(CLASS)
#     print("*"*50)
#     preds_class = []
if True:
    for fold in [0,1,2,3,4]:
        tmp_df = pd.read_csv(f'./result/{VERSION}/pred_fold{fold}.csv')
        #tmp_df = pd.read_csv(f'./result/{VERSION}/pred_{CLASS}_fold{fold}.csv')
        #embeds = np.load(f'./result/{VERSION}/embeds_{CLASS}_fold{fold}.npz')['arr_0']
        #tmp_df[f'embed_{CLASS}'] = embeds.tolist()
        #preds_class.append(tmp_df)
        preds.append(tmp_df)
#     pred_df = pd.concat(preds_class, axis=0).reset_index(drop=True)
#     if len(preds)==0:
#         preds.append(pred_df)
#     else:
#         del pred_df["text_id"]
#         preds.append(pred_df)
    
#all_pred_df = pd.concat(preds, axis=1)
all_pred_df = pd.concat(preds, axis=0).reset_index(drop=True)

train_df = pd.read_csv('../../input/feedback-prize-english-language-learning/train.csv')
oof_df = train_df[['text_id']].merge(all_pred_df, on='text_id', how='left')
oof_df.to_csv(f'./result/{VERSION}/oof_df.csv', index=False)

# %%
oof_df.shape, oof_df.isnull().sum()
# Out:
# ((3911, 13),
#  text_id             0
#  cohesion            0
#  syntax              0
#  vocabulary          0
#  phraseology         0
#  grammar             0
#  conventions         0
#  loss_cohesion       0
#  loss_syntax         0
#  loss_vocabulary     0
#  loss_phraseology    0
#  loss_grammar        0
#  loss_conventions    0
#  dtype: int64)

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
oof_df[cols].describe()
# Out:
#           cohesion       syntax   vocabulary  phraseology      grammar  \
# count  3911.000000  3911.000000  3911.000000  3911.000000  3911.000000
# mean      3.133458     3.040899     3.249763     3.121807     3.059602
# std       0.469432     0.478569     0.409871     0.478799     0.524893
# min       1.499834     1.418557     2.029174     1.678671     1.686857
# 25%       2.819707     2.709692     2.968489     2.792674     2.673240
# 50%       3.127222     3.022984     3.222696     3.111710     3.043662
# 75%       3.443690     3.372861     3.501176     3.446589     3.415731
# max       4.947530     4.764126     5.160777     4.881864     4.799074
#
#        conventions
# count  3911.000000
# mean      3.072675
# std       0.519294
# min       0.978777
# 25%       2.719323
# 50%       3.073902
# 75%       3.425136
# max       4.783917

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
train_df[cols].describe()
# Out:
#           cohesion       syntax   vocabulary  phraseology      grammar  \
# count  3911.000000  3911.000000  3911.000000  3911.000000  3911.000000
# mean      3.127077     3.028254     3.235745     3.116850     3.032856
# std       0.662542     0.644399     0.583148     0.655997     0.699841
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%       2.500000     2.500000     3.000000     2.500000     2.500000
# 50%       3.000000     3.000000     3.000000     3.000000     3.000000
# 75%       3.500000     3.500000     3.500000     3.500000     3.500000
# max       5.000000     5.000000     5.000000     5.000000     5.000000
#
#        conventions
# count  3911.000000
# mean      3.081053
# std       0.671450
# min       1.000000
# 25%       2.500000
# 50%       3.000000
# 75%       3.500000
# max       5.000000

# %% [markdown]
# # Error Analysis - Check Corr

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
train_df[cols].corr()
# Out:
#              cohesion    syntax  vocabulary  phraseology   grammar  \
# cohesion     1.000000  0.695459    0.666151     0.690058  0.638689
# syntax       0.695459  1.000000    0.680562     0.725467  0.709525
# vocabulary   0.666151  0.680562    1.000000     0.735261  0.654852
# phraseology  0.690058  0.725467    0.735261     1.000000  0.719746
# grammar      0.638689  0.709525    0.654852     0.719746  1.000000
# conventions  0.666151  0.700025    0.664292     0.666842  0.673301
#
#              conventions
# cohesion        0.666151
# syntax          0.700025
# vocabulary      0.664292
# phraseology     0.666842
# grammar         0.673301
# conventions     1.000000

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
oof_df[cols].corr()
# Out:
#              cohesion    syntax  vocabulary  phraseology   grammar  \
# cohesion     1.000000  0.955305    0.931669     0.917548  0.835191
# syntax       0.955305  1.000000    0.941992     0.950087  0.911687
# vocabulary   0.931669  0.941992    1.000000     0.948627  0.876186
# phraseology  0.917548  0.950087    0.948627     1.000000  0.935491
# grammar      0.835191  0.911687    0.876186     0.935491  1.000000
# conventions  0.901316  0.922952    0.888604     0.874461  0.847946
#
#              conventions
# cohesion        0.901316
# syntax          0.922952
# vocabulary      0.888604
# phraseology     0.874461
# grammar         0.847946
# conventions     1.000000
