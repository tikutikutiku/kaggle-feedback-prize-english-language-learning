# %%
VERSION = '28_v1_01'
MODEL = 'microsoft/deberta-v3-base'
#TEACHER_VERSION = '14_v1_15' # deverta-v2-xlarge
#'bert-large-cased'
#'bert-large-cased-whole-word-masking'
#'albert-large-v2'
#'facebook/bart-large'
#'xlm-roberta-large'
#'deepset/roberta-large-squad2'
#'google/electra-large-discriminator'
#'sentence-transformeres/paraphrase-mpnet-base-v2'
#'funnel-transformer/large-base'
#'facebook/bart-base'
#'distilroberta-base'
#'deepset/roberta-base-squad2'
#'microsoft/deberta-v3-base'
#'roberta-large'
#'roberta-base'
#'microsoft/deberta-v3-large'
#'microsoft/deberta-base'
LR = 2e-5 #8e-6
HEAD_LR = 2e-4 #2e-5 #8e-6 
SEED = 100
TRN_BS = 8
VAL_BS = 8
ACCUM_STEP = 1
HIDDEN_DROP_PROB = 0
P_DROP = 0
RNN = 'none'
WARMUP_RATIO = 0.1
HEAD = 'simple'
AUG = 'false'
MIXUP_ALPHA = 0
P_AUG = 0
AUG_STOP_EPOCH = 0
MSD = 'false'
POOLING = 'mean' #'transformer+mean' #'attention' #'weighted_layer'
NUM_POOLING_LAYERS = 4 #1
MULTI_LAYERS = 1
EVAL_STEP_START_EPOCH = -1
EVAL_STEP = -1
NUM_LABELS = 1 #6
NUM_LABELS_2 = -1
FP16 = 'true'
WD = 0.01
FREEZE = 'false'
MULTI_TASK = 'false' 
W_MT = 0 
AWP = 'false'
AWP_LR = 0
AWP_EPS = 0
AWP_START_EPOCH = -1
#PRETRAINED_DETECTOR_PATH = f'../../input/tascj/result/deberta_base_fold0.pth'
PRETRAINED_DETECTOR_PATH = 'none' #f'../../05_Detection/exp/result/05_v2_09/model_seed100_fold0_swa.pth'
MASK_PROB = 0 #0.8
MASK_RATIO = 0 #0.3
SCHEDULER = 'cosine_hard'
CP = 'true' #'false'
WINDOW_SIZE = -1
INNER_LEN = -1
EDGE_LEN = -1
MAX_LEN = 512

GRAD_CLIP = 1

LOSS = 'smoothl1'#'mse'

CROP_PROB = 0 #1.0

USE_STATS = 'false' #'true'
USE_SEPARATE_HEAD = 'false'

LOW_LOSS_THR = 0.5
OOF_DF_PATH = '../../14_Baseline4/exp/result/14_v1_01/oof_df.csv'

# %% [markdown]
# # Train

# %%
MODE = 'train'
EPOCHS = 5
STOP_EPOCH = 5
RESTART = 1
NUM_CYCLES = EPOCHS
EVAL_STEP = -1
ADD_FB3 = 'false'
FB3_FOLD_PATH = 'none' #'../../00_EDA/00_v1_02/result/'

for CLASS in [
    'cohesion',
    #'syntax','vocabulary','phraseology','grammar','conventions'
]:
    print("*"*50)
    print(CLASS)
    print("*"*50)
# if True:
#     CLASS = 'none'
    for FOLD in [0]: #[0,1,2,3,4]:
        print("-"*50)
        print("FOLD = ", FOLD)
        print("-"*50)
        INPUT_PATH = '../../00_EDA/00_v1_12/result/' #'../../input/feedback-prize-english-language-learning/'
        FOLD_PATH = '../../00_EDA/00_v1_02/result/'
        #INPUT_PATH = f'../../99_Ensemble/99_v1_03/result/99_v1_03_03_pseudo_fold{FOLD}.csv'
        #INPUT_PATH = f'../../99_Ensemble/99_v1_03/result/99_v1_03_03_{TEACHER_VERSION}_pseudo_fold{FOLD}.csv'
        #FOLD_PATH = '../../00_EDA/00_v1_08/result/' # for pseudo-label
        PRETRAIN_PATH = 'none'
        # !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
        --lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
        --epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
        --accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
        --mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
        --msd $MSD --multi_layers $MULTI_LAYERS \
        --eval_step_start_epoch $EVAL_STEP_START_EPOCH --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
        --num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
        --restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
        --mt $MULTI_TASK --w_mt $W_MT \
        --awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
        --pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
        --scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
        --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN \
        --gradient_clip_val $GRAD_CLIP \
        --input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN \
        --crop_prob $CROP_PROB --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS --class_name $CLASS \
        --add_fb3 $ADD_FB3 --fb3_fold_path $FB3_FOLD_PATH --use_stats $USE_STATS \
        --use_separate_head $USE_SEPARATE_HEAD --low_loss_thr $LOW_LOSS_THR --oof_df_path $OOF_DF_PATH
# Out:
# **************************************************
# cohesion
# **************************************************
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3128, 13)
# val_df.shape =  (783, 13)
# trn_df.shape =  (3020, 13)
# 2022-11-13 16:29:07.474113: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-13 16:29:07.474137: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['cohesion']
# self.warmup_ratio =  0.1
# self.num_train_steps =  1887
# num_warmup_steps =  188
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 377/377 [02:19<00:00,  2.70it/s, loss=0.361]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.30it/s]
# epoch 1: trn_loss = 0.3609, val_loss = 0.1691, trn_score = 1.0741, val_score = 0.5883
# model_cohesion (best score) saved
# lr :  [8.243288662033432e-06, 8.243288662033432e-06, 8.243288662033432e-05]
# 100%|███████████████████████████████| 377/377 [02:22<00:00,  2.65it/s, loss=0.1]
# 100%|███████████████████████████████████████████| 98/98 [00:23<00:00,  4.23it/s]
# epoch 2: trn_loss = 0.1000, val_loss = 0.1337, trn_score = 0.4477, val_score = 0.5214
# model_cohesion (best score) saved
# lr :  [5.026712921152283e-06, 5.026712921152283e-06, 5.0267129211522834e-05]
# 100%|████████████████████████████| 377/377 [02:23<00:00,  2.62it/s, loss=0.0947]
# 100%|███████████████████████████████████████████| 98/98 [00:23<00:00,  4.23it/s]
# epoch 3: trn_loss = 0.0947, val_loss = 0.1206, trn_score = 0.4357, val_score = 0.4939
# model_cohesion (best score) saved
# lr :  [2.3926388973639367e-06, 2.3926388973639367e-06, 2.3926388973639367e-05]
# 100%|████████████████████████████| 377/377 [02:23<00:00,  2.62it/s, loss=0.0815]
# 100%|███████████████████████████████████████████| 98/98 [00:23<00:00,  4.22it/s]
# epoch 4: trn_loss = 0.0815, val_loss = 0.1172, trn_score = 0.4040, val_score = 0.4867
# model_cohesion (best score) saved
# lr :  [6.495854067914764e-07, 6.495854067914764e-07, 6.495854067914764e-06]
# 100%|████████████████████████████| 377/377 [02:22<00:00,  2.65it/s, loss=0.0718]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.30it/s]
# epoch 5: trn_loss = 0.0718, val_loss = 0.1173, trn_score = 0.3790, val_score = 0.4867

# %%
MODE = 'train'
EPOCHS = 5
STOP_EPOCH = 5
RESTART = 1
NUM_CYCLES = EPOCHS
EVAL_STEP = -1
ADD_FB3 = 'false'
FB3_FOLD_PATH = 'none' #'../../00_EDA/00_v1_02/result/'

for CLASS in [
    'cohesion',
    'syntax','vocabulary','phraseology','grammar','conventions'
]:
    print("*"*50)
    print(CLASS)
    print("*"*50)
# if True:
#     CLASS = 'none'
    for FOLD in [0,1,2,3,4]:
        if CLASS=='cohesion' and FOLD==0:
            continue
        print("-"*50)
        print("FOLD = ", FOLD)
        print("-"*50)
        INPUT_PATH = '../../00_EDA/00_v1_12/result/' #'../../input/feedback-prize-english-language-learning/'
        FOLD_PATH = '../../00_EDA/00_v1_02/result/'
        #INPUT_PATH = f'../../99_Ensemble/99_v1_03/result/99_v1_03_03_pseudo_fold{FOLD}.csv'
        #INPUT_PATH = f'../../99_Ensemble/99_v1_03/result/99_v1_03_03_{TEACHER_VERSION}_pseudo_fold{FOLD}.csv'
        #FOLD_PATH = '../../00_EDA/00_v1_08/result/' # for pseudo-label
        PRETRAIN_PATH = 'none'
        # !python ../$VERSION/train.py --model $MODEL --version $VERSION --fold_path $FOLD_PATH --fold $FOLD --seed $SEED \
        --lr $LR --head_lr $HEAD_LR --trn_batch_size $TRN_BS --val_batch_size $VAL_BS \
        --epochs $EPOCHS --hidden_drop_prob $HIDDEN_DROP_PROB --p_drop $P_DROP \
        --accumulate_grad_batches $ACCUM_STEP --rnn $RNN --warmup_ratio $WARMUP_RATIO --loss $LOSS --aug $AUG --head $HEAD \
        --mixup_alpha $MIXUP_ALPHA --p_aug $P_AUG --aug_stop_epoch $AUG_STOP_EPOCH \
        --msd $MSD --multi_layers $MULTI_LAYERS \
        --eval_step_start_epoch $EVAL_STEP_START_EPOCH --eval_step $EVAL_STEP --stop_epoch $STOP_EPOCH \
        --num_labels $NUM_LABELS --num_labels_2 $NUM_LABELS_2 \
        --restart_epoch $RESTART --fp16 $FP16 --weight_decay $WD --freeze_layers $FREEZE \
        --mt $MULTI_TASK --w_mt $W_MT \
        --awp $AWP --awp_lr $AWP_LR --awp_eps $AWP_EPS --awp_start_epoch $AWP_START_EPOCH \
        --pretrained_detector_path $PRETRAINED_DETECTOR_PATH --mask_prob $MASK_PROB --mask_ratio $MASK_RATIO \
        --scheduler $SCHEDULER --num_cycles $NUM_CYCLES --check_pointing $CP \
        --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN \
        --gradient_clip_val $GRAD_CLIP \
        --input_path $INPUT_PATH --mode $MODE --pretrain_path $PRETRAIN_PATH --max_length $MAX_LEN \
        --crop_prob $CROP_PROB --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS --class_name $CLASS \
        --add_fb3 $ADD_FB3 --fb3_fold_path $FB3_FOLD_PATH --use_stats $USE_STATS \
        --use_separate_head $USE_SEPARATE_HEAD --low_loss_thr $LOW_LOSS_THR --oof_df_path $OOF_DF_PATH
# Out:
# **************************************************
# cohesion
# **************************************************
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# trn_df.shape =  (3016, 13)
# 2022-11-15 00:21:42.619385: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 00:21:42.619409: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['cohesion']
# self.warmup_ratio =  0.1
# self.num_train_steps =  1885
# num_warmup_steps =  188
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 377/377 [02:20<00:00,  2.68it/s, loss=0.273]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.27it/s]
# epoch 1: trn_loss = 0.2733, val_loss = 0.1107, trn_score = 0.8472, val_score = 0.4717
# model_cohesion (best score) saved
# lr :  [8.223018859218893e-06, 8.223018859218893e-06, 8.223018859218893e-05]
# 100%|████████████████████████████| 377/377 [02:22<00:00,  2.64it/s, loss=0.0988]
# 100%|███████████████████████████████████████████| 98/98 [00:23<00:00,  4.24it/s]
# epoch 2: trn_loss = 0.0988, val_loss = 0.1173, trn_score = 0.4451, val_score = 0.4865
# lr :  [4.973303167998688e-06, 4.973303167998688e-06, 4.9733031679986874e-05]
# 100%|████████████████████████████| 377/377 [02:24<00:00,  2.61it/s, loss=0.0882]
# 100%|███████████████████████████████████████████| 98/98 [00:23<00:00,  4.22it/s]
# epoch 3: trn_loss = 0.0882, val_loss = 0.1053, trn_score = 0.4201, val_score = 0.4594
# model_cohesion (best score) saved
# lr :  [2.3263499099903286e-06, 2.3263499099903286e-06, 2.3263499099903286e-05]
# 100%|████████████████████████████| 377/377 [02:23<00:00,  2.62it/s, loss=0.0771]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.31it/s]
# epoch 4: trn_loss = 0.0771, val_loss = 0.1137, trn_score = 0.3928, val_score = 0.4784
# lr :  [5.995611565178305e-07, 5.995611565178305e-07, 5.995611565178305e-06]
# 100%|████████████████████████████| 377/377 [02:23<00:00,  2.62it/s, loss=0.0623]
# 100%|███████████████████████████████████████████| 98/98 [00:23<00:00,  4.25it/s]
# epoch 5: trn_loss = 0.0623, val_loss = 0.1143, trn_score = 0.3531, val_score = 0.4794
#
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# trn_df.shape =  (3021, 13)
# 2022-11-15 00:35:55.069548: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 00:35:55.069572: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['cohesion']
# self.warmup_ratio =  0.1
# self.num_train_steps =  1888
# num_warmup_steps =  188
# lr :  [0.0, 0.0, 0.0]
# 100%|███████████████████████████████| 377/377 [02:24<00:00,  2.60it/s, loss=0.3]
# 100%|███████████████████████████████████████████| 98/98 [00:23<00:00,  4.18it/s]
# epoch 1: trn_loss = 0.2999, val_loss = 0.1570, trn_score = 0.9164, val_score = 0.5656
# model_cohesion (best score) saved
# lr :  [8.253408470979212e-06, 8.253408470979212e-06, 8.253408470979211e-05]
# 100%|█████████████████████████████| 377/377 [02:24<00:00,  2.61it/s, loss=0.101]
# 100%|███████████████████████████████████████████| 98/98 [00:23<00:00,  4.24it/s]
# epoch 2: trn_loss = 0.1008, val_loss = 0.1197, trn_score = 0.4497, val_score = 0.4905
# model_cohesion (best score) saved
# lr :  [5.053441566002211e-06, 5.053441566002211e-06, 5.05344156600221e-05]
# 100%|████████████████████████████| 377/377 [02:23<00:00,  2.62it/s, loss=0.0941]
# 100%|███████████████████████████████████████████| 98/98 [00:23<00:00,  4.24it/s]
# epoch 3: trn_loss = 0.0941, val_loss = 0.1172, trn_score = 0.4343, val_score = 0.4853
# model_cohesion (best score) saved
# lr :  [2.4260258184535747e-06, 2.4260258184535747e-06, 2.4260258184535744e-05]
# 100%|████████████████████████████| 377/377 [02:23<00:00,  2.62it/s, loss=0.0812]
# 100%|███████████████████████████████████████████| 98/98 [00:23<00:00,  4.23it/s]
# epoch 4: trn_loss = 0.0812, val_loss = 0.1258, trn_score = 0.4032, val_score = 0.5042
# lr :  [6.752777059564431e-07, 6.752777059564431e-07, 6.75277705956443e-06]
# 100%|████████████████████████████| 377/377 [02:23<00:00,  2.62it/s, loss=0.0741]
# 100%|███████████████████████████████████████████| 98/98 [00:23<00:00,  4.23it/s]
# epoch 5: trn_loss = 0.0741, val_loss = 0.1254, trn_score = 0.3853, val_score = 0.5024
#
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# trn_df.shape =  (3023, 13)
# 2022-11-15 00:50:14.695607: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 00:50:14.695629: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['cohesion']
# self.warmup_ratio =  0.1
# self.num_train_steps =  1889
# num_warmup_steps =  188
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 377/377 [02:24<00:00,  2.60it/s, loss=0.321]
# 100%|███████████████████████████████████████████| 98/98 [00:23<00:00,  4.17it/s]
# epoch 1: trn_loss = 0.3209, val_loss = 0.1428, trn_score = 0.9620, val_score = 0.5388
# model_cohesion (best score) saved
# lr :  [8.263518223330698e-06, 8.263518223330698e-06, 8.263518223330697e-05]
# 100%|████████████████████████████| 377/377 [02:24<00:00,  2.61it/s, loss=0.0996]
# 100%|███████████████████████████████████████████| 98/98 [00:23<00:00,  4.20it/s]
# epoch 2: trn_loss = 0.0996, val_loss = 0.1218, trn_score = 0.4469, val_score = 0.4946
# model_cohesion (best score) saved
# lr :  [5.080185570896894e-06, 5.080185570896894e-06, 5.080185570896894e-05]
# 100%|████████████████████████████| 377/377 [02:24<00:00,  2.62it/s, loss=0.0871]
# 100%|███████████████████████████████████████████| 98/98 [00:23<00:00,  4.25it/s]
# epoch 3: trn_loss = 0.0871, val_loss = 0.1176, trn_score = 0.4178, val_score = 0.4858
# model_cohesion (best score) saved
# lr :  [2.459572338592194e-06, 2.459572338592194e-06, 2.459572338592194e-05]
# 100%|████████████████████████████| 377/377 [02:23<00:00,  2.63it/s, loss=0.0808]
# 100%|███████████████████████████████████████████| 98/98 [00:23<00:00,  4.22it/s]
# epoch 4: trn_loss = 0.0808, val_loss = 0.1173, trn_score = 0.4022, val_score = 0.4850
# model_cohesion (best score) saved
# lr :  [7.014194982999467e-07, 7.014194982999467e-07, 7.014194982999467e-06]
# 100%|████████████████████████████| 377/377 [02:23<00:00,  2.63it/s, loss=0.0667]
# 100%|███████████████████████████████████████████| 98/98 [00:23<00:00,  4.23it/s]
# epoch 5: trn_loss = 0.0667, val_loss = 0.1235, trn_score = 0.3655, val_score = 0.4982
#
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# trn_df.shape =  (3024, 13)
# 2022-11-15 01:04:36.242296: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 01:04:36.242323: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['cohesion']
# self.warmup_ratio =  0.1
# self.num_train_steps =  1890
# num_warmup_steps =  189
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 378/378 [02:24<00:00,  2.61it/s, loss=0.303]
# 100%|███████████████████████████████████████████| 98/98 [00:23<00:00,  4.17it/s]
# epoch 1: trn_loss = 0.3031, val_loss = 0.1273, trn_score = 0.9067, val_score = 0.5064
# model_cohesion (best score) saved
# lr :  [8.263518223330698e-06, 8.263518223330698e-06, 8.263518223330697e-05]
# 100%|█████████████████████████████| 378/378 [02:25<00:00,  2.60it/s, loss=0.102]
# 100%|███████████████████████████████████████████| 98/98 [00:23<00:00,  4.23it/s]
# epoch 2: trn_loss = 0.1021, val_loss = 0.1137, trn_score = 0.4528, val_score = 0.4781
# model_cohesion (best score) saved
# lr :  [5.000000000000007e-06, 5.000000000000007e-06, 5.000000000000007e-05]
# 100%|████████████████████████████| 378/378 [02:24<00:00,  2.62it/s, loss=0.0869]
# 100%|███████████████████████████████████████████| 98/98 [00:23<00:00,  4.23it/s]
# epoch 3: trn_loss = 0.0869, val_loss = 0.1135, trn_score = 0.4171, val_score = 0.4772
# model_cohesion (best score) saved
# lr :  [2.339555568810221e-06, 2.339555568810221e-06, 2.339555568810221e-05]
# 100%|█████████████████████████████| 378/378 [02:24<00:00,  2.62it/s, loss=0.081]
# 100%|███████████████████████████████████████████| 98/98 [00:23<00:00,  4.23it/s]
# epoch 4: trn_loss = 0.0810, val_loss = 0.1174, trn_score = 0.4029, val_score = 0.4859
# lr :  [6.030737921409169e-07, 6.030737921409169e-07, 6.030737921409169e-06]
# 100%|████████████████████████████| 378/378 [02:23<00:00,  2.63it/s, loss=0.0633]
# 100%|███████████████████████████████████████████| 98/98 [00:23<00:00,  4.24it/s]
# epoch 5: trn_loss = 0.0633, val_loss = 0.1201, trn_score = 0.3559, val_score = 0.4913
#
# **************************************************
# syntax
# **************************************************
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3128, 13)
# val_df.shape =  (783, 13)
# trn_df.shape =  (3049, 13)
# 2022-11-15 01:18:57.860110: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 01:18:57.860134: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['syntax']
# self.warmup_ratio =  0.1
# self.num_train_steps =  1905
# num_warmup_steps =  190
# lr :  [0.0, 0.0, 0.0]
# 100%|██████████████████████████████| 381/381 [02:26<00:00,  2.60it/s, loss=0.34]
# 100%|███████████████████████████████████████████| 98/98 [00:23<00:00,  4.17it/s]
# epoch 1: trn_loss = 0.3397, val_loss = 0.0988, trn_score = 1.0263, val_score = 0.4451
# model_syntax (best score) saved
# lr :  [8.22344377046254e-06, 8.22344377046254e-06, 8.22344377046254e-05]
# 100%|████████████████████████████| 381/381 [02:25<00:00,  2.61it/s, loss=0.0855]
# 100%|███████████████████████████████████████████| 98/98 [00:23<00:00,  4.23it/s]
# epoch 2: trn_loss = 0.0855, val_loss = 0.1083, trn_score = 0.4135, val_score = 0.4660
# lr :  [4.973583119937069e-06, 4.973583119937069e-06, 4.973583119937069e-05]
# 100%|████████████████████████████| 381/381 [02:24<00:00,  2.64it/s, loss=0.0808]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.27it/s]
# epoch 3: trn_loss = 0.0808, val_loss = 0.1001, trn_score = 0.4023, val_score = 0.4482
# lr :  [2.3264883431581875e-06, 2.3264883431581875e-06, 2.3264883431581876e-05]
# 100%|████████████████████████████| 381/381 [02:24<00:00,  2.64it/s, loss=0.0779]
# 100%|███████████████████████████████████████████| 98/98 [00:23<00:00,  4.24it/s]
# epoch 4: trn_loss = 0.0779, val_loss = 0.0987, trn_score = 0.3951, val_score = 0.4449
# model_syntax (best score) saved
# lr :  [5.995979722030476e-07, 5.995979722030476e-07, 5.995979722030476e-06]
# 100%|████████████████████████████| 381/381 [02:25<00:00,  2.63it/s, loss=0.0658]
# 100%|███████████████████████████████████████████| 98/98 [00:23<00:00,  4.24it/s]
# epoch 5: trn_loss = 0.0658, val_loss = 0.1019, trn_score = 0.3630, val_score = 0.4520
#
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# trn_df.shape =  (3053, 13)
# 2022-11-15 01:33:28.406563: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 01:33:28.406677: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['syntax']
# self.warmup_ratio =  0.1
# self.num_train_steps =  1908
# num_warmup_steps =  190
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 381/381 [02:26<00:00,  2.61it/s, loss=0.248]
# 100%|███████████████████████████████████████████| 98/98 [00:23<00:00,  4.22it/s]
# epoch 1: trn_loss = 0.2481, val_loss = 0.1042, trn_score = 0.7986, val_score = 0.4574
# model_syntax (best score) saved
# lr :  [8.253514384354706e-06, 8.253514384354706e-06, 8.253514384354707e-05]
# 100%|████████████████████████████| 381/381 [02:24<00:00,  2.63it/s, loss=0.0861]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.36it/s]
# epoch 2: trn_loss = 0.0861, val_loss = 0.1008, trn_score = 0.4153, val_score = 0.4504
# model_syntax (best score) saved
# lr :  [5.0528806661940945e-06, 5.0528806661940945e-06, 5.052880666194094e-05]
# 100%|████████████████████████████| 381/381 [02:23<00:00,  2.65it/s, loss=0.0775]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.35it/s]
# epoch 3: trn_loss = 0.0775, val_loss = 0.0996, trn_score = 0.3937, val_score = 0.4476
# model_syntax (best score) saved
# lr :  [2.425112822988611e-06, 2.425112822988611e-06, 2.425112822988611e-05]
# 100%|████████████████████████████| 381/381 [02:23<00:00,  2.66it/s, loss=0.0713]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.37it/s]
# epoch 4: trn_loss = 0.0713, val_loss = 0.1007, trn_score = 0.3778, val_score = 0.4503
# lr :  [6.745007703645023e-07, 6.745007703645023e-07, 6.7450077036450235e-06]
# 100%|████████████████████████████| 381/381 [02:23<00:00,  2.66it/s, loss=0.0622]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.37it/s]
# epoch 5: trn_loss = 0.0622, val_loss = 0.1049, trn_score = 0.3527, val_score = 0.4599
#
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# trn_df.shape =  (3053, 13)
# 2022-11-15 01:47:58.467646: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 01:47:58.467710: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['syntax']
# self.warmup_ratio =  0.1
# self.num_train_steps =  1908
# num_warmup_steps =  190
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 381/381 [02:25<00:00,  2.63it/s, loss=0.272]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.27it/s]
# epoch 1: trn_loss = 0.2716, val_loss = 0.1048, trn_score = 0.8667, val_score = 0.4599
# model_syntax (best score) saved
# lr :  [8.253514384354706e-06, 8.253514384354706e-06, 8.253514384354707e-05]
# 100%|████████████████████████████| 381/381 [02:25<00:00,  2.63it/s, loss=0.0936]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.31it/s]
# epoch 2: trn_loss = 0.0936, val_loss = 0.1147, trn_score = 0.4329, val_score = 0.4816
# lr :  [5.0528806661940945e-06, 5.0528806661940945e-06, 5.052880666194094e-05]
# 100%|████████████████████████████| 381/381 [02:23<00:00,  2.65it/s, loss=0.0808]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.32it/s]
# epoch 3: trn_loss = 0.0808, val_loss = 0.1007, trn_score = 0.4020, val_score = 0.4511
# model_syntax (best score) saved
# lr :  [2.425112822988611e-06, 2.425112822988611e-06, 2.425112822988611e-05]
# 100%|████████████████████████████| 381/381 [02:23<00:00,  2.66it/s, loss=0.0749]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.32it/s]
# epoch 4: trn_loss = 0.0749, val_loss = 0.0987, trn_score = 0.3871, val_score = 0.4461
# model_syntax (best score) saved
# lr :  [6.745007703645023e-07, 6.745007703645023e-07, 6.7450077036450235e-06]
# 100%|████████████████████████████| 381/381 [02:24<00:00,  2.64it/s, loss=0.0679]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.32it/s]
# epoch 5: trn_loss = 0.0679, val_loss = 0.1044, trn_score = 0.3686, val_score = 0.4593
#
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# trn_df.shape =  (3047, 13)
# 2022-11-15 02:02:24.437569: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 02:02:24.437655: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['syntax']
# self.warmup_ratio =  0.1
# self.num_train_steps =  1904
# num_warmup_steps =  190
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 380/380 [02:25<00:00,  2.61it/s, loss=0.299]
# 100%|███████████████████████████████████████████| 98/98 [00:23<00:00,  4.25it/s]
# epoch 1: trn_loss = 0.2985, val_loss = 0.1223, trn_score = 0.9204, val_score = 0.4977
# model_syntax (best score) saved
# lr :  [8.303644856968564e-06, 8.303644856968564e-06, 8.303644856968564e-05]
# 100%|████████████████████████████| 380/380 [02:25<00:00,  2.61it/s, loss=0.0883]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.29it/s]
# epoch 2: trn_loss = 0.0883, val_loss = 0.0984, trn_score = 0.4204, val_score = 0.4441
# model_syntax (best score) saved
# lr :  [5.106193242708518e-06, 5.106193242708518e-06, 5.106193242708518e-05]
# 100%|████████████████████████████| 380/380 [02:24<00:00,  2.63it/s, loss=0.0792]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.31it/s]
# epoch 3: trn_loss = 0.0792, val_loss = 0.1042, trn_score = 0.3982, val_score = 0.4571
# lr :  [2.472042427466759e-06, 2.472042427466759e-06, 2.4720424274667588e-05]
# 100%|████████████████████████████| 380/380 [02:23<00:00,  2.64it/s, loss=0.0747]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.33it/s]
# epoch 4: trn_loss = 0.0747, val_loss = 0.1024, trn_score = 0.3866, val_score = 0.4532
# lr :  [7.043958952692253e-07, 7.043958952692253e-07, 7.043958952692254e-06]
# 100%|████████████████████████████| 380/380 [02:23<00:00,  2.65it/s, loss=0.0655]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.34it/s]
# epoch 5: trn_loss = 0.0655, val_loss = 0.0985, trn_score = 0.3619, val_score = 0.4447
#
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# trn_df.shape =  (3054, 13)
# 2022-11-15 02:16:50.360639: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 02:16:50.360723: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['syntax']
# self.warmup_ratio =  0.1
# self.num_train_steps =  1908
# num_warmup_steps =  190
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 381/381 [02:24<00:00,  2.64it/s, loss=0.267]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.26it/s]
# epoch 1: trn_loss = 0.2672, val_loss = 0.1091, trn_score = 0.8434, val_score = 0.4686
# model_syntax (best score) saved
# lr :  [8.253514384354706e-06, 8.253514384354706e-06, 8.253514384354707e-05]
# 100%|████████████████████████████| 381/381 [02:25<00:00,  2.63it/s, loss=0.0907]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.31it/s]
# epoch 2: trn_loss = 0.0907, val_loss = 0.1181, trn_score = 0.4263, val_score = 0.4882
# lr :  [5.0528806661940945e-06, 5.0528806661940945e-06, 5.052880666194094e-05]
# 100%|████████████████████████████| 381/381 [02:23<00:00,  2.65it/s, loss=0.0803]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.33it/s]
# epoch 3: trn_loss = 0.0803, val_loss = 0.1002, trn_score = 0.4009, val_score = 0.4489
# model_syntax (best score) saved
# lr :  [2.425112822988611e-06, 2.425112822988611e-06, 2.425112822988611e-05]
# 100%|████████████████████████████| 381/381 [02:23<00:00,  2.65it/s, loss=0.0753]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.32it/s]
# epoch 4: trn_loss = 0.0753, val_loss = 0.1005, trn_score = 0.3882, val_score = 0.4493
# lr :  [6.745007703645023e-07, 6.745007703645023e-07, 6.7450077036450235e-06]
# 100%|████████████████████████████| 381/381 [02:23<00:00,  2.65it/s, loss=0.0655]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.42it/s]
# epoch 5: trn_loss = 0.0655, val_loss = 0.1003, trn_score = 0.3620, val_score = 0.4494
#
# **************************************************
# vocabulary
# **************************************************
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3128, 13)
# val_df.shape =  (783, 13)
# trn_df.shape =  (3076, 13)
# 2022-11-15 02:31:12.398306: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 02:31:12.398410: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['vocabulary']
# self.warmup_ratio =  0.1
# self.num_train_steps =  1922
# num_warmup_steps =  192
# lr :  [0.0, 0.0, 0.0]
# 100%|██████████████████████████████| 384/384 [02:24<00:00,  2.66it/s, loss=0.36]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.33it/s]
# epoch 1: trn_loss = 0.3605, val_loss = 0.0826, trn_score = 1.0976, val_score = 0.4075
# model_vocabulary (best score) saved
# lr :  [8.28339242415468e-06, 8.28339242415468e-06, 8.283392424154679e-05]
# 100%|████████████████████████████| 384/384 [02:25<00:00,  2.65it/s, loss=0.0828]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.38it/s]
# epoch 2: trn_loss = 0.0828, val_loss = 0.0817, trn_score = 0.4072, val_score = 0.4051
# model_vocabulary (best score) saved
# lr :  [5.052513228551044e-06, 5.052513228551044e-06, 5.0525132285510435e-05]
# 100%|████████████████████████████| 384/384 [02:23<00:00,  2.67it/s, loss=0.0756]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.38it/s]
# epoch 3: trn_loss = 0.0756, val_loss = 0.0808, trn_score = 0.3889, val_score = 0.4028
# model_vocabulary (best score) saved
# lr :  [2.404792630296642e-06, 2.404792630296642e-06, 2.4047926302966418e-05]
# 100%|████████████████████████████| 384/384 [02:23<00:00,  2.67it/s, loss=0.0706]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.32it/s]
# epoch 4: trn_loss = 0.0706, val_loss = 0.0793, trn_score = 0.3758, val_score = 0.3988
# model_vocabulary (best score) saved
# lr :  [6.523165634380047e-07, 6.523165634380047e-07, 6.523165634380046e-06]
# 100%|████████████████████████████| 384/384 [02:24<00:00,  2.66it/s, loss=0.0591]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.32it/s]
# epoch 5: trn_loss = 0.0591, val_loss = 0.0816, trn_score = 0.3439, val_score = 0.4047
#
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# trn_df.shape =  (3075, 13)
# 2022-11-15 02:45:34.042439: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 02:45:34.042462: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['vocabulary']
# self.warmup_ratio =  0.1
# self.num_train_steps =  1921
# num_warmup_steps =  192
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 384/384 [02:26<00:00,  2.62it/s, loss=0.254]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.40it/s]
# epoch 1: trn_loss = 0.2545, val_loss = 0.0904, trn_score = 0.8225, val_score = 0.4263
# model_vocabulary (best score) saved
# lr :  [8.273460192415654e-06, 8.273460192415654e-06, 8.273460192415653e-05]
# 100%|████████████████████████████| 384/384 [02:23<00:00,  2.68it/s, loss=0.0774]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.46it/s]
# epoch 2: trn_loss = 0.0774, val_loss = 0.0856, trn_score = 0.3936, val_score = 0.4155
# model_vocabulary (best score) saved
# lr :  [5.0262490199847015e-06, 5.0262490199847015e-06, 5.026249019984701e-05]
# 100%|████████████████████████████| 384/384 [02:21<00:00,  2.71it/s, loss=0.0698]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.49it/s]
# epoch 3: trn_loss = 0.0698, val_loss = 0.0823, trn_score = 0.3738, val_score = 0.4069
# model_vocabulary (best score) saved
# lr :  [2.372095919150562e-06, 2.372095919150562e-06, 2.372095919150562e-05]
# 100%|████████████████████████████| 384/384 [02:21<00:00,  2.71it/s, loss=0.0657]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.47it/s]
# epoch 4: trn_loss = 0.0657, val_loss = 0.0843, trn_score = 0.3626, val_score = 0.4121
# lr :  [6.274757046009861e-07, 6.274757046009861e-07, 6.27475704600986e-06]
# 100%|████████████████████████████| 384/384 [02:21<00:00,  2.71it/s, loss=0.0552]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.49it/s]
# epoch 5: trn_loss = 0.0552, val_loss = 0.0850, trn_score = 0.3322, val_score = 0.4140
#
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# trn_df.shape =  (3081, 13)
# 2022-11-15 02:59:44.919456: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 02:59:44.919479: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['vocabulary']
# self.warmup_ratio =  0.1
# self.num_train_steps =  1925
# num_warmup_steps =  192
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 385/385 [02:23<00:00,  2.68it/s, loss=0.292]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.40it/s]
# epoch 1: trn_loss = 0.2918, val_loss = 0.0903, trn_score = 0.9217, val_score = 0.4260
# model_vocabulary (best score) saved
# lr :  [8.223859858138691e-06, 8.223859858138691e-06, 8.223859858138691e-05]
# 100%|████████████████████████████| 385/385 [02:25<00:00,  2.65it/s, loss=0.0794]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.33it/s]
# epoch 2: trn_loss = 0.0794, val_loss = 0.0943, trn_score = 0.3985, val_score = 0.4359
# lr :  [4.97385726147876e-06, 4.97385726147876e-06, 4.9738572614787594e-05]
# 100%|████████████████████████████| 385/385 [02:25<00:00,  2.66it/s, loss=0.0735]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.33it/s]
# epoch 3: trn_loss = 0.0735, val_loss = 0.0854, trn_score = 0.3835, val_score = 0.4137
# model_vocabulary (best score) saved
# lr :  [2.3266239040884597e-06, 2.3266239040884597e-06, 2.3266239040884597e-05]
# 100%|████████████████████████████| 385/385 [02:25<00:00,  2.65it/s, loss=0.0661]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.32it/s]
# epoch 4: trn_loss = 0.0661, val_loss = 0.0896, trn_score = 0.3638, val_score = 0.4242
# lr :  [5.996340241691834e-07, 5.996340241691834e-07, 5.996340241691834e-06]
# 100%|████████████████████████████| 385/385 [02:25<00:00,  2.65it/s, loss=0.0577]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.32it/s]
# epoch 5: trn_loss = 0.0577, val_loss = 0.0886, trn_score = 0.3397, val_score = 0.4214
#
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# trn_df.shape =  (3081, 13)
# 2022-11-15 03:14:04.941876: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 03:14:04.941898: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['vocabulary']
# self.warmup_ratio =  0.1
# self.num_train_steps =  1925
# num_warmup_steps =  192
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 385/385 [02:26<00:00,  2.63it/s, loss=0.307]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.29it/s]
# epoch 1: trn_loss = 0.3072, val_loss = 0.0934, trn_score = 0.9692, val_score = 0.4325
# model_vocabulary (best score) saved
# lr :  [8.223859858138691e-06, 8.223859858138691e-06, 8.223859858138691e-05]
# 100%|████████████████████████████| 385/385 [02:25<00:00,  2.64it/s, loss=0.0775]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.45it/s]
# epoch 2: trn_loss = 0.0775, val_loss = 0.0932, trn_score = 0.3939, val_score = 0.4326
# lr :  [4.97385726147876e-06, 4.97385726147876e-06, 4.9738572614787594e-05]
# 100%|████████████████████████████| 385/385 [02:22<00:00,  2.70it/s, loss=0.0714]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.45it/s]
# epoch 3: trn_loss = 0.0714, val_loss = 0.0881, trn_score = 0.3780, val_score = 0.4201
# model_vocabulary (best score) saved
# lr :  [2.3266239040884597e-06, 2.3266239040884597e-06, 2.3266239040884597e-05]
# 100%|████████████████████████████| 385/385 [02:22<00:00,  2.71it/s, loss=0.0641]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.48it/s]
# epoch 4: trn_loss = 0.0641, val_loss = 0.0892, trn_score = 0.3580, val_score = 0.4228
# lr :  [5.996340241691834e-07, 5.996340241691834e-07, 5.996340241691834e-06]
# 100%|████████████████████████████| 385/385 [02:22<00:00,  2.70it/s, loss=0.0536]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.44it/s]
# epoch 5: trn_loss = 0.0536, val_loss = 0.0914, trn_score = 0.3275, val_score = 0.4280
#
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# trn_df.shape =  (3079, 13)
# 2022-11-15 03:28:16.404353: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 03:28:16.404377: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['vocabulary']
# self.warmup_ratio =  0.1
# self.num_train_steps =  1924
# num_warmup_steps =  192
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 384/384 [02:23<00:00,  2.68it/s, loss=0.269]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.39it/s]
# epoch 1: trn_loss = 0.2687, val_loss = 0.0887, trn_score = 0.8673, val_score = 0.4219
# model_vocabulary (best score) saved
# lr :  [8.303227690653819e-06, 8.303227690653819e-06, 8.303227690653819e-05]
# 100%|████████████████████████████| 384/384 [02:23<00:00,  2.68it/s, loss=0.0834]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.44it/s]
# epoch 2: trn_loss = 0.0834, val_loss = 0.0873, trn_score = 0.4086, val_score = 0.4182
# model_vocabulary (best score) saved
# lr :  [5.105085832767019e-06, 5.105085832767019e-06, 5.1050858327670184e-05]
# 100%|█████████████████████████████| 384/384 [02:22<00:00,  2.70it/s, loss=0.083]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.47it/s]
# epoch 3: trn_loss = 0.0830, val_loss = 0.0891, trn_score = 0.4083, val_score = 0.4227
# lr :  [2.470649391874017e-06, 2.470649391874017e-06, 2.470649391874017e-05]
# 100%|████████████████████████████| 384/384 [02:23<00:00,  2.67it/s, loss=0.0746]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.39it/s]
# epoch 4: trn_loss = 0.0746, val_loss = 0.0901, trn_score = 0.3867, val_score = 0.4252
# lr :  [7.033038905235812e-07, 7.033038905235812e-07, 7.033038905235812e-06]
# 100%|████████████████████████████| 384/384 [02:24<00:00,  2.66it/s, loss=0.0726]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.33it/s]
# epoch 5: trn_loss = 0.0726, val_loss = 0.0867, trn_score = 0.3811, val_score = 0.4168
# model_vocabulary (best score) saved
#
# **************************************************
# phraseology
# **************************************************
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3128, 13)
# val_df.shape =  (783, 13)
# trn_df.shape =  (3048, 13)
# 2022-11-15 03:42:26.836385: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 03:42:26.836406: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['phraseology']
# self.warmup_ratio =  0.1
# self.num_train_steps =  1905
# num_warmup_steps =  190
# lr :  [0.0, 0.0, 0.0]
# 100%|██████████████████████████████| 381/381 [02:24<00:00,  2.63it/s, loss=0.35]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.27it/s]
# epoch 1: trn_loss = 0.3499, val_loss = 0.1237, trn_score = 1.0770, val_score = 0.4990
# model_phraseology (best score) saved
# lr :  [8.22344377046254e-06, 8.22344377046254e-06, 8.22344377046254e-05]
# 100%|████████████████████████████| 381/381 [02:24<00:00,  2.63it/s, loss=0.0934]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.31it/s]
# epoch 2: trn_loss = 0.0934, val_loss = 0.1064, trn_score = 0.4325, val_score = 0.4623
# model_phraseology (best score) saved
# lr :  [4.973583119937069e-06, 4.973583119937069e-06, 4.973583119937069e-05]
# 100%|████████████████████████████| 381/381 [02:23<00:00,  2.65it/s, loss=0.0841]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.31it/s]
# epoch 3: trn_loss = 0.0841, val_loss = 0.1058, trn_score = 0.4104, val_score = 0.4613
# model_phraseology (best score) saved
# lr :  [2.3264883431581875e-06, 2.3264883431581875e-06, 2.3264883431581876e-05]
# 100%|████████████████████████████| 381/381 [02:23<00:00,  2.66it/s, loss=0.0761]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.45it/s]
# epoch 4: trn_loss = 0.0761, val_loss = 0.1031, trn_score = 0.3903, val_score = 0.4549
# model_phraseology (best score) saved
# lr :  [5.995979722030476e-07, 5.995979722030476e-07, 5.995979722030476e-06]
# 100%|████████████████████████████| 381/381 [02:20<00:00,  2.71it/s, loss=0.0717]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.45it/s]
# epoch 5: trn_loss = 0.0717, val_loss = 0.1023, trn_score = 0.3789, val_score = 0.4534
# model_phraseology (best score) saved
#
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# trn_df.shape =  (3046, 13)
# 2022-11-15 03:56:40.712723: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 03:56:40.712747: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['phraseology']
# self.warmup_ratio =  0.1
# self.num_train_steps =  1903
# num_warmup_steps =  190
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 380/380 [02:21<00:00,  2.68it/s, loss=0.263]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.42it/s]
# epoch 1: trn_loss = 0.2631, val_loss = 0.1102, trn_score = 0.8280, val_score = 0.4710
# model_phraseology (best score) saved
# lr :  [8.293628105848623e-06, 8.293628105848623e-06, 8.293628105848624e-05]
# 100%|████████████████████████████| 380/380 [02:21<00:00,  2.68it/s, loss=0.0871]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.47it/s]
# epoch 2: trn_loss = 0.0871, val_loss = 0.1111, trn_score = 0.4174, val_score = 0.4729
# lr :  [5.079622383396938e-06, 5.079622383396938e-06, 5.079622383396938e-05]
# 100%|████████████████████████████| 380/380 [02:20<00:00,  2.70it/s, loss=0.0827]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.48it/s]
# epoch 3: trn_loss = 0.0827, val_loss = 0.1138, trn_score = 0.4069, val_score = 0.4792
# lr :  [2.4386841933702044e-06, 2.4386841933702044e-06, 2.4386841933702043e-05]
# 100%|████████████████████████████| 380/380 [02:20<00:00,  2.71it/s, loss=0.0752]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.48it/s]
# epoch 4: trn_loss = 0.0752, val_loss = 0.1081, trn_score = 0.3879, val_score = 0.4662
# model_phraseology (best score) saved
# lr :  [6.783988574190347e-07, 6.783988574190347e-07, 6.783988574190348e-06]
# 100%|████████████████████████████| 380/380 [02:21<00:00,  2.69it/s, loss=0.0617]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.44it/s]
# epoch 5: trn_loss = 0.0617, val_loss = 0.1124, trn_score = 0.3513, val_score = 0.4758
#
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# trn_df.shape =  (3034, 13)
# 2022-11-15 04:10:37.587530: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 04:10:37.587554: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['phraseology']
# self.warmup_ratio =  0.1
# self.num_train_steps =  1896
# num_warmup_steps =  189
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 379/379 [02:23<00:00,  2.64it/s, loss=0.296]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.32it/s]
# epoch 1: trn_loss = 0.2962, val_loss = 0.1002, trn_score = 0.9115, val_score = 0.4485
# model_phraseology (best score) saved
# lr :  [8.233318816191233e-06, 8.233318816191233e-06, 8.233318816191232e-05]
# 100%|████████████████████████████| 379/379 [02:23<00:00,  2.65it/s, loss=0.0939]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.39it/s]
# epoch 2: trn_loss = 0.0939, val_loss = 0.1090, trn_score = 0.4338, val_score = 0.4677
# lr :  [5.000000000000007e-06, 5.000000000000007e-06, 5.000000000000007e-05]
# 100%|████████████████████████████| 379/379 [02:21<00:00,  2.67it/s, loss=0.0828]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.38it/s]
# epoch 3: trn_loss = 0.0828, val_loss = 0.0952, trn_score = 0.4071, val_score = 0.4372
# model_phraseology (best score) saved
# lr :  [2.359308201299454e-06, 2.359308201299454e-06, 2.359308201299454e-05]
# 100%|████████████████████████████| 379/379 [02:21<00:00,  2.67it/s, loss=0.0695]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.39it/s]
# epoch 4: trn_loss = 0.0695, val_loss = 0.0935, trn_score = 0.3730, val_score = 0.4333
# model_phraseology (best score) saved
# lr :  [6.242324810447864e-07, 6.242324810447864e-07, 6.242324810447864e-06]
# 100%|█████████████████████████████| 379/379 [02:22<00:00,  2.67it/s, loss=0.063]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.40it/s]
# epoch 5: trn_loss = 0.0630, val_loss = 0.0914, trn_score = 0.3550, val_score = 0.4281
# model_phraseology (best score) saved
#
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# trn_df.shape =  (3053, 13)
# 2022-11-15 04:24:44.350759: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 04:24:44.350782: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['phraseology']
# self.warmup_ratio =  0.1
# self.num_train_steps =  1908
# num_warmup_steps =  190
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 381/381 [02:22<00:00,  2.67it/s, loss=0.301]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.40it/s]
# epoch 1: trn_loss = 0.3014, val_loss = 0.1081, trn_score = 0.9436, val_score = 0.4667
# model_phraseology (best score) saved
# lr :  [8.253514384354706e-06, 8.253514384354706e-06, 8.253514384354707e-05]
# 100%|████████████████████████████| 381/381 [02:21<00:00,  2.69it/s, loss=0.0892]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.45it/s]
# epoch 2: trn_loss = 0.0892, val_loss = 0.1075, trn_score = 0.4228, val_score = 0.4649
# model_phraseology (best score) saved
# lr :  [5.0528806661940945e-06, 5.0528806661940945e-06, 5.052880666194094e-05]
# 100%|████████████████████████████| 381/381 [02:20<00:00,  2.70it/s, loss=0.0756]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.47it/s]
# epoch 3: trn_loss = 0.0756, val_loss = 0.1220, trn_score = 0.3889, val_score = 0.4970
# lr :  [2.425112822988611e-06, 2.425112822988611e-06, 2.425112822988611e-05]
# 100%|█████████████████████████████| 381/381 [02:20<00:00,  2.71it/s, loss=0.065]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.46it/s]
# epoch 4: trn_loss = 0.0650, val_loss = 0.1104, trn_score = 0.3608, val_score = 0.4711
# lr :  [6.745007703645023e-07, 6.745007703645023e-07, 6.7450077036450235e-06]
# 100%|████████████████████████████| 381/381 [02:20<00:00,  2.71it/s, loss=0.0536]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.46it/s]
# epoch 5: trn_loss = 0.0536, val_loss = 0.1148, trn_score = 0.3276, val_score = 0.4810
#
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# trn_df.shape =  (3059, 13)
# 2022-11-15 04:38:41.344482: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 04:38:41.344503: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['phraseology']
# self.warmup_ratio =  0.1
# self.num_train_steps =  1911
# num_warmup_steps =  191
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 382/382 [02:22<00:00,  2.68it/s, loss=0.283]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.36it/s]
# epoch 1: trn_loss = 0.2826, val_loss = 0.1176, trn_score = 0.8817, val_score = 0.4862
# model_phraseology (best score) saved
# lr :  [8.273512218982666e-06, 8.273512218982666e-06, 8.273512218982667e-05]
# 100%|█████████████████████████████| 382/382 [02:23<00:00,  2.66it/s, loss=0.094]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.36it/s]
# epoch 2: trn_loss = 0.0940, val_loss = 0.1076, trn_score = 0.4341, val_score = 0.4659
# model_phraseology (best score) saved
# lr :  [5.0263864896794046e-06, 5.0263864896794046e-06, 5.0263864896794046e-05]
# 100%|█████████████████████████████| 382/382 [02:23<00:00,  2.66it/s, loss=0.083]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.37it/s]
# epoch 3: trn_loss = 0.0830, val_loss = 0.1082, trn_score = 0.4076, val_score = 0.4668
# lr :  [2.372266700196292e-06, 2.372266700196292e-06, 2.3722667001962916e-05]
# 100%|████████████████████████████| 382/382 [02:23<00:00,  2.67it/s, loss=0.0749]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.38it/s]
# epoch 4: trn_loss = 0.0749, val_loss = 0.1108, trn_score = 0.3872, val_score = 0.4734
# lr :  [6.276046208390873e-07, 6.276046208390873e-07, 6.276046208390873e-06]
# 100%|████████████████████████████| 382/382 [02:23<00:00,  2.66it/s, loss=0.0679]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.38it/s]
# epoch 5: trn_loss = 0.0679, val_loss = 0.1131, trn_score = 0.3687, val_score = 0.4787
#
# **************************************************
# grammar
# **************************************************
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3128, 13)
# val_df.shape =  (783, 13)
# trn_df.shape =  (3026, 13)
# ...
# model_grammar (best score) saved
# lr :  [5.08004402843938e-06, 5.08004402843938e-06, 5.0800440284393804e-05]
# 100%|████████████████████████████| 378/378 [02:19<00:00,  2.70it/s, loss=0.0804]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.46it/s]
# epoch 3: trn_loss = 0.0804, val_loss = 0.1159, trn_score = 0.4012, val_score = 0.4848
# lr :  [2.439212469201889e-06, 2.439212469201889e-06, 2.4392124692018893e-05]
# 100%|████████████████████████████| 378/378 [02:19<00:00,  2.71it/s, loss=0.0679]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.47it/s]
# epoch 4: trn_loss = 0.0679, val_loss = 0.1177, trn_score = 0.3686, val_score = 0.4882
# lr :  [6.788080610748404e-07, 6.788080610748404e-07, 6.7880806107484045e-06]
# 100%|████████████████████████████| 378/378 [02:19<00:00,  2.71it/s, loss=0.0531]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.48it/s]
# epoch 5: trn_loss = 0.0531, val_loss = 0.1205, trn_score = 0.3260, val_score = 0.4952
#
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# trn_df.shape =  (3024, 13)
# 2022-11-15 05:49:02.186273: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 05:49:02.186297: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['grammar']
# self.warmup_ratio =  0.1
# self.num_train_steps =  1890
# num_warmup_steps =  189
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 378/378 [02:20<00:00,  2.68it/s, loss=0.274]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.39it/s]
# epoch 1: trn_loss = 0.2739, val_loss = 0.1198, trn_score = 0.8490, val_score = 0.4930
# model_grammar (best score) saved
# lr :  [8.263518223330698e-06, 8.263518223330698e-06, 8.263518223330697e-05]
# 100%|████████████████████████████| 378/378 [02:21<00:00,  2.68it/s, loss=0.0893]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.45it/s]
# epoch 2: trn_loss = 0.0893, val_loss = 0.1187, trn_score = 0.4229, val_score = 0.4907
# model_grammar (best score) saved
# lr :  [5.000000000000007e-06, 5.000000000000007e-06, 5.000000000000007e-05]
# 100%|████████████████████████████| 378/378 [02:20<00:00,  2.70it/s, loss=0.0794]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.45it/s]
# epoch 3: trn_loss = 0.0794, val_loss = 0.1260, trn_score = 0.3987, val_score = 0.5055
# lr :  [2.339555568810221e-06, 2.339555568810221e-06, 2.339555568810221e-05]
# 100%|████████████████████████████| 378/378 [02:21<00:00,  2.67it/s, loss=0.0725]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.34it/s]
# epoch 4: trn_loss = 0.0725, val_loss = 0.1243, trn_score = 0.3811, val_score = 0.5021
# lr :  [6.030737921409169e-07, 6.030737921409169e-07, 6.030737921409169e-06]
# 100%|████████████████████████████| 378/378 [02:21<00:00,  2.66it/s, loss=0.0665]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.34it/s]
# epoch 5: trn_loss = 0.0665, val_loss = 0.1192, trn_score = 0.3648, val_score = 0.4916
#
# **************************************************
# conventions
# **************************************************
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3128, 13)
# val_df.shape =  (783, 13)
# trn_df.shape =  (3052, 13)
# 2022-11-15 06:03:00.035004: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 06:03:00.035029: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['conventions']
# self.warmup_ratio =  0.1
# self.num_train_steps =  1907
# num_warmup_steps =  190
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 381/381 [02:24<00:00,  2.63it/s, loss=0.346]
# 100%|███████████████████████████████████████████| 98/98 [00:23<00:00,  4.26it/s]
# epoch 1: trn_loss = 0.3458, val_loss = 0.0972, trn_score = 1.0598, val_score = 0.4411
# model_conventions (best score) saved
# lr :  [8.243500698330149e-06, 8.243500698330149e-06, 8.243500698330148e-05]
# 100%|█████████████████████████████| 381/381 [02:24<00:00,  2.63it/s, loss=0.089]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.30it/s]
# epoch 2: trn_loss = 0.0890, val_loss = 0.0954, trn_score = 0.4222, val_score = 0.4372
# model_conventions (best score) saved
# lr :  [5.026432633446474e-06, 5.026432633446474e-06, 5.026432633446474e-05]
# 100%|████████████████████████████| 381/381 [02:23<00:00,  2.65it/s, loss=0.0812]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.32it/s]
# epoch 3: trn_loss = 0.0812, val_loss = 0.0943, trn_score = 0.4031, val_score = 0.4346
# model_conventions (best score) saved
# lr :  [2.392079732373086e-06, 2.392079732373086e-06, 2.3920797323730858e-05]
# 100%|█████████████████████████████| 381/381 [02:23<00:00,  2.66it/s, loss=0.075]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.34it/s]
# epoch 4: trn_loss = 0.0750, val_loss = 0.0946, trn_score = 0.3873, val_score = 0.4353
# lr :  [6.490891429512225e-07, 6.490891429512225e-07, 6.490891429512225e-06]
# 100%|█████████████████████████████| 381/381 [02:20<00:00,  2.71it/s, loss=0.068]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.45it/s]
# epoch 5: trn_loss = 0.0680, val_loss = 0.0950, trn_score = 0.3689, val_score = 0.4363
#
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# trn_df.shape =  (3055, 13)
# 2022-11-15 06:17:12.960462: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 06:17:12.960486: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['conventions']
# self.warmup_ratio =  0.1
# self.num_train_steps =  1909
# num_warmup_steps =  190
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 381/381 [02:22<00:00,  2.68it/s, loss=0.256]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.39it/s]
# epoch 1: trn_loss = 0.2556, val_loss = 0.1067, trn_score = 0.8150, val_score = 0.4643
# model_conventions (best score) saved
# lr :  [8.263518223330698e-06, 8.263518223330698e-06, 8.263518223330697e-05]
# 100%|████████████████████████████| 381/381 [02:22<00:00,  2.68it/s, loss=0.0836]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.44it/s]
# epoch 2: trn_loss = 0.0836, val_loss = 0.0967, trn_score = 0.4089, val_score = 0.4412
# model_conventions (best score) saved
# lr :  [5.079343745886571e-06, 5.079343745886571e-06, 5.079343745886571e-05]
# 100%|████████████████████████████| 381/381 [02:20<00:00,  2.70it/s, loss=0.0722]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.44it/s]
# epoch 3: trn_loss = 0.0722, val_loss = 0.1025, trn_score = 0.3800, val_score = 0.4546
# lr :  [2.4583022212072894e-06, 2.4583022212072894e-06, 2.458302221207289e-05]
# 100%|█████████████████████████████| 381/381 [02:20<00:00,  2.71it/s, loss=0.062]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.46it/s]
# epoch 4: trn_loss = 0.0620, val_loss = 0.1036, trn_score = 0.3521, val_score = 0.4576
# lr :  [7.003525931589828e-07, 7.003525931589828e-07, 7.003525931589827e-06]
# 100%|████████████████████████████| 381/381 [02:20<00:00,  2.71it/s, loss=0.0504]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.47it/s]
# epoch 5: trn_loss = 0.0504, val_loss = 0.1062, trn_score = 0.3174, val_score = 0.4635
#
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# trn_df.shape =  (3056, 13)
# 2022-11-15 06:31:10.102472: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 06:31:10.102492: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['conventions']
# self.warmup_ratio =  0.1
# self.num_train_steps =  1910
# num_warmup_steps =  191
# lr :  [0.0, 0.0, 0.0]
# 100%|██████████████████████████████| 382/382 [02:24<00:00,  2.64it/s, loss=0.28]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.30it/s]
# epoch 1: trn_loss = 0.2800, val_loss = 0.1107, trn_score = 0.8783, val_score = 0.4736
# model_conventions (best score) saved
# lr :  [8.263518223330698e-06, 8.263518223330698e-06, 8.263518223330697e-05]
# 100%|████████████████████████████| 382/382 [02:24<00:00,  2.65it/s, loss=0.0988]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.37it/s]
# epoch 2: trn_loss = 0.0988, val_loss = 0.1009, trn_score = 0.4451, val_score = 0.4513
# model_conventions (best score) saved
# lr :  [5.000000000000007e-06, 5.000000000000007e-06, 5.000000000000007e-05]
# 100%|████████████████████████████| 382/382 [02:22<00:00,  2.67it/s, loss=0.0862]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.37it/s]
# epoch 3: trn_loss = 0.0862, val_loss = 0.0991, trn_score = 0.4155, val_score = 0.4476
# model_conventions (best score) saved
# lr :  [2.339555568810221e-06, 2.339555568810221e-06, 2.339555568810221e-05]
# 100%|████████████████████████████| 382/382 [02:22<00:00,  2.67it/s, loss=0.0735]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.38it/s]
# epoch 4: trn_loss = 0.0735, val_loss = 0.0980, trn_score = 0.3836, val_score = 0.4451
# model_conventions (best score) saved
# lr :  [6.030737921409169e-07, 6.030737921409169e-07, 6.030737921409169e-06]
# 100%|████████████████████████████| 382/382 [02:22<00:00,  2.68it/s, loss=0.0645]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.37it/s]
# epoch 5: trn_loss = 0.0645, val_loss = 0.1029, trn_score = 0.3594, val_score = 0.4560
#
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# trn_df.shape =  (3058, 13)
# 2022-11-15 06:45:22.631135: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 06:45:22.631158: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['conventions']
# self.warmup_ratio =  0.1
# self.num_train_steps =  1911
# num_warmup_steps =  191
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 382/382 [02:24<00:00,  2.64it/s, loss=0.304]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.37it/s]
# epoch 1: trn_loss = 0.3041, val_loss = 0.1127, trn_score = 0.9390, val_score = 0.4766
# model_conventions (best score) saved
# lr :  [8.273512218982666e-06, 8.273512218982666e-06, 8.273512218982667e-05]
# 100%|████████████████████████████| 382/382 [02:21<00:00,  2.69it/s, loss=0.0833]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.44it/s]
# epoch 2: trn_loss = 0.0833, val_loss = 0.1071, trn_score = 0.4083, val_score = 0.4643
# model_conventions (best score) saved
# lr :  [5.0263864896794046e-06, 5.0263864896794046e-06, 5.0263864896794046e-05]
# 100%|████████████████████████████| 382/382 [02:20<00:00,  2.71it/s, loss=0.0749]
# 100%|███████████████████████████████████████████| 98/98 [00:21<00:00,  4.47it/s]
# epoch 3: trn_loss = 0.0749, val_loss = 0.1108, trn_score = 0.3872, val_score = 0.4721
# lr :  [2.372266700196292e-06, 2.372266700196292e-06, 2.3722667001962916e-05]
# 100%|████████████████████████████| 382/382 [02:20<00:00,  2.72it/s, loss=0.0645]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.45it/s]
# epoch 4: trn_loss = 0.0645, val_loss = 0.1067, trn_score = 0.3591, val_score = 0.4632
# model_conventions (best score) saved
# lr :  [6.276046208390873e-07, 6.276046208390873e-07, 6.276046208390873e-06]
# 100%|████████████████████████████| 382/382 [02:20<00:00,  2.71it/s, loss=0.0565]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.45it/s]
# epoch 5: trn_loss = 0.0565, val_loss = 0.1058, trn_score = 0.3361, val_score = 0.4612
# model_conventions (best score) saved
#
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.1
# args.mode =  train
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# trn_df.shape =  (3055, 13)
# 2022-11-15 06:59:24.293259: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 06:59:24.293312: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# target_cols =  ['conventions']
# self.warmup_ratio =  0.1
# self.num_train_steps =  1909
# num_warmup_steps =  190
# lr :  [0.0, 0.0, 0.0]
# 100%|█████████████████████████████| 381/381 [02:21<00:00,  2.69it/s, loss=0.272]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.39it/s]
# epoch 1: trn_loss = 0.2720, val_loss = 0.0994, trn_score = 0.8583, val_score = 0.4470
# model_conventions (best score) saved
# lr :  [8.263518223330698e-06, 8.263518223330698e-06, 8.263518223330697e-05]
# 100%|████████████████████████████| 381/381 [02:22<00:00,  2.67it/s, loss=0.0892]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.38it/s]
# epoch 2: trn_loss = 0.0892, val_loss = 0.1158, trn_score = 0.4227, val_score = 0.4831
# lr :  [5.079343745886571e-06, 5.079343745886571e-06, 5.079343745886571e-05]
# 100%|████████████████████████████| 381/381 [02:22<00:00,  2.67it/s, loss=0.0783]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.39it/s]
# epoch 3: trn_loss = 0.0783, val_loss = 0.1009, trn_score = 0.3959, val_score = 0.4501
# lr :  [2.4583022212072894e-06, 2.4583022212072894e-06, 2.458302221207289e-05]
# 100%|████████████████████████████| 381/381 [02:22<00:00,  2.68it/s, loss=0.0643]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.39it/s]
# epoch 4: trn_loss = 0.0643, val_loss = 0.1045, trn_score = 0.3587, val_score = 0.4581
# lr :  [7.003525931589828e-07, 7.003525931589828e-07, 7.003525931589827e-06]
# 100%|████████████████████████████| 381/381 [02:22<00:00,  2.68it/s, loss=0.0547]
# 100%|███████████████████████████████████████████| 98/98 [00:22<00:00,  4.39it/s]
# epoch 5: trn_loss = 0.0547, val_loss = 0.1000, trn_score = 0.3307, val_score = 0.4481

# %% [markdown]
# # OOF

# %%
INPUT_PATH = '../../00_EDA/00_v1_12/result/' #'../../input/feedback-prize-english-language-learning/'
FOLD_PATH = '../../00_EDA/00_v1_02/result/'

# %%
for CLASS in [
    'cohesion',
    'syntax','vocabulary','phraseology','grammar','conventions'
]:
    print("*"*50)
    print(CLASS)
    print("*"*50)
# if True:
#     CLASS = 'none'
    for FOLD in [0,1,2,3,4]:
        print("-"*50)
        print("FOLD = ", FOLD)
        print("-"*50)
        #WEIGHT_PATH = f'./result/{VERSION}/model_seed{SEED}_fold{FOLD}.pth'
        WEIGHT_PATH = f'./result/{VERSION}/model_{CLASS}_seed{SEED}_fold{FOLD}.pth'
        #WEIGHT_PATH = f'result/{VERSION}/model_{CLASS}_seed{SEED}_fold{FOLD}_pseudo.pth'
        # !python ../$VERSION/validation.py --model $MODEL --version $VERSION \
        --fold_path $FOLD_PATH --fold $FOLD --seed $SEED --val_batch_size $VAL_BS \
        --rnn $RNN --loss $LOSS --mt $MULTI_TASK --num_labels $NUM_LABELS --loss $LOSS --weight_path $WEIGHT_PATH \
        --window_size $WINDOW_SIZE --inner_len $INNER_LEN --edge_len $EDGE_LEN --max_length $MAX_LEN \
        --pooling $POOLING --num_pooling_layers $NUM_POOLING_LAYERS \
        --class_name $CLASS --input_path $INPUT_PATH --use_stats $USE_STATS \
        --use_separate_head $USE_SEPARATE_HEAD
# Out:
# **************************************************
# cohesion
# **************************************************
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# 2022-11-15 07:13:25.172215: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 07:13:25.172241: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3128, 13)
# val_df.shape =  (783, 13)
# target_cols =  ['cohesion']
# 100%|███████████████████████████████████████████| 98/98 [00:16<00:00,  5.92it/s]
# val_loss=0.1172, val_score=0.4867
# essay_ids.shape =  (783,)
# preds.shape =  (783, 1)
# labels.shape =  (783, 1)
# losses.shape =  (783, 1)
# embeds.shape =  (783, 768)
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# 2022-11-15 07:13:59.944640: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 07:13:59.944665: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['cohesion']
# 100%|███████████████████████████████████████████| 98/98 [00:16<00:00,  5.95it/s]
# val_loss=0.1053, val_score=0.4594
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 768)
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# 2022-11-15 07:14:33.924743: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 07:14:33.924768: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['cohesion']
# 100%|███████████████████████████████████████████| 98/98 [00:16<00:00,  5.95it/s]
# val_loss=0.1172, val_score=0.4853
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 768)
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.1
# 2022-11-15 07:15:08.011779: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 07:15:08.011801: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['cohesion']
# 100%|███████████████████████████████████████████| 98/98 [00:16<00:00,  5.97it/s]
# val_loss=0.1173, val_score=0.4850
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 768)
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.1
# 2022-11-15 07:15:41.972004: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 07:15:41.972026: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['cohesion']
# 100%|███████████████████████████████████████████| 98/98 [00:16<00:00,  5.97it/s]
# val_loss=0.1135, val_score=0.4772
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 768)
# **************************************************
# syntax
# **************************************************
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# 2022-11-15 07:16:16.180834: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 07:16:16.180852: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3128, 13)
# val_df.shape =  (783, 13)
# target_cols =  ['syntax']
# 100%|███████████████████████████████████████████| 98/98 [00:16<00:00,  5.97it/s]
# val_loss=0.0987, val_score=0.4449
# essay_ids.shape =  (783,)
# preds.shape =  (783, 1)
# labels.shape =  (783, 1)
# losses.shape =  (783, 1)
# embeds.shape =  (783, 768)
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# 2022-11-15 07:16:49.943794: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 07:16:49.943819: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['syntax']
# 100%|███████████████████████████████████████████| 98/98 [00:16<00:00,  5.97it/s]
# val_loss=0.0996, val_score=0.4476
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 768)
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# 2022-11-15 07:17:24.388226: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 07:17:24.388251: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['syntax']
# 100%|███████████████████████████████████████████| 98/98 [00:16<00:00,  5.95it/s]
# val_loss=0.0987, val_score=0.4461
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 768)
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.1
# 2022-11-15 07:17:58.223333: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 07:17:58.223358: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['syntax']
# 100%|███████████████████████████████████████████| 98/98 [00:16<00:00,  5.97it/s]
# val_loss=0.0984, val_score=0.4441
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 768)
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.1
# 2022-11-15 07:18:32.281830: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 07:18:32.281854: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['syntax']
# 100%|███████████████████████████████████████████| 98/98 [00:16<00:00,  5.96it/s]
# val_loss=0.1002, val_score=0.4489
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 768)
# **************************************************
# vocabulary
# **************************************************
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# 2022-11-15 07:19:06.698076: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 07:19:06.698105: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3128, 13)
# val_df.shape =  (783, 13)
# target_cols =  ['vocabulary']
# 100%|███████████████████████████████████████████| 98/98 [00:16<00:00,  5.96it/s]
# val_loss=0.0793, val_score=0.3988
# essay_ids.shape =  (783,)
# preds.shape =  (783, 1)
# labels.shape =  (783, 1)
# losses.shape =  (783, 1)
# embeds.shape =  (783, 768)
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# 2022-11-15 07:19:40.753173: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 07:19:40.753197: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['vocabulary']
# 100%|███████████████████████████████████████████| 98/98 [00:16<00:00,  5.98it/s]
# val_loss=0.0823, val_score=0.4069
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 768)
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# 2022-11-15 07:20:14.847881: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 07:20:14.847907: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['vocabulary']
# 100%|███████████████████████████████████████████| 98/98 [00:16<00:00,  5.97it/s]
# val_loss=0.0854, val_score=0.4137
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 768)
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.1
# 2022-11-15 07:20:48.602107: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 07:20:48.602131: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['vocabulary']
# 100%|███████████████████████████████████████████| 98/98 [00:16<00:00,  6.07it/s]
# val_loss=0.0881, val_score=0.4201
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 768)
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.1
# 2022-11-15 07:21:22.269611: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 07:21:22.269632: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['vocabulary']
# 100%|███████████████████████████████████████████| 98/98 [00:16<00:00,  6.02it/s]
# val_loss=0.0867, val_score=0.4168
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 768)
# **************************************************
# phraseology
# **************************************************
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# 2022-11-15 07:21:56.063422: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 07:21:56.063447: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3128, 13)
# val_df.shape =  (783, 13)
# target_cols =  ['phraseology']
# 100%|███████████████████████████████████████████| 98/98 [00:16<00:00,  5.98it/s]
# val_loss=0.1023, val_score=0.4534
# essay_ids.shape =  (783,)
# preds.shape =  (783, 1)
# labels.shape =  (783, 1)
# losses.shape =  (783, 1)
# embeds.shape =  (783, 768)
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# 2022-11-15 07:22:30.014603: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 07:22:30.014628: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['phraseology']
# 100%|███████████████████████████████████████████| 98/98 [00:16<00:00,  6.03it/s]
# val_loss=0.1081, val_score=0.4662
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 768)
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# 2022-11-15 07:23:03.791531: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 07:23:03.791552: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['phraseology']
# 100%|███████████████████████████████████████████| 98/98 [00:16<00:00,  5.95it/s]
# val_loss=0.0914, val_score=0.4281
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 768)
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.1
# 2022-11-15 07:23:37.659448: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 07:23:37.659497: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['phraseology']
# 100%|███████████████████████████████████████████| 98/98 [00:16<00:00,  5.98it/s]
# val_loss=0.1075, val_score=0.4649
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 768)
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.1
# 2022-11-15 07:24:12.124373: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 07:24:12.124396: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['phraseology']
# 100%|███████████████████████████████████████████| 98/98 [00:16<00:00,  5.96it/s]
# val_loss=0.1076, val_score=0.4659
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 768)
# **************************************************
# grammar
# **************************************************
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# 2022-11-15 07:24:46.190777: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 07:24:46.190801: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3128, 13)
# val_df.shape =  (783, 13)
# target_cols =  ['grammar']
# 100%|███████████████████████████████████████████| 98/98 [00:16<00:00,  5.96it/s]
# val_loss=0.1131, val_score=0.4771
# essay_ids.shape =  (783,)
# preds.shape =  (783, 1)
# labels.shape =  (783, 1)
# losses.shape =  (783, 1)
# embeds.shape =  (783, 768)
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# 2022-11-15 07:25:20.153138: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 07:25:20.153162: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['grammar']
# 100%|███████████████████████████████████████████| 98/98 [00:16<00:00,  5.98it/s]
# val_loss=0.1166, val_score=0.4854
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 768)
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# 2022-11-15 07:25:54.415889: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 07:25:54.415909: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['grammar']
# 100%|███████████████████████████████████████████| 98/98 [00:16<00:00,  5.97it/s]
# val_loss=0.1052, val_score=0.4598
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 768)
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.1
# 2022-11-15 07:26:28.761963: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 07:26:28.761987: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['grammar']
# 100%|███████████████████████████████████████████| 98/98 [00:16<00:00,  5.98it/s]
# val_loss=0.1112, val_score=0.4740
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 768)
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.1
# 2022-11-15 07:27:03.023643: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 07:27:03.023667: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['grammar']
# 100%|███████████████████████████████████████████| 98/98 [00:16<00:00,  5.95it/s]
# val_loss=0.1187, val_score=0.4907
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 768)
# **************************************************
# conventions
# **************************************************
# --------------------------------------------------
# FOLD =  0
# --------------------------------------------------
# torch 1.10.1
# 2022-11-15 07:27:37.069501: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 07:27:37.069524: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3128, 13)
# val_df.shape =  (783, 13)
# target_cols =  ['conventions']
# 100%|███████████████████████████████████████████| 98/98 [00:16<00:00,  5.96it/s]
# val_loss=0.0943, val_score=0.4346
# essay_ids.shape =  (783,)
# preds.shape =  (783, 1)
# labels.shape =  (783, 1)
# losses.shape =  (783, 1)
# embeds.shape =  (783, 768)
# --------------------------------------------------
# FOLD =  1
# --------------------------------------------------
# torch 1.10.1
# 2022-11-15 07:28:11.214891: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 07:28:11.214916: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['conventions']
# 100%|███████████████████████████████████████████| 98/98 [00:16<00:00,  5.98it/s]
# val_loss=0.0967, val_score=0.4412
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 768)
# --------------------------------------------------
# FOLD =  2
# --------------------------------------------------
# torch 1.10.1
# 2022-11-15 07:28:45.301929: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 07:28:45.301951: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['conventions']
# 100%|███████████████████████████████████████████| 98/98 [00:16<00:00,  5.95it/s]
# val_loss=0.0980, val_score=0.4451
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 768)
# --------------------------------------------------
# FOLD =  3
# --------------------------------------------------
# torch 1.10.1
# 2022-11-15 07:29:19.405256: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 07:29:19.405282: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['conventions']
# 100%|███████████████████████████████████████████| 98/98 [00:16<00:00,  5.99it/s]
# val_loss=0.1058, val_score=0.4612
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 768)
# --------------------------------------------------
# FOLD =  4
# --------------------------------------------------
# torch 1.10.1
# 2022-11-15 07:29:53.094820: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-10.2/lib64:
# 2022-11-15 07:29:53.094840: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# train_df.shape =  (3911, 13)
# load folds...
# trn_df.shape =  (3129, 13)
# val_df.shape =  (782, 13)
# target_cols =  ['conventions']
# 100%|███████████████████████████████████████████| 98/98 [00:16<00:00,  5.96it/s]
# val_loss=0.0994, val_score=0.4470
# essay_ids.shape =  (782,)
# preds.shape =  (782, 1)
# labels.shape =  (782, 1)
# losses.shape =  (782, 1)
# embeds.shape =  (782, 768)

# %%
import pandas as pd
import numpy as np

preds = []
for CLASS in [
    'cohesion',
    'syntax','vocabulary','phraseology','grammar','conventions'
]:
    print("*"*50)
    print(CLASS)
    print("*"*50)
    preds_class = []
#if True:
    for fold in [0,1,2,3,4]:
        #tmp_df = pd.read_csv(f'./result/{VERSION}/pred_fold{fold}.csv')
        tmp_df = pd.read_csv(f'./result/{VERSION}/pred_{CLASS}_fold{fold}.csv')
        #embeds = np.load(f'./result/{VERSION}/embeds_{CLASS}_fold{fold}.npz')['arr_0']
        #tmp_df[f'embed_{CLASS}'] = embeds.tolist()
        preds_class.append(tmp_df)
        #preds.append(tmp_df)
    pred_df = pd.concat(preds_class, axis=0).reset_index(drop=True)
    if len(preds)==0:
        preds.append(pred_df)
    else:
        del pred_df["text_id"]
        preds.append(pred_df)
    
all_pred_df = pd.concat(preds, axis=1)
#all_pred_df = pd.concat(preds, axis=0).reset_index(drop=True)

train_df = pd.read_csv('../../input/feedback-prize-english-language-learning/train.csv')
oof_df = train_df[['text_id']].merge(all_pred_df, on='text_id', how='left')
oof_df.to_csv(f'./result/{VERSION}/oof_df.csv', index=False)
# Out:
# **************************************************
# cohesion
# **************************************************
# **************************************************
# syntax
# **************************************************
# **************************************************
# vocabulary
# **************************************************
# **************************************************
# phraseology
# **************************************************
# **************************************************
# grammar
# **************************************************
# **************************************************
# conventions
# **************************************************

# %%
oof_df.shape, oof_df.isnull().sum()
# Out:
# ((3911, 13),
#  text_id             0
#  cohesion            0
#  loss_cohesion       0
#  syntax              0
#  loss_syntax         0
#  vocabulary          0
#  loss_vocabulary     0
#  phraseology         0
#  loss_phraseology    0
#  grammar             0
#  loss_grammar        0
#  conventions         0
#  loss_conventions    0
#  dtype: int64)

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
oof_df[cols].describe()
# Out:
#           cohesion       syntax   vocabulary  phraseology      grammar  \
# count  3911.000000  3911.000000  3911.000000  3911.000000  3911.000000
# mean      3.136315     3.049443     3.231459     3.135548     3.050357
# std       0.494236     0.494266     0.401214     0.518564     0.566784
# min       1.412885     1.442747     1.968885     0.953561     1.661238
# 25%       2.794575     2.701973     2.951680     2.765549     2.602506
# 50%       3.150483     3.046477     3.204688     3.125322     3.015567
# 75%       3.484046     3.392076     3.491862     3.507607     3.463336
# max       4.687347     4.686781     5.228743     5.007022     4.808452
#
#        conventions
# count  3911.000000
# mean      3.061266
# std       0.515510
# min       1.208409
# 25%       2.704025
# 50%       3.063537
# 75%       3.421283
# max       4.759627

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
train_df[cols].describe()
# Out:
#           cohesion       syntax   vocabulary  phraseology      grammar  \
# count  3911.000000  3911.000000  3911.000000  3911.000000  3911.000000
# mean      3.127077     3.028254     3.235745     3.116850     3.032856
# std       0.662542     0.644399     0.583148     0.655997     0.699841
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%       2.500000     2.500000     3.000000     2.500000     2.500000
# 50%       3.000000     3.000000     3.000000     3.000000     3.000000
# 75%       3.500000     3.500000     3.500000     3.500000     3.500000
# max       5.000000     5.000000     5.000000     5.000000     5.000000
#
#        conventions
# count  3911.000000
# mean      3.081053
# std       0.671450
# min       1.000000
# 25%       2.500000
# 50%       3.000000
# 75%       3.500000
# max       5.000000

# %% [markdown]
# # Error Analysis - Check Corr

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
train_df[cols].corr()
# Out:
#              cohesion    syntax  vocabulary  phraseology   grammar  \
# cohesion     1.000000  0.695459    0.666151     0.690058  0.638689
# syntax       0.695459  1.000000    0.680562     0.725467  0.709525
# vocabulary   0.666151  0.680562    1.000000     0.735261  0.654852
# phraseology  0.690058  0.725467    0.735261     1.000000  0.719746
# grammar      0.638689  0.709525    0.654852     0.719746  1.000000
# conventions  0.666151  0.700025    0.664292     0.666842  0.673301
#
#              conventions
# cohesion        0.666151
# syntax          0.700025
# vocabulary      0.664292
# phraseology     0.666842
# grammar         0.673301
# conventions     1.000000

# %%
cols = ['cohesion','syntax','vocabulary','phraseology','grammar','conventions']
oof_df[cols].corr()
# Out:
#              cohesion    syntax  vocabulary  phraseology   grammar  \
# cohesion     1.000000  0.917968    0.872285     0.878954  0.791439
# syntax       0.917968  1.000000    0.900339     0.932759  0.894080
# vocabulary   0.872285  0.900339    1.000000     0.930337  0.837628
# phraseology  0.878954  0.932759    0.930337     1.000000  0.920550
# grammar      0.791439  0.894080    0.837628     0.920550  1.000000
# conventions  0.833291  0.893757    0.846552     0.837944  0.811565
#
#              conventions
# cohesion        0.833291
# syntax          0.893757
# vocabulary      0.846552
# phraseology     0.837944
# grammar         0.811565
# conventions     1.000000
